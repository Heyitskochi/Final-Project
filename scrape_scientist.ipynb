# %%
import requests
import bs4
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import os
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

max_page = 710

jobs12 = []
companies12 = []
locations12 = []
summaries12 = []

for start in range(0, max_page, 10):
    indeed_url = 'http://www.indeed.com/jobs?q=data%20scientist&l=California&start=' + str(start)
    browser.visit(indeed_url)
    time.sleep(5)  
    html = browser.html
    soup = bs(html, "html.parser")
    print(indeed_url)  
    
    #grabbing job title
    #for div in soup.find_all(name='div', attrs={'class':'job_seen_beacon'}):
    for td in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div in td.find_all(name='div', attrs={'class':'heading4 color-text-primary singleLineTitle tapItem-gutter'}):
            for span in div.find_all(name='span'):
                if span.text.strip() != 'new':
                    jobs12.append(span.text.strip())  

    #grabbing company name
    for td2 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div2 in td2.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for span2 in div2.find_all(name='span', attrs={'class':'companyName'}):
                companies12.append(span2.text.strip())      

    #grabbing location
    for td3 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div3 in td3.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for div4 in div3.find_all(name='div'):
                locations12.append(div4.text.strip())   

    #grabbing summary text
    divs = soup.findAll('div', attrs={'class': 'job-snippet'})
    for div5 in divs:
        summaries12.append(div5.text.strip())

browser.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\SC\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=0
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=10
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=20
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=30
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=40
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=50
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=60
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=70
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=80
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=90
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=100
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=110
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=120
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=130
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=140
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=150
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=160
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=170
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=180
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=190
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=200
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=210
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=220
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=230
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=240
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=250
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=260
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=270
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=280
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=290
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=300
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=310
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=320
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=330
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=340
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=350
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=360
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=370
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=380
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=390
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=400
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=410
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=420
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=430
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=440
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=450
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=460
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=470
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=480
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=490
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=500
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=510
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=520
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=530
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=540
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=550
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=560
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=570
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=580
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=590
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=600
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=610
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=620
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=630
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=640
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=650
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=660
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=670
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=680
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=690
# http://www.indeed.com/jobs?q=data%20scientist&l=California&start=700

# %%
jobs12
# Out:
# ['Senior Data Scientist',
#  'Data Scientist / Biostatistician',
#  'Data Scientist',
#  'Data Scientist',
#  'Sr. Data Scientist',
#  'Data Scientist - ML Ops',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Annotation Specialist (part-time)',
#  'Data Scientist (Open to Remote)',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Annotation Specialist (part-time)',
#  'Data Scientist (Open to Remote)',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Analyst / Data Scientist - Alteryx',
#  'Data Scientist (Full Time) United States',
#  'Data Scientist',
#  'Data Scientist - Entry Level',
#  'Sr. Data Scientist',
#  'Data Scientist',
#  'Head of Data Science',
#  'Data Scientist - Intermediate',
#  'Data Scientist - Tiktok Ads Growth',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Data Associate',
#  'Data Scientist for GRMDS.org',
#  'Data Scientist',
#  'Data Scientist',
#  'AI/ML Scientist, Integrative Biology',
#  'Data Scientist',
#  'Administrative Assistant, Data Science & Engineering',
#  'Data Scientist - Entry Level',
#  'Senior Data Scientist',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist',
#  'Staff Data Scientist - Ads Measurement',
#  'Statistician',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist (Remote)',
#  'Data Scientist (Recent M.S./Ph.D. Graduates)',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist, Podcasts (The Ringer)',
#  'Sr. Data Scientist - ZWS',
#  'Sr. Data Analyst',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Junior Data Analyst',
#  'Cloud Machine Learning Engineer',
#  'Jr. Data Analysis Scientist',
#  'Data Assimilation Scientist',
#  'Machine Learning Engineers',
#  'Data Scientist, Machine Learning',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist, ML Evaluation - McD Tech Labs',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist, International Payments',
#  'Staff Data Scientist - Deep Learning',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist, Reliability Engineering',
#  'Lead Data Scientist, Tableau',
#  'Vitria Data Scientist',
#  'Biomedical Informatics Data Scientist',
#  'Data Scientist, Triage - McD Tech Labs',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Junior Data Science Engineer (Remote)',
#  'Chief Data Scientist',
#  'Data Science Associate',
#  'Machine Learning Engineer, Risk Data Mining',
#  'Data Scientist, Marketing',
#  'Data Scientist',
#  'R50006 Bioinformatics Data Scientist',
#  'Decision Scientist',
#  'Data Scientist',
#  'Executive Assistant, Research & Data Science',
#  'Machine Learning Data Analysis/Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist / Software Engineer (Prognostics)',
#  'Data Scientist',
#  'Staff Data Scientist, Machine Learning',
#  'Data Scientist, Insights (RippleX)',
#  'Genomic Data Scientist (Hereditary Disease)',
#  'Data Modeling Analyst',
#  'Senior Machine Learning Data Engineer',
#  'Data Scientist',
#  'Sr Clinical Data Analyst',
#  'Data Science Analyst II',
#  'Senior Data Scientist',
#  'Machine Learning Engineer',
#  'Data Scientist - Avatar',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist 2',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist, In-Market',
#  'Data Scientist',
#  'Data Science & Analytics Specialist',
#  'Staff Data Scientist, Ads Marketplace Analytics',
#  'Senior Applied Data Scientist',
#  'Data Scientist, Ads Machine Learning',
#  'Data Scientist, Triage - McD Tech Labs',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Staff Data Scientist & TLM - Search & Recommendation, Machin...',
#  'Data Scientist',
#  'Machine Learning Engineer, 1+ Years Experience - Mountain Vi...',
#  'Data Scientist',
#  'Data Scientist, Analytics (University Grad)',
#  'Health Data Scientist (Multiple Locations)',
#  'Data Scientist / Senior Data Scientist',
#  'Data Scientist',
#  'Real Estate Data Scientist - Remote',
#  'Mechanical Design Engineer, Autopilot AI (Dojo)',
#  'Data Scientist - Sensing & Shaping',
#  'Data Scientist',
#  'Junior Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist/ Engineer - R Expertise',
#  'Senior Data Scientist I',
#  'Data Science Engineer',
#  'Machine Learning Engineer, Autopilot Simulation',
#  'Data Scientist',
#  'Data Scientist / Machine Learning Engineer (NLP)',
#  'Machine Learning Engineer',
#  'Entry Level Data Scientist',
#  'Data Scientist - Sensing & Shaping',
#  'Data Science Analyst II',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist, Machine Learning Evaluation',
#  'MRM Data Science & Reporting Analyst',
#  'Sr. Data Scientist',
#  'Sr. Data Scientist',
#  'Data Scientist, System Analytics',
#  'Data Scientist',
#  'Data Science Analyst II',
#  'Senior Product Data Scientist',
#  'Data Scientist',
#  'Sr. Data Analyst',
#  'Entry Level Data Scientist',
#  'Data Scientist',
#  'Data Scientist (Remote)',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Mathematical Scientist',
#  'Data Scientist, Data Intelligence',
#  'Data Scientist (Recent M.S./Ph.D. Graduates)',
#  'Junior Data Analyst',
#  'Data Scientist',
#  'Data Scientist',
#  'Sr. Data Scientist',
#  'Entry Level Data Scientist',
#  'Sr. Staff Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Senior Applied Data Scientist',
#  'Senior Machine Learning Scientist and Developer',
#  'Senior Data Scientist - Optimization',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Staff Data Scientist, Machine Learning',
#  'Senior Data Scientist, Advanced Modeling',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Research Engineer',
#  'Machine Learning Scientist - Knowledge Graphs',
#  'Genomic Data Scientist (Hereditary Disease)',
#  'Data Scientist',
#  'Data Scientist - Lumedic',
#  'Data Scientist (Recent M.S./Ph.D. Graduates)',
#  'Sr. Staff Data Scientist',
#  'Forensic Data Scientist',
#  'Data Scientist : 21-04959',
#  'Machine Learning Engineer',
#  'Junior Data Scientist',
#  'Sr. Data Scientist, Modeling and Predictions',
#  'Data Scientist',
#  'Data Scientist / Senior Data Scientist',
#  'Senior Data Scientist',
#  'Data Science Engineer',
#  'Data Scientist',
#  'Analyst, Data Science and Analytics',
#  'Senior Data Scientist, Ads Machine Learning',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Science & Analytics Specialist',
#  'Data Scientist',
#  'Statistician I',
#  'Data Scientist',
#  'Data Scientist: Real-time Credit & Insights',
#  'Sr. Data Scientist, Supply',
#  'Statistician',
#  'Data Scientist',
#  'Senior Data Scientist/Product Analyst',
#  'Deep Learning Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist, Netskope Threat Labs',
#  'Data Scientist',
#  'Senior Data Scientist (Product)',
#  'Senior Data Scientist',
#  'Senior Data Analyst/Data Scientist',
#  'Data Scientist, System Analytics',
#  'Senior Data Scientist',
#  'Data Scientist, Capacity Engineering - Location Flexible',
#  'Senior Data Scientist/Product Analyst',
#  'Data Scientist - Lumedic',
#  'Data Scientist',
#  'Senior Data Analyst/Data Scientist',
#  'Senior Machine Learning Data Engineer',
#  'Senior Data Scientist (Remote)',
#  'AI/ML - Annotation Analyst, Arabic Language',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Quantum Machine Learning Researcher, Research Scientist, Qua...',
#  'Data Scientist, Client Services',
#  'Data Scientist',
#  'Senior Applied Data Scientist',
#  'Data Scientist, Biology',
#  'AI/ML Scientist, Integrative Biology',
#  'Machine Learning Data Analysis/Scientist',
#  'Machine Learning Research Engineer',
#  'Product Analytics Data Scientist, Matcha',
#  'Senior Data Scientist',
#  'Associate Data Scientist',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Staff Data Scientist',
#  'Data Scientist',
#  'Lead (Health) Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Quantitative Researcher',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Data Analysis/Scientist',
#  'Quantitative Researcher',
#  'Machine Learning Engineer',
#  'Staff Data Scientist, Machine Learning',
#  'Senior Data Scientist, Growth - Location Flexible',
#  'Sr. Data Scientist, Modeling and Predictions',
#  'Data Scientist',
#  'Sr. Data Analyst / Architect',
#  'Senior Data Scientist',
#  'Full Stack Data Scientist, WishX',
#  'Senior Data Analyst',
#  'Data Scientist, System Analytics',
#  'Staff Data Scientist, Education',
#  'BSA Data Science',
#  'Senior Machine Learning Scientist and Developer',
#  'Quantitative Researcher',
#  'Senior Data Analyst',
#  'Data Scientist',
#  'Data Scientist - Research and Economics, Special Projects',
#  'Sr Consultant, Data Analyst',
#  'Quantum Machine Learning Researcher, Research Scientist, Qua...',
#  'Data Scientist',
#  'Data Scientist / Data Engineer',
#  'Machine Learning Engineer',
#  'Senior Data Scientist/Product Analyst',
#  'Data Scientist',
#  'Deep Learning Data Scientist',
#  'Data Scientist, ML Evaluation - McD Tech Labs',
#  'Sr Data Analyst',
#  'Grading Assistant, MS Data Science (Temporary Employee Pool)',
#  'Senior Data Scientist',
#  'Machine Learning & NLP Data Scientist',
#  'Data Scientist (Telemedicine Analytics)',
#  'Machine Learning Engineer (Remote)',
#  'Data Scientist',
#  'Sr. Data Analyst / Architect',
#  'Senior Data Scientist',
#  'Data Scientist - NLP And AI',
#  'Senior Data Scientist',
#  'Senior Data Scientist (Remote Work / Work from home)',
#  'Data Scientist, Data & Visualization (Contract)',
#  'Data Scientist',
#  'Data Scientist',
#  'Forensics, Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist, Data & Visualization (Contract)',
#  'Internal Audit Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Bioinformatics Data Scientist',
#  'Data Scientist',
#  'Data Scientist (Telemedicine Analytics)',
#  'Data Scientist',
#  'Data Planning Program Manager, Autonomous Vehicles',
#  'Senior Product Data Analyst',
#  'Data Scientist / ML Engineer',
#  'Quantitative Researcher',
#  'Senior Data Scientist, Growth - Location Flexible',
#  'Senior Data Analyst-Marketing',
#  'Data Science Engineer',
#  'Postdoctoral Scholar - Data Science Program - School of Info...',
#  'Staff Data Scientist',
#  'Machine Learning & NLP Data Scientist',
#  'Data Scientist',
#  'SR Data Analyst',
#  'Sr. Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer, Cameos',
#  'Senior Data Scientist',
#  'Sr. Data Scientist, Supply',
#  'Senior Data Scientist',
#  'Data Scientist - Analytics',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Machine Learning Data Analysis/Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer, Cameos',
#  'Data Scientist',
#  'Senior Data Scientist, Individualized Therapies',
#  'Senior Data Scientist',
#  'Data Scientist (Marketing)',
#  'Senior Data Scientist - Bioinformatics and Integrating Omics',
#  'Data Engineer (Remote)',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist : 21-04959',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist - Machine Learning [Remote]',
#  'Research Scientist, Machine Learning',
#  'Marketing Analytics Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist and AI Engineer',
#  'Senior Data Scientist/Product Analyst',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist (Associate, Academic, and Institutional Studi...',
#  'Mass Spectrometry and Data Analysis Scientist',
#  'Data Scientist (Marketing)',
#  'Sr Data Analyst, Media Library',
#  'Senior Data Analyst',
#  'Software Engineer, Machine Learning',
#  'Data Analyst/Data Mining Specialist',
#  'Data Scientist',
#  'Senior Data Engineer - Machine Learning',
#  'Staff Data Scientist',
#  'Data Science Manager',
#  'Data Scientist',
#  'Biological Data Science Fellow',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Full Stack Data Scientist, WishX',
#  'Statistical Analyst',
#  'Senior Data Scientist',
#  'Sr. Data Scientist',
#  'Senior Data Scientist',
#  'Statistical Analyst',
#  'Principal Data Scientist',
#  'Data Science Engineer',
#  'Senior Data Analyst',
#  'Epidemiologist / Data Scientist (Environmental Surveillance)',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Senior Data Scientist, Ads Machine Learning',
#  'Data Analyst',
#  'Data Scientist-San Francisco',
#  'Analyst, Partnerships Science',
#  'Business Analyst - Part Time',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer, Voci (Remote, US)',
#  'Prin Data Science & Analytics Engineer',
#  'Python Developer / ML (Machine Learning)',
#  'Data Scientist',
#  'Data Scientist',
#  'Sr. Data Scientist - Deep Learning',
#  'Data Scientist',
#  'Principal Data Scientist',
#  'Marketing Analytics Data Scientist',
#  'Analyst, Partnerships Science',
#  'Machine Learning Data Analysis/Scientist',
#  'Data Scientist - Deep Learning',
#  'Full Stack Data Scientist, WishX',
#  'Senior Data Analyst, Market Research',
#  'Staff Applied Scientist, Computer Vision',
#  'Data Analyst',
#  'DATA SCIENTIST',
#  'Software Engineer, Risk Data Mining',
#  'Data Scientist',
#  'Sr Data Analyst, Media Library',
#  'Applied Scientist - AR',
#  'Business Analyst - Part Time',
#  'Data Scientist and AI Engineer',
#  'Principal Applied Scientist (Machine Learning) - US Remote -...',
#  'Machine Learning Engineer, Voci (Remote, US)',
#  'Principal Data Scientist',
#  'Senior Data Scientist, Education',
#  'Senior Data Scientist',
#  'Director, Data Scientist',
#  'Data Scientist',
#  'Staff Engineer - Machine Learning',
#  'Machine Learning Engineer - MLOps',
#  'Head of Research Data Science Platforms',
#  'Data Strategy Data Scientist',
#  'Data Scientist-San Francisco',
#  'Data Scientist - Supply Chain',
#  'Machine Learning Engineer - Opportunity for Working Remotely...',
#  'Data Scientist',
#  'Data Scientist : 21-04959',
#  'Machine learning engineer',
#  'Sr. Data Engineer',
#  'Lead Data Scientist - Analyst',
#  'Data Scientist/Machine Learning Engineer',
#  'Data Analyst',
#  'Biological Data Science Fellow',
#  'Staff Machine Learning Engineer',
#  'Principal, Science & Analytics-Climate Change Data Scientist',
#  'Communications Manager, Health Artificial Intelligence',
#  'Machine Learning Data Engineer',
#  'Senior Machine Learning Scientist',
#  'Senior Data Scientist, Membership Programs',
#  'Head of Analytics and Data Science, Monetization',
#  'Senior Data Analyst',
#  'Senior Data Scientist (f/m/d)',
#  'Sr. Staff Data Scientist',
#  'Machine Learning Engineer - Opportunity for Working Remotely...',
#  'Data Scientist, Computational Biology',
#  'Lead Data Scientist, Risk Data Mining',
#  'Senior Data Scientist, Membership Programs',
#  'Senior Data Scientist',
#  'Software Engineer, Machine Learning',
#  'Data Scientist',
#  'Senior Machine Learning Scientist',
#  'Senior Data Scientist (Remote)',
#  'Lead Data Scientist',
#  'Senior Data Scientist - Marketplace Optimization',
#  'Biological Data Science Fellow',
#  'Applied Scientist - AR',
#  'Artificial Intelligence Product Marketer',
#  'Data Scientist - Networking',
#  'Senior Data Scientist, Advanced Modeling',
#  'Head of Data Science',
#  'Data Scientist - Deep Learning',
#  'Data Scientist (Marketing)',
#  'Director of Data Science Product Development, Global Analyti...',
#  'Biomedical Informatician',
#  'INTERDISCIPLINARY ENGINEER/ MATHEMATICIAN/PHYSICIST/COMPUTER...',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Project Manager / Release Manager - Big Data',
#  'Senior Data Scientist, Ads Machine Learning',
#  'Deep Learning Researcher',
#  'Data Analyst/Data Mining Specialist',
#  'Data Science Manager',
#  'Sr. Data Analyst',
#  'Principal, Science & Analytics-Climate Change Data Scientist',
#  'Sr. Associate Data Analyst',
#  'Sr. Data Analyst',
#  'Marketing Sr Data Scientist',
#  'Manager, Data Science',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer, 21-04725',
#  'Sr. Data Engineer',
#  'Data Engineer',
#  'Machine Learning Engineer - MLOps',
#  'Data Scientist - Deep Learning',
#  'Director Data Science',
#  'Director, Data Science',
#  'Biological Data Science Fellow',
#  'Data Scientist',
#  'Developer Technology Engineer, AI - New College Grad',
#  'Sr Stat Programmer',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Data Science Manager - Analytics',
#  'Senior Data Scientist (Remote Work / Work from home)',
#  'Deep Learning Researcher',
#  'Project Scientist - Artificial Intelligence in Medicine (AIM...',
#  'Software Engineer - Big Data Technologies',
#  'Senior Environmental Sustainability Data Analyst',
#  'Senior Data Analyst - Product and Clinical Analytics',
#  'Lead Data Scientist - Analytics Support',
#  'Machine learning engineer',
#  'Analyst, Partnerships Science',
#  'Data Scientist, ML Evaluation - McD Tech Labs',
#  'Machine Learning Engineer, Ads Ranking',
#  'Senior Data Analyst',
#  'Machine Learning Engineer',
#  'Sr. Data Scientist',
#  'Backend Data Scientist',
#  'Senior Data Scientist (Remote)',
#  'Data Scientist - #1342 (Remote)',
#  'Sr. Staff Data Scientist',
#  'Senior Data Scientist',
#  'Statistician II',
#  'Product Manager - Data & Visualization',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist, Advanced Modeling',
#  'Senior Data Scientist (f/m/d)',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Environmental Sustainability Data Analyst',
#  'Senior Data Scientist',
#  'Analyst, Partnerships Science',
#  'Deep Learning Researcher',
#  'Data Scientist - Deep Learning',
#  'Lead Data Scientist',
#  'Data Scientist, Computational Biology',
#  'Data Science Manager - Analytics',
#  'Senior Data Scientist',
#  'Backend Data Scientist',
#  'Senior Data Scientist',
#  'Data Science Manager',
#  'Project Scientist - Artificial Intelligence in Medicine (AIM...',
#  'Senior Data Scientist (f/m/d)',
#  'Senior Data Scientist',
#  'Data Scientist / ML Engineer',
#  'Sr. Data Scientist',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Senior Data Scientist (Remote)',
#  'Marketing Analytics Data Scientist',
#  'Machine Learning Engineer - RAPs',
#  'Senior Data Scientist',
#  'Data Scientist/Machine Learning Engineer',
#  'Mechanical Design Engineer, Autopilot AI (Dojo)',
#  'Senior Data Scientist, Advanced Modeling',
#  'Associate Legal Counsel - Data/Design',
#  'Data Scientist',
#  'Sr. Data Analyst',
#  'Senior Applied Machine Learning Scientist',
#  'Data Scientist',
#  'Sr. Data Analyst',
#  'Senior Applied Machine Learning Scientist',
#  'Sr Stat Programmer',
#  'Principal Data Scientist, Content Platforms, Data & Intellig...',
#  'Artificial Intelligence, Consultant - Applied Artificial Int...',
#  'Data Scientist II (Remote)',
#  'DATA ANALYTICS DEVELOPER',
#  'Senior Lead Data Scientist',
#  'Staff Research Scientist',
#  'Biomedical Informatician',
#  'Technical Marketing Engineer-Artificial Intelligence',
#  'Machine Learning Engineer',
#  'Sr, Data Analyst',
#  'Machine Learning Engineer',
#  'Product, Markets, & User Data Scientist',
#  'Statistician Programmer (Modeling Team)',
#  'Knowledge Engineer with Portuguese - Alexa AI',
#  'Sr. Data Analyst',
#  'Data Scientist',
#  'Senior Machine Learning Data Engineer',
#  'Vice President, Data Science',
#  'Principal, Data Scientist ProServe',
#  'Machine Learning Engineer',
#  'Senior Director, Data Science',
#  'Sr. Marketing Data Analyst/Data Scientist',
#  'Senior Data Analyst',
#  'Machine Learning Engineer - Search Ads',
#  'Machine Learning Engineer',
#  'Quality Data Analyst',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Senior Machine Learning Engineer',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Technical Marketing Engineer-Artificial Intelligence',
#  'Bioimaging Data Scientist',
#  'Principal Data Scientist, Content Platforms, Data & Intellig...',
#  'Data Science Manager',
#  'Data Scientist/ Sr. Data Scientist',
#  'Data Scientist / Machine Learning Engineer (NLP)',
#  'Senior Data Scientist, Applied Machine Learning- Risk & Frau...',
#  'Senior Data Analyst',
#  'Marketing Analytics Data Scientist',
#  'Principal, Data Scientist ProServe',
#  'Data Scientist',
#  'Staff Machine Learning Engineer',
#  'Lead Data Scientist',
#  'Machine Learning Engineer, Ads Ranking',
#  'Sr. Data Scientist (Remote)',
#  'Senior Machine Learning Scientist and Developer',
#  'Machine Learning Engineer',
#  'Artificial Intelligence, Consultant - Applied Artificial Int...',
#  'Senior Software Engineer - Machine Learning',
#  'Machine Learning Engineer - Search & Recommendation',
#  'Lead Data Scientist',
#  'Senior Data Scientist (Remote)',
#  '(Director or Manager) of Data Science and Technology',
#  'Machine Learning Engineer',
#  'Data Scientist',
#  'Staff Machine Learning Engineer',
#  'Data Scientist',
#  'Data Scientist/Machine Learning Engineer',
#  'Sr. Data Scientist',
#  'Machine Learning Engineer',
#  'Senior Data Scientist- Experimentation',
#  'Lead Data Scientist',
#  'Machine Learning Engineer',
#  'Biological Data Science Fellow',
#  '[Machine Learning/AI] Learning and Control Research',
#  'Data Science Manager',
#  'Senior Data Scientist, Catalog, NLP',
#  'Director of Data Science Product Development, Global Analyti...',
#  'Researcher/Statistician',
#  'Machine Learning Scientist',
#  'Senior Data Analyst - Product and Clinical Analytics',
#  'Senior Data Scientist, Technology',
#  'Cloud Machine Learning Engineer',
#  'Data Scientist',
#  'Sr. BI Data Analyst / Developer',
#  'Director of Data Science Product Development, Global Analyti...',
#  'Data Scientist I',
#  'Sr. Data Analyst-Product',
#  'Senior Data Scientist',
#  'Backend Data Scientist',
#  'Data Science Manager - Analytics',
#  'Data Engineer',
#  'Staff Imaging and Data Scientist',
#  'Senior Data Analyst',
#  'Lead Data Scientist',
#  'Sr. Data Science',
#  'Senior Data Scientist',
#  'Lead Data Scientist, Consumer Marketing Analytics',
#  'Staff Software Engineer, Machine Learning',
#  'Biological Data Science Fellow',
#  'Senior / Staff Data Analyst',
#  'Senior Product Data Scientist',
#  'AI/ML Engineer - Clinical Imaging',
#  'Media Insights Analyst - Savage X Fenty',
#  'Principal Data Scientist, Content Platforms, Data & Intellig...',
#  'Innovation - Sr Data Scientist',
#  'Staff Imaging and Data Scientist',
#  'Senior Data Scientist',
#  'Machine Learning Engineer (Research)',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist/ Sr. Data Scientist',
#  'Artificial Intelligence/Machine Learning Scientist',
#  'Senior Director, Data Science',
#  'Senior Product Data Analyst',
#  'Data Scientist, Forecasting - Fandango',
#  'Senior Applied Machine Learning Scientist',
#  'Senior Data Scientist',
#  'Sr. Data Analyst',
#  'Senior Data Science Engineer',
#  'Machine Learning Scientist IV',
#  'Data Scientist- LGC',
#  'Machine Learning Engineer, 21-04725',
#  'Senior Data Science',
#  'Senior Data Scientist (f/m/d)',
#  'Data Scientist – Genetics Platform Analytics',
#  'Technical Marketing Engineer-Artificial Intelligence',
#  'Simplr Sr Data Scientist, Conversational AI',
#  'Staff Scientist - Machine Learning',
#  'ML Engineer',
#  'Innovation - Sr Data Scientist',
#  'Research Scientist, Machine Learning, Graph Neural Net Model...',
#  'Mid Data Scientist',
#  'Associate Legal Counsel - Data/Design',
#  'Senior Data Scientist',
#  'Machine Learning Scientist - Computer Vision',
#  'Lead Software Engineer, Risk Data Mining',
#  'Analytics Strategy Consultant',
#  'Data Scientist, Experience Innovation',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Senior Product Data Analyst',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Associate Scientist - Machine Learning',
#  'Senior Machine Learning Scientist',
#  'Senior Data Scientist - 18853',
#  'Data Scientist',
#  'Data Science Manager',
#  'SR Data Analyst',
#  'Machine Learning Engineer - Search Ads',
#  'Simplr Sr Data Scientist, Conversational AI',
#  'Staff Machine Learning Engineer',
#  'Data Engineer',
#  'Artificial Intelligence/Machine Learning Scientist',
#  'Senior Data Analyst',
#  'Senior Data Scientist',
#  'Research Scientist, Deep Learning',
#  'Machine Learning Engineer',
#  'Machine Learning Engineer (Research)',
#  'Senior Machine Learning Scientist',
#  'Senior Research Scientist, Machine Learning',
#  'Staff Scientist - Machine Learning',
#  'Research Scientist – Multimodal Machine Learning',
#  'SR Data Analyst',
#  'Data Scientist - Protein Design',
#  'ML Platform - Data Annotator',
#  'AI for RAN Wireless Data Scientist (Full-Time)',
#  'Lead Software Engineer, Risk Data Mining',
#  'Simplr Sr Data Scientist, Conversational AI',
#  'Sr. Data Science',
#  'Deals Data & Analytics Associate - Summer/Fall 2022',
#  'Data Scientist',
#  'Research Scientist, Deep Learning',
#  'Senior Data Scientist',
#  'Machine Learning Engineer',
#  'Lead Software Engineer, Risk Data Mining',
#  'Lead Marketing Analyst/Data Scientist',
#  'Jr. Data Scientist',
#  'Senior Data Scientist, Product',
#  'Data and Machine Learning Specialist',
#  'Research Scientist – Multimodal Machine Learning',
#  'Senior Machine Learning Engineer',
#  'AVP, Senior ETL Developer/Data Analyst',
#  'Senior Director, Data Science',
#  'Machine Learning Engineer',
#  'Senior Software Engineer - Machine Learning',
#  'AI/ML Engineer - Clinical Imaging',
#  'Machine Learning Engineer, (Staff/Senior)',
#  'Senior Data Scientist',
#  'Principal Data Scientist - Marketing',
#  'Data Scientist/Machine Learning/AI',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Senior Director, Data Science',
#  'Senior Data Scientist',
#  'Director, Data Science',
#  'Sr. Statistical Programmer, Early Oncology',
#  'Senior Data Engineer, Machine Learning',
#  'Data Scientist, Energy Storage',
#  'ML Platform - Data Annotator',
#  'Data Scientist',
#  'Simplr Sr Data Scientist, Conversational AI',
#  'Data Scientist',
#  'Data Scientist II',
#  'Sr, Data Analyst',
#  'Sr. Statistical Programmer, Early Oncology',
#  'Sr. Data Analyst',
#  'Senior Data Scientist',
#  'Data Science Manager - Discovery and Evaluation of New Produ...',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'Lead Data Scientist- Call of Duty Mobile',
#  'Research Scientist, Machine Learning, Graph Neural Net Model...',
#  'Data Scientist',
#  'Director, Data Science',
#  'Data Scientist, Energy Storage',
#  'Applied Artificial Intelligence (AI) Research Scientist',
#  'Senior Data Scientist, Conversational AI',
#  'Senior Data Scientist',
#  'Machine Learning Scientist - Computer Vision',
#  'Staff Software Engineer, Machine Learning',
#  'AVP, Senior ETL Developer/Data Analyst',
#  'Senior Research Scientist, Machine Learning',
#  'Applied Machine Learning Engineer',
#  'Senior Data Scientist, Intelligent Services',
#  'Senior Data Scientist (CV-IRL)',
#  'Machine Learning Engineer (Research)',
#  'Research Scientist, Machine Learning, Graph Neural Net Model...',
#  'Machine Learning Engineer, Ads Ranking',
#  'Applied Artificial Intelligence (AI) Research Scientist',
#  'Applied Machine Learning Engineer',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Staff Data Scientist - Forecasting',
#  'Senior Research Scientist, Machine Learning',
#  'Machine Learning Research Scientist (Computer Vision/Safety)',
#  'Senior Data Scientist, R&D',
#  'Sr. Data Scientist, Modeling',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist / Vision Scientist',
#  'Senior Product Data Analyst',
#  'Senior Data Analyst',
#  'AI for RAN Wireless Data Scientist (Full-Time)',
#  'Machine Learning Scientist',
#  'Machine Learning Engineer',
#  'Senior Engineer - Machine Learning',
#  'Lead Data Scientist - Healthcare',
#  'Senior Product Data Scientist',
#  'Senior Data Scientist',
#  'Forward Deployed Senior Data Scientist',
#  'Senior Data Scientist',
#  'Machine Learning Operations Engineer',
#  'Senior Data Analyst',
#  'Senior Data Scientist, Product',
#  '(Senior) Clinical Data Scientist - Biostatistician',
#  'Sr. Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst, Advanced Analytics',
#  'Director, Data Science',
#  'Staff Data Scientist',
#  'Lead Data Scientist',
#  '[Machine Learning/AI] Learning and Control Research',
#  'Sr. Data Analyst',
#  'Associate Data Scientist',
#  'Clinical Data Scientist / Statistical Programmer',
#  'AI Engineer, Professional Services, Google Cloud',
#  'Natural Language Processing Scientist (REMOTE)',
#  'Senior Data Scientist, Ad Intelligence',
#  'Data Science Manager - Discovery and Evaluation of New Produ...',
#  'Applied Machine Learning Engineer',
#  'Senior Data Scientist',
#  'Principal Data Scientist',
#  'Applied Machine Learning Engineer',
#  'Senior Machine Learning Engineer',
#  'Senior Data Analyst',
#  'Sr. Data Analyst',
#  'Knowledge Engineer with Portuguese - Alexa AI',
#  'Senior Data Scientist',
#  'Data Scientist 3',
#  'Lead Machine Learning Engineer - Opportunity for Working Rem...',
#  'Lead Data Scientist',
#  'Data Scientist (Bioinformatics)',
#  'Clinical Data Scientist / Statistical Programmer',
#  'IC Packaging Engineer, Autopilot AI (Dojo)',
#  'Machine Learning Operations Engineer',
#  'Senior Scientist, Machine Learning',
#  'Research Scientist in NLP',
#  '[Machine Learning/AI] Learning and Control Research',
#  'Principal Data Scientist',
#  'Data Science Manager - Discovery and Evaluation of New Produ...',
#  'Sr. Marketing Data Analyst',
#  'Chief of Staff (AI Research)',
#  'Data Scientist / AI / NLP / Machine Learning Engineer',
#  'Data Visualization & Research Analyst',
#  'Data and Machine Learning Specialist',
#  'Data Engineer, Machine Learning',
#  'Sr. Data Scientist, Predictive Maintenance',
#  'Machine Learning Infrastructure Engineer',
#  'Deep Learning Manager, Self-Driving',
#  'Software Engineer - Risk Data Mining',
#  'Senior NLP/Text Mining/Data Abstraction Expert - Roche Infor...',
#  'Applied Machine Learning Engineer',
#  'Senior NLP/Text Mining/Data Abstraction Expert - Roche Infor...',
#  'Applied Machine Learning Engineer',
#  'Director, Direct Data and AI Services',
#  'Senior Data Scientist',
#  '(Senior) Clinical Data Scientist - Biostatistician',
#  'Lead Data Scientist- Call of Duty Mobile',
#  'Staff/Sr. Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Analyst , BI & Data Science',
#  'Applied Scientist',
#  'Data Science & Technology - Postdoctoral Researcher',
#  'Senior Data Scientist, Ad Intelligence',
#  'Senior Data Analyst',
#  'Machine Learning Engineer',
#  '(Director or Manager) of Data Science and Technology',
#  'Senior Product Data Analyst',
#  'Machine Learning Engineer',
#  'Embedded Data Scientist',
#  'AI Platform Sales Analyst',
#  'Lead Data Scientist',
#  'Senior Machine Learning Scientist and Developer',
#  'Software Engineer II - Data & AI',
#  'Data Scientist',
#  'Patent Agent / Patent Engineer / Software AI CS Computer',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'Data Engineer (Remote)',
#  'Data Scientist/Machine Learning Engineer 6',
#  'Senior Data Scientist',
#  'Senior Programmer Writer - AI/ML',
#  'Head of Data Science & Analytics',
#  'Data Scientist II',
#  'Senior Data Scientist',
#  'Machine Learning Scientist IV',
#  'Jr. Data Engineer',
#  'Big Data and Open Source DB Support Engineer',
#  'Data Scientist - FULL TIME',
#  'Senior Programmer Writer - AI/ML',
#  '(Senior) ML Engineer - Clinical Data',
#  'Senior Data Scientist',
#  'Patent Agent / Patent Engineer / Software AI CS Computer',
#  'Senior Software Engineer - Machine Learning',
#  'Senior Data Scientist',
#  'Lead Data Scientist',
#  'Image Processing & Machine Learning Specialist',
#  'Senior Data Analyst',
#  'Senior Product Data Scientist',
#  'Senior Data Engineer - Machine Learning',
#  'Senior Data Scientist',
#  'Senior Data Scientist (US Remote)',
#  'AI/ML Engineer (Production)',
#  'Senior Data Scientist',
#  'Director, Commercial Data Science & AI',
#  'Software Engineer I, Machine Learning Platform',
#  'Data Analyst',
#  'Patent Agent / Patent Engineer / Software AI CS Computer',
#  'Sr. Data Analyst',
#  'Embedded Data Scientist',
#  'Analytics Software – Machine Learning Scientist',
#  'Computer Vision and Machine Learning Engineer',
#  'Machine Learning (ML) Engineer',
#  'Director of Product Analytics and Data Science',
#  'Senior Data Analyst (Marketing)',
#  'Senior Machine Learning Data Scientist',
#  'Data Scientist',
#  'Image Processing & Machine Learning Specialist',
#  'Senior Product Manager, Applied Data Science',
#  'Sr Staff, Data Analyst',
#  '(Senior) Clinical Data Scientist - Biostatistician',
#  'Sr. BI Data Analyst / Developer',
#  'Analytics Software – Machine Learning Scientist',
#  'Lead Machine Learning Engineer - Opportunity for Working Rem...',
#  'Director, Commercial Data Science & AI',
#  'Principal Data Scientist, Content Platforms, Data & Intellig...',
#  'Senior Data Scientist',
#  'Data Visualization & Research Analyst',
#  'Data Analyst – Business Intelligence',
#  'Machine Learning Research Engineer',
#  'Sr. Data Analyst',
#  'Data Analyst / Senior Data Analyst',
#  'Senior Data Analyst',
#  'Senior Product Data Analyst',
#  'Sr. Statistical Programmer, Early Oncology',
#  'Cloud Machine Learning Engineer',
#  'Senior BI Data Analyst - REMOTE',
#  'Sr. Deep Learning & Computer Vision Scientist',
#  'Machine Learning Engineer, Video Ranking',
#  'Senior Data Scientist / Vision Scientist',
#  'Sr Data Analyst, Media Library',
#  'Director, Commercial Data Science & AI',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Analyst, Workforce Insights',
#  'Senior AI Engineer / AI Scientist',
#  'Data Science & Technology - Postdoctoral Researcher',
#  'Senior Business Intelligence & Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Scientist',
#  'Associate Biostatistician/Data Scientist',
#  'Camera Perception - Deep Learning Optimization Engineer',
#  'Technical Program Manager, Data Engineering and Science',
#  'Data Science Manager (100% Remote)',
#  'Remote Senior Engineering Manager/ Machine Learning',
#  'AI/ML - iOS Engineer Voice Input/Dictation, Siri Client',
#  'AI/ML - Security Engineering Lead - Siri Search, Knowledge a...',
#  'Senior Engineering Manager / Machine Learning - Remote',
#  'Touch Algorithm Systems Manager',
#  'Technical Program Manager, Machine Learning',
#  'Sr. Stat Programming Analyst (JO-2108-130260)',
#  'Senior Data Scientist',
#  'Staff Scientist - Machine Learning',
#  'Sr. Machine Learning Engineer',
#  'Python Developer / ML (Machine Learning)',
#  'Associate Biostatistician/Data Scientist',
#  'Senior Digital Marketing Data Analyst',
#  'Technical Program Manager, Data Engineering and Science',
#  'Data Support Technician-Research Assistant',
#  'AI/ML, Senior Operations Process Engineer - Business Plannin...',
#  'ISE, SIML - Deep Learning Research Eng.',
#  'AI/ML - iOS Engineer Voice Input/Dictation, Siri Client',
#  'Patent Agent / Patent Engineer / Software AI CS Computer',
#  'Director Computational Biomarker Discovery CNS or Oncology 1...',
#  'Sr/Lead Software Engineer - Python, NLP, ML (REMOTE)',
#  'Software Engineer, Full Stack - Data Visualization',
#  'Senior / Principal Scientist, Proteomics & Data Science',
#  'Machine Learning Engineer',
#  'Python Developer / ML (Machine Learning)',
#  'Machine Learning Engineer Attention Mechanism',
#  'Data Science Engineer, Battery & Cell',
#  '(Sr/Staff) Engineer, AI framework Research software',
#  'Senior Forecast & Data Analyst, Finance',
#  ...]

# %%
companies12
# Out:
# ['Intuit',
#  'Blinktbi, Inc',
#  'Intel',
#  'Environmental Risk Management Inc',
#  'Experian',
#  'KPI Partners',
#  'Experian',
#  'Pluto TV',
#  'Doorstead',
#  'Micron Technology',
#  'Scripps Health',
#  'Steady Platform',
#  'Experian',
#  'ITRenew',
#  'Xerox',
#  'Steady Platform',
#  'Experian',
#  'Skan',
#  'ITRenew',
#  'Xerox',
#  'Adept Consultants',
#  'Cisco Systems',
#  "Warman O'Brien",
#  'Numerdox',
#  'omega solutions inc',
#  'Wealthfront',
#  'Optimum Technologies',
#  'Bayer',
#  'TikTok',
#  'Cognoa',
#  'Foursquare',
#  'IBM',
#  'Amazon.com Services LLC',
#  'RMDS Lab',
#  'Tinder',
#  'HG Insights',
#  'Roche',
#  "Warman O'Brien",
#  'Netflix',
#  'Lawrence Livermore National Laboratory',
#  'Netflix',
#  'Environmental Risk Management Inc',
#  'Blue River Technology',
#  'Hewlett Packard Enterprise',
#  'CareDx',
#  'Instacart',
#  'Agilent Technologies, Inc.',
#  'National Research Group',
#  'ALLDATA',
#  'Quora',
#  'Tubular Labs',
#  'Quantifind',
#  "Warman O'Brien",
#  'Amazon.com Services LLC',
#  'Spotify',
#  'Zscaler',
#  'Yellow Jacket Inc',
#  'Upgrade',
#  'project44',
#  'LendingHome',
#  'Capgemini',
#  'Bosch Group',
#  'TAE TECHNOLOGIES INC',
#  'UC San Diego',
#  'Sumner & Scott',
#  'Discord',
#  'J.D. Power',
#  "Warman O'Brien",
#  'McD Tech Labs',
#  'Mantek Solutions',
#  'Zest AI',
#  'Bytedance',
#  'Square',
#  'GE Healthcare',
#  'Driveway Finance Corporation',
#  'Ezoic',
#  'Tesla',
#  'Salesforce',
#  'Vitria Technology',
#  'Stanford Health Care',
#  "McDonald's Corporate",
#  'FriendFinder Networks',
#  "Warman O'Brien",
#  '99',
#  'Wurl, Inc',
#  'Moonshot Brands',
#  'Fisher Investments',
#  'TikTok',
#  'Airtable',
#  'UCLA',
#  'CODA Biotherapeutics',
#  'TeleSign',
#  'Zscaler',
#  'Opendoor',
#  'Automat Solutions, Inc.',
#  'California State University',
#  'Carta',
#  'Tesla',
#  "Warman O'Brien",
#  'Varo Money',
#  'Ripple',
#  'Tempus',
#  'Experian',
#  'Moveworks',
#  'Kuaishou Technology',
#  'Cedars-Sinai Medical Center',
#  'Experian',
#  'Projas Technologies',
#  'Riiid Labs',
#  'Roblox',
#  'Pocket Gems',
#  'Allianz Global Investors',
#  'Microsoft',
#  'Zigzy',
#  "Warman O'Brien",
#  'Microsoft',
#  'information technology sector',
#  'Tinder',
#  'Zipcar, Inc.',
#  'Skai',
#  'Skan',
#  'Cuker',
#  'Reddit',
#  'dunnhumby',
#  'Snapchat',
#  'McD Tech Labs',
#  'Cool Minds LLC',
#  'WarnerMedia',
#  'Faire',
#  'NumberOne AI',
#  'Snapchat',
#  "Warman O'Brien",
#  'Facebook',
#  'Evidation',
#  'C3 AI',
#  'Second Genome',
#  'Harbor Freight Tools USA, Inc.',
#  'Tesla',
#  'Deloitte',
#  'Magnite',
#  'Farmers Insurance Group',
#  'magnitude',
#  'GXO Logistics',
#  "Warman O'Brien",
#  'Cognizant Technology Solutions',
#  'Kaiser Permanente',
#  'Ancestry',
#  'Tesla',
#  'Manifest Medex',
#  'Ciitizen',
#  'Mantek Solutions',
#  'Spectra Infosystems',
#  'Deloitte',
#  'Experian',
#  'Surya Systems',
#  'Manifest Medex',
#  'Feedzai',
#  'Tiktok Pte. Ltd.',
#  'Inflammatix',
#  'Adobe',
#  'AIG',
#  'Lark Health',
#  'Oportun Inc',
#  'Stealth Mode Startup',
#  'Micron Technology',
#  'Experian',
#  'FieldLevel',
#  'Infogen Labs',
#  'Yellow Jacket Inc',
#  'Spectra Infosystems',
#  'FT Optimize',
#  'Wurl, Inc',
#  'GXO Logistics',
#  'Akili Interactive',
#  'Adobe',
#  'Pit.AI Technologies Inc.',
#  'Salesforce',
#  'Tubular Labs',
#  'Capgemini',
#  'Ritual',
#  'Feedzai',
#  'Snowflake',
#  'Spectra Infosystems',
#  'TeamViewer GmbH',
#  'Magnite',
#  'Gurucul',
#  'Aktify',
#  'dunnhumby',
#  'MariaDB Corporation Ab',
#  'AutoGrid Systems',
#  'eHealth',
#  'Infogen Labs',
#  'Zest AI',
#  'Fractal.ai',
#  'Tiktok Pte. Ltd.',
#  'TWO NIL',
#  'Varo Money',
#  'Komodo Health',
#  'Engage3',
#  'Snapdocs',
#  'Intel',
#  'Tempus',
#  'Tempus',
#  'Upgrade',
#  'Providence',
#  'Tubular Labs',
#  'TeamViewer GmbH',
#  'Snapchat',
#  'Akraya Inc.',
#  'Adobe',
#  'Farmers Insurance Group',
#  'MasterClass',
#  'Feedzai',
#  'C3 AI',
#  'Joby Aviation',
#  'Ancestry',
#  'Foursquare',
#  'Verkada',
#  'Reddit',
#  'magnitude',
#  'Teknatio',
#  'Cuker',
#  'ALLDATA',
#  'USC',
#  'Engage3',
#  'Pngme',
#  'Wish',
#  'UCLA',
#  'Pocket Gems',
#  'ClassDojo',
#  'Intel',
#  'Demandbase',
#  'Netskope',
#  'Infogen Labs',
#  'CircleCI',
#  'Blink Health',
#  'Synctera',
#  'Stealth Mode Startup',
#  'VIZIO, Inc.',
#  'Dropbox',
#  'ClassDojo',
#  'Providence',
#  'ALLDATA',
#  'Synctera',
#  'Moveworks',
#  'Levi Strauss & Co.',
#  'Apple',
#  'Exsilio',
#  'Zoom Video Communications, Inc.',
#  'Zscaler',
#  'GXO Logistics',
#  'Google',
#  'Morning Consult',
#  'Tubi',
#  'dunnhumby',
#  'Atreca',
#  'Roche',
#  'Automat Solutions, Inc.',
#  'Intel',
#  '0x',
#  'Snapdocs',
#  'Gallagher',
#  'information technology sector',
#  'Adobe',
#  'Fandom',
#  'Feedzai',
#  'Transcarent',
#  'Zigzy',
#  'DocuSign',
#  'Facebook',
#  'Crossover Health',
#  'Knowesis',
#  'Automat Solutions, Inc.',
#  'Facebook',
#  'Zoom Video Communications, Inc.',
#  'Varo Money',
#  'Dropbox',
#  'MasterClass',
#  'Mercury Insurance',
#  'QuantumBricks',
#  'Pollen',
#  'Wish',
#  'Square',
#  'Stealth Mode Startup',
#  'Chan Zuckerberg Initiative',
#  'Agama Solutions',
#  'MariaDB Corporation Ab',
#  'Facebook',
#  'Tradesy',
#  'Prealize Health',
#  'Uber',
#  'Cedars-Sinai',
#  'Google',
#  'AutoZone',
#  'DeepMap, Inc',
#  'Adobe',
#  'ClassDojo',
#  'Aspiration Partners',
#  'Intel',
#  'McD Tech Labs',
#  'Capgemini',
#  'University of the Pacific',
#  'Demandbase',
#  'Hanumayamma Innovations and Technologies',
#  'Forward',
#  'Cobalt Robotics',
#  'Akili Interactive',
#  'QuantumBricks',
#  'eHealth',
#  'Aston Carter',
#  'CEDENT',
#  'The/Studio',
#  'STAR Labs',
#  'QuinStreet',
#  'Arista Networks',
#  'Deloitte',
#  'DocuSign',
#  'Magnite',
#  'STAR Labs',
#  'Oracle',
#  'Feedzai',
#  'QuinStreet',
#  'Seer',
#  'Eugenus Inc',
#  'Forward',
#  'Centerfield',
#  'NVIDIA',
#  'SimplePractice',
#  'INFISWIFT TECHNOLOGIES',
#  'Mythical Games',
#  'Dropbox',
#  'Kaiser Permanente',
#  'OpenTable',
#  'University of California Berkeley',
#  'Fandom',
#  'Hanumayamma Innovations and Technologies',
#  'Enquero Inc',
#  'Surya Systems',
#  'Rubicon Temps',
#  'Beshton Software',
#  'Snapchat',
#  'Blink Health',
#  'Wish',
#  'SB Energy',
#  'Commure',
#  'Visa',
#  'Tinder',
#  'Automat Solutions, Inc.',
#  'NICE Actimize',
#  'Snapchat',
#  'Rhombus Power',
#  'Genentech',
#  'Projas Technologies',
#  'Mattel',
#  'Amgen',
#  'Medable',
#  'Aktify',
#  'ScaleMonk',
#  '99',
#  'Akraya Inc.',
#  'Mythical Games',
#  'Inflammatix',
#  'Blue Owl',
#  'KLA-Tencor',
#  'Byte',
#  'Kia America, Inc.',
#  'Tesla',
#  'SKT Lab',
#  'ClassDojo',
#  'Jerry',
#  'eBay Inc.',
#  'San Diego State University',
#  'Bristol Myers Squibb',
#  'Mattel',
#  'Disney Media & Entertainment Distribution',
#  'Zuora',
#  'Grammarly',
#  'Xcel Agency',
#  'Crossover Health',
#  'Samsara',
#  'SoFi',
#  'DISH',
#  'Exsilio',
#  'Parker Institute of Cancer Immunotherapy (PICI)',
#  'KelaHealth',
#  'Magnite',
#  '99',
#  'Wish',
#  'Merchant Centric',
#  'Red Bull',
#  'Apartment List',
#  'Red Bull',
#  'Merchant Centric',
#  'Capital One - US',
#  'OpenTable',
#  'Brightwheel',
#  'Heluna Health',
#  'Blue River Technology',
#  'Zoom Video Communications, Inc.',
#  'Reddit',
#  'Beshton Software',
#  'Capgemini',
#  'Facebook',
#  'Spartan Technologies',
#  'Infogen Labs',
#  'Centerfield',
#  'Infogen Labs',
#  'Medallia, Inc.',
#  'Medtronic',
#  'VENUS GEO SOLUTIONS PRIVATE LIMITED',
#  'Aspiration Partners',
#  'Manifest Medex',
#  'GE Healthcare',
#  'Ranker',
#  'Capital One - US',
#  'Byte',
#  'Facebook',
#  'Automat Solutions, Inc.',
#  'Verb Surgical',
#  'Wish',
#  'WarnerMedia',
#  'Etsy',
#  'Beshton Software',
#  'Grimmway Enterprises',
#  'TikTok',
#  'Gurucul',
#  'Disney Media & Entertainment Distribution',
#  'Amazon.com Services LLC',
#  'Spartan Technologies',
#  'SKT Lab',
#  'Splunk',
#  'Medallia, Inc.',
#  'BXGI',
#  'Chan Zuckerberg Initiative',
#  'Abnormal Security',
#  'Capitol Music Group',
#  'Kharon',
#  "McDonald's Corporate",
#  'Standard Cognition',
#  'Genentech',
#  'Jefferies & Company, Inc.',
#  'Capgemini',
#  'TaylorMade Golf Company',
#  'VMware Design',
#  'Crossover Health',
#  'Akraya Inc.',
#  'BusinesStaff',
#  'Capgemini',
#  'Sony Corporation of America',
#  'Weee! Inc',
#  'Beshton Software',
#  'Parker Institute for Cancer Immunotherapy',
#  'The RealReal',
#  'CoreLogic',
#  'Google',
#  'Toyota Research Institute',
#  'Beyond Limits',
#  'Petco',
#  'Pinterest',
#  'Zuora',
#  'atai',
#  'TeamViewer GmbH',
#  'VMware Design',
#  'Valo Health',
#  'TikTok',
#  'Petco',
#  'VIZIO, Inc.',
#  'Grammarly',
#  'Exsilio',
#  'Beyond Limits',
#  'Quora',
#  'Amply Power',
#  'Faire',
#  'Parker Institute for Cancer Immunotherapy',
#  'Amazon.com Services LLC',
#  'Intel',
#  'Plume',
#  'Komodo Health',
#  'Datatron Technologies',
#  'Verb Surgical',
#  'Mattel',
#  'Experian',
#  'Stanford University',
#  'US Naval Air Systems Command',
#  'Fitbod',
#  'Snapdocs',
#  'IBM',
#  'Reddit',
#  'Dolby',
#  'Xcel Agency',
#  'DISH',
#  'Gimbal',
#  'CoreLogic',
#  'Amgen',
#  'Cool Minds LLC',
#  'SoFi',
#  'Agilent Technologies, Inc.',
#  'Lawrence Berkeley National Laboratory',
#  'Akraya Inc.',
#  'Capgemini',
#  'NextEra Energy',
#  'Standard Cognition',
#  'Verb Surgical',
#  'Zwift',
#  'Housecall Pro',
#  'Parker Institute for Cancer Immunotherapy',
#  'Eugenus Inc',
#  'NVIDIA',
#  'Gilead Sciences',
#  'Amply Power',
#  '3T Biosciences',
#  'Blue River Technology',
#  'CLARA analytics',
#  'Spin',
#  'The/Studio',
#  'Dolby',
#  'Cedars-Sinai',
#  'IBM',
#  'Tesla',
#  'Omada Health',
#  'Woodruff Sawyer',
#  'BusinesStaff',
#  'Facebook',
#  'McD Tech Labs',
#  'Pinterest',
#  'Electronic Arts',
#  'Change Healthcare',
#  'hims & hers',
#  'EDO, Inc',
#  'Quora',
#  'Myriad Genetics Inc.',
#  'TeamViewer GmbH',
#  'Zest AI',
#  'USC',
#  'Citrine Informatics',
#  'Roche',
#  'Colsh Consultants',
#  'Komodo Health',
#  'atai',
#  'SymphonyAI',
#  'GroupM Services',
#  'Tesla',
#  'SB Energy',
#  'Facebook',
#  'Dolby',
#  'Verb Surgical',
#  'Natera',
#  'Valo Health',
#  'Spin',
#  'GXO Logistics',
#  'EDO, Inc',
#  'Spin',
#  'thredUP Inc',
#  'Cedars-Sinai',
#  'atai',
#  'Spin',
#  'INFISWIFT TECHNOLOGIES',
#  'Ericsson',
#  'UnitedHealth Group',
#  'Quora',
#  'Byte',
#  'Oura',
#  'Amino, Inc.',
#  'Weee! Inc',
#  'Tesla',
#  'Komodo Health',
#  'Adobe',
#  'Akili Interactive',
#  'Cool Minds LLC',
#  'Microsoft',
#  'Akili Interactive',
#  'Cool Minds LLC',
#  'Microsoft',
#  'Gilead Sciences',
#  'Disney Media & Entertainment Distribution',
#  'Deloitte',
#  'GoGuardian',
#  'University of California Office of the President',
#  'MyFitnessPal',
#  'WarnerMedia',
#  'Stanford University',
#  'Intel',
#  'Blue River Technology',
#  'NetStrive Consulting, LLC',
#  'Hive',
#  'Cavnue',
#  'Heluna Health',
#  'Amazon.com Services LLC',
#  'Chairish, Inc.',
#  'Grimmway Farms',
#  'Moveworks',
#  'Sonoma Biotherapeutics',
#  'Amazon Web Services, Inc.',
#  '99',
#  'Headspace',
#  'Scale Media',
#  'DISQO',
#  'Tiktok Pte. Ltd.',
#  'Cotocus',
#  'ViaSat',
#  'Amply Power',
#  'Bolt',
#  'Upstart',
#  'Embark Trucks',
#  'Crossover Health',
#  'Intel',
#  'Calico',
#  'Disney Media & Entertainment Distribution',
#  'thredUP Inc',
#  'Engine Biosciences',
#  'Ciitizen',
#  'Robinhood',
#  'Udacity',
#  'Byte',
#  'Amazon Web Services, Inc.',
#  'ScaleMonk',
#  'Affirm',
#  'GXO Logistics',
#  'Pinterest',
#  'Tile',
#  'MariaDB Corporation Ab',
#  '99',
#  'Deloitte',
#  'Discord',
#  'Faire',
#  'Seranova',
#  'Levi Strauss & Co.',
#  'Central Coast Community Energy',
#  'Lawrence Berkeley National Laboratory',
#  'AutoZone',
#  'Affirm',
#  'ScaleMonk',
#  'Weee! Inc',
#  'Taboola',
#  'CrowdAI',
#  'Robinhood',
#  'Medidata Solutions',
#  'Cotocus',
#  'Parker Institute for Cancer Immunotherapy',
#  'Honda Research Institute USA',
#  'UKG (Ultimate Kronos Group)',
#  'Wayfair',
#  'Experian',
#  'University of California - Irvine',
#  'Amplitude',
#  'Omada Health',
#  'Finra',
#  'Bosch Group',
#  'Engage3',
#  'OSI Digital',
#  'Experian',
#  'Resilience',
#  'Weee! Inc',
#  'Samsara',
#  'EDO, Inc',
#  'Spin',
#  'NextEra Energy',
#  'Alphatec Spine, Inc.',
#  'Mfour Mobile Research Inc',
#  'Farmers Insurance Group',
#  'PennyMac',
#  'Zenith',
#  'Extend',
#  'Discord',
#  'Parker Institute for Cancer Immunotherapy',
#  'Platform Science',
#  'Descript',
#  'GSK',
#  'TechStyle Fashion Group',
#  'Disney Media & Entertainment Distribution',
#  'RSM US LLP',
#  'Alphatec Spine, Inc.',
#  'Bolt',
#  'Diffbot',
#  '4Insite',
#  '4Insite',
#  'Engine Biosciences',
#  'Ford Motor Company',
#  'Headspace',
#  'SimplePractice',
#  'NBCUniversal',
#  'Microsoft',
#  'Plum Lending',
#  'Omaze',
#  'Qualys',
#  'HRL Laboratories LLC',
#  'The Topps Company',
#  'Akraya Inc.',
#  'Metromile',
#  'atai',
#  '23andMe',
#  'Intel',
#  'Asurion',
#  'SLAC National Accelerator Laboratory',
#  'Tesla',
#  'RSM US LLP',
#  'Nuro',
#  'Falconwood, Inc.',
#  'Adobe',
#  'Bolt',
#  'Spring Discovery',
#  'TikTok',
#  'Accenture',
#  'Genesys',
#  'Beyond Limits',
#  'Joby Aviation',
#  'SimplePractice',
#  'GroundTruth',
#  'Chartboost',
#  'SLAC National Accelerator Laboratory',
#  'Beyond Limits',
#  'Splunk',
#  'AE Studio',
#  'thredUP Inc',
#  'Surya Systems',
#  'Tiktok Pte. Ltd.',
#  'Asurion',
#  'Affirm',
#  'Amick Brown, LLC',
#  'Ford Motor Company',
#  'Mfour Mobile Research Inc',
#  'Lucid Motors',
#  'Bytedance',
#  'CrowdAI',
#  'Diffbot',
#  'iRhythm Technologies',
#  'Nuro',
#  'SLAC National Accelerator Laboratory',
#  'Samsung Research America',
#  'Surya Systems',
#  'Takeda Pharmaceutical',
#  'TuSimple',
#  'DOCOMO Innovations, Inc.',
#  'TikTok',
#  'Asurion',
#  'PennyMac',
#  'PRICE WATERHOUSE COOPERS',
#  'Illumina',
#  'Bytedance',
#  'Amino, Inc.',
#  'CrowdAI',
#  'TikTok',
#  'Afterpay Touch',
#  'Ipsos North America',
#  'Chime',
#  'Catalytic Data Science',
#  'Samsung Research America',
#  'FieldLevel',
#  'CIT Group',
#  'Headspace',
#  'Sisu',
#  'Discord',
#  'GSK',
#  'Instacart',
#  'Mathematica Policy Research',
#  'Wealthfront',
#  'Juniper Networks',
#  'AE Studio',
#  'Oracle',
#  'Headspace',
#  'Samsara',
#  'ShareThis, Inc',
#  'AstraZeneca',
#  'Flock Freight',
#  'LG Energy Solution Michigan, Inc.',
#  'TuSimple',
#  'First American',
#  'Asurion',
#  'Circle',
#  'Inland Empire Health Plans',
#  'NetStrive Consulting, LLC',
#  'AstraZeneca',
#  'Borrego Solar Systems, Inc.',
#  'Foursquare',
#  'Stitch Fix',
#  'DocuSign',
#  'PAX Labs',
#  'AE Studio',
#  'Activision',
#  'Nuro',
#  'First American',
#  'ShareThis, Inc',
#  'LG Energy Solution Michigan, Inc.',
#  'Accenture',
#  'Carvana',
#  'NutaNXT Technologies',
#  'Spring Discovery',
#  'Discord',
#  'CIT Group',
#  'Nuro',
#  'Bytedance',
#  'Adobe',
#  'Store No. 8',
#  'Diffbot',
#  'Nuro',
#  'Pinterest',
#  'Accenture',
#  'Bytedance',
#  'Niagara Bottling',
#  'Clean Power Research',
#  'Geli',
#  'Nuro',
#  'Toyota Research Institute',
#  'Pendulum.co',
#  'Yamaha',
#  'Lucid Motors',
#  'Embark Trucks',
#  'Alcon',
#  'Academia.edu',
#  'Tradesy',
#  'DOCOMO Innovations, Inc.',
#  'Enevate Corporation',
#  'kover',
#  'Amex',
#  'Kaiser Permanente',
#  'The Clorox Company',
#  'ConcertAI',
#  'Noodle.ai',
#  'The Climate Corporation',
#  'Motorola Solutions',
#  'Tradesy',
#  'Chime',
#  'insitro',
#  'Gimbal',
#  'Udacity',
#  'American Advisors Group',
#  'ShareThis, Inc',
#  'Chegg',
#  'Logic20/20',
#  'Honda Research Institute USA',
#  'Omaze',
#  'Everest Consultants, Inc.',
#  'Denali Therapeutics',
#  'Google',
#  'gumgum',
#  'Sensor Tower',
#  'Stitch Fix',
#  'Bytedance',
#  'Foursquare',
#  'Anomali',
#  'Bytedance',
#  'Upstart',
#  'Udacity',
#  'Chairish, Inc.',
#  'Amazon.com Services LLC',
#  'Coda',
#  'Amyris, Inc.',
#  'VMware',
#  'PAX Labs',
#  'Exagen Inc.',
#  'Denali Therapeutics',
#  'Tesla',
#  'Motorola Solutions',
#  'Niantic',
#  'Bytedance',
#  'Honda Research Institute USA',
#  'Johnson & Johnson Family of Companies',
#  'Stitch Fix',
#  'Scale Media',
#  'Generally Intelligent',
#  'Mynurse.ai',
#  'Northcentral University',
#  'Catalytic Data Science',
#  'Motional',
#  'Lucid Motors',
#  'XPeng Motors',
#  'Rivian Automotive',
#  'Bytedance',
#  'Roche',
#  'Cerebras Systems',
#  'Roche',
#  'Cerebras Systems',
#  'The Patrick J. McGovern Foundation',
#  'Chartboost',
#  'insitro',
#  'Activision',
#  'ShareThis, Inc',
#  'The Climate Corporation',
#  'Twilio',
#  'Twitch',
#  'Lawrence Berkeley National Laboratory',
#  'Sensor Tower',
#  'First Republic Bank',
#  'Cotocus',
#  'Central Coast Community Energy',
#  'SimplePractice',
#  'Sisu',
#  'TRM Labs Inc.',
#  'Deloitte',
#  'PAX Labs',
#  'MariaDB Corporation Ab',
#  'Electronic Arts',
#  'Circle',
#  'IPRecruiter Group',
#  'DocuSign',
#  'Medable',
#  'Teledyne Controls',
#  'GoodRx',
#  'Amazon Dev Center U.S., Inc.',
#  'NewsBreak',
#  'Levi Strauss & Co.',
#  'Verdigris Technologies',
#  'HRL Laboratories LLC',
#  'Toyota Research Institute',
#  'IBM',
#  'Chabez Tech',
#  'Amazon Dev Center U.S., Inc.',
#  'insitro',
#  'Rockstar Games',
#  'IPRecruiter Group',
#  'Discord',
#  'GoodRx',
#  'PAX Labs',
#  'ViQi',
#  'TitanX',
#  'The Clorox Company',
#  'Samsara',
#  'Coda',
#  'primer.ai',
#  'GSK',
#  'NutaNXT Technologies',
#  'AstraZeneca',
#  'Sony Interactive Entertainment PlayStation',
#  'Overair',
#  'IPRecruiter Group',
#  'Borrego Solar Systems, Inc.',
#  'TRM Labs Inc.',
#  'FICO',
#  'Plato Systems',
#  'Streamlyne',
#  'Workato',
#  'Turo',
#  'Oura',
#  'Kernel',
#  'ViQi',
#  'Ciitizen',
#  'realtor.com',
#  'insitro',
#  'OSI Digital',
#  'FICO',
#  'VMware',
#  'AstraZeneca',
#  'Disney Media & Entertainment Distribution',
#  'Onto Innovation',
#  'Northcentral University',
#  'OpenX',
#  'Embark Trucks',
#  'Gimbal',
#  'Allakos',
#  'GEP Administrative Services, LLC',
#  'Academia.edu',
#  'AstraZeneca',
#  'Bosch Group',
#  'Medable',
#  'Leica Biosystems',
#  'Reddit',
#  'Alcon',
#  'Disney Media & Entertainment Distribution',
#  'AstraZeneca',
#  'GoodRx',
#  'Verdigris Technologies',
#  'Steady Platform',
#  'Mythic-AI',
#  'Lawrence Berkeley National Laboratory',
#  'Affirm',
#  'Kareo',
#  "Moody's Corporation",
#  'Actalent',
#  'Lucid Motors',
#  'Lucid Motors',
#  'National General Insurance',
#  'RecruiHcare',
#  'Apple',
#  'Apple',
#  'Medicalink Recruiters',
#  'Apple',
#  'TuSimple, Inc.',
#  'Ultimate Staffing Services',
#  'Step',
#  'SLAC National Accelerator Laboratory',
#  'Velodyne',
#  'VENUS GEO SOLUTIONS PRIVATE LIMITED',
#  'Actalent',
#  'Juvo Plus, Inc.',
#  'Lucid Motors',
#  'Opeeka, Inc.',
#  'Apple',
#  'Apple',
#  'Apple',
#  'IPRecruiter Group',
#  'JGB BioPharma Consulting Inc.',
#  'CyberCoders',
#  'TuSimple, Inc.',
#  'Frontier Medicines',
#  'Stealth Mode Startup',
#  'VENUS GEO SOLUTIONS PRIVATE LIMITED',
#  'Manifold Valley',
#  'Lucid Motors',
#  'Black Sesame Technologies Inc',
#  'BioMed Realty',
#  ...]

# %%
locations12
# Out:
# ['Mountain View, CA 94041+1 location',
#  'California•Remote',
#  'Folsom, CA 95630+1 location',
#  'Sunnyvale, CA+1 location•Temporarily Remote',
#  'Costa Mesa, CA 92626+1 location',
#  'Newark, CA 94560•Temporarily Remote',
#  'Costa Mesa, CA 92626+2 locations',
#  'Los Angeles, CA 90069',
#  'San Francisco, CA•Remote',
#  'San Jose, CA 95131 (North San Jose area)+1 location',
#  'San Diego, CA 92121 (Sorrento Valley area)',
#  'Playa Vista, CA•Remote',
#  'San Diego, CA 92130 (Carmel Valley area)+1 location•Remote',
#  'Newark, CA 94560•Temporarily Remote',
#  'Palo Alto, CA+2 locations',
#  'Playa Vista, CA•Remote',
#  'San Diego, CA 92130 (Carmel Valley area)+1 location•Remote',
#  'San Jose, CA•Remote',
#  'Newark, CA 94560•Temporarily Remote',
#  'Palo Alto, CA+2 locations',
#  'Irvine, CA 92602•Temporarily Remote',
#  'San Jose, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Sacramento, CA+1 location•Remote',
#  'Santa Ana, CA',
#  'Palo Alto, CA 94301 (University South area)•Remote',
#  'Mountain View, CA 94043',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'Mountain View, CA+21 locations',
#  'Palo Alto, CA 94306 (College Terrace area)•Remote',
#  'Los Angeles, CA+1 location',
#  'San Jose, CA 95101 (North Valley area)',
#  'Santa Barbara, CA+25 locations',
#  'Pasadena, CA 91101 (South area)•Remote',
#  'Los Angeles, CA+1 location',
#  'California•Remote',
#  'South San Francisco, CA 94080+1 location',
#  'San Francisco, CA•Temporarily Remote',
#  'Los Gatos, CA+4 locations',
#  'Livermore, CA 94550+2 locations',
#  'Los Gatos, CA',
#  'San Diego, CA 92121•Temporarily Remote',
#  'Sunnyvale, CA+2 locations•Remote',
#  'San Jose, CA 95002 (North San Jose area)+1 location',
#  'South San Francisco, CA+1 location',
#  'California+3 locations•Remote',
#  'Carpinteria, CA 93013',
#  'California+1 location•Remote',
#  'Elk Grove, CA 95757',
#  'California+1 location•Remote',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'Palo Alto, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Sunnyvale, CA+22 locations',
#  'Los Angeles, CA•Remote',
#  'San Jose, CA 95134 (North San Jose area)+2 locations',
#  'Menlo Park, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94108 (Downtown area)•Remote',
#  'Burbank, CA+1 location',
#  'Sunnyvale, CA 94085 (East Murphy area)',
#  'Foothill Ranch, CA+1 location',
#  'San Diego, CA+1 location',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA+2 locations',
#  'California•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'Mountain View, CA 94040',
#  'California•Remote',
#  'Burbank, CA',
#  'Mountain View, CA+4 locations',
#  'San Francisco, CA+6 locations',
#  'San Ramon, CA 94583',
#  'California•Remote',
#  'Carlsbad, CA',
#  'Palo Alto, CA',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Menlo Park, CA 94025 (Lorelei Manor area)•Remote',
#  'Palo Alto, CA 94305',
#  'Mountain View, CA+1 location',
#  'San Jose, CA 95128 (Willow Glen area)•Temporarily Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'Mountain View, CA',
#  'California+3 locations•Remote',
#  'San Francisco, CA•Remote',
#  'San Mateo, CA 94404 (Mariners Island area)',
#  'Mountain View, CA+23 locations',
#  'San Francisco, CA+2 locations',
#  'Los Angeles, CA',
#  'South San Francisco, CA 94080',
#  'California•Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Francisco Bay Area, CA+2 locations•Remote',
#  'Fremont, CA 94538 (Baylands area)',
#  'San Diego, CA',
#  'San Francisco, CA+2 locations',
#  'Palo Alto, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'San Francisco, CA 94105 (Yerba Buena area)',
#  'San Francisco, CA 94108 (Downtown area)+1 location',
#  'Costa Mesa, CA 92626+1 location',
#  'Mountain View, CA+1 location',
#  'Palo Alto, CA 94303+2 locations•Temporarily Remote',
#  'Los Angeles, CA 90048+1 location',
#  'Costa Mesa, CA 92626+3 locations',
#  'San Jose, CA 95126 (Downtown area)•Temporarily Remote',
#  'San Ramon, CA 94583•Remote',
#  'San Mateo, CA+4 locations',
#  'San Francisco, CA',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'Sunnyvale, CA 94085 (West Murphy area)',
#  'Tustin, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Mountain View, CA 94043+1 location',
#  'San Francisco, CA',
#  'San Francisco, CA+1 location',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'San Jose, CA•Remote',
#  'Carlsbad, CA 92008',
#  'California•Remote',
#  'West Sacramento, CA',
#  'Mountain View, CA 94041 (Old Mountain View area)+11 locations',
#  'Mountain View, CA 94040+1 location',
#  'San Francisco, CA 94103 (South of Market area)•Temporarily Remote',
#  'Burbank, CA 91505+2 locations',
#  'California+2 locations•Remote',
#  'Tustin, CA 92780•Remote',
#  'Mountain View, CA 94041 (Old Mountain View area)+8 locations',
#  'San Francisco, CA•Temporarily Remote',
#  'Menlo Park, CA 94025+83 locations',
#  'California•Remote',
#  'Redwood City, CA',
#  'Brisbane, CA 94005',
#  'Calabasas, CA 91302•Remote',
#  'Palo Alto, CA',
#  'Los Angeles, CA 90013 (Downtown area)+38 locations',
#  'Los Angeles, CA',
#  'Woodland Hills, CA 91367',
#  'San Francisco, CA',
#  'Bloomington, CA 92316',
#  'San Francisco, CA•Temporarily Remote',
#  'Campbell, CA',
#  'Burbank, CA 91504+1 location',
#  'San Francisco, CA 94107 (South Beach area)+1 location',
#  'Palo Alto, CA+2 locations',
#  'Emeryville, CA•Remote',
#  'Palo Alto, CA 94301 (Professorville area)+1 location•Remote',
#  'California•Remote',
#  'San Francisco, CA (Financial District area)',
#  'Los Angeles, CA 90013 (Downtown area)+38 locations',
#  'Costa Mesa, CA 92626+3 locations',
#  'San Francisco, CA•Temporarily Remote',
#  'Emeryville, CA•Remote',
#  'San Mateo, CA',
#  'Los Angeles, CA•Temporarily Remote',
#  'Burlingame, CA',
#  'San Francisco, CA',
#  'Woodland Hills, CA',
#  'California•Remote',
#  'San Carlos, CA 94070+1 location•Remote',
#  'Newark, CA',
#  'Folsom, CA 95630+1 location',
#  'Costa Mesa, CA 92626+3 locations',
#  'California•Remote',
#  'Valencia, CA 91355',
#  'Menlo Park, CA•Temporarily Remote',
#  'San Francisco, CA (Financial District area)',
#  'Half Moon Bay, CA',
#  'California+3 locations•Remote',
#  'Bloomington, CA 92316',
#  'Larkspur, CA',
#  'San Jose, CA+5 locations',
#  'San Jose, CA 95131 (North Valley area)',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'Burbank, CA+1 location',
#  'Culver City, CA•Remote',
#  'San Mateo, CA',
#  'San Mateo, CA 94401 (Central Business District area)+1 location',
#  'San Francisco, CA (Financial District area)',
#  'San Jose, CA',
#  'Los Angeles, CA',
#  'El Segundo, CA 90245',
#  'Menlo Park, CA 94025•Remote',
#  'West Sacramento, CA',
#  'Redwood City, CA•Remote',
#  'Redwood City, CA 94065 (Dolphin area)',
#  'Santa Clara, CA+1 location',
#  'Valencia, CA 91355',
#  'Burbank, CA',
#  'California•Remote',
#  'Los Angeles, CA•Temporarily Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'California+1 location•Remote',
#  'Davis, CA',
#  'San Francisco, CA 94102 (Downtown area)',
#  'Santa Clara, CA 95052+1 location',
#  'Redwood City, CA+4 locations',
#  'San Francisco, CA 94108 (Downtown area)+1 location',
#  'San Francisco, CA',
#  'Torrance, CA 90509+1 location•Remote',
#  'Mountain View, CA 94041 (Old Mountain View area)',
#  'San Jose, CA',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Bruno, CA 94066+1 location',
#  'San Jose, CA+5 locations',
#  'Woodland Hills, CA 91367',
#  'San Francisco, CA+2 locations',
#  'San Mateo, CA',
#  'Redwood City, CA',
#  'Santa Cruz, CA 95060',
#  'San Francisco, CA 94107 (South Beach area)+1 location',
#  'Los Angeles, CA+1 location',
#  'San Mateo, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Menlo Park, CA•Remote',
#  'Carlsbad, CA 92008',
#  'Elk Grove, CA 95757',
#  'Los Angeles, CA',
#  'Davis, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Los Angeles, CA+1 location',
#  'San Francisco, CA',
#  'California•Remote',
#  'Santa Clara, CA 95052+2 locations',
#  'California•Remote',
#  'California+1 location•Remote',
#  'Valencia, CA 91355',
#  'San Francisco, CA•Remote',
#  'California+1 location•Remote',
#  'California•Remote',
#  'Newark, CA',
#  'San Francisco, CA 94108 (Financial District area)',
#  'California+1 location•Remote',
#  'California•Remote',
#  'California+1 location•Remote',
#  'Elk Grove, CA 95757',
#  'California•Remote',
#  'Mountain View, CA+1 location',
#  'San Francisco, CA (North Waterfront area)•Remote',
#  'San Diego, CA',
#  'Irvine, CA 92614',
#  'San Francisco Bay Area, CA+1 location•Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'Bloomington, CA 92316',
#  'Los Angeles, CA (Venice area)',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'West Sacramento, CA',
#  'San Carlos, CA 94070',
#  'South San Francisco, CA 94080+1 location',
#  'Fremont, CA 94538 (Baylands area)',
#  'Santa Clara, CA 95052+1 location',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94102 (Downtown area)',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'San Jose, CA+5 locations',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Mateo, CA',
#  'California•Remote',
#  'Tustin, CA',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Menlo Park, CA 94025+2 locations',
#  'San Clemente, CA',
#  'Coronado, CA',
#  'Fremont, CA 94538 (Baylands area)',
#  'Menlo Park, CA 94025+2 locations',
#  'San Francisco Bay Area, CA+1 location•Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Francisco, CA+2 locations',
#  'Brea, CA',
#  'Milpitas, CA•Temporarily Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA+1 location',
#  'Newark, CA',
#  'California+1 location•Remote',
#  'San Francisco, CA',
#  'Redwood City, CA•Remote',
#  'Menlo Park, CA 94025+2 locations',
#  'California•Remote',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'San Francisco, CA 94103 (South of Market area)+6 locations',
#  'Beverly Hills, CA+1 location•Remote',
#  'Los Angeles, CA (Venice area)',
#  'Elk Grove, CA 95757',
#  'Palo Alto, CA 94303',
#  'San Jose, CA+5 locations',
#  'California•Remote',
#  'Los Angeles, CA•Remote',
#  'Santa Clara, CA 95052+2 locations',
#  'Mountain View, CA 94040',
#  'Universal City, CA+2 locations',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'California•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'San Francisco, CA+1 location',
#  'San Mateo, CA•Remote',
#  'Larkspur, CA',
#  'Milpitas, CA•Temporarily Remote',
#  'Santa Clara, CA',
#  'Los Angeles, CA 90001',
#  'Corona, CA',
#  'California•Remote',
#  'Los Gatos, CA',
#  'Foster City, CA 94404•Temporarily Remote',
#  'Santa Clara, CA 95054',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Los Angeles, CA',
#  'Los Gatos, CA',
#  'Redwood City, CA 94065 (Marine area)',
#  'San Mateo, CA',
#  'Foster City, CA 94404•Temporarily Remote',
#  'Redwood City, CA',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Francisco, CA+1 location',
#  'Los Angeles, CA',
#  'California•Remote',
#  'California+1 location•Remote',
#  'Milpitas, CA•Remote',
#  'California•Remote',
#  'California•Remote',
#  'Oakland, CA+8 locations•Remote',
#  'Los Angeles, CA+1 location',
#  'Berkeley, CA 94720',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Francisco, CA•Temporarily Remote',
#  'Milpitas, CA 95035•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'San Francisco Bay Area, CA',
#  'Los Angeles, CA 90291 (Venice area)+8 locations',
#  'California+1 location•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Redwood City, CA•Remote',
#  'San Francisco, CA',
#  'Foster City, CA+2 locations',
#  'San Francisco, CA+1 location',
#  'Fremont, CA 94538 (Baylands area)',
#  'Mountain View, CA',
#  'Los Angeles, CA 90291 (Venice area)+8 locations',
#  'Mountain View, CA',
#  'South San Francisco, CA 94080+1 location',
#  'San Jose, CA 95126 (Downtown area)•Temporarily Remote',
#  'El Segundo, CA 90245',
#  'South San Francisco, CA+1 location',
#  'Palo Alto, CA•Remote',
#  'Menlo Park, CA 94025•Remote',
#  'Palo Alto, CA',
#  'Mountain View, CA',
#  'San Bruno, CA 94066+1 location',
#  'California',
#  'Burlingame, CA',
#  'San Francisco, CA+4 locations•Remote',
#  'Milpitas, CA 95035',
#  'Santa Monica, CA 90404',
#  'Irvine, CA 92606',
#  'Fremont, CA+2 locations',
#  'Santa Clara, CA',
#  'California•Remote',
#  'San Francisco Bay Area, CA',
#  'San Jose, CA+2 locations',
#  'San Diego, CA 92182 (College West area)',
#  'Redwood City, CA',
#  'El Segundo, CA 90245',
#  'Burbank, CA',
#  'California•Remote',
#  'California+4 locations•Remote',
#  'San Francisco, CA 94114 (Eureka Valley - Dolores Heights - Castro area)',
#  'San Clemente, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94129 (Presidio area)',
#  'Foster City, CA 94404',
#  'Irvine, CA 92614',
#  'San Francisco, CA 94129 (Presidio area)•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Mountain View, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Westlake Village, CA 91361•Remote',
#  'Santa Monica, CA',
#  'California•Remote',
#  'Santa Monica, CA',
#  'Westlake Village, CA 91361•Remote',
#  'San Francisco, CA 94108 (Downtown area)',
#  'Los Angeles, CA+1 location',
#  'San Francisco, CA•Remote',
#  'Richmond, CA+1 location',
#  'Sunnyvale, CA',
#  'San Francisco Bay Area, CA+1 location•Remote',
#  'California•Remote',
#  'San Francisco Bay Area, CA',
#  'South San Francisco, CA+1 location',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Palo Alto, CA',
#  'Valencia, CA 91355',
#  'Los Angeles, CA',
#  'Valencia, CA 91355',
#  'California•Remote',
#  'Northridge, CA 91325+4 locations',
#  'Santa Clara, CA•Remote',
#  'Los Angeles, CA•Remote',
#  'Emeryville, CA•Remote',
#  'San Ramon, CA 94583',
#  'Los Angeles, CA 90048',
#  'San Francisco, CA 94108 (Downtown area)',
#  'Santa Monica, CA 90404',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Fremont, CA 94538 (Baylands area)',
#  'Mountain View, CA 94043',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Burbank, CA 91505',
#  'San Francisco, CA 94111 (Financial District area)•Remote',
#  'San Francisco Bay Area, CA',
#  'Bakersfield, CA 93307',
#  'Mountain View, CA+1 location',
#  'El Segundo, CA 90245',
#  'Burbank, CA',
#  'East Palo Alto, CA',
#  'Palo Alto, CA',
#  'Santa Clara, CA',
#  'San Jose, CA 95131 (North Valley area)+3 locations•Remote',
#  'California•Remote',
#  'Palo Alto, CA•Remote',
#  'California•Remote',
#  'California•Remote',
#  'Hollywood, CA 90028',
#  'Los Angeles, CA',
#  'Mountain View, CA+1 location',
#  'San Francisco, CA+2 locations•Remote',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA 94111 (Financial District area)',
#  'South San Francisco, CA+1 location',
#  'Carlsbad, CA 92008 (North Beach area)',
#  'Los Angeles, CA•Remote',
#  'San Clemente, CA',
#  'San Bruno, CA 94066+1 location',
#  'Los Angeles, CA',
#  'San Jose, CA+1 location',
#  'San Jose, CA',
#  'Fremont, CA',
#  'San Francisco Bay Area, CA',
#  'San Francisco, CA 94129•Temporarily Remote',
#  'California•Remote',
#  'Oakland, CA+1 location',
#  'San Francisco, CA',
#  'Los Altos, CA 94022+2 locations•Remote',
#  'Glendale, CA 91203+1 location•Temporarily Remote',
#  'San Diego, CA 92127 (Rancho Bernardo area)+1 location',
#  'San Francisco, CA 94103 (South of Market area)+1 location',
#  'California•Remote',
#  'California•Remote',
#  'San Jose, CA',
#  'Los Angeles, CA•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA+1 location',
#  'San Diego, CA 92127 (Rancho Bernardo area)+1 location',
#  'San Francisco, CA 94108 (Financial District area)',
#  'California+4 locations•Remote',
#  'Irvine, CA 92614',
#  'Glendale, CA 91203+1 location•Temporarily Remote',
#  'California•Remote',
#  'San Jose, CA',
#  'San Francisco, CA+1 location',
#  'San Francisco, CA 94129•Temporarily Remote',
#  'East Palo Alto, CA',
#  'Santa Clara, CA 95052',
#  'California•Remote',
#  'California+1 location•Remote',
#  'California•Remote',
#  'Mountain View, CA 94043',
#  'El Segundo, CA 90245',
#  'Costa Mesa, CA 92626•Remote',
#  'Stanford, CA',
#  'China Lake, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94102 (Downtown area)',
#  'San Jose, CA 95101 (North Valley area)',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA 94114 (Eureka Valley - Dolores Heights - Castro area)',
#  'Foster City, CA 94404',
#  'Los Angeles, CA',
#  'Oakland, CA+1 location',
#  'Thousand Oaks, CA',
#  'Milpitas, CA 95035•Temporarily Remote',
#  'San Francisco, CA 94129 (Presidio area)',
#  'Santa Clara, CA 95051',
#  'San Francisco Bay Area, CA',
#  'Costa Mesa, CA 92626',
#  'San Jose, CA+1 location',
#  'San Francisco, CA 94108 (Financial District area)',
#  'San Francisco, CA+2 locations•Remote',
#  'Mountain View, CA 94043',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA 94129•Temporarily Remote',
#  'San Jose, CA 95134 (North San Jose area)',
#  'Santa Clara, CA+2 locations',
#  'Foster City, CA+1 location',
#  'San Jose, CA',
#  'South San Francisco, CA 94080',
#  'Sunnyvale, CA',
#  'Santa Clara, CA•Remote',
#  'California+1 location•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Jose, CA 95101 (North Valley area)+1 location',
#  'Fremont, CA+1 location',
#  'California•Remote',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA',
#  'Menlo Park, CA 94025+1 location',
#  'Mountain View, CA 94040',
#  'San Francisco, CA 94103 (South of Market area)+4 locations',
#  'Sacramento, CA•Remote',
#  'California+4 locations',
#  'California•Remote',
#  'Los Angeles, CA',
#  'California•Remote',
#  'South San Francisco, CA 94080•Remote',
#  'San Jose, CA',
#  'Burbank, CA',
#  'Los Angeles, CA',
#  'Furnace Creek, CA+2 locations•Remote',
#  'South San Francisco, CA 94080',
#  'Santa Clara, CA',
#  'California+1 location•Remote',
#  'California•Remote',
#  'Palo Alto, CA',
#  'San Francisco, CA 94107 (South Of Market area)+3 locations',
#  'Fremont, CA+1 location',
#  'Redwood City, CA•Remote',
#  'Menlo Park, CA 94025+1 location',
#  'San Francisco, CA',
#  'Mountain View, CA 94043',
#  'San Carlos, CA 94070',
#  'San Francisco, CA',
#  'California+1 location•Remote',
#  'Bloomington, CA 92316',
#  'Los Angeles, CA',
#  'California+1 location•Remote',
#  'Oakland, CA',
#  'Los Angeles, CA',
#  'California•Remote',
#  'California+1 location•Remote',
#  'Milpitas, CA•Remote',
#  'Santa Clara, CA 95054',
#  'Santa Ana, CA 92702+1 location',
#  'California•Remote',
#  'Santa Monica, CA 90404',
#  'San Francisco, CA',
#  'California•Remote',
#  'Fremont, CA',
#  'Palo Alto, CA',
#  'California+1 location•Remote',
#  'San Francisco, CA',
#  'Larkspur, CA',
#  'Milpitas, CA 95035•Temporarily Remote',
#  'Mountain View, CA 94043',
#  'Larkspur, CA',
#  'Milpitas, CA 95035•Temporarily Remote',
#  'Mountain View, CA 94043',
#  'Foster City, CA+1 location',
#  'Burbank, CA',
#  'Costa Mesa, CA 92626+3 locations',
#  'El Segundo, CA•Remote',
#  'Oakland, CA 94607 (Downtown area)',
#  'California•Remote',
#  'Culver City, CA',
#  'Stanford, CA',
#  'Santa Clara, CA 95052',
#  'Sunnyvale, CA+2 locations•Remote',
#  'San Mateo, CA',
#  'San Francisco, CA',
#  'Palo Alto, CA',
#  'Richmond, CA',
#  'Santa Barbara, CA',
#  'San Francisco, CA 94104 (Financial District area)•Remote',
#  'Bakersfield, CA',
#  'Mountain View, CA+1 location',
#  'South San Francisco, CA 94080•Remote',
#  'Irvine, CA+17 locations',
#  'Mountain View, CA+3 locations',
#  'Santa Monica, CA•Remote',
#  'Los Angeles, CA 90048 (Mid City West area)',
#  'Glendale, CA',
#  'Mountain View, CA•Temporarily Remote',
#  'Sacramento, CA 95822 (Airport area)+5 locations',
#  'Carlsbad, CA',
#  'San Jose, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Francisco, CA+1 location',
#  'San Clemente, CA',
#  'Santa Clara, CA 95052',
#  'South San Francisco, CA 94080',
#  'Burbank, CA',
#  'Oakland, CA',
#  'San Francisco Bay Area, CA',
#  'Palo Alto, CA 94301 (Professorville area)+1 location•Remote',
#  'Menlo Park, CA+5 locations',
#  'California•Remote',
#  'Santa Monica, CA 90404',
#  'Irvine, CA+17 locations',
#  'Palo Alto, CA',
#  'California•Remote',
#  'Perris, CA 92571+1 location',
#  'San Francisco, CA 94103 (South of Market area)+4 locations',
#  'San Mateo, CA•Remote',
#  'Redwood City, CA•Remote',
#  'Mountain View, CA+3 locations',
#  'Costa Mesa, CA 92626+3 locations',
#  'San Francisco, CA',
#  'California•Remote',
#  'South San Francisco, CA',
#  'San Francisco, CA (North Waterfront area)•Remote',
#  'Monterey, CA',
#  'San Francisco Bay Area, CA',
#  'Elk Grove, CA 95757',
#  'California•Remote',
#  'Palo Alto, CA',
#  'Fremont, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Menlo Park, CA+5 locations',
#  'San Francisco, CA 94123 (Marina area)',
#  'Sacramento, CA 95822 (Airport area)+5 locations',
#  'San Francisco, CA 94129•Temporarily Remote',
#  'San Jose, CA+2 locations',
#  'California•Remote',
#  'San Francisco, CA',
#  'Costa Mesa, CA 92626•Remote',
#  'Irvine, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Sunnyvale, CA 94085 (East Murphy area)',
#  'Davis, CA',
#  'Irvine, CA•Remote',
#  'Costa Mesa, CA 92626•Remote',
#  'La Jolla, CA',
#  'Fremont, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'California+1 location•Remote',
#  'San Francisco, CA 94108 (Financial District area)',
#  'Carlsbad, CA',
#  'Irvine, CA 92612 (Business District area)',
#  'Woodland Hills, CA 91367',
#  'Westlake Village, CA 91361',
#  'Burbank, CA 91502 (Burbank Center area)',
#  'San Francisco, CA',
#  'California+2 locations•Remote',
#  'San Francisco, CA 94129•Temporarily Remote',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA+1 location',
#  'El Segundo, CA',
#  'Burbank, CA',
#  'San Francisco, CA 94102 (Downtown area)',
#  'Carlsbad, CA',
#  'Los Angeles, CA',
#  'Mountain View, CA+1 location',
#  'Sacramento, CA 95828',
#  'Sacramento, CA 95828',
#  'San Francisco Bay Area, CA',
#  'Palo Alto, CA',
#  'Santa Monica, CA•Remote',
#  'California+1 location•Remote',
#  'Beverly Hills, CA',
#  'Mountain View, CA 94043',
#  'San Francisco, CA 94108 (Chinatown area)',
#  'Los Angeles, CA',
#  'Foster City, CA 94404',
#  'Malibu, CA 90265',
#  'Encino, CA 91436',
#  'Costa Mesa, CA 92626',
#  'San Francisco, CA 94107 (Yerba Buena area)+2 locations',
#  'California•Remote',
#  'Sunnyvale, CA+1 location',
#  'Santa Clara, CA 95052',
#  'San Francisco, CA 94107 (South Of Market area)',
#  'Menlo Park, CA•Temporarily Remote',
#  'Fremont, CA',
#  'San Francisco, CA 94102 (Downtown area)',
#  'Mountain View, CA+2 locations',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Carlos, CA 94070',
#  'Mountain View, CA',
#  'San Francisco, CA+1 location',
#  'Daly City, CA 94014',
#  'Glendale, CA 91203•Temporarily Remote',
#  'Santa Cruz, CA 95060',
#  'California+1 location•Remote',
#  'Mountain View, CA 94043',
#  'Oakland, CA',
#  'Menlo Park, CA•Temporarily Remote',
#  'Glendale, CA 91203+1 location•Temporarily Remote',
#  'San Jose, CA 95131 (North Valley area)+1 location',
#  'Venice, CA',
#  'Oakland, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Mountain View, CA•Temporarily Remote',
#  'San Francisco, CA 94107 (South Of Market area)',
#  'California•Remote',
#  'Santa Clara, CA',
#  'Palo Alto, CA',
#  'Irvine, CA 92612 (Business District area)',
#  'Newark, CA 94560+4 locations',
#  'Mountain View, CA+3 locations',
#  'San Francisco, CA',
#  'Mountain View, CA+1 location',
#  'California•Remote',
#  'Mountain View, CA',
#  'Menlo Park, CA•Temporarily Remote',
#  'Mountain View, CA 94043',
#  'San Francisco, CA•Temporarily Remote',
#  'San Diego, CA',
#  'San Diego, CA',
#  'Palo Alto, CA 94304',
#  'Mountain View, CA',
#  'San Francisco, CA 94107 (South Of Market area)',
#  'Westlake Village, CA 91361',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Diego, CA',
#  'Mountain View, CA+3 locations',
#  'California•Remote',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'Culver City, CA',
#  'San Francisco, CA 94108 (Chinatown area)+1 location',
#  'San Francisco, CA 94102 (Downtown area)',
#  'Mountain View, CA 94043',
#  'California•Remote',
#  'Pasadena, CA 91103 (West Central area)',
#  'Santa Monica, CA•Remote',
#  'San Francisco, CA+1 location',
#  'San Francisco, CA',
#  'San Francisco, CA+1 location',
#  'California+4 locations•Remote',
#  'Oakland, CA 94612 (Downtown area)',
#  'Palo Alto, CA 94301 (University South area)•Remote',
#  'Cupertino, CA 95014+1 location',
#  'Venice, CA',
#  'Redwood City, CA 94065 (Marine area)',
#  'Santa Monica, CA•Remote',
#  'California•Remote',
#  'Palo Alto, CA 94304',
#  'South San Francisco, CA 94080',
#  'California•Remote',
#  'San Jose, CA 95131 (North Valley area)',
#  'San Diego, CA',
#  'Santa Ana, CA 92707',
#  'San Francisco, CA 94107 (South Of Market area)',
#  'California•Remote',
#  'Rancho Cucamonga, CA',
#  'San Mateo, CA',
#  'South San Francisco, CA 94080',
#  'Oakland, CA 94612',
#  'Los Angeles, CA',
#  'California•Remote',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'San Francisco, CA',
#  'Venice, CA',
#  'Santa Monica, CA•Temporarily Remote',
#  'Mountain View, CA+2 locations',
#  'Santa Ana, CA 92707',
#  'Palo Alto, CA 94304',
#  'San Jose, CA 95131 (North Valley area)',
#  'San Jose, CA 95113 (Downtown area)+1 location',
#  'San Francisco, CA',
#  'Santa Clara, CA',
#  'San Carlos, CA 94070',
#  'California+2 locations•Remote',
#  'Pasadena, CA 91103 (West Central area)',
#  'Mountain View, CA',
#  'Mountain View, CA+7 locations',
#  'San Jose, CA',
#  'Sunnyvale, CA 94087',
#  'Mountain View, CA+1 location',
#  'Mountain View, CA+2 locations',
#  'Palo Alto, CA 94301 (Professorville area)+4 locations',
#  'San Jose, CA 95113 (Downtown area)+1 location',
#  'Mountain View, CA+7 locations',
#  'Diamond Bar, CA 91765+1 location',
#  'Napa, CA 94559 (Fuller Park area)•Temporarily Remote',
#  'San Francisco, CA 94105 (Financial District area)+1 location',
#  'Mountain View, CA',
#  'Los Altos, CA 94022+3 locations',
#  'San Francisco, CA',
#  'Cypress, CA 90630',
#  'Newark, CA 94560+4 locations',
#  'San Francisco, CA',
#  'Lake Forest, CA 92630',
#  'San Francisco, CA•Temporarily Remote',
#  'California•Remote',
#  'Palo Alto, CA 94304',
#  'Orange County, CA',
#  'San Francisco, CA',
#  'Palo Alto, CA',
#  'Oakland, CA',
#  'Pleasanton, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'California•Remote',
#  'San Francisco, CA 94108 (Chinatown area)+1 location',
#  'South San Francisco, CA 94080',
#  'Los Angeles, CA',
#  'California•Remote',
#  'Irvine, CA 92612 (Business District area)',
#  'Palo Alto, CA 94304',
#  'Santa Clara, CA 95054',
#  'San Francisco, CA 94016+1 location',
#  'San Jose, CA+2 locations',
#  'Los Angeles, CA',
#  'United States•Remote',
#  'South San Francisco, CA',
#  'Sunnyvale, CA (Lakewood area)',
#  'California',
#  'Los Angeles, CA+1 location',
#  'California•Remote',
#  'Mountain View, CA+7 locations',
#  'Los Angeles, CA',
#  'San Francisco Bay Area, CA',
#  'Mountain View, CA+7 locations',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA 94104 (Financial District area)•Remote',
#  'Santa Barbara, CA',
#  'California•Remote',
#  'Emeryville, CA 94608',
#  'Palo Alto, CA+3 locations•Remote',
#  'San Francisco, CA',
#  'Vista, CA 92081',
#  'South San Francisco, CA',
#  'Palo Alto, CA+1 location',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'San Francisco, CA+1 location',
#  'Mountain View, CA+1 location',
#  'San Jose, CA+2 locations',
#  'Vacaville, CA+8 locations',
#  'California•Remote',
#  'Los Angeles, CA 90048 (Mid City West area)',
#  'San Francisco, CA',
#  'Emeryville, CA 94662',
#  'Los Angeles, CA 90057+1 location',
#  'San Francisco, CA 94102 (Downtown area)',
#  'Santa Monica, CA+10 locations',
#  'Newark, CA 94560+4 locations',
#  'Mountain View, CA',
#  'Palo Alto, CA+6 locations',
#  'Mountain View, CA+1 location',
#  'Santa Clara, CA',
#  'California•Remote',
#  'Santa Clara, CA',
#  'California•Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'Oakland, CA',
#  'South San Francisco, CA 94080',
#  'Santa Monica, CA•Temporarily Remote',
#  'Palo Alto, CA 94304',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'California+1 location•Remote',
#  'Irvine, CA+1 location',
#  'San Francisco Bay Area, CA',
#  'Los Angeles, CA+1 location',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Sacramento, CA 95822 (Airport area)+5 locations',
#  'Monterey, CA',
#  'California+1 location•Remote',
#  'San Francisco, CA+1 location',
#  'California•Remote',
#  'San Jose, CA 95113 (Downtown area)',
#  'San Francisco, CA',
#  'Redwood City, CA•Remote',
#  'Redwood City, CA 94065 (Dolphin area)+1 location',
#  'California•Remote',
#  'San Jose, CA 95132 (Berryessa area)•Temporarily Remote',
#  'San Francisco, CA 94105 (South Beach area)+1 location',
#  'Palo Alto, CA•Remote',
#  'El Segundo, CA',
#  'California',
#  'East Palo Alto, CA',
#  'Mountain View, CA',
#  'San Francisco, CA (North Waterfront area)',
#  'Moffett Field, CA 94035',
#  'Malibu, CA 90265',
#  'Los Altos, CA 94022',
#  'San Jose, CA 95101 (North Valley area)',
#  'Irvine, CA•Remote',
#  'East Palo Alto, CA',
#  'South San Francisco, CA 94080',
#  'San Diego, CA',
#  'San Jose, CA 95132 (Berryessa area)•Temporarily Remote',
#  'San Francisco, CA',
#  'California',
#  'San Francisco, CA',
#  'Santa Barbara, CA 93109 (West Mesa area)',
#  'Los Angeles, CA•Temporarily Remote',
#  'Pleasanton, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'Santa Clara, CA',
#  'South San Francisco, CA 94080',
#  'San Francisco, CA+1 location',
#  'Santa Ana, CA',
#  'San Jose, CA 95132 (Berryessa area)•Temporarily Remote',
#  'Oakland, CA 94612',
#  'California•Remote',
#  'San Jose, CA',
#  'San Carlos, CA',
#  'San Diego, CA•Remote',
#  'California•Remote',
#  'San Francisco, CA (Mission Terrace area)',
#  'San Francisco, CA',
#  'Culver City, CA',
#  'Santa Barbara, CA 93109 (West Mesa area)',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'Santa Clara, CA+1 location',
#  'South San Francisco, CA 94080',
#  'Irvine, CA•Remote',
#  'San Jose, CA',
#  'Palo Alto, CA+3 locations•Remote',
#  'South San Francisco, CA 94080',
#  'Burbank, CA',
#  'Milpitas, CA',
#  'Los Angeles, CA 90057+1 location',
#  'Los Angeles, CA',
#  'San Francisco, CA+1 location',
#  'Los Angeles, CA',
#  'Redwood City, CA',
#  'Burbank, CA 91504',
#  'San Francisco, CA•Temporarily Remote',
#  'South San Francisco, CA 94080',
#  'Sunnyvale, CA 94085 (East Murphy area)',
#  'Palo Alto, CA•Remote',
#  'Vista, CA 92081',
#  'California+1 location•Remote',
#  'Lake Forest, CA 92630',
#  'Burbank, CA',
#  'South San Francisco, CA 94080',
#  'California',
#  'Moffett Field, CA 94035',
#  'Playa Vista, CA•Remote',
#  'San Francisco Bay Area, CA',
#  'San Francisco Bay Area, CA',
#  'California•Remote',
#  'Irvine, CA 92612',
#  'San Francisco, CA',
#  'San Diego, CA 92101',
#  'Redwood City, CA 94063',
#  'San Jose, CA 95132 (Berryessa area)',
#  'Ontario, CA 91764•Remote',
#  'Los Angeles, CA•Remote',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014',
#  'San Francisco Bay Area, CA•Remote',
#  'Santa Clara Valley, CA 95014+1 location',
#  'California•Remote',
#  'Irvine, CA 92614•Remote',
#  'Palo Alto, CA',
#  'Menlo Park, CA•Temporarily Remote',
#  'San Jose, CA 95138 (Evergreen area)+1 location',
#  'Santa Clara, CA•Remote',
#  'San Diego, CA 92101',
#  'Monrovia, CA 91016',
#  'Redwood City, CA 94063',
#  'Folsom, CA 95630',
#  'Santa Clara Valley, CA 95014',
#  'Santa Clara Valley, CA 95014+3 locations',
#  'Santa Clara Valley, CA 95014',
#  'San Jose, CA 95132 (Berryessa area)•Temporarily Remote',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Mateo, CA 94404•Remote',
#  'Mountain View, CA•Temporarily Remote',
#  'South San Francisco, CA 94080',
#  'Newark, CA',
#  'Santa Clara, CA•Remote',
#  'Los Angeles, CA 90023 (Boyle Heights area)',
#  'Redwood City, CA 94063+1 location',
#  'San Jose, CA 95131 (North San Jose area)',
#  'San Diego, CA',
#  ...]

# %%
summaries12
# Out:
# ['Apply data mining, NLP, and machine learning (both supervised and unsupervised) to improve relevance and personalization algorithms.\nIn this role, you’ll.',
#  'A minimum of eight (8) years of experience conducting statistical analysis for clinical research projects.\nUse of machine learning, statistical modeling, and…',
#  'Uses predictive modeling, statistics, Machine Learning, Data Mining, and other data analysis techniques to collect, explore, and extract insights from structure…',
#  'Responsible for managing and developing the companies data utilization and translation into measurable, quantitative action points.\nTemporarily due to COVID-19.',
#  'Holistic and end to end approach to data, including querying, aggregation, deep analysis, visualization and models; communicate and present findings/actionable…',
#  'Extensive expereince developing sofrware with python, SQL, Spark and leveraging leading numerical and machine learning libraries(NumPy, Pandas, Scikit-learn,…',
#  'Work closely with our data scientists to pilot our products with beta customers.\nDesign and development of complex frameworks for applying ML / data science…',
#  '1 to 3 years of commercial experience in a data analyst or data scientist role.\nProviding data analysis and recommendations to the business group to make…',
#  'Experience with data visualization tools, such as Plotly.\nEnhancing data collection procedures to include information that is relevant for building analytic…',
#  'Backed by more than 40 years of technology leadership, our memory and storage solutions enable disruptive trends, including artificial intelligence, 5G, machine…',
#  'We are looking for a sharp, strong communicator who can provide strategic data input to evolve Advanced care planning and Disease management to increase quality…',
#  'We are looking for detail-oriented individuals who will collaborate with our team, label large amounts of data, and provide feedback to our data scientists and…',
#  'Develop complex machine learning-based analytical solutions extracting insights from large amount of structured and unstructured data from diverse data sources.',
#  'Minimum 2 years of experience with utilizing business intelligence / analytics / data visualization tools including Tableau, Power BI, and Microsoft NAV.',
#  'We are looking for a Data Scientist who will be responsible for developing algorithms for anomaly detection, diagnostics, and prognostics of failure using…',
#  'We are looking for detail-oriented individuals who will collaborate with our team, label large amounts of data, and provide feedback to our data scientists and…',
#  'Develop complex machine learning-based analytical solutions extracting insights from large amount of structured and unstructured data from diverse data sources.',
#  'Experiment against data points, provide insights based on experiment results and provide previously undiscovered solutions to command data challenges using a…',
#  'Minimum 2 years of experience with utilizing business intelligence / analytics / data visualization tools including Tableau, Power BI, and Microsoft NAV.',
#  'We are looking for a Data Scientist who will be responsible for developing algorithms for anomaly detection, diagnostics, and prognostics of failure using…',
#  'Experience in data visualization e.g. Tableau and ability to communicate results to a nontechnical audience.\nData analytics: 10 years (Preferred).',
#  'Technical knowledge regarding data models, database design development, data mining and segmentation techniques.\nWho You’ll Work With.',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'You will be performing thorough testing and validation of models, and support various aspects of the business with data analytics.',
#  'Field Team Modernization/Intelligent Decision Management - build and support of new predictive data models 2) Coding Transformation - build and support of new…',
#  'Curiosity to discover business-relevant patterns in the data.\nBuild statistical and machine learning models for statistical inference and prediction.',
#  'Experience managing a team of data scientists.\nRecruit top talent and build/ retain a stellar team of data scientists.\nTech Lead experience is a plus.',
#  'As a member of the Yield Modeling team, you will use state-of-the-art statistical, machine and deep learning models to tackle hard problems related to…',
#  'Mentor and partner with embedded data scientists on individual channel teams to drive business performance.\nExamples of projects you would work on include, but…',
#  'Collaborate with data engineers, other data scientists, product managers, and clinical researchers to align R&D with business objectives.',
#  '3+ years of work or educational experience in data science, machine learning, statistics, or applied mathematics a plus.\n401(k) with company match.',
#  '1-5 yrs experience in applying machine learning to applied use-cases.\nCollaborating with data and subject matter experts within IBM and its clients to…',
#  'This role focuses on language data, primarily in the areas of writing and general data analysis deliverables.\nWriting high-quality and engaging copy.',
#  'Present information using data visualization techniques.\nWe want to see a passion for machine-learning and research.\nCombine models through ensemble modeling.',
#  'Comprehensive health coverage, competitive salary, 401(k) employer match, Employee Stock Purchase Plan (ESPP).',
#  'Conduct cutting edge research and experiments in and around machine learning, text classification, entity linking, and entity extraction and other related…',
#  'The successful candidate will lead the development and execution of novel machine learning methods for the analysis of biological data, with focus on scRNA-seq…',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'This is a demanding role supporting a high-impact team that needs someone who is highly proactive and self-motivated, flexible, and solution-oriented while…',
#  'Collaborate with scientists and researchers in one or more of the following areas: data intensive applications, text processing, graph analysis, machine…',
#  'Present your research and insights to all levels of the company.\nProven track record of leveraging massive amounts of data to drive product innovation.',
#  'Responsible for managing and developing the companies data utilization and translation into intelligent systems to drive efficiency of environmental mitigation…',
#  '5+ years in developing machine learning systems, with extensive experience on deep learning systems.\nHelping to architect and develop the data pipeline and…',
#  'You have 2+ years of experience working in the machine learning space.\nYou will work closely with our data science, engineering, customer support and product…',
#  'Collaborate proficiently across functions from software engineers to clinical scientists.\nExpertise in clinical data standards, controlled vocabularies and…',
#  'Use expertise in causal inference, machine learning, complex systems modeling, behavioral decision theory etc. to shape the future of Instacart.',
#  'This role is remote within the LA area, Bay area, or Carpinteria, CA.\nPerforms quality control checks of data transcription, analyses and reports.',
#  'We are looking for a data scientist with a very strong background in analytics and problem-solving abilities.\nBuild predictive models, classification models and…',
#  'Contribute to expand the knowledge base within area of expertise, which includes IaaS, DaaS, visualization, analytics, OR techniques, and strategy…',
#  'Improve the work of other data scientists through mentorship and by bringing industry best practices to the team.\nB.S., M.S., or Ph.D. in a quantitative field.',
#  'Opportunity for mentorship with data science and technology experts with decades of subject matter expertise.\nCompetitive salary, equity and benefits.',
#  "In financial crimes risk management, Quantifind's solution uniquely combines internal financial institution data with public domain data to assess risk in the…",
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'Experience in data analytics in the fields of recommendation systems, deep learning and machine learning.\nExperience with machine learning, statistical analysis…',
#  'Conduct analysis of large datasets, extracting insights from user listening data that will drive content decision-making.',
#  '5+ years of industry experience in data-driven machine learning.\nSolid foundation in computer science, software development, and machine learning.',
#  'Build and maintain data pipelines for analytics, measurement, and dashboarding purposes.\nExperience problem solving and providing business insights and…',
#  'Develop and implement statistical/machine learning models for various business areas, including Credit Risk, Fraud, Marketing, and Operations.',
#  'Build tools to enable other data scientists to scale their knowledge and increase impact.\nMaking a high quality data science project available in a public forum…',
#  'Build production grade machine learning pipelines and data products that solve critical, complex problems and deliver business value.',
#  'Experience with one or more data visualization business intelligence tools (Looker and Tableau, preferred).\nExcellent verbal and written communication skills,…',
#  'Collaborate with data scientists and engineers to deploy new machine learning and deep learning models into complex and mission critical production systems.',
#  'All Scientists will also actively participate the Fusion Power research program by designing and performing experiments, performing data analysis, occasional…',
#  'Skills in scientific graphical representation, scientific writing and experience presenting at scientific conferences (poster, and oral presentations).',
#  'Their first product is an API that makes banking transactions accessible to both humans and machine learning models at scale, with minimal engineering overhead…',
#  "If you're passionate about data, impact, and working on an amazing team, read on!\xa0 You will:\xa0 Apply state-of-the-art machine learning techniques to…",
#  'The data, analytics, insights, best practices, and action plans clients need are available whenever and wherever they need them, to help them make data-driven…',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'Work with teams of data scientists in the ML evaluation work of our AI Drive Through Product.\nThe ideal candidate will have previous experience using advanced…',
#  'Develop experimental ML Models to solve complex data mining problems.\nEvaluate approaches and algorithms based on available data and research objectives.',
#  'Machine Learning Engineers at Zest AI build software that enables our customers to quickly create, adopt, and operate machine learning models in production.',
#  'Lead data-driven projects from definition to execution, from gathering data, defining metrics to communicating actionable insights;',
#  '[Bonus] Experience applying both data-backed heuristics and machine-learning techniques to solve personalization and recommendation problems.',
#  'Design and implement networks to provide automation of clinical tasks using one or more of medical images, electronic medical records, waveforms, and clinical…',
#  'Strong predictive data modeling experience is required with proven application in applying Decision Trees, Regression analysis, and other data mining techniques…',
#  'Experience in two or more of: traditional machine learning models, online learning, deep learning, reinforcement learning, representation learning.',
#  'Experience and interest in data visualization techniques (e.g. Matplotlib, Superset, Tableau).\nApply statistical analysis to test (accelerated life) and field …',
#  'The Di team is made up of data scientists, engineers, and analysts who are dedicated to driving product and distribution strategy with data-driven insights.',
#  'Proven data science or data analysis experience.\nRecommend and test predictive models and machine-learning algorithms.\nExperience analysis time-series data.',
#  'An ideal person for this position is an individual with a deep knowledge of clinical data, quality analysis and validation methodologies, strong interpersonal…',
#  'We are currently looking for a talented data scientist to join the machine learning data triage team.\nBonus qualification having experience in designing and…',
#  'FriendFinder Networks is looking for a Data Scientist with the primary responsibility to query or mine data and analyze large disparate datasets looking for…',
#  'You will be joining a world leading team of scientists and Data Science professionals based in San Francisco, who are at the top of their game and are…',
#  'Requires skills and experience to include: Data modeling skillset; Data manipulation and Data analytics tools; SQL, R, Python, Hive, or Spark; Tableau and…',
#  'Wurl is seeking a detail-oriented data scientist/engineer with strong analytical and communication skills to join and grow with our data analytics team.',
#  'Knowledge of data management, data engineering and visualization techniques.\nIn this role you will work to uncover patterns and generate insights by building…',
#  'Be a part of our data modernization efforts through the implementation of new data architecture, cloud, and machine learning technology.',
#  'Proficiency or publications in modern machine learning theories and applications such as deep neural nets, transfer/multi-task learning, reinforcement learning,…',
#  'High deductible health plan with health spend account contribution.\nYou have 5+ years previous experience as a marketing analyst, data scientist, or data…',
#  'The Data Scientist will have the opportunity to work on a portfolio of projects applying machine learning to public policy research in homelessness, criminal…',
#  'We invite applications both from dry-lab scientists and from wet-lab scientists with substantial quantitative experience.',
#  'Practical and theoretical understanding of common machine learning processes.\nUse domain leadership and deep understanding of customer problems to yield…',
#  'We are looking for data scientists with experience applying machine learning and modeling techniques, including natural language processing, anomaly detection,…',
#  'Full medical, dental, and vision with optional 70% coverage for dependents.\nPaid time off to volunteer.',
#  'Able to transform complex data to easily communicate insights, detect trends, and present visualizations.\nDesign, develop and test machine learning methods for…',
#  'The ASIR Data Scientist will develop and maintain a learning/data analytics infrastructure for the campus, including novel machine learning innovations for the…',
#  'The team consists of experts in product analytics, machine learning and data engineering.\nA deep understanding of modern statistical and machine learning models…',
#  'You will lead our Prognostics application, where we build machine learning pipelines to help identify which cars may need service so we can address issues…',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'Have the opportunity to mentor junior data scientists.\nWe rely on advanced techniques in machine learning, cloud platforms, and big data to drive decisions…',
#  'Develop and implement modeling and testing frameworks to ensure that we operate with the highest level of scientific rigor.',
#  'Experience with longitudinal human clinical/phenotype data, e.g. from electronic health records, epidemiological cohorts, or clinical trials.',
#  'Minimum of 2 years’ experience in data mining and analysis, statistical modeling, or machine learning in “big-data” environment.',
#  "Closely work with machine learning teams to understand their data needs, influence data team's roadmap, and lead as well as execute on various projects.",
#  'Partner with product managers, analysts and data scientists to ensure the rationality and scientific of A/B experiments.\nPosition: Data Scientist (A/B Test)*.',
#  'A key focus will be on combining different types of data to assess clinical trends, opportunities for improvement, and measure clinical and financial outcomes.',
#  'You should be comfortable doing both exploratory evaluations of data in a big data environment and identifying new cutting-edge data sources to drive commercial…',
#  'Act as a subject matter expert in providing technical guidance and mentorship to peer team members on analytics and analysis best practices, solution design as…',
#  'Develop a culture of best practices in transforming machine learning code into operant and performant IaaS, SaaS, and AIaaS.',
#  'We cover a wide area of the data spectrum including analytical data engineering, product analytics, experimentation, causal inference, statistical modeling and…',
#  "Collaborate with other data analysts and data scientists on the analytics team.\nYou'll carry out research and development projects aimed at optimizing player…",
#  'This position will provide active engagement in experiencing the correlation between data science, especially deep learning and NLP, and real-world applications…',
#  'Enable other machine learning scientists in the broader group to experiment quickly and accurately.\nExperience with large scale data mining tools such as Spark.',
#  'Given the growing nature of the department, this position calls for individuals who can perform exploratory data analysis as well as developing / deploying…',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'Experience with statistical modeling and deep learning especially with frameworks such as PyTorch, Tensorflow or Keras.\nFluency in C++/C# and Python preferred.',
#  'The candidate should also have had experience working on projects with data scientists building models and deploying.\nJob Types: Full-time, Contract.',
#  'Collaborate with a team of data scientists, engineers, and business partners to take an opportunity or problem from concept to scaled solution.',
#  'You will have time to dig deep into subject areas of importance.\nExperience working with spatial data.\nComfortable writing SQL and evaluating the quality of…',
#  '2+ years in consulting/data science/marketing analytics roles.\nIdeally in a relevant field to analytics (finance, business, engineering, information systems,…',
#  'Experiment against data points, provide insights based on experiment results and provide previously undiscovered solutions to command data challenges using a…',
#  'Organize data from multiple analytics platforms.\nThis is a full time position with benefits.\nManage spreadsheets and performance reports.',
#  'Desire to mentor other data scientists and share best practices to elevate the data science practice at Reddit.',
#  'Degree / experience in a relevant subject.\nUsing big data, deep expertise and AI-driven platforms to decode the 21st century human experience – then redefine it…',
#  'Collaborate with machine learning engineers, build tools to understand complex machine learning models and identify areas of improvements for the model.',
#  'Bonus qualification having experience in designing and automating ML analysis at scale and leveraging data-mining techniques to identify insights and patterns…',
#  'Experience developing and productionizing machine learning models is a plus.\nExperience with distributed data processing tools like Hive, Spark, Airflow and.',
#  'The data scientist will be responsible for predictive modeling and analysis of customer data, as well as researching best practices in analytics and data…',
#  'A history of mentoring other data scientists, if not being a direct manager and scaling a team successfully.\nExperience leading a data science team and managing…',
#  'Expertise in data analysis and data mining.\nResponsible for algorithm design, development, implementation, testing, and documentation for machine learning model…',
#  'Strong understanding of machine learning approaches and algorithms.\nExperience working with machine learning frameworks such as TensorFlow, Caffe2, PyTorch,…',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'Work closely with Product or Engineering & Operations teams to proactively create rule and manage decisions.\nCandidates will help own analytics for a particular…',
#  'Our work lies at the intersection of many diverse fields including machine learning, signal processing, biostatistics, and epidemiology, and in this role you…',
#  'You will work directly with data scientists, software engineers, and subject matter experts in the definition of new analytics capabilities able to provide our…',
#  'You have demonstrated experience in developing, implementing and communicating machine learning algorithms or high-dimensional data analyses.',
#  'This individual’s primary focus will be applying data mining techniques, doing statistical analysis, and building high quality prediction systems to evaluate…',
#  'Run validation tests and perform data analysis.\nAbility to perform first-principles analysis to ensure a successful design (stress-strain, thermal, tolerance,…',
#  'Deep understanding of data science principles, including machine learning, deep learning and artificial intelligence concepts.',
#  'Solid understanding of predictive analytics, statistical modeling, and data-mining (theory, algorithms, and application).',
#  'Part of a group of data scientists applying state of the art analytics and ETL to Distribution, Life and Financial Services challenges.',
#  'Present information using data visualization techniques.\nWe will rely on you to build data products to extract valuable business insights.',
#  'Identify, analyze and interpret trends, patterns and relationships in complex data sets, using advanced analytics tools and models.',
#  'PhD in Computational Biology or equivalent subject with strong statistical foundations.\nExperience working with single cell or T-cell data sets.',
#  'Our clients need flexible data structures and a streamlined data architecture that quickly turns data resources in.\nEmployee Status : Full Time Employee.',
#  'Knowledge of health care industry preferred.\nFamiliarity with Kaiser Permanente health care system preferred.\nTranslates needs, issues, and ideas into effective…',
#  "This team provides data pipelines and data APIs to data scientists so they can make our products better for Ancestry's customers.",
#  'Additional requirements include the ability to read and implement related academic literature and experience in applying state of the art deep learning models…',
#  'Brings a combination of 1) healthcare clinical/claims domain expertise, 2) database query capabilities and 3) data science/analytics expertise.',
#  'The ideal candidate will have no issue digging into messy data, working with clinical subject matter experts to develop annotation guidelines to produce high…',
#  'Develop experimental ML Models to solve complex data mining problems.\nEvaluate approaches and algorithms based on available data and research objectives.',
#  'Applicants will be expected to work with a diverse set of data sources, such as time series data, spatial, graph data, semi-structured and unstructured data,…',
#  'Deep understanding of data science principles, including machine learning, deep learning and artificial intelligence concepts.',
#  'You should be comfortable doing both exploratory evaluations of data in a big data environment and identifying new cutting-edge data sources to drive commercial…',
#  'Inform, influence, support, and execute analysis that feeds into one of our many analytics domains - Customer analytics, product analytics, business operation…',
#  'Brings a combination of 1) healthcare clinical/claims domain expertise, 2) database query capabilities and 3) data science/analytics expertise.',
#  'Work together with key stakeholders (data scientists, engineers, risk managers) from our clients;\nCommunicating your findings to the project manager and…',
#  'Collaborate with members of your team (e.g., data analysts, data scientists, channel managers, product managers) on project goals.\nTemporarily due to COVID-19.',
#  'We are looking for a scientist excited about the opportunity to make an immediate impact and help us create and curate training sets for Inflammatix machine…',
#  'Exposure to applied machine learning in an enterprise setting.\nTraining data – Adobe’s training datasets often contain digital art, photos, videos, text, or…',
#  'We consider qualified applicants with criminal histories, consistent with applicable law.\nIn this role, the Reporting Analyst will work with a multidisciplinary…',
#  'Nurses. Lark uses cutting-edge AI and connected health monitors to provide real-time unlimited 24/7 text-based counseling to help users make healthier choices…',
#  '3+ years of coding experience using machine learning toolset within Python, SQL, Spark and/or Scala; 3+ years of experience leveraging machine learning…',
#  '4 years hands-on data science/data analysis experience, working with scientific data.\nExperience with scientific data visualization is preferred.',
#  '5+ years to data science and machine learning.\nAbility to extract data from different databases via SQL and other query languages and applying data cleansing,…',
#  'You should be comfortable doing both exploratory evaluations of data in a big data environment and identifying new cutting-edge data sources to drive commercial…',
#  'Answer tough questions that come up by analyzing our data and provide insights gained from analyzing data.\nFrom the data we have.\nAnd by collecting new data.',
#  'Formulation of machine-learning problem statements from the data.\nPresenting information using data visualization techniques.\nFinding patterns in the data.',
#  'Build and maintain data pipelines for analytics, measurement, and dashboarding purposes.\nExperience problem solving and providing business insights and…',
#  'Applicants will be expected to work with a diverse set of data sources, such as time series data, spatial, graph data, semi-structured and unstructured data,…',
#  'Minimum 3 year of work experience applying scientific methods to solve real-world problems on web-scale data.\nWork with product managers and engineers to design…',
#  'Contributing to data processing and machine learning initiatives.\nThe ideal candidate is experienced with Big Data, ML processes, SQL, Python, and is most…',
#  'Identify, analyze and interpret trends, patterns and relationships in complex data sets, using advanced analytics tools and models.',
#  '2+ years of relevant experience applying statistical/machine learning methods to large datasets in an industry setting.\nKnowledge and experience with SQL.',
#  'Deep understanding of statistical modeling, machine learning, deep learning, or data mining concepts, and a track record of solving problems with these methods.',
#  'Pit.AI Technologies supports publications of methodological findings to top machine learning venues.\nNo finance or machine learning experience is required.',
#  'The DSA team, comprising of other data scientists and machine learning engineers, works with other data scientists, engineers, designers, executives, product…',
#  'Opportunity for mentorship with data science and technology experts with decades of subject matter expertise.\nCompetitive salary, equity and benefits.',
#  'Experience with one or more data visualization business intelligence tools (Looker and Tableau, preferred).\nExcellent verbal and written communication skills,…',
#  'Practical experience establishing and utilizing data analytics standard methodologies.\nYou will work closely with the Director of Data Science and key…',
#  'Work together with key stakeholders (data scientists, engineers, risk managers) from our clients;\nCommunicating your findings to the project manager and…',
#  'Conduct ad-hoc analysis to understand unexpected metric movements and communicate results to other data scientists, product managers and company leadership.',
#  'Applicants will be expected to work with a diverse set of data sources, such as time series data, spatial, graph data, semi-structured and unstructured data,…',
#  '5+ years of industry experience in one or more machine/deep learning frameworks.\nYou might not be an expert in every stage of a Machine Learning project, but…',
#  'Solid understanding of predictive analytics, statistical modeling, and data-mining (theory, algorithms, and application).',
#  'The ideal candidate will have previous experience in the Cyber Security domain analyzing large data sets to develop actionable analytics solution.',
#  'You have a masters or PhD in computer science, statistics, math or a quantitative / scientific STEM substitute like physics or chemistry (an MIS or MBA do not…',
#  'Degree / experience in a relevant subject.\nUsing big data, deep expertise and AI-driven platforms to decode the 21st century human experience – then redefine it…',
#  'Advanced knowledge of data science and machine learning fundamentals, strong analytical and critical thinking skills.\nMaintain and develop CI/CD workflows.',
#  'Competitive health care, dental, and vision coverage.\nCandidate should have a deep understanding of various optimization algorithms as well as practical…',
#  'Participate in all aspects of the project lifecycle from requirements gathering, data acquisition and preparation, hypothesis generation, ideation, coding,…',
#  'Formulation of machine-learning problem statements from the data.\nPresenting information using data visualization techniques.\nFinding patterns in the data.',
#  'Translate unstructured business problems into well-defined machine learning projects.\nExpert experience designing, developing, and implementing machine learning…',
#  'Conduct research and prototyping innovations; data and requirements gathering; solution scoping and architecture; consulting clients and client facing teams on…',
#  'Collaborate with members of your team (e.g., data analysts, data scientists, channel managers, product managers) on project goals.\nTemporarily due to COVID-19.',
#  'This position requires strong analytical skills in understanding and applying machine learning and optimization techniques as well as the experience in…',
#  'Have the opportunity to mentor junior data scientists.\nWe rely on advanced techniques in machine learning, cloud platforms, and big data to drive decisions…',
#  'Strong academic and industry experience with advanced mathematical concepts - e.g. statistical inference, machine learning, network graph models.',
#  'Experience with popular statistical methods and machine learning algorithms, preferably forecasting and time series analysis.',
#  "Additionally, you'll build and maintain production quality machine learning models and explore and prepare disparate data sources for machine learning work.",
#  'In your role you will work with the research scientists participating in all phases of end-to-end machine learning solutions development - including technical…',
#  'Proficiency in machine learning frameworks like scikit-learn and deep learning frameworks like Pytorch, Tensorflow, or Keras.\nProficient in Python and SQL.',
#  'Experience with longitudinal human clinical/phenotype data, e.g. from electronic health records, epidemiological cohorts, or clinical trials.',
#  'Develop and implement statistical/machine learning models for various business areas, including Credit Risk, Fraud, Marketing, and Operations.',
#  'This role will primarily focus on performing exploratory data analysis, engineering features using domain knowledge, and building relevant machine learning…',
#  'Opportunity for mentorship with data science and technology experts with decades of subject matter expertise.\nCompetitive salary, equity and benefits.',
#  '5+ years of industry experience in one or more machine/deep learning frameworks.\nYou might not be an expert in every stage of a Machine Learning project, but…',
#  'Collaborate with data scientists and business owners across the company to strategically and accurately craft their public facing statements.',
#  'Knowledge of machine learning, information retrieval, data mining, statistics, NLP or related field.\nExperience managing end-to-end machine learning pipeline…',
#  'Deep understanding of statistical modeling, machine learning, deep learning, or data mining concepts, and a track record of solving problems with these methods.',
#  'Part of a group of data scientists applying state of the art analytics and ETL to Distribution, Life and Financial Services challenges.',
#  'Expertise with statistical analysis, applying various machine learning techniques, predictive modeling and data mining to solve business problems.',
#  'Work together with key stakeholders (data scientists, engineers, risk managers) from our clients;\nFounded and developed by data scientists and aerospace…',
#  'You will work directly with data scientists, software engineers, and subject matter experts in the definition of new analytics capabilities able to provide our…',
#  'You should be able to work cohesively with subject matter experts, understand both data systems and physical systems, and have an eye for anomalies in physical…',
#  "This team provides data pipelines and data APIs to data scientists so they can make our products better for Ancestry's customers.",
#  '3+ years of work or educational experience in data science, machine learning, statistics, or applied mathematics a plus.\n401(k) with company match.',
#  'Lead data analytics projects: translate complex business questions into concrete data analysis problems, improve on existing or build new models, deliver…',
#  'Serve as a thought-partner for product managers, engineering managers and leadership in influencing the monetization roadmap and strategy for Reddit by…',
#  'Present information using data visualization techniques.\nWe will rely on you to build data products to extract valuable business insights.',
#  'Design and develop data analytics system for networking telemetry and configuration data;\nEvaluate and adopt stream processing, batch processing and monitoring…',
#  'Organize data from multiple analytics platforms.\nWe offer competitive salary, PTO, and excellent benefits.\nBe a part of creating the digital future.',
#  'Contribute to expand the knowledge base within area of expertise, which includes IaaS, DaaS, visualization, analytics, OR techniques, and strategy…',
#  'Perform data linkages with cancer registries, Medicare files, and other data resources.\nAssist in interpretation of large epidemiologic data sets.',
#  'Experience with popular statistical methods and machine learning algorithms, preferably forecasting and time series analysis.',
#  'Expert in statistics and data science, and machine learning models.\nCollaborate with product, design and the broader engineering team on data science models,…',
#  'Mentor junior data scientists on how to use more advanced methods and solve business problems.\nDomain expert in one of the fields: statistics, machine learning,…',
#  'Knowledge and experience in creating confidential and public analytical survey files including survey data quality control, data augmentation, data…',
#  "Collaborate with other data analysts and data scientists on the analytics team.\nYou'll carry out research and development projects aimed at optimizing player…",
#  'You have 5+ years experience in a data science or analytics role at a consumer company, ideally with a stint on a high quality growth team.',
#  '3+ years of relevant work experience (e.g., as a data scientist) or equivalent.\nThe data center is the underpinning for every data-driven service, from…',
#  'You are willing to build end-to-end and own the machine learning products you build or help build.\n3+ years of data science experience.',
#  'Understanding and experience in the visualization of security data.\nAbility and experience in extracting insights from data, and summarizing learnings /…',
#  'Formulation of machine-learning problem statements from the data.\nPresenting information using data visualization techniques.\nFinding patterns in the data.',
#  'Evaluate available data and define requirements for needed data.\nAble to uncover insights in messy data sources.\nPresent to stakeholders and executives.',
#  'A bias for action in applying analytics to solve problems and a focus on identifying efficient solutions to complex issues.',
#  'Deep experience with one or more data Visualization tools - we use Looker, but Tableau, Matplotlib or Mode are all relevant alternatives.',
#  '4 years hands-on data science/data analysis experience, working with scientific data.\nExperience with scientific data visualization is preferred.',
#  'Dig deep into high volumes of data to find anomalies and propose solutions to fix them.\nTrack record of delivering data-driven products and insights, and…',
#  'Build cool models to find actionable insights around customer experience metrics through funnels, cohort analyses, long-term trends, user segmentation, ML…',
#  'You have 5+ years experience in a data science or analytics role at a consumer company, ideally with a stint on a high quality growth team.',
#  'This role will primarily focus on performing exploratory data analysis, engineering features using domain knowledge, and building relevant machine learning…',
#  'Contribute to expand the knowledge base within area of expertise, which includes IaaS, DaaS, visualization, analytics, OR techniques, and strategy…',
#  'Deep experience with one or more data Visualization tools - we use Looker, but Tableau, Matplotlib or Mode are all relevant alternatives.',
#  "Closely work with machine learning teams to understand their data needs, influence data team's roadmap, and lead as well as execute on various projects.",
#  'Apply advanced analytics, machine learning, and AI techniques to obtain value from the full range of all data sets, applying Cloud-based technology.',
#  'Fluency in the Arabic language with excellent comprehension, grammar and proofreading skills.\nExcellent English reading comprehension and writing skills.',
#  'Perform data mining on large sets of data for various industries.\nUnderstanding and working with multiple data sources to create a unified solution that…',
#  'Relevant professional experience with applied data analytics and predictive modeling.\nBuild data pipeline for data acquisition, cleanup and related tooling.',
#  'We are looking for data scientists with experience applying machine learning and modeling techniques, including natural language processing, anomaly detection,…',
#  'Identify, analyze and interpret trends, patterns and relationships in complex data sets, using advanced analytics tools and models.',
#  'To achieve this, we’re working on projects that utilize the latest computer science techniques developed by skilled software engineers and research scientists.',
#  'Take ownership over all aspects of the data collection process, such as programming survey questionnaires, managing sample collection for surveys in the field,…',
#  'Uncover insights to ensure data-driven decision making.\nExperience with product analytics and working with event-data.\n2-4 years experience in a similar role.',
#  'Degree / experience in a relevant subject.\nUsing big data, deep expertise and AI-driven platforms to decode the 21st century human experience – then redefine it…',
#  'Your strong communication skills and scientific knowledge will enable you to work collaboratively with a diversity of cross functional scientific team members…',
#  'The successful candidate will lead the development and execution of novel machine learning methods for the analysis of biological data, with focus on scRNA-seq…',
#  'Able to transform complex data to easily communicate insights, detect trends, and present visualizations.\nDesign, develop and test machine learning methods for…',
#  'In your role you will work with the research scientists participating in all phases of end-to-end machine learning solutions development - including technical…',
#  'Build up product analytics taxonomy and documentation framework to ensure a sustainable workflow for cross-team data availability.\n12-week paid parental leave.',
#  "Additionally, you'll build and maintain production quality machine learning models and explore and prepare disparate data sources for machine learning work.",
#  'Experience in data mining, machine learning, statistical models, data clustering and classification techniques.\nHelp develop key business metrics.',
#  'The candidate should also have had experience working on projects with data scientists building models and deploying.\nJob Types: Full-time, Contract.',
#  'Deep understanding of statistical modeling, machine learning, deep learning, or data mining concepts, and a track record of solving problems with these methods.',
#  'Gather knowledge through data analyses and discover insights.\n8+ years of experience in data science or related.\nYou will report to our VP of Data.',
#  'Work together with key stakeholders (data scientists, engineers, risk managers) from our clients;\nCommunicating your findings to the project manager and…',
#  'Understand how to identify, acquire, and utilize data sources to answer specific business questions related to clinical/health outcomes, SDoH, provider quality,…',
#  'Given the growing nature of the department, this position calls for individuals who can perform exploratory data analysis as well as developing / deploying…',
#  'Strong data analysis and scientific thinking skills.\n8+ years of demonstrated experience with machine learning or data science.\nProficiency in Python and SQL.',
#  'The ideal candidate will be a subject matter expert in statistical methods or machine learning, is scrappy, focused on results, self-motivated and has a history…',
#  'Minimum of 2 years of experience in data science and/or data analytics.\nIdentifies meaningful insights from large data and metadata sources; interprets and…',
#  'Skilled in using statistics and data visualization techniques to provide an accessible way to see and understand trends, outliers, and patterns in data.',
#  'Able to transform complex data to easily communicate insights, detect trends, and present visualizations.\nDesign, develop and test machine learning methods for…',
#  'The ideal candidate will be a subject matter expert in statistical methods or machine learning, is scrappy, focused on results, self-motivated and has a history…',
#  'Relevant professional experience with applied data analytics and predictive modeling.\nBuild data pipeline for data acquisition, cleanup and related tooling.',
#  'Have the opportunity to mentor junior data scientists.\nWe rely on advanced techniques in machine learning, cloud platforms, and big data to drive decisions…',
#  'We solve challenging problems and boost business growth through a deep understanding of user behaviors with applied analytics techniques and business insights.',
#  'Expertise with statistical analysis, applying various machine learning techniques, predictive modeling and data mining to solve business problems.',
#  'The team member will work closely with cross-functional teams of software engineers, data analysts and product leaders and will require a solid background on…',
#  'Communicate and liaison with senior stakeholders on key changes and ensure to keep the process maps and data models current.\nJob Types: Part-time, Contract.',
#  'Because the European Union Commission has determined that United States data privacy laws do not ensure an adequate level of protection for personal data…',
#  'We’re looking for smart and scrappy data scientists to help accelerate the rate of development for multiple initiatives at various stages of maturity.',
#  'Ability to bring data to life for any audience via written communication, verbal communication and data visualization.',
#  '4 years hands-on data science/data analysis experience, working with scientific data.\nExperience with scientific data visualization is preferred.',
#  'Experience creating and using advanced machine learning algorithms and statistics, and experience building automated output as a data product with R or Python.',
#  'Experienced with the principles and techniques of project management including the ability to develop and track complex project plans, manage risks, manage…',
#  'You are expected to work at the intersection of machine learning and software engineering and should possess a deep, working knowledge of data exploration,…',
#  'The ideal candidate will be a subject matter expert in statistical methods or machine learning, is scrappy, focused on results, self-motivated and has a history…',
#  'This role will report into the Business Intelligence Manager and join a team of analysts, data scientists, and engineers.\nExperience with BigQuery is a plus.',
#  'You will work closely with our other data scientists, engineers, and product managers to help develop data-driven products and machine learning systems that…',
#  'Our policy data scientists support our policy issue experts around the world, equipping them with data to support our public policy positions.',
#  'A key focus will be on combining different types of data to assess clinical trends, opportunities for improvement, and measure clinical and financial outcomes.',
#  'As a Quantum Machine Learning Researcher, you will use your experience in machine learning and quantum computing to better understand the ways in which quantum…',
#  'Contribute to expand the knowledge base within area of expertise, which includes IaaS, DaaS, visualization, analytics, OR techniques, and strategy…',
#  'Ability to investigate down to data source to ensure accuracy of data.\nOur Metrics team combines data science, statistics, and engineering to provide real-time…',
#  'Deep understanding of statistical modeling, machine learning, deep learning, or data mining concepts, and a track record of solving problems with these methods.',
#  'You have 5+ years experience in a data science or analytics role at a consumer company, ideally with a stint on a high quality growth team.',
#  'This role will play a pivotal role in implementing machine learning models across our products as well as, running high business impacting analytics that will…',
#  '3+ years of relevant work experience (e.g., as a data scientist) or equivalent.\nThe data center is the underpinning for every data-driven service, from…',
#  'We are currently looking for a talented data scientist to work with technology, engineering, and other data scientists to define success of machine learning…',
#  'Experience with one or more data visualization business intelligence tools (Looker and Tableau, preferred).\nExcellent verbal and written communication skills,…',
#  'Practical experience in applying data science computer programming methods in these specific areas, using R and Python.\nGraduate degree in Data Science.',
#  'You are willing to build end-to-end and own the machine learning products you build or help build.\n3+ years of data science experience.',
#  'We are looking for data science & machine learning (ML) engineer with exclusive knowledge of Macroeconomic, Government Finance Analytics, Budgets, and develop…',
#  'Clearly communicate insights and recommendations to leadership through effective data visualization and presentations to inform business decisions.',
# ...
#  'Knowledge of machine learning frameworks, such as XGBoost or SKLearn, and/or...\nExperience using content publishing tools to write, format, manage, and publish…',
#  '10+ years of experience in at least 3 of the 4 following areas: product analytics, experimentation, analytics platforms, and/or user research.',
#  '4+ years of experience with data visualization tools (D3 Js, R Shiny, Looker, Tableau, or similar); able to determine the appropriate visualization for a…',
#  'You will work across teams with product managers and customer teams to build deep customer empathy and prioritize work that delivers meaningful customer…',
#  'Primary job function is to perform R&D in machine learning, deep learning, reinforcement learning, and other areas.',
#  'At TRI, the Annotation Operations team is responsible for managing and auditing (QAing) data to provide accurately labeled annotations for machine learning…',
#  'Well-being programs to support mental and physical health.\nFinancial programs that empower you to plan, save, and manage your money (including expert financial…',
#  'Must have experience working with enterprise data warehouses, data marts, data bases, data lakes, or other distributed or cloud-based data storage systems.',
#  'Knowledge of machine learning frameworks, such as XGBoost or SKLearn, and/or...\nExperience using content publishing tools to write, format, manage, and publish…',
#  'You will also work closely with a cross-functional team of life scientists, statistical geneticists, bioengineers and machine learning scientists to integrate…',
#  'Partner with data analysts, data engineers, data scientists, and stakeholders to better understand requirements, find bottlenecks, and implement resolutions.',
#  'Relevant Terms: patent law, patent prosecution, claims drafting, USPTO, patent engineer, patent agent, patent claims, patent prosecution, USPTO, office actions,…',
#  'Experience or willingness to learn state of the art machine learning paradigms and application of them into areas such as Text Classification, Semantic Modeling…',
#  'Master’s degree in a quantitative field; advanced degree with relevance to data science, machine learning, or operations research preferred.',
#  'You will also be responsible for enabling different teams at PAX to make data driven decisions using our big data, analytics and business intelligence tools,…',
#  'Your work would involve data science, image processing research and development, machine learning in both small and large scales working with a very diverse set…',
#  '3+ years of experience visualizing and analyzing data as a data analyst/ data scientist.\nProficient in Data Visualization and storytelling with data with the…',
#  'You will work closely with other data scientists, engineers and partners across Marketing, Sales and R&D to derive insights from diverse data sources, help the…',
#  'The Data Engineer will also work closely with Samsara data analysts, data scientists, and ML Engineers to help prep data for models and dashboards.',
#  'We focus on data-driven analytics that strengthen our understanding of how things work, helping the company understand how to interpret data, and creating data…',
#  'Experience applying machine learning algorithms to real data sets, preferably including text analysis and NLP.\nExperience with ElasticSearch and Postgres.',
#  'Embed with AI/ML and data science project teams to provide deep expertise in software engineering, parallel computing, and big data tools.',
#  'Staying informed about developments in Data Science and adjacent fields to ensure that outputs are always relevant.\nProficiency in Python is preferred.',
#  'Lead and apply ongoing knowledge and awareness in trends, standard methodology and new developments in analytics and data science to influence functional…',
#  'Great understanding of functional programming, data structures and algorithms.\nDesign, build and maintain real-time distributed systems.',
#  'BS, or MS in computer science, data science, engineering, math, physics, data analytics or related field.\nOverair is seeking an experienced data scientist who…',
#  'Relevant Terms: patent law, patent prosecution, claims drafting, USPTO, patent engineer, patent agent, patent claims, patent prosecution, USPTO, office actions,…',
#  'Using statistical tools to interpret data sets, paying particular attention to trends and patterns that could be valuable for diagnostic and predictive…',
#  'Serve as the investigative and technical subject-matter expert during preliminary conversations and presentations with potential customers.',
#  'Experience working with Big Data Technologies (ex. Spark) and applying machine learning techniques at large scale with these technologies.',
#  'The candidate will join a multi-disciplinary team of scientists and engineers and work on a full stack of developing cutting edge Computer Vision (CV) and…',
#  'Bachelor’s degree and/or 2-3 years of experience in development, training and optimization of machine learning models.\nExposure to NLTK, Genism and SciPy.',
#  'Deliver full visibility of subscription plans, add-ons purchased, reporting and visualizations for trends, and tools for usage analytics.',
#  'Experience using data visualization tools (i.e., Domo, Tableau, Looker); comfortable transforming data into actionable insights.',
#  'Provide scientific content in support of data stories that help users understand the rigor of the data science underlying Oura’s approach.',
#  'Experience with state of the art big data tools for parallel processing, analysis, and machine learning.\nThe ideal candidate has an intuitive grasp of a rich…',
#  'Your work would involve data science, image processing research and development, machine learning in both small and large scales working with a very diverse set…',
#  'Working with the clinical science, clinical operations and clinical informatics teams to develop a detailed understanding of the data workflows.',
#  'In partnership with finance, analytics and data science teams, design a framework for market yield optimization and oversee execution of tests.',
#  'You will also work closely with a cross-functional team of life scientists, statistical geneticists, bioengineers and machine learning scientists to integrate…',
#  'Knowledge of data architecture, data modeling, data mapping, data analysis, and data visualization.\nExcellent analytical skills to forecast and predict trends…',
#  'Experience working with Big Data Technologies (ex. Spark) and applying machine learning techniques at large scale with these technologies.',
#  'You have previously productized machine learning algorithms (or high-volume data processing jobs) providing accurate results with low latency.',
#  'Lead and apply ongoing knowledge and awareness in trends, standard methodology and new developments in analytics and data science to influence functional…',
#  'The core contributions of the Principal Data Scientist will consist of technically define problems gathered from stakeholders, define experimentation setups,…',
#  'The highly self-motivated individual will work closely with research scientists, software developers and application scientists to innovate, prototype, validate…',
#  'Helps to maintain and develop documentation for all data visualization project deliverables and ensure ease of use for end-users.',
#  'Execute deep dive quantitative analyses that translates data into actionable insights.\nSuperior analytical abilities and the ability to form key, succinct…',
#  '3+ years of research or practical experience applying deep learning on large scale and real world data.\nResearch and prototype perception deep learning systems…',
#  'Perform deep dive analyses on a wide range of topics and present insights and recommendations to key stakeholders.\nStrong knowledge of SQL required.',
#  'This role requires advanced technical skills, experience working with large datasets (EMR, clinical trial data, data cleaning and building analysis models, etc.…',
#  'Experience working with large amount of unstructured data and developing templates, visualizations, dashboards or analytics to deliver insights.',
#  'Extensive experience querying large, complex data sets & proven ability to derive and present insights from multiple imperfect, varied, and inconsistent data…',
#  'Delivery of the Clinical Study Report (CSR), Study Data Tabulation Model (SDTM)/Analysis Data Model (ADaM) databases and Tables, Figures and Listings (TFL)…',
#  'Collaborate with data scientists and engineers to deploy new machine learning and deep learning models into complex and mission critical production systems.',
#  'We provide an end-to-end, cloud-based platform with a flexible suite of tools that allows patients, healthcare providers, clinical research organizations and…',
#  'Deep Learning & Computer Vision Scientist you will be responsible for designing and developing deep learning and computer vision models to advance the frontier…',
#  'Extract intelligence from data by applying analysis and feature-engineering techniques.\nComfortable with distributed learning, big data (Petabyte scale) and…',
#  'This role involves applying advanced data analytical for product development and digital Innovation.\nAdvanced expertise in specialized software and other…',
#  'Develop data automation tools and dashboards to enable innovative data visualization.\nPerform data management tasks including data validation, data curation,…',
#  'Lead and apply ongoing knowledge and awareness in trends, standard methodology and new developments in analytics and data science to influence functional…',
#  'Master’s degree in a quantitative field; advanced degree with relevance to data science, machine learning, or operations research preferred.',
#  'You will work across teams with product managers and customer teams to build deep customer empathy and prioritize work that delivers meaningful customer…',
#  'Surface data-driven insights that drive strategy and optimal decision making for the leaders across the organization.',
#  'Experience working with machine learning, applied optimization, and/or statistical learning.\nUnderstanding of creating new datasets and eliminating biases.',
#  'DST engages in partnerships with scientists to understand their computing and data analysis challenges to develop leading-edge solutions that fit the needs of…',
#  'A passion for finding insights in data and driving change based on those insights.\nAnalyze high volumes of customer interaction data to drive insights.',
#  'Provide expertise and translate the business needs to design; and develop tools, techniques, and metrics, and dashboards for insights and data visualization.',
#  'Do research on emerging AI, machine learning, deep learning solutions applied to structured and unstructured data and be conversant with the latest developments…',
#  'Responsible for sample size determinations, calculations of clinical accuracy, PPV, NPV, and other statistics of value for clinical trials and regulatory…',
#  'Understanding the architectures of perception models, designing and implementing deep learning optimization routines for fast and efficient inference and…',
#  'Hand-on experience with large distributed data warehousing, data architecture, modeling, data analysis, trends and statistical analysis.',
#  'Champion and project manage data related initiatives with engineering and business teams to improve the data science capabilities of Transparently.',
#  "You've worked with complex distributed machine learning systems deployed at scale.\nYou keep up with the industry trends and continuously identify new tools to…",
#  'We build, maintain, and evolve the on-device user interfaces and frameworks that power the voice input experience across iPhone, iPad, Apple TV, and Watch.',
#  'Superb interpersonal skills, project prioritization and ability to discern signal from noise.\nStrong public cloud experience (AWS/GCP preferred).',
#  "*You've worked with complex distributed machine learning systems.\n*You keep up with the industry trends and continuously identify new.",
#  'Strong background in digital signal processing, estimation, or machine learning algorithm development applied to imaging or sensing systems.',
#  'Collect requirements from engineering teams, particularly machine learning teams, prioritize and triage the requirements.\nUp to a 30% discretionary bonus.',
#  'The ability to serve as a subject matter expert (SME) regarding threats and vulnerabilities.\nThis is an exciting opportunity to work for a global leader in life…',
#  '6+ years experience in data engineering or data science.\nExperience developing and deploying machine learning models.\nStock in an early-stage startup.',
#  'Four years of post-graduate research applying machine learning to the physical sciences.\nHelp lead the ML community broadly across the lab, including education…',
#  'This role will require in-depth knowledge of different machine learning frameworks and hands-on experience in training large scale machine learning models.',
#  'Experience creating and executing test cases from functional requirement documents and test plans.\nBe able to learn and understand complex products very quickly…',
#  'Responsible for sample size determinations, calculations of clinical accuracy, PPV, NPV, and other statistics of value for clinical trials and regulatory…',
#  'Minimum 5 years of experience in digital marketing data analytics and/or eCommerce data analytics.\nMust be comfortable analyzing large quantities of data to…',
#  'Hand-on experience with large distributed data warehousing, data architecture, modeling, data analysis, trends and statistical analysis.',
#  'Working in a social health, mental health, behavioral health or primary care field.\nPassionate about digital health and driving operational efficiency.',
#  'Ensure alignment with the program requirements including relevant process performance metrics & KPIs and compliance requirements/controls, in collaboration with…',
#  'Hands-on experience with deep learning and other current machine learning algorithms.\nM.S. or PhD in Electrical Engineering/Computer Science or a related field …',
#  'We build, maintain, and evolve the on-device user interfaces and frameworks that power the voice input experience across iPhone, iPad, Apple TV, and Watch.',
#  'Relevant Terms: patent law, patent prosecution, claims drafting, USPTO, patent engineer, patent agent, patent claims, patent prosecution, USPTO, office actions,…',
#  'Well published in data science, bioinformatics, machine learning or other relevant fields.\nMulti-dimensional genomics/proteomic data analysis, visualization,…',
#  'You will be responsible for design and development of enterprise grade features and micro-services involving information retrieval, text mining, classifier…',
#  'Your work will greatly improve the efficiency of the research of our algorithm scientists, and expedite the development of engineering infrastructure projects.',
#  'This role requires creativity and ingenuity in developing analysis methods including machine learning/AI type algorithms on our proprietary data to generate…',
#  'Collaborate closely with data scientists and system engineers.\nInterface with data analysis pipeline team to ensure that your code runs reliably.',
#  'Experience creating and executing test cases from functional requirement documents and test plans.\nBe able to learn and understand complex products very quickly…',
#  'A strong candidate has knowledge of deep learning, transformer/attention architectures, unsupervised sequence learning.\nMachine Learning: 2 years (Preferred).',
#  'Good mathematical knowledge and experience in statistical analysis, optimization, machine learning, and deep learning tools.',
#  'Experience using or developing deep learning frameworks, such as TensorFlow, PyTorch, ONNX, Caffe, etc.\nFamiliar with internal data representation and APIs of…',
#  '3-5 years of corporate finance, FP&A reporting, data analysis, public accounting, or commercial real estate experience.',
#  ...]

# %%
job_list_max2_df = pd.DataFrame(list(zip(jobs12, companies12, locations12, summaries12)),
               columns = ['job_title', 'company_name', 'location', 'summary'])
job_list_max2_df
# Out:
#                                               job_title  \
# 0                                 Senior Data Scientist
# 1                      Data Scientist / Biostatistician
# 2                                        Data Scientist
# 3                                        Data Scientist
# 4                                    Sr. Data Scientist
# ...                                                 ...
# 1048             Senior Associate, AI, NLP Data Modeler
# 1049                               Performance Engineer
# 1050                 Data Science Manager (100% Remote)
# 1051  Senior Engineering Manager / Machine Learning ...
# 1052                      Senior Statistical Programmer
#
#                            company_name  \
# 0                                Intuit
# 1                         Blinktbi, Inc
# 2                                 Intel
# 3     Environmental Risk Management Inc
# 4                              Experian
# ...                                 ...
# 1048                               KPMG
# 1049                              Apple
# 1050         National General Insurance
# 1051              Medicalink Recruiters
# 1052                     EPM Scientific
#
#                                          location  \
# 0              Mountain View, CA 94041+1 location
# 1                               California•Remote
# 2                     Folsom, CA 95630+1 location
# 3     Sunnyvale, CA+1 location•Temporarily Remote
# 4                 Costa Mesa, CA 92626+1 location
# ...                                           ...
# 1048        Los Angeles, CA 90071 (Downtown area)
# 1049                 Santa Clara Valley, CA 95014
# 1050                     Ontario, CA 91764•Remote
# 1051            San Francisco Bay Area, CA•Remote
# 1052                                  Alameda, CA
#
#                                                 summary
# 0     Apply data mining, NLP, and machine learning (...
# 1     A minimum of eight (8) years of experience con...
# 2     Uses predictive modeling, statistics, Machine ...
# 3     Responsible for managing and developing the co...
# 4     Holistic and end to end approach to data, incl...
# ...                                                 ...
# 1048  Minimum of three years of experience leading w...
# 1049  In-depth knowledge of tools and techniques for...
# 1050  Champion and project manage data related initi...
# 1051  *You've worked with complex distributed machin...
# 1052  About 7 years of statistical programming exper...
#
# [1053 rows x 4 columns]

# %%
job_list_max2_df.to_csv('job_list_scientist.csv', index=False)
