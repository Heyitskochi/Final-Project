# %%
import requests
import bs4
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import os
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

max_page = 670

jobs11 = []
companies11 = []
locations11 = []
summaries11 = []

for start in range(0, max_page, 10):
    indeed_url = 'http://www.indeed.com/jobs?q=data%20analyst&l=California&start=' + str(start)
    browser.visit(indeed_url)
    time.sleep(5)  
    html = browser.html
    soup = bs(html, "html.parser")
    print(indeed_url)  
    
    #grabbing job title
    #for div in soup.find_all(name='div', attrs={'class':'job_seen_beacon'}):
    for td in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div in td.find_all(name='div', attrs={'class':'heading4 color-text-primary singleLineTitle tapItem-gutter'}):
            for span in div.find_all(name='span'):
                if span.text.strip() != 'new':
                    jobs11.append(span.text.strip())  

    #grabbing company name
    for td2 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div2 in td2.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for span2 in div2.find_all(name='span', attrs={'class':'companyName'}):
                companies11.append(span2.text.strip())      

    #grabbing location
    for td3 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div3 in td3.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for div4 in div3.find_all(name='div'):
                locations11.append(div4.text.strip())   

    #grabbing summary text
    divs = soup.findAll('div', attrs={'class': 'job-snippet'})
    for div5 in divs:
        summaries11.append(div5.text.strip())

browser.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Get LATEST driver version for 92.0.4515
# Trying to download new driver from https://chromedriver.storage.googleapis.com/92.0.4515.107/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\SC\.wdm\drivers\chromedriver\win32\92.0.4515.107]
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=0
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=10
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=20
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=30
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=40
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=50
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=60
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=70
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=80
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=90
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=100
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=110
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=120
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=130
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=140
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=150
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=160
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=170
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=180
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=190
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=200
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=210
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=220
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=230
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=240
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=250
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=260
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=270
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=280
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=290
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=300
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=310
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=320
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=330
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=340
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=350
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=360
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=370
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=380
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=390
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=400
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=410
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=420
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=430
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=440
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=450
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=460
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=470
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=480
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=490
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=500
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=510
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=520
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=530
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=540
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=550
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=560
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=570
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=580
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=590
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=600
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=610
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=620
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=630
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=640
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=650
# http://www.indeed.com/jobs?q=data%20analyst&l=California&start=660

# %%
jobs11
# Out:
# ['Data Analyst - YouTube',
#  'Data Entry Analyst',
#  'Marketing Data Analyst (REMOTE)',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst/Data Engineer',
#  'Consumer Insight Analyst',
#  'Data Analyst (Full Time) United States',
#  'Entry Level Data Analyst',
#  'Entry Level Data Analyst',
#  '118: Sr Marketing Data/Business Analyst',
#  'Entry Level - Data Engineer / Data Analyst (STEM)',
#  'Data Analyst with Tableau',
#  'Data & Reporting Specialist',
#  'Data Analyst I',
#  'Data Analyst with Tableau',
#  'Data & Reporting Specialist',
#  'Data Analyst I',
#  'Research Data Analyst',
#  'Sr. Data Analyst',
#  'Junior Data Analyst',
#  'Jr Data Analyst / Technician',
#  'Data Analyst -Recent Graduate',
#  'Data Analyst',
#  'Data Analyst',
#  'Marketing Data Analyst',
#  'Associate Analyst, Data Analytics',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Data Analyst - Abbott Diabetes Care',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Data Analyst - Abbott Diabetes Care',
#  'Analyst, Data & Reporting',
#  'Senior Data Analyst',
#  'Healthcare Data Analyst',
#  'Consulting Data Analyst',
#  'Global Operations Data Center Analyst',
#  'Data Labeling Analyst',
#  'PROGRAM ANALYST',
#  'Data Modeling Analyst',
#  'YMCA CSS Research & Data Analyst',
#  'Data Analyst',
#  'Research Analyst IV',
#  'Management Analyst',
#  'TikTok LIVE Data Analyst',
#  'IRS Pathways Recent Graduate Program (Management and Program...',
#  'Disney: Data Analyst',
#  'Data Analyst',
#  'Machine Learning Data Associate',
#  'Data Analyst MONGO DB Required',
#  'Data Labeling Analyst',
#  'Sr. Data Analyst',
#  'Data Analyst',
#  'Assistant Data Analyst- COVID 19 Response (Contract)',
#  'Healthcare Data Analyst',
#  'Data Analyst, Operations',
#  'Data Science Analyst II',
#  'Data Analyst',
#  'Senior Data Analyst - Revenue Management',
#  'Management Analyst I/II',
#  'Compliance Data Analyst - Work From Home',
#  'Business/Data/Quality Analyst',
#  'Analyst, Data (Remote)',
#  'Data Labeling Analyst',
#  'PRINCIPAL HUMAN RESOURCES ANALYST (H.E.A.R. OFFICE)',
#  'Data Analyst (Remote) - 20668',
#  'Input Data Analyst',
#  'Data Analyst',
#  'Jr. Data Analyst, ETL',
#  'Data Analyst - Law Enforcement Response Enablement',
#  'Forecasting Analyst',
#  'Data Analyst 3 : 21-04964',
#  'Data Entry Analyst',
#  'Data Analyst',
#  'Junior Analyst',
#  'Data Labeling Analyst',
#  'Data Analyst, Community Operations',
#  'Sr Clinical Data Analyst',
#  'Marketing Specialist - Data Analyst',
#  'Senior Data Analyst',
#  'Business Analyst - Full Time',
#  'Business Analyst I',
#  'Data Analyst',
#  'Staff Analyst, Production Data & Analytics',
#  'Data Analyst',
#  'Business Data Analyst - Not remote office based',
#  'Data Analyst, Product',
#  'Data Analytics Associate',
#  'Data Analyst',
#  'HR Data Analyst',
#  'Data Analyst',
#  'Research Data Analyst 2 (One Year Fixed Term)',
#  'Data Analyst',
#  'Data Analyst',
#  'Student Success Support Analyst',
#  'Data Labeling Analyst',
#  'Management and Program Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst II - Telecommute',
#  'Business Data Analyst - Not remote office based',
#  'Business Analyst',
#  'Data Analyst/Tableau Developer',
#  'Business Analyst: Level 1',
#  'Business Analyst (Full Time) United States',
#  'Associate Performance Analyst (System)',
#  'Data Analyst 3',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Research Analyst',
#  'Business Data Analyst',
#  'Data Management Analyst',
#  'Research Data Analyst',
#  'Business Data Analyst - Not remote office based',
#  'Data and Reporting Specialist – Remote',
#  'DreamWorks Technology - Data Analyst',
#  'Business Intelligence Analyst 4',
#  'Senior Data Analyst (Marketing)',
#  'Business Data Analyst',
#  'Data Labeling Analyst',
#  'Research Data Analyst',
#  'Data Analyst',
#  'Game Data Analyst',
#  'Data Analyst',
#  'Data Conversion Analyst',
#  'Boot Camp/ Junior Data Analyst',
#  'Senior Data Analyst-Marketing',
#  'Data Analyst / Data Scientist - Alteryx',
#  'BI Analyst-SQL ( Power BI)',
#  'Business Data Analyst - Not remote office based',
#  'Entry Level Business Analyst',
#  'Healthcare Data Analyst I',
#  'Data Analyst',
#  'Data Intelligence Analyst',
#  'DEPARTMENTAL ADMINISTRATIVE ANALYST',
#  'Data Analyst / Data Engineer',
#  'Research Data Analyst (6256U) 19103',
#  'CRA Data & Reporting Analyst',
#  'Sr Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Data Analyst - Not remote office based',
#  'Data Consultant',
#  'Data Analyst – Workday Core Applications (HR)',
#  'Data Science Analyst',
#  'Data Analyst',
#  'Analyst, Data & Insights',
#  'Data Analyst',
#  'DATA ANALYST',
#  'Data Analyst',
#  'Data Analyst I',
#  'Data Analyst in SQA',
#  'TikTok LIVE Data Analyst',
#  'Marketing Data Analyst',
#  'Data Analyst',
#  'Data Labeling Analyst',
#  'Data Analyst',
#  'Revenue Cycle Analyst/Healthcare Data Analyst',
#  'Data & Reporting Specialist',
#  'Jr. Data Analyst',
#  'Data Analyst',
#  'Disney: Data Analyst',
#  'RMA Data Analyst',
#  'Sr. Data Analyst',
#  'Data Analyst - Talent Operations',
#  'Data Analyst',
#  'Business Analyst',
#  'Research Data Analyst',
#  'Jr. Data Analyst',
#  'Senior Data Analyst (Marketing)',
#  'Analyst, Data Management',
#  'Data Analyst, People Analytics',
#  'Marketing Data Analyst',
#  'JC- 263724 Research Data Analyst ll',
#  'Entry Level Data Analyst',
#  'Data Analyst',
#  'Marketing Data Analyst',
#  'Data Analyst',
#  'Game Data Analyst',
#  'Data Analyst (Remote) - 20668',
#  'Data Analyst',
#  'IT Jr. Business Analyst',
#  'DATA ANALYST',
#  'Data Labeling Analyst',
#  'Data & Reporting Analyst',
#  'Data Analyst',
#  'Revenue Cycle Analyst/Healthcare Data Analyst',
#  'data analyst',
#  'Data Specialist',
#  'DreamWorks Technology - Data Analyst',
#  'Business Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'AVP, Senior ETL Developer/Data Analyst',
#  'Management Analyst I/II',
#  'Data Analyst',
#  'People Data Analyst',
#  'DEPARTMENTAL ADMINISTRATIVE ANALYST',
#  'Entry Level Business Analyst',
#  'Data Analyst',
#  'Data Analyst - US',
#  'Assistant Staff Analyst, (EHV Assistant Staff Data Analyst),...',
#  'Sr. Data Analyst',
#  'Data Analyst 3',
#  'Business Analyst',
#  'Senior Data Analyst',
#  'Associate Data Analyst (LA or Remote)',
#  'Jr Business Analyst',
#  'SEM Energy Data Analyst',
#  'Data Analyst',
#  'Data Analysts',
#  'Data Analyst – Workday Core Applications (HR)',
#  'Business Analyst I',
#  'Data Analyst 2',
#  'Sr Clinical Data Analyst',
#  'Business Insights Analyst',
#  'Data & Reporting Analyst',
#  'Data Analyst - Call Center Reporting / Excel / SQL',
#  'Data Analyst',
#  'Financial Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Associate Data Analyst (LA or Remote)',
#  'IT Jr. Business Analyst',
#  'Data Analyst',
#  'Data Analyst Norwegian A799',
#  'Enrollment Data Analyst III',
#  'Jr Business Analyst',
#  'Data Analyst',
#  'Senior Data Analyst : 21-04928',
#  'Data Analyst',
#  'Data Analyst - Screening',
#  'Data Analyst, CLIA Services Lab',
#  'Healthcare Data Analyst – Finance',
#  'Marketing Specialist - Data Analyst',
#  'Business Data Analyst',
#  'Research Data Analyst (6256U) 19103',
#  'Quality Data Analyst',
#  'Senior Data Analyst, Workforce Insights',
#  'Data Analyst',
#  'Master Data Analyst II',
#  'Senior Data Analyst',
#  'DATA ANALYST - CRM',
#  'Data Analyst',
#  'Data Analyst',
#  'Research Data Analyst',
#  'Visual Data Analyst - Kaiser Permanente Bernard J. Tyson Sch...',
#  'Data Analyst - Advertising',
#  'Data Analyst, People Analytics',
#  'Senior BI Data Analyst - REMOTE',
#  'Management Analyst I/II',
#  'Molecular Genetics Data Analyst (Seasonal)',
#  'Data Analyst Norwegian A799',
#  'BI Data Analyst',
#  'Data Analyst, Customer Success',
#  'Data Governance Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Cyber Data Analyst, Cortex Xpanse - West Coast',
#  'Data Analyst - Advertising',
#  'Quality Data Analyst',
#  'Data Analyst - Strategic Analytics',
#  'Senior Product Data Analyst',
#  'GTM Data Analyst',
#  'Molecular Genetics Data Analyst (Seasonal)',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Management Analyst',
#  'Data Analyst - Call Center Reporting / Excel / SQL',
#  'Data Analyst, Customer Success',
#  'Data Analyst - Creator',
#  'Healthcare Data Analyst',
#  'Data Analyst (SAS, statistics, SQL, Healthcare)',
#  'Merchant Banking Data Analyst',
#  'Entry Level Business Analyst',
#  'Sr. Data Analyst',
#  'Sr. Data Analyst / Architect',
#  'Senior Data Analyst',
#  'Sr. Data Analyst',
#  'Data Analyst - MS Access / Excel',
#  'Marketing Data Analyst',
#  'Senior Data Analyst , BI & Data Science',
#  'Data Governance Analyst',
#  'Senior / Staff Data Analyst',
#  'Data Analyst',
#  'Data Services Analyst',
#  'Data Labeling Analyst',
#  'Data Analyst, New Products',
#  'Business Analyst (Entry-Level)',
#  'data analyst',
#  'Senior Product Data Analyst',
#  'Senior Data Analyst',
#  'Sr. Data Analyst, Services',
#  'Player Support Analyst',
#  'Data Analyst - Remote',
#  'Senior Data Analyst',
#  'Marketing Analyst',
#  'Business Analyst: Level 1',
#  'Blackbaud Data Analyst',
#  'Clinical Data Analyst',
#  'Business Analyst',
#  'Senior Data Analyst-Marketing',
#  'Data Analyst',
#  'Senior Data Analyst, Travel Insights',
#  'Business Analyst',
#  'Business Analyst I/II',
#  'Senior Data Analyst',
#  'Business Insights Analyst',
#  'Staff Analyst, Production Data & Analytics',
#  'Lead Data Analyst',
#  'Senior Product Data Analyst',
#  'SQL Developer/Data Analyst',
#  'Decision Support Analyst, Full Time, Day Shift, Accountable...',
#  'Tableau Analyst, Junior',
#  'Analytic Application Developer/Data Analyst (All Levels)',
#  'Trust & Safety Analyst - Night Watch',
#  'Data Analyst',
#  'Data Labeling Analyst',
#  'Promo & Content Data Analyst, Peacock On-Product Promotion',
#  'Senior Data Analyst-Marketing',
#  'Data Analyst',
#  'Senior Data Analyst, Travel Insights',
#  'Data and Policy Analyst - Writer/Coordinator',
#  'Data and Policy Analyst - Writer/Coordinator',
#  'Business Data Analyst',
#  'Marketing Data Analyst',
#  'Clinical Data Analyst',
#  'Data Analyst / Senior Data Analyst',
#  'Business Analyst',
#  'Analyst, Data & Lifecycle Marketing Technology',
#  'Data & Reporting Analyst',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'Data Analyst',
#  'Marketing Data Analyst',
#  'Promo & Content Data Analyst, Peacock On-Product Promotion',
#  'Data Analyst - Call Center Reporting / Excel / SQL',
#  'Product Data Analyst',
#  'Senior Data Analyst, Market Research',
#  'Neuroimaging Data Analyst',
#  'Senior Data Analyst',
#  'Logistics Data Analyst',
#  'Data Analyst / Enginner',
#  'Business Analyst (Data & Analytics)',
#  'CRA Data & Reporting Analyst',
#  'Marketing Data Analyst, Lifecycle',
#  'Senior Data Analyst',
#  'Data Analyst - Talent Operations',
#  'BI Data Analyst',
#  'Data & Insights Analyst - Ecommerce',
#  'Data Conversion Analyst',
#  'Analyst I',
#  'ET&A Data Analyst',
#  'Data Analysts',
#  'Product Data Analyst - Remote',
#  'PRINCIPAL HUMAN RESOURCES ANALYST (H.E.A.R. OFFICE)',
#  'Data Analyst, New Products',
#  'Insights Analyst',
#  'Sr. Data Analyst, Services',
#  'Student Services Systems Analyst - Admissions & Records',
#  'Business Analyst, Data Platform Business Operations',
#  'Data Analyst',
#  'Jr Business Analyst',
#  'Data Analyst',
#  'Demand Planning Data Analyst',
#  'Data Analyst – Automotive Analytics & Advisory',
#  'Business Intelligence Analyst',
#  'Data Analyst',
#  'Business Data Analyst',
#  'Network Systems Support Analyst I/II',
#  'LMS Business Analyst',
#  'Data Management Analyst',
#  'Digital Data Analyst',
#  'Senior Data Analyst, Business Analytics',
#  'Data Analyst',
#  'RMA Data Analyst',
#  'Water Quality Analyst I',
#  'Analyst',
#  'Data Analyst - Strategic Analytics',
#  'Creator Operations - Marketplace Operation Business Analyst',
#  'Business Analyst/Associate',
#  'Senior Data Analyst',
#  'Data & Insights Analyst - Ecommerce',
#  'Data Analyst – Automotive Analytics & Advisory',
#  'Product Business Analyst I',
#  'Analyst I/II (Housing Department) - Eviction Help Center',
#  'Technical Business Analyst',
#  'Supply Chain Data Analyst - Infrastructure Data Centers',
#  'Quantitative Analyst',
#  'Business Intelligence Analyst III',
#  'Senior Data Analyst, Product Insights',
#  'IT Business Analyst',
#  'DATA ANALYST - CRM',
#  'Data Analyst',
#  'Business Analyst',
#  'Analyst',
#  'Data Analyst',
#  'Data Analyst – Automotive Analytics & Advisory',
#  'Business Analyst (REMOTE)',
#  'Data Analyst (Ryan White)',
#  'Data Analyst',
#  'METRC Data Analyst',
#  'Data Analyst',
#  'Healthcare Data Analyst',
#  'Marketing Data Analyst',
#  'Data Analyst',
#  'Business Intelligence Analyst',
#  'Senior BI Data Analyst - REMOTE',
#  'Data Quality Analyst',
#  'Business Data Analyst, Remote',
#  'Data Analyst',
#  'Business Analyst',
#  'Analyst',
#  'Business Analyst',
#  'Senior Data Analyst, Strategic Insights',
#  'Business Analyst',
#  'Data Analyst - Strategic Analytics',
#  'Healthcare Data Analyst II - Finance Analytics (Remote Optio...',
#  'Human Resources Data Analyst',
#  'Data Analyst',
#  'Business Analyst',
#  'Investment Analyst / Power Market Analyst',
#  'PROGRAM ANALYST',
#  'Business Analyst (Data & Analytics)',
#  'Analyst I/II (Housing Department) - Eviction Help Center',
#  'Data Analyst, Hearthstone Analytics',
#  'Lead Data Analyst',
#  'Management Analyst',
#  'Data Analyst',
#  'Senior / Staff Data Analyst',
#  'Business Analyst',
#  'Business Analyst (DOM)',
#  'Lead Data Analyst',
#  'Analyst, Research Analytics + Insights',
#  'Location Strategy Data Analyst - FCS',
#  'Data Analyst, CLIA Services Lab',
#  'Business Intelligence Analyst I',
#  'Quality Data Analyst',
#  'Data Conversion Analyst - 32419894',
#  'Principal Data Analyst - Telecommute',
#  'Quality Data Analyst',
#  'DHM Data Analyst',
#  'Data Analyst',
#  'Programmer Analyst I/II',
#  'Sr. Data Analyst / Architect',
#  'Business Intelligence Analyst',
#  'Senior / Staff Data Analyst',
#  'DHM Data Analyst',
#  'Molecular Genetics Data Analyst (Seasonal)',
#  'Analyst, Research Analytics + Insights',
#  'SQL Developer/Data Analyst',
#  'Data Analyst - Operations',
#  'PROGRAM ANALYST',
#  'Data Analyst - Next Generation Sequencing',
#  'Data Analyst (Operations Research Analyst)',
#  'Data Analyst - Venice, CA',
#  'Blackbaud Data Analyst',
#  'Business Analyst',
#  'Senior BI Data Analyst - REMOTE',
#  'HR Data Analyst',
#  'Quantitative Analyst',
#  'Sr. Data Science Analyst',
#  'Growth Analyst',
#  'Data Analyst, US & Canada Analytics & Insights - CommOps',
#  'Business Data Analyst',
#  'Data Analytics Analyst',
#  'Junior Marketing\xa0analyst',
#  'Forecasting Analyst',
#  'Business Data Analyst, Remote',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst 2',
#  'Data Analyst',
#  'Data Analyst',
#  'Business Intelligence Analyst - Data',
#  'JC- 263724 Research Data Analyst ll',
#  'Analyst - Western Region',
#  'Data Analyst – Business Intelligence',
#  'Junior Marketing\xa0analyst',
#  'Data Informatics Analyst - Remote (Anywhere US)',
#  'Senior Product Data Analyst',
#  'Sr. Data Science Analyst',
#  'Sr. Business Analyst',
#  'Business Analyst',
#  'LMS Business Analyst',
#  'Data Analyst and Test Reporting',
#  'Senior Data Analyst/Data Scientist',
#  'Data Analyst - Call Center Reporting / Excel / SQL',
#  'Quality Data Analyst',
#  'Business Analyst',
#  'Metrics and Data Analyst',
#  'Sr. Analyst, Data Management',
#  'Lead Data Analyst',
#  'Sr. Data Analyst',
#  'Info & Data Systems Analyst',
#  'Business Analyst',
#  'Staff Business Intelligence Analyst',
#  'Data Analyst',
#  'Senior Product Data Management Analyst',
#  'Clinical Data Analyst',
#  'Climate Data Analyst',
#  'Business Data Analyst',
#  'Data Operations Analyst — Remote',
#  'Healthcare Data Analyst II - Finance Analytics (Remote Optio...',
#  'Business Analyst',
#  'Business Analyst',
#  'Data Analyst, Design Technology',
#  'Senior Data Analyst, Growth',
#  'Business Analyst',
#  'Sr. Marketing Data Analyst',
#  'IA5 - Data & Impact Analyst - Full Time - 40 Hours/Week - No...',
#  'BI Analyst-SQL ( Power BI)',
#  'Business Analyst (DOM)',
#  'Staff Business Intelligence Analyst',
#  'Data Analyst',
#  'Data Analyst, US & Canada Analytics & Insights - CommOps',
#  'Full-time Senior Management Analyst',
#  'Research Data Analyst',
#  'Data Operations Analyst — Remote',
#  'Data Analyst - 0.8 - Days - Concern: EAP',
#  'Sr. Data Analyst, Marketing',
#  'Senior Data Governance Analyst',
#  'Sr. Data Analyst',
#  'Clinical Data Management Analyst, R&D',
#  'Associate Data Science Analyst',
#  'Business Analyst',
#  'Intermediate Corporate Data Analyst',
#  'Data Quality Analyst',
#  'Business Analyst',
#  'Business Analyst',
#  'Digital Business Analyst (Remote)',
#  'Climate Data Analyst',
#  'Data Insights Analyst',
#  'Healthcare Data Analyst II - Finance Analytics (Remote Optio...',
#  'Data Analyst, US & Canada Analytics & Insights - CommOps',
#  'Intermediate Corporate Data Analyst',
#  'Consulting Data Analyst - Tableau, Python, SAS',
#  'Business Analyst, Order Management - Opportunity for Working...',
#  'Senior Data Analyst, Lending',
#  'Senior Data Analyst, FCRA',
#  'Data Optimization Analyst',
#  'Business Analyst',
#  'Management Analyst',
#  'Data Analyst',
#  'Management and Program Analyst',
#  'Business Analyst/Associate',
#  'Business Intelligence Analyst',
#  'Data Analyst',
#  'Senior Enterprise Data Governance Analyst',
#  'Senior Product Data Analyst',
#  'Business Analyst I',
#  'Senior Data Analyst',
#  'Operations Data Analyst',
#  'Quality Data Analyst',
#  'Senior Data Analyst',
#  'Senior Data Analyst - Product Consumption Analytics',
#  'Business Operations Reporting Analyst',
#  'Data Analyst',
#  'Senior Data Analyst, Customer Success',
#  'Data Labeling Analyst',
#  'Data Analyst - Precision Medicine',
#  'Data Analyst',
#  'Business Analyst',
#  'Risk Business Analyst',
#  'Data Analyst - Precision Medicine',
#  'Pharma Business Analyst / Process Modeler',
#  'Data Analyst',
#  'Data Analyst - SGSS',
#  'Data Analyst',
#  'Data Specialist',
#  'Data Analyst, Collections',
#  'Business Intelligence Analyst',
#  'Business Analyst III',
#  'Payment Data Analyst',
#  'Data Analyst (Growth Marketing)',
#  'Data Analyst (Revenue)',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Data Modeling Analyst Sr.',
#  'Student Services Systems Analyst - Admissions & Records',
#  'Supply Chain Data Analyst, Sacramento',
#  'Learning Data Analyst',
#  'EHS Analyst',
#  'Contract Analyst',
#  'Data Analyst II',
#  'Business Operations Reporting Analyst',
#  'Info & Data Systems Analyst',
#  'Pharma Business Analyst / Process Modeler',
#  'Data Analyst',
#  'Molecular Genetics Data Analyst (Seasonal)',
#  'Senior Data Analyst - Inservice Education',
#  'SQL Developer/Data Analyst',
#  'Program Data Analyst',
#  'Resolution Analyst',
#  'Senior Data Management Analyst',
#  'Payroll Business Analyst',
#  'Business Analyst',
#  'OluKai Data Analytics Specialist',
#  'Business Analyst',
#  'SENIOR Master Data Management(MDM) ANALYST',
#  'BI Analyst-SQL ( Power BI)',
#  'Business Intelligence Analyst',
#  'Market Research Analyst',
#  'Commercial Business Analyst - Remote',
#  'Sr. Associate Data Analyst',
#  'Data Analyst/Report Writer',
#  'Business Intelligence Analyst',
#  'Business Analyst',
#  'Data Analyst (Informatics)',
#  'Business Intelligence Analyst - Custom Support Analytics',
#  'Data Analyst Coordinator - Case Management',
#  'Senior Product Data Management Analyst',
#  'Business Analyst',
#  'Data Analyst (Growth Marketing)',
#  'Healthcare Data Analyst II - Finance Analytics (Remote Optio...',
#  'Associate Data Analyst (temporary)',
#  'Product Analyst',
#  'Senior Enterprise Data Governance Analyst',
#  'Data Analytics Analyst',
#  'Associate Business Analyst',
#  'Employee Relations Analyst I or II',
#  'Data Labeling Analyst',
#  'Analyst I',
#  'Digital Data Analyst',
#  'Trauma Data Associate',
#  'Sr. Business Analyst',
#  'Sr. Business Analyst',
#  'Investment Analyst / Power Market Analyst',
#  'Quality Data Analyst',
#  'Senior Data Analytics Analyst',
#  'Senior Data Analyst',
#  'Technical Business Analyst',
#  'Business Analyst',
#  'SEO Analyst-REMOTE',
#  'Senior Business Intelligence Analyst',
#  'Staff People Data Analyst',
#  'Data Analyst',
#  'Trauma Data Associate',
#  'Data Analyst 1LOD',
#  'Sr Consulting Data Analyst',
#  'Data Analyst',
#  'Data Analyst, WW BPR',
#  'Data Analyst - Next Generation Sequencing',
#  'Sr. Product Analyst',
#  'Business Intelligence Analyst',
#  'Learning Data Analyst',
#  'Data Analyst - SGSS',
#  'Sr. Data Analyst / Architect',
#  'IA5 - Data & Impact Analyst - Full Time - 40 Hours/Week - No...',
#  'Data Analyst',
#  'Senior Data Analyst - HEDIS &Star',
#  'Data Analyst, CLIA Services Lab',
#  'Senior Product Data Management Analyst',
#  'Program Data Analyst',
#  'Senior Data Analyst_Marketing',
#  'Senior Data Analyst_Marketing',
#  'Consulting Data Analyst - Health Research, Statistics',
#  'Sr. Business Intelligence Analyst',
#  'Business Analyst',
#  'eCommerce Senior Data Analyst',
#  'Senior Data Analyst, Lending',
#  'Staff Business Intelligence Analyst',
#  'Research Data Analyst',
#  'Senior Data Analyst , BI & Data Science',
#  'Junior Data Analyst with Work Life Culture',
#  'Finance Data Analyst, Devices and Services',
#  'Data Analyst',
#  'Sr. Data Analyst, Marketing',
#  'IAG Data Management Analyst',
#  'Business Analyst : 21-04489',
#  'IT Business Analyst',
#  'Business Analyst',
#  'Business Analyst III',
#  'Junior Business & Technology Analyst - Data',
#  'Collaborative Network Analyst',
#  'Associate Logistics Data Analyst',
#  'Digital Data Analyst',
#  'Contract Analyst',
#  'Marketplace Strategy & Operations Analyst (Demand) - Remote',
#  'Data and Reporting Specialist – Remote',
#  'Data Analyst, Web Analytics',
#  'Data Analyst',
#  'Product Analyst',
#  'Lead Analyst - Data & Production Support',
#  'Senior Business Analyst',
#  'Marketplace Strategy & Operations Analyst (Demand) - Remote',
#  'Data and Reporting Specialist – Remote',
#  'Digital Data Analyst',
#  'Lead Analyst - Data & Production Support',
#  'Product Analyst',
#  'Senior Business Analyst',
#  'Data Analyst',
#  'Business Analyst I',
#  'Data Analytics Manager - Tiktok Ads',
#  'Associate Data Analyst (temporary)',
#  'Senior Data Analyst - Santa Ana, CA or Minnetonka, MN',
#  'Senior Data Analyst, Risk',
#  'Programmer Analyst (5 month limited appointment)',
#  'Quality Data Analyst',
#  'Analyst, Data (Pharmacy) Remote',
#  'Business Analyst - Nationwide Telecommute',
#  'Data Consultant - Jr. SAS Developer',
#  'Senior Data Modeling Analyst',
#  'Management Analyst II (Human Resources) (20154433)',
#  'Senior Data Analyst',
#  'Lead Data Analyst',
#  'Senior Data Analyst, Marketing',
#  'Senior Data Analyst',
#  'Performance Marketing Analyst',
#  'Senior Data Analyst - Data Governance Tool Analyst, Data Cat...',
#  'Mobile Growth Analyst/Data scientist : 21-04149',
#  'Data and Reporting Specialist – Remote',
#  'Media Analyst',
#  'Research Data Analyst',
#  'Marketing Data Analyst (Credit Union/Banking)',
#  'Junior Business & Technology Analyst - Data',
#  'Data Analyst – Business Intelligence',
#  'Senior Product Data Analyst',
#  'DATA CONTROL ANALYST',
#  'Business Intelligence Analyst',
#  'Business Analyst',
#  'Associate Business Analyst',
#  'Data Analyst',
#  'Sr. Data Analyst',
#  'Digital Data Analyst (Must have previous experience as an SQ...',
#  'Senior Analyst, Data Tech & Operations',
#  'Business Analyst',
#  'Manager, Data Analytics',
#  'Business Intelligence Analyst',
#  'Sr Consulting Data Analyst',
#  'Data Analyst, Risk Operations',
#  'Business Analyst - Temp',
#  'Data Management Services Analyst',
#  'Sr. Data Analyst / Architect',
#  'Analyst, Paid Search',
#  'Data/Business Analyst',
#  'Junior Data Analyst with Work Life Culture',
#  'IT Systems Analyst (Business Intelligence)',
#  'Payment Ops & Risk Data Analyst',
#  'Sr Data Analyst, Media Library',
#  'Business Analyst',
#  'Staff Data Analyst',
#  'Data Analytics Manager, Google Data Center',
#  'Senior Health Data Analyst',
#  'Quantitative Analyst',
#  'Senior Enterprise Data Governance Analyst',
#  'Customer Experience Project/Data Analyst',
#  'Management Analyst-C',
#  'Systems Analyst, FACET Project',
#  'Business Analyst',
#  'Senior Product Data Management Analyst',
#  'Resolution Analyst',
#  'Marketing Data Analyst / Data Scientist',
#  'Data Analyst',
#  'Digital Marketing Analyst',
#  'Program Analyst (Space Operations)',
#  'Sr. Business Analyst',
#  'Data Analyst - Venice, CA',
#  'Business Intelligence Analyst',
#  'Health Data Analyst',
#  'Strategy and Operations Analyst',
#  'Finance Data Analyst, Devices and Services',
#  'Senior Data Analyst (Product)',
#  'Data Analyst (Growth Marketing)',
#  'Data Analyst - Predictive Data Science',
#  'Business Analyst',
#  'Data and Reporting Specialist – Remote',
#  'Sr. Product Analyst',
#  'Data Analyst',
#  'Healthcare Data Analyst',
#  'Business Data Analyst',
#  'Analyst, BI & Analytics',
#  'Procurement Data & Systems Analyst',
#  'Sr Data Analyst, Media Library',
#  'Business Analyst, Marketplace',
#  'Business Analyst',
#  'Senior Health Data Analyst',
#  'Clinical Data Analyst',
#  'Sr. Data Analyst',
#  'Data Analytics Manager, Google Data Center',
#  'Data Analyst',
#  'Program Data Analyst',
#  'Senior Data Analyst, Lending',
#  'Data Analyst (Informatics)',
#  'Senior Data Analyst',
#  'Finance Data Analyst, Devices and Services',
#  'Data/Business Analyst',
#  'Business Intelligence Analyst',
#  'Manager, Data Analytics',
#  'Sr. Business Analyst',
#  'Sr. Operations Data Analyst',
#  'Online Data Science Analyst - Apple Retail Online',
#  'Business/Financial Data Analyst',
#  'Analyst',
#  'Sr Lead Data Analytics Analyst',
#  'SEO Analyst-REMOTE',
#  'User Acquisition Data Analyst',
#  'Technical Business Analyst',
#  'Data Analyst 1LOD',
#  'MDM Analyst',
#  'Data Management Analyst, Platform Operations',
#  'Lead Data Scientist - Analyst',
#  'Digital Data Analyst (Must have previous experience as an SQ...',
#  'Data Analyst, CLIA Services Lab',
#  'Marketing Data Analyst (Credit Union/Banking)',
#  'Senior Data Analyst',
#  'Application Support Analyst 1',
#  'Sr. Survey Data Analyst',
#  'Data Analyst - Health, Senior',
#  'Staff Data Governance Analyst',
#  'Sr Lead Data Analytics Analyst',
#  'Business Analyst',
#  'Workforce Analyst, Mission Control',
#  'Marketing Data Analyst',
#  'Data Analyst/ BI- Reporting Analyst III : 21-05006',
#  'Business Analyst',
#  'Associate Application Support Analyst',
#  'Business Analyst III',
#  'Online Data Science Analyst - Apple Retail Online',
#  'IT Business Analyst',
#  'Program Analyst',
#  'Data Analyst/ BI- Reporting Analyst III : 21-05006',
#  'Application Support Analyst 1',
#  'Associate Application Support Analyst',
#  'Business Intelligence Analyst',
#  'IT Business Analyst',
#  'Business Data Analyst',
#  'Traceability Analyst',
#  'SQL Developer/Data Analyst',
#  'Sr. Data Analyst',
#  'Admissions Processing Analyst',
#  'Business Intelligence Analyst',
#  'Business Analyst II',
#  'Sr. Manager, Data Analytics',
#  'Senior Data Analyst - Success at Scale',
#  'Senior Data Analyst - Telecommute in CA or WA',
#  'Business Analyst',
#  'Administrative Data Analyst (temporary)',
#  'Business Intelligence Analyst',
#  'Senior Product Analyst',
#  'Data Conversion Analyst - 32419894',
#  'Supply Chain Proposal Analyst',
#  'Sr Lead Data Analytics Analyst',
#  'BI Analyst (H)',
#  'Logistics Business Analyst',
#  'Senior Data Analyst',
#  'Student Accounts Analyst',
#  'Senior Data Analyst',
#  'Business Analyst',
#  'Senior Data Analyst, Marketing Operations',
#  'Healthcare Data Analyst I - Quality Systems',
#  'Real-time Payment Fraud Analyst',
#  'Business Operations Analyst',
#  'Analyst Business Intelligence',
#  'FINANCIAL MANAGEMENT ANALYST',
#  'Senior Data Analyst, Sales Operations',
#  'Business Intelligence Analyst',
#  'Business Analyst EBS - Remote-Based',
#  'Business Intelligence Analyst',
#  'Staff Services Analyst I/II',
#  'Sr. ML Data Associate',
#  'Data Analyst',
#  'Data Analyst',
#  'Senior Data Analyst, Lending',
#  'Sales Data Analyst',
#  'Data Analyst III',
#  'Business Intelligence Analyst',
#  'E-Commerce Data Analyst',
#  'Client Data Analyst',
#  'Sales Data Analyst',
#  'Management and Program Analyst (Fire Business)',
#  'People Analyst',
#  'Social Media Data Analyst',
#  'PMO Business Analyst',
#  'Senior Data Analyst - Uber Freight',
#  'Data Analyst',
#  'Sr. Business Data Management Analyst',
#  'Admissions Processing Analyst',
#  'Strategic Insights Leader, West',
#  'Now Learning Business Analyst',
#  'Senior Data Product Analyst',
#  'Sr. Data Analyst - Sales',
#  'Real-time Payment Fraud Analyst',
#  'Student Accounts Analyst',
#  'Data Specialist',
#  'Sr. Data Analyst, Experience Innovation',
#  'Business Intelligence Analyst',
#  'Online Data Science Analyst - Apple Retail Online',
#  'Business Analyst',
#  'Sr. Business Operations Analyst - Transportation',
#  'Clinical Quality Management Data Analyst – Out-Stationed',
#  'Data Labeling Analyst',
#  'Full-time Senior Management Analyst',
#  'Data Analyst (Revenue)',
#  'Community and Economic Recovery Exec Analyst I/II',
#  'Research Data Management Analyst - Kaiser Permanente Bernard...',
#  'Business Analyst, Business Technology Services',
#  'Lead Data Scientist - Analyst',
#  'Quality Data Analytics Analyst',
#  'Data Analyst, Web Analytics',
#  'Data Analyst',
#  'Business Intelligence Analyst',
#  'Growth Analyst',
#  'PMO Business Analyst',
#  'Project Manager/ Business Analyst (IT Specialist I)',
#  'Business Research Analyst',
#  'Loan Boarding Data Analyst',
#  'Data Labeling Analyst',
#  'Business Intelligence Analyst',
#  'Data Specialist',
#  'Data Analyst, Inauthentic Behavior Operations',
#  'Business Analyst',
#  'Business Intelligence Analyst',
#  'Jr. Technical Business Analyst',
#  'Data Analyst Level 2 - 21-02033',
#  'Loan Boarding Data Analyst',
#  'Data Integrity Analyst',
#  'Business Analyst',
#  'Business Analyst - 16354',
#  'Senior Data Analyst',
#  'Associate Business Analyst',
#  'Sr.BI Analyst-remote',
#  'Sr. Business Analyst',
#  'Senior Business Data Analyst - Channel Management',
#  'Strategic Insights Leader, West',
#  'Data Analyst, Inauthentic Behavior Operations',
#  'Senior BI Analyst',
#  'Research Analyst',
#  'Data Analyst / Business Incentives',
#  'Business Data Analyst',
#  'Senior Business Analyst',
#  'HRIS Analyst',
#  'Business Analyst',
#  'Payroll Data Analyst (Temporary Position)',
#  'Business Analyst',
#  'Data Consultant - Jr. SAS Developer',
#  'Digital Marketing Analyst',
#  'Technical Sr Data Analyst',
#  'Quality Data Analyst',
#  'Business Analyst',
#  'Business Intelligence Analyst',
#  'Business Analyst',
#  'Human Resources Data Analyst',
#  'Senior Business Analyst',
#  'Reporting & Analytics Specialist - IM-Data Services',
#  'Business Analyst',
#  'Entry Level Healthcare IT Analyst',
#  'Senior Business Information Data Analyst',
#  'Data Analyst',
#  'Senior Operations Analyst',
#  'Sr. Data Analyst, Experience Innovation',
#  'Business Analyst',
#  'Senior BI Analyst',
#  'Business Intelligence Analyst, Seller Experience - Automatio...',
#  'Data Analyst Level 2 - 21-02033',
#  'Senior IT Business Analyst',
#  'Sr. Data Analyst',
#  'Associate Application Support Analyst',
#  'Senior Data Analyst/Data Scientist',
#  'Business Intelligence Analyst',
#  'Business Intelligence Analyst',
#  'Lead Data Analyst',
#  'Business Analyst',
#  'Clinical Data Analyst - R (Contract)',
#  'Analyst Business Intelligence',
#  'OluKai Data Analytics Specialist',
#  'Data Analyst - MS Access / Excel',
#  'Administrative Data Analyst (temporary)',
#  'Senior Business Information Data Analyst',
#  'Lead Data and Insights Analyst',
#  'Data Analyst – SQL',
#  'Data Analyst - Solutions Architect',
#  'Sr. Business Intelligence Analyst',
#  'Business Analyst',
#  'Entry Level Data Analysts',
#  'Sr. Business Analyst (JO-2107-126404)',
#  'Sr. Business Analyst',
#  'Board Certified Behavior Analyst - Up to $65 Per Hr w/ $1000...',
#  'Business Analyst',
#  'Senior Privacy and Compliance Analyst',
#  'Senior Business Analyst',
#  'Senior Data Informatics Analyst',
#  'Systems Analyst',
#  'Sr. BI Analyst, Operations (Contract-to-Hire) - Entertainmen...',
#  'Public Health Staff Analyst - Finance',
#  'Lead Product Analyst',
#  'Health Information Analyst',
#  'Data Analyst - San Francisco, CA',
#  'Principal Business Analyst',
#  'Business Analyst',
#  'Digital Web Analyst',
#  'Financial Analyst Assistant - Logistics Company']

# %%
companies11
# Out:
# ['Webhelp Americas',
#  'CR&R Incorporated',
#  'Molina Healthcare',
#  'Databricks',
#  'Ursus',
#  'MT Global US INC',
#  'Disney Parks, Experiences and Products',
#  'Cisco Systems',
#  'Insight Global',
#  'FieldLevel',
#  'Dataspace',
#  'PCS Global Tech',
#  'Zensar Technologies',
#  'Pearson',
#  'Tarzana Treatment Centers, Inc',
#  'Zensar Technologies',
#  'Pearson',
#  'Tarzana Treatment Centers, Inc',
#  'Stanford University',
#  'Yellow Jacket Inc',
#  'Capgemini',
#  'Tesla',
#  'Goodman Manufacturing Company',
#  'HG Insights',
#  'Deckers Brands',
#  'Mixbook',
#  'Edwards Lifesciences',
#  'Eisenhower Health',
#  'NCIRE',
#  'Abbott Laboratories',
#  'Eisenhower Health',
#  'NCIRE',
#  'Abbott Laboratories',
#  'Disney Streaming Services',
#  'Square',
#  'Curative Inc.',
#  'Kaiser Permanente',
#  'Salesforce',
#  'Ursus',
#  'US Secretary of the Navy Offices (SECNAV)',
#  'Experian',
#  'YMCA of San Diego County',
#  'Curative Inc.',
#  'County of Orange',
#  'City of Cupertino, CA',
#  'TikTok',
#  'US Internal Revenue Service',
#  'silicon tech solutions',
#  'Shift',
#  'Amazon.com Services LLC',
#  'Braintrust',
#  'Ursus',
#  'Cool Minds LLC',
#  'zb.io',
#  'Brilliant Corners',
#  'American Indian Health & Services',
#  'Trove Recommerce',
#  'Experian',
#  'TikTok',
#  'Public Storage',
#  'City of Redding',
#  'Sutter Health',
#  'Precision technologies',
#  'Molina Healthcare',
#  'Ursus',
#  'Los Angeles County Metropolitan Transportation...',
#  'Splunk',
#  'Beyond Meat',
#  'Ernest Packaging Solutions',
#  'Nuna',
#  'Snapchat',
#  'Google',
#  'Akraya Inc.',
#  'Calbee North America',
#  'Activision',
#  'Golin',
#  'Ursus',
#  'Facebook',
#  'Cedars-Sinai Medical Center',
#  'Sony Electronics Inc',
#  'Hulu',
#  'Therma',
#  'Experian',
#  'Fisher & Phillips LLP',
#  'Walt Disney Animation Studios',
#  'Incredible Health',
#  'FujiSan Franchising Corp',
#  'Trove Recommerce',
#  'Mathematica Policy Research',
#  'LTS',
#  'Niagara Bottling',
#  'Pilot.com',
#  'Stanford University',
#  'ActiveVideo',
#  'Amazon.com Services LLC',
#  'California State University, Long Beach',
#  'Ursus',
#  'US Internal Revenue Service',
#  'Vervent Inc',
#  'Helium 10',
#  'UnitedHealth Group',
#  'FujiSan Franchising Corp',
#  'American Honda Motor Co., Inc.',
#  'BigRentz, Inc.',
#  'BAYEN GROUP',
#  'Cisco Systems',
#  'Adventist Health Roseville',
#  'BD',
#  'FocusKPI Inc.',
#  'San Antonio Regional Hospital',
#  'Rancho Santiago Community College District',
#  'Digital Dhara',
#  'KBR',
#  'University of California San Francisco',
#  'FujiSan Franchising Corp',
#  'Center for Domestic Peace',
#  'NBCUniversal',
#  'Adobe',
#  'Turo',
#  'USC',
#  'Ursus',
#  'University of California Santa Cruz',
#  'Luxoft',
#  'Bytedance',
#  'QuinStreet',
#  'Deloitte',
#  'PCS Global Tech',
#  'Kaiser Permanente',
#  'Adept Consultants',
#  'Triune Infomatics Inc',
#  'FujiSan Franchising Corp',
#  'ALCGlobalSoftware',
#  'ApolloMed',
#  'Opendoor',
#  'Cedars-Sinai',
#  'County of Santa Cruz',
#  'Alphataraxia',
#  'University of California Berkeley',
#  'Silicon Valley Bank',
#  'Capgemini',
#  'Enjoy Technology',
#  'Synergy Companies',
#  'Babylist',
#  'University of California San Francisco',
#  'eHealth',
#  'FujiSan Franchising Corp',
#  'Kaiser Permanente',
#  'Workday',
#  'REVOLVE',
#  'Wiser Solutions',
#  'Volta Charging',
#  'Deckers Brands',
#  'Gaine Technology LLC',
#  'TalentBurst, Inc',
#  'Brain Corp',
#  'Akili Interactive',
#  'TikTok',
#  'Scale Media',
#  'Hagerty Consulting Inc',
#  'Tailored Management',
#  'Engage3',
#  'Curative Inc.',
#  'Pearson',
#  'Health Advocates',
#  'DocuSign',
#  'silicon tech solutions',
#  'Super Micro Computer, Inc.',
#  'Borrego Solar Systems, Inc.',
#  'Veeva Systems',
#  'GSS',
#  'Dew Software',
#  'Stanford University',
#  'Health Advocates',
#  'Turo',
#  'Edwards Lifesciences',
#  'Facebook',
#  'Scale Media',
#  'California Department of Housing and Community...',
#  'Insight Global',
#  '211 San Diego',
#  'Scale Media',
#  'GSS',
#  'Bytedance',
#  'Splunk',
#  'TalentBurst, Inc',
#  'Hollywood Park',
#  'Gaine Technology LLC',
#  'Tailored Management',
#  'Coalition for Responsible Community Development',
#  'Vaco',
#  'Curative Inc.',
#  'Lead5 Media',
#  'California State University',
#  'NBCUniversal',
#  'USC',
#  'Hagerty Consulting Inc',
#  'Ginger',
#  'Fisker Inc',
#  'CIT Group',
#  'City of Redding',
#  'Plume',
#  'Facebook',
#  'County of Santa Cruz',
#  'ALCGlobalSoftware',
#  'TalentBurst, Inc',
#  'MOLOCO',
#  'Heluna Health',
#  'Omaze',
#  'BD',
#  'PG&E Corporation',
#  'MFour Mobile Research, Inc.',
#  'Bridg',
#  'Netpace, Inc.',
#  'CLEAResult',
#  'VGW',
#  'Cotocus',
#  'Workday',
#  'Insight Global',
#  'Natera',
#  'Cedars-Sinai Medical Center',
#  'Adobe',
#  'Coalition for Responsible Community Development',
#  'LIBERTY Dental Plan',
#  'Spectra Infosystems',
#  'Scale Media',
#  'Vervent Inc',
#  'TalentBurst, Inc',
#  'Insight Global',
#  'Facebook',
#  'Bridg',
#  'Hollywood Park',
#  'EasyPay Finance',
#  'Anzu Global',
#  'Anthem',
#  'Netpace, Inc.',
#  'Overair',
#  'Akraya Inc.',
#  'Boot Barn',
#  'AppFolio',
#  'BioNano Genomics',
#  'CVS Health',
#  'Sony Electronics Inc',
#  'Digital Dhara',
#  'University of California Berkeley',
#  'City of Hope',
#  'Steady Platform',
#  'Community Action Partnership of San Luis Obispo',
#  'Surgalign Spine Technologies Inc',
#  'Ginger',
#  'Boardriders',
#  'GSS',
#  'Vaco',
#  'University of California San Francisco',
#  'Kaiser Permanente',
#  'Ursus',
#  'Facebook',
#  'Medable',
#  'City of Redding',
#  'HM.CLAUSE',
#  'Anzu Global',
#  'Credible',
#  'Square',
#  'Tekrek Solutions',
#  'TCS',
#  'Sail Internet',
#  'Palo Alto Networks',
#  'Ursus',
#  'City of Hope',
#  'Twitch',
#  'SimplePractice',
#  'Lattice',
#  'HM.CLAUSE',
#  'Kajabi',
#  'Enterprise Resource Partners',
#  'KBR',
#  'LIBERTY Dental Plan',
#  'Square',
#  'Twitch',
#  'American Indian Health & Services',
#  'Kinetic Personnel Group Inc.',
#  'VS Media',
#  'Agama Solutions',
#  'Gimbal',
#  'QuantumBricks',
#  'First Republic Bank',
#  'Omaze',
#  'Cenergy International',
#  'FocusKPI Inc.',
#  'Twilio',
#  'Tekrek Solutions',
#  'Platform Science',
#  'Hagerty Consulting Inc',
#  'Albertsons Companies',
#  'Tailored Management',
#  'Criteo',
#  'Agama Solutions',
#  'Lead5 Media',
#  'Tubi',
#  'Enquero Inc',
#  'Prealize Health',
#  'Activision',
#  'New Relic',
#  'FocusKPI Inc.',
#  'H&L Partners',
#  'BAYEN GROUP',
#  'Loyola High School',
#  'University of California San Francisco',
#  'Informative Research',
#  'Kaiser Permanente',
#  'Vaco',
#  'Sojern',
#  'FUSE MEDIA',
#  'City of Escondido',
#  'GEP Administrative Services, LLC',
#  'Adobe',
#  'Walt Disney Animation Studios',
#  'UCLA Health',
#  'SimplePractice',
#  'Argen Corporation',
#  'Adventist Health Glendale',
#  'Booz Allen Hamilton',
#  'Workday',
#  'Discord',
#  'ViaSat',
#  'Ursus',
#  'NBCUniversal',
#  'Kaiser Permanente',
#  'Overair',
#  'Sojern',
#  'Acumen LLC',
#  'Acumen LLC',
#  'SESLOC Federal Credit Union',
#  'PUBG Santa Monica',
#  'University of California San Francisco',
#  'Allakos',
#  'California State University',
#  'WarnerMedia',
#  'Coalition for Responsible Community Development',
#  'DocuSign',
#  'Auto Club of Southern California',
#  'FocusKPI Inc.',
#  'NBCUniversal',
#  'LIBERTY Dental Plan',
#  'Cricket Health',
#  'WarnerMedia',
#  'University of California San Francisco',
#  'DISQO',
#  'ICI Services',
#  'QuEST Global Engineering',
#  'USC',
#  'Silicon Valley Bank',
#  'hims & hers',
#  'MediaAlpha',
#  'Veeva Systems',
#  'Credible',
#  'noissue',
#  'Deloitte',
#  'Nan McKay & Associates',
#  'Deloitte',
#  'Zoxima',
#  'Skilljar',
#  'Los Angeles County Metropolitan Transportation...',
#  'Criteo',
#  'Lexer',
#  'Prealize Health',
#  'Cabrillo College',
#  'Visa',
#  'TalentBurst, Inc',
#  'Netpace, Inc.',
#  'Raybeam, Inc.',
#  'Accenture',
#  'J.D. Power',
#  'Live Nation',
#  'Frontapp',
#  'Convex Tech',
#  'Merced County, CA',
#  'GP Strategies Corporation',
#  'Aristotle Capital Management',
#  'Porsche Digital Inc.',
#  'hims & hers',
#  'GOAT',
#  'Super Micro Computer, Inc.',
#  'Golden State Water Company',
#  'Nan McKay',
#  'Twitch',
#  'TikTok',
#  'VentureChoice',
#  'Kareo',
#  'noissue',
#  'J.D. Power',
#  'L.A. Care Health Plan',
#  'City of San Jose',
#  'TCS',
#  'TikTok',
#  'First Republic Bank',
#  'UCLA Health',
#  'Pantheon',
#  'Superior Court of California, County of Imperial',
#  'Boardriders',
#  'First Republic Bank',
#  'Colsh Consultants',
#  'Nan McKay',
#  'Avail Medsystems',
#  'J.D. Power',
#  'BD',
#  'AIDS Healthcare Foundation',
#  'ViaSat',
#  'LA Cannabis Co.',
#  'Aspiration Partners',
#  'Acadia Healthcare',
#  'FocusKPI Inc.',
#  'ONG HUMAN CAPITAL',
#  'Live Nation',
#  'Medable',
#  'Kinect',
#  'Cepheid',
#  'VIZ Media',
#  'Colsh Consultants',
#  'Nan McKay',
#  'Business Talent Group',
#  'Pantheon',
#  'Colsh Consultants',
#  'Twitch',
#  'Inland Empire Health Plans',
#  'Romeo Power',
#  'Info Way Solutions',
#  'Cedars-Sinai',
#  'Alphataraxia',
#  'US Naval Medical Command',
#  'USC',
#  'City of San Jose',
#  'Blizzard Entertainment',
#  'UCLA Health',
#  'City of Cupertino, CA',
#  'EasyPay Finance',
#  'Platform Science',
#  'Transom Consulting',
#  'Universal Music Group',
#  'UCLA Health',
#  'RPA',
#  'Facebook',
#  'BioNano Genomics',
#  'Cerner Corporation',
#  'City of Hope',
#  'Capio Group',
#  'UnitedHealth Group',
#  'ViaSat',
#  'University of California San Francisco',
#  'Overair',
#  'Merced County, CA',
#  'QuantumBricks',
#  'Change Healthcare',
#  'Platform Science',
#  'University of California San Francisco',
#  'HM.CLAUSE',
#  'RPA',
#  'Argen Corporation',
#  'Booster Fuels',
#  'US Naval Medical Command',
#  'Arc Bio',
#  'LAs Totally Awesome',
#  'Sameday Health',
#  'Loyola High School',
#  'Business Talent Group',
#  'Medable',
#  'Axos Bank',
#  'First Republic Bank',
#  'Auto Club of Southern California',
#  'Collective Inc',
#  'Uber',
#  'National Funding',
#  'Bank of the West',
#  'DUOPEAK',
#  'Google',
#  'Cepheid',
#  'Vaco',
#  'Sail Internet',
#  'Natera',
#  'Alten',
#  'GSS',
#  'ConsejoSano',
#  'California Department of Housing and Community...',
#  'Avison Young',
#  'OpenX',
#  'DUOPEAK',
#  'Change Healthcare',
#  'Bill.com',
#  'Auto Club of Southern California',
#  'Netpace, Inc.',
#  'Agama Solutions',
#  'GP Strategies Corporation',
#  'Volt Workforce Solutions',
#  'Synctera',
#  'LIBERTY Dental Plan',
#  'City of Hope',
#  'Fortinet',
#  'IAP Worldwide Services, Inc',
#  'Edwards Lifesciences',
#  'Winc',
#  'Borrego Solar Systems, Inc.',
#  'WarnerMedia',
#  'Inglewood Park Cemetery',
#  'Procore Technologies',
#  'Vaco',
#  'Neato Robotics',
#  'University of California San Francisco',
#  "Moody's Corporation",
#  'Illumina',
#  'Tinuiti - 2',
#  'Inland Empire Health Plans',
#  'Claritas Rx',
#  'Thumbtack',
#  'Tesla',
#  'NorthOne',
#  'Ukund',
#  'Scale Media',
#  'Episcopal Community Services Of San Francisco',
#  'Triune Infomatics Inc',
#  'Universal Music Group',
#  'Procore Technologies',
#  'ViaSat',
#  'Uber',
#  'Rancho Simi Recreation and Park District',
#  'University of California San Francisco',
#  'Tinuiti - 2',
#  'El Camino Health',
#  'Good Eggs',
#  'Capital Group',
#  'Marqeta',
#  'Abbott Laboratories',
#  'LendingClub',
#  'Fisec Gobal',
#  'Health Plan of San Joaquin',
#  '1010data',
#  'Business Talent Group',
#  'TWO NIL',
#  'Palo Alto Networks',
#  "Moody's Corporation",
#  'Saddleback Church',
#  'Inland Empire Health Plans',
#  'Uber',
#  'Health Plan of San Joaquin',
#  'Kaiser Permanente',
#  'VMware',
#  'Varo Money',
#  'WarnerMedia',
#  'Spokeo',
#  'FUSE MEDIA',
#  'City of Cupertino, CA',
#  'TalentBurst, Inc',
#  'US Internal Revenue Service',
#  'VentureChoice',
#  'Carrot Fertility',
#  'ViaSat',
#  'Delta Dental Ins.',
#  'Academia.edu',
#  'San Joaquin General Hospital',
#  'Energy Solutions',
#  'ConsejoSano',
#  'ViaSat',
#  'Tapjoy',
#  'DocuSign',
#  'Stanford Health Care',
#  'Prospect Medical Systems',
#  'Square',
#  'Tailored Management',
#  'City of Hope',
#  'BLITZ APP INC',
#  'Thumbtack',
#  'TikTok',
#  'City of Hope',
#  'Pinnacle Group',
#  'EasyPay Finance',
#  'General Atomics and Affiliated Companies',
#  'Overair',
#  'KANTAR',
#  'Afterpay Touch',
#  'Anaheim Ducks',
#  'Thermo Fisher Scientific',
#  'Albertsons Companies',
#  'thredUP Inc',
#  'Hive Media Group',
#  'UnitedHealth Group',
#  'Experian',
#  'Cabrillo College',
#  'Siemens',
#  'Columbus Technologies',
#  'Cruise',
#  'CALIFORNIA PRISON INDUSTRY AUTHORITY',
#  'JT4',
#  'Stanford Health Care',
#  'WarnerMedia',
#  'Pinnacle Group',
#  'Vaco',
#  'HM.CLAUSE',
#  'Keck Medical Center of USC',
#  'Argen Corporation',
#  'Mathematica Policy Research',
#  'Delta Dental Ins.',
#  'Experian',
#  'PayPal',
#  'Amazon.com Services LLC',
#  'OluKai-Kaenon-melin-Roark',
#  'Fisec Gobal',
#  'Projas Technologies',
#  'Triune Infomatics Inc',
#  'TikTok',
#  'GEP Administrative Services, LLC',
#  'Molecular Devices',
#  'Amgen',
#  'Comprehensive Community Health Centers',
#  'Deliverr Inc',
#  'FGS IT SOLUTIONS',
#  'Heluna Health',
#  'Workday',
#  'Sharp Healthcare',
#  'Neato Robotics',
#  'Ukund',
#  'thredUP Inc',
#  'Inland Empire Health Plans',
#  'Adventist Health Roseville',
#  'Faire',
#  'Delta Dental Ins.',
#  'Bank of the West',
#  'Intermedia.net, Inc.',
#  'City of Anaheim, CA',
#  'Tailored Management',
#  'Nan McKay & Associates',
#  'Auto Club of Southern California',
#  'California Hospital Medical Center',
#  'Netpace, Inc.',
#  'Amazon.com Services LLC',
#  'Alphataraxia',
#  'ViaSat',
#  'SLEEP NUMBER',
#  'CareRev',
#  'Elation Health',
#  'Xerox',
#  'Pearson',
#  'The County of Santa Clara - County-Wide...',
#  'Mozilla',
#  'Vaco',
#  'California Hospital Medical Center',
#  'City National Bank',
#  'Kaiser Permanente',
#  'Fiserv',
#  'Apple',
#  'Arc Bio',
#  'Wag Walking',
#  'UC San Diego',
#  'Columbus Technologies',
#  'General Atomics and Affiliated Companies',
#  'Enquero Inc',
#  'Episcopal Community Services Of San Francisco',
#  'Creative Financial Staffing',
#  'SCAN Group',
#  'BioNano Genomics',
#  'Neato Robotics',
#  'Mathematica Policy Research',
#  'WarnerMedia',
#  'WarnerMedia',
#  'Kaiser Permanente',
#  'Silk Road Medical Inc',
#  'STAT Revenue',
#  'Callisto Media',
#  'Varo Money',
#  'Procore Technologies',
#  'Heluna Health',
#  'Twilio',
#  'Recruiting for Good',
#  'Google',
#  'Vaco',
#  'Good Eggs',
#  'BlackRock',
#  'Akraya Inc.',
#  'Superior Court of California, County of Imperial',
#  'Thumbtack',
#  'Thermo Fisher Scientific',
#  'Axos Bank',
#  'California State University',
#  'Flock Freight',
#  'Auto Club of Southern California',
#  'CALIFORNIA PRISON INDUSTRY AUTHORITY',
#  'Getaround',
#  'Center for Domestic Peace',
#  'Razorfish',
#  'Vaco',
#  'Faire',
#  'HCL Technologies',
#  'Angi',
#  'Getaround',
#  'Center for Domestic Peace',
#  'Auto Club of Southern California',
#  'HCL Technologies',
#  'Faire',
#  'Angi',
#  'Creative Financial Staffing',
#  'San Joaquin General Hospital',
#  'TikTok',
#  'Adventist Health Roseville',
#  'UnitedHealth Group',
#  'Circle',
#  'UCLA Health',
#  'VACCO Industries',
#  'Molina Healthcare',
#  'UnitedHealth Group',
#  'Luxoft',
#  'Experian',
#  'MROSD',
#  'Zuora',
#  'LeanTaaS',
#  'Ethos',
#  'Rockstar Games',
#  'Iron Horse',
#  'Capgemini',
#  'Akraya Inc.',
#  'Center for Domestic Peace',
#  'H&L Partners',
#  'Heluna Health',
#  'Farmers Insurance Group',
#  'Axos Bank',
#  'OpenX',
#  'Bill.com',
#  'Simplex Construction Management, Inc. (Simplex)',
#  'National Education Partners',
#  'SeaWorld San Diego',
#  'Intermedia.net, Inc.',
#  "O'Neill Vintners & Distillers",
#  'MNTN',
#  'Luth Research',
#  'Sony Pictures Entertainment, Inc.',
#  'Ukund',
#  'Universal Music Group',
#  'Deliverr Inc',
#  'Kaiser Permanente',
#  'Facebook',
#  'Blizzard Entertainment',
#  'University of California Santa Cruz',
#  'Enquero Inc',
#  'RPA',
#  'WestEd',
#  'Recruiting for Good',
#  'California Department of Managed Health Care',
#  'Fast AF',
#  'Disney Media & Entertainment Distribution',
#  'Claritas Rx',
#  'ServiceNow',
#  'Google',
#  'Nuna',
#  'RAND Corporation',
#  'Delta Dental Ins.',
#  'Western Digital',
#  'Butte County, CA',
#  'UCLA',
#  'Specright Inc.',
#  'Neato Robotics',
#  'Delta Dental Ins.',
#  'Intercom',
#  'Vaco',
#  'Monster Energy',
#  'US Headquarters, Air Force Space Command',
#  'Envision',
#  'Sameday Health',
#  'NEXT Trucking',
#  'Bay Area Community Health',
#  'Veo',
#  'Google',
#  'Hinge Health',
#  'thredUP Inc',
#  'KKCS',
#  'Thumbtack',
#  'Center for Domestic Peace',
#  'Wag Walking',
#  'TalentBurst, Inc',
#  'West Health',
#  'Illumina',
#  'JLL',
#  'Scripps Research',
#  'Disney Media & Entertainment Distribution',
#  'TaskRabbit',
#  'Inglewood Park Cemetery',
#  'Nuna',
#  'ZOLL LifeVest',
#  'MNTN',
#  'Google',
#  'GroupM Services',
#  'Mathematica Policy Research',
#  'Varo Money',
#  'Heluna Health',
#  'Stance',
#  'Google',
#  'WestEd',
#  'UC San Diego',
#  'Universal Music Group',
#  'Mulligan Funding, LLC',
#  'Cepheid',
#  'Apple',
#  'USC',
#  'Nan McKay',
#  'Bank of the West',
#  'Pearson',
#  'VS Media',
#  'Elation Health',
#  'City National Bank',
#  'DocuSign',
#  'Deluxe Entertainment Services Group',
#  'Sony Corporation of America',
#  'Luth Research',
#  'BioNano Genomics',
#  'Farmers Insurance Group',
#  'Fashion Nova - Careers',
#  'BlackLine',
#  'Change Research',
#  'Blue Shield of California',
#  'ServiceNow',
#  'Bank of the West',
#  'Happiest Baby, Inc.',
#  'Facebook',
#  'Viant',
#  'Akraya Inc.',
#  'Fisec Gobal',
#  'BlackLine',
#  'Thermo Fisher Scientific',
#  'Apple',
#  'Delicato Family Wines',
#  'U.S. Army Corps of Engineers',
#  'Akraya Inc.',
#  'BlackLine',
#  'BlackLine',
#  'Wing',
#  'Delicato Family Wines',
#  'Illumina',
#  'Chipotle',
#  'Argen Corporation',
#  'MATRIX Resources',
#  'California State University, Monterey Bay',
#  'Virgin Orbit',
#  'Virgin Hyperloop',
#  'Internet Brands',
#  'DocuSign',
#  'UnitedHealth Group',
#  'FUSE MEDIA',
#  'Fruit Growers Supply',
#  'UC San Diego',
#  'hims & hers',
#  'Capio Group',
#  'Raytheon Intelligence & Space',
#  'Bank of the West',
#  'Avispa Technology',
#  'Lucid Motors',
#  'Tapjoy',
#  'California State University, Monterey Bay',
#  'Energy Solutions',
#  'Fisec Gobal',
#  'Compass',
#  'Inland Empire Health Plans',
#  'First Republic Bank',
#  'Stanford Federal Credit Union',
#  'Southern Glazer’s Wine and Spirits',
#  'US Naval Medical Command',
#  'Quantcast',
#  'Analog Devices',
#  'USDM Life Sciences',
#  'The Trade Desk',
#  'County of Siskiyou',
#  'Amazon.com Services LLC',
#  'Boot Barn',
#  'Creative Financial Staffing',
#  'Varo Money',
#  'Trek Bikes',
#  'Bio-Rad Laboratories, Inc.',
#  'Wing',
#  'Lakeshore Learning Materials',
#  'Kinta AI',
#  'Trek Bikes',
#  'US Bureau of Land Management',
#  'Enjoy Technology',
#  'First Media',
#  'Pomona College',
#  'Uber',
#  'Creative Financial Staffing',
#  'Varo Money',
#  'California State University, Monterey Bay',
#  'GE Healthcare',
#  'ServiceNow',
#  'Capital Group',
#  'Egnyte',
#  'First Republic Bank',
#  'California State University, Monterey Bay',
#  'California State University',
#  'Genesys',
#  'Recruiter.com',
#  'Apple',
#  'Agama Solutions',
#  'Tesla',
#  'The San Diego LGBT Community Center',
#  'Tailored Management',
#  'Rancho Simi Recreation and Park District',
#  'Hive Media Group',
#  'City of San Jose',
#  'Kaiser Permanente',
#  'Stanford University',
#  'Sony Corporation of America',
#  'Eisenhower Health',
#  'Razorfish',
#  'Sounding Board Inc',
#  'Internet Brands',
#  'Collective Inc',
#  'Pomona College',
#  'CalRecycle',
#  'ProcurementIQ',
#  'loanDepot',
#  'Tailored Management',
#  'Port of San Diego',
#  'Good Samaritan Hospital',
#  'Facebook',
#  'Happiest Baby, Inc.',
#  'Internet Brands',
#  'Deloitte',
#  'Evergreen Technologies, LLC.',
#  'loanDepot',
#  'Sage Intacct',
#  'Joybird',
#  'Infinite Computing Systems',
#  'Electronic Arts',
#  'Intermedia.net, Inc.',
#  'Kairos Technologies',
#  'Netpace, Inc.',
#  'SquareTrade',
#  'GE Healthcare',
#  'Facebook',
#  'Internet Brands',
#  'John Burns Real Estate Consulting LLC',
#  'CTI III LLC',
#  'PUBG Santa Monica',
#  'Empower Retirement',
#  'General Atomics and Affiliated Companies',
#  'Ukund',
#  'Foster Farms',
#  'Swinsoft',
#  'Luxoft',
#  'Monster Energy',
#  'Ursus',
#  'Katalyst Healthcares & Life Sciences',
#  'Lamps Plus',
#  'Port of San Diego',
#  'Vallarta Supermarkets',
#  'Romeo Power',
#  'Empower Retirement',
#  "Rady Children's Hospital-San Diego",
#  'Magellan Health',
#  'Optimum Healthcare IT',
#  'Capital Group',
#  'Insight Global',
#  'HomeLight',
#  'Genesys',
#  'Photon',
#  'Internet Brands',
#  'Square',
#  'Evergreen Technologies, LLC.',
#  'Vivo',
#  'Loyola Marymount University',
#  'BlackLine',
#  'Synctera',
#  'UC San Diego',
#  'HERBL',
#  'Marqeta',
#  'SAS Retail Services',
#  'GRAIL, Inc.',
#  'Southern Glazer’s Wine and Spirits',
#  'OluKai-Kaenon-melin-Roark',
#  'Cenergy International',
#  'Fruit Growers Supply',
#  'Capital Group',
#  'Goodway Group',
#  'Vista Community Clinic',
#  'Ursus',
#  'Guardian Life Insurance Company',
#  'Ursus',
#  'Volt Workforce Solutions',
#  'Ledgent Technology',
#  'Insight Global',
#  'Guiding Behavior Outcomes',
#  'Los Angeles Homeless Services Authority',
#  'Epson America, Inc',
#  'San Diego County Credit Union',
#  'Robert Half',
#  'DataStaff, Inc.',
#  'Harnham',
#  'Healthcare Staffing Professionals, Inc.',
#  'Harnham',
#  'WellSpace Health',
#  'Kelly',
#  'Majesco- Insurance/Software',
#  'APR Consulting Inc',
#  'Ursus',
#  'Wollborg Michelson Recruiting']

# %%
locations11
# Out:
# ['San Bruno, CA•Temporarily Remote',
#  'Stanton, CA',
#  'Long Beach, CA 90802•Remote',
#  'California+1 location•Remote',
#  'Sunnyvale, CA 94089',
#  'Foster City, CA 94404',
#  'Anaheim, CA',
#  'San Jose, CA',
#  'Carlsbad, CA 92008',
#  'California•Remote',
#  'Santa Clara, CA•Temporarily Remote',
#  'Poway, CA•Temporarily Remote',
#  'San Jose, CA 95131 (North San Jose area)•Remote',
#  'Sacramento, CA',
#  'Los Angeles, CA 91367+1 location',
#  'San Jose, CA 95131 (North San Jose area)•Remote',
#  'Sacramento, CA',
#  'Los Angeles, CA 91367+1 location',
#  'Stanford, CA',
#  'Menlo Park, CA•Temporarily Remote',
#  'Burbank, CA+1 location',
#  'Fremont, CA',
#  'Irvine, CA 92614 (Business District area)',
#  'California•Remote',
#  'Goleta, CA 93117',
#  'Redwood City, CA 94063',
#  'Irvine, CA',
#  'Rancho Mirage, CA 92270',
#  'San Francisco, CA',
#  'Alameda, CA',
#  'Rancho Mirage, CA 92270',
#  'San Francisco, CA',
#  'Alameda, CA',
#  'Burbank, CA',
#  'San Francisco, CA',
#  'San Dimas, CA 91773',
#  'Santa Clara, CA+2 locations',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Menlo Park, CA 94025',
#  'Marine Corps Air Station Miramar, CA•Remote',
#  'Costa Mesa, CA 92626',
#  'San Diego, CA',
#  'San Dimas, CA 91773',
#  'Santa Ana, CA',
#  'Cupertino, CA (South Blaney area)',
#  'Los Angeles, CA',
#  'Oakland, CA•Temporarily Remote',
#  'Los Angeles, CA',
#  'California•Remote',
#  'Santa Barbara, CA',
#  'San Francisco, CA 94147 (Marina area)•Remote',
#  'Menlo Park, CA 94025',
#  'Milpitas, CA 95035•Temporarily Remote',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA 90014 (Downtown area)•Temporarily Remote',
#  'Santa Barbara, CA 93110',
#  'Brisbane, CA',
#  'Costa Mesa, CA 92626',
#  'Los Angeles, CA+1 location',
#  'Glendale, CA',
#  'Redding, CA',
#  'Sacramento, CA•Remote',
#  'California City, CA•Temporarily Remote',
#  'Long Beach, CA 90802•Remote',
#  'Menlo Park, CA 94025',
#  'Los Angeles County, CA',
#  'San Jose, CA 95131 (North Valley area)+2 locations•Remote',
#  'El Segundo, CA',
#  'Commerce, CA 90040',
#  'California•Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Mountain View, CA',
#  'San Jose, CA 95110 (Downtown area)',
#  'Madera, CA•Remote',
#  'Santa Monica, CA',
#  'California•Remote',
#  'Menlo Park, CA 94025',
#  'Sunnyvale, CA 94089 (Lakewood area)+1 location',
#  'Los Angeles, CA 90048',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'Santa Monica, CA',
#  'San Francisco, CA',
#  'Costa Mesa, CA 92626',
#  'Irvine, CA 92614 (Business District area)',
#  'Burbank, CA',
#  'California•Remote',
#  'Santa Fe Springs, CA 90670',
#  'California•Remote',
#  'Oakland, CA 94612 (Downtown area)',
#  'Newark, CA 94560',
#  'Diamond Bar, CA 91765',
#  'San Francisco, CA•Remote',
#  'Stanford, CA',
#  'San Jose, CA 95110 (Downtown area)',
#  'Beaumont, CA',
#  'Long Beach, CA 90840 (State College Area area)',
#  'Menlo Park, CA 94025',
#  'Fresno, CA',
#  'San Diego, CA 92121',
#  'California•Remote',
#  'Irvine, CA 92603•Remote',
#  'Santa Fe Springs, CA 90670',
#  'Chino, CA 91710',
#  'Irvine, CA 92614 (Business District area)',
#  'Torrance, CA 90502',
#  'San Jose, CA',
#  'Roseville, CA',
#  'San Diego, CA 92130 (Carmel Valley area)',
#  'San Francisco Bay Area, CA',
#  'Upland, CA 91786',
#  'Santa Ana, CA 92706',
#  'Santa Clara, CA•Temporarily Remote',
#  'China Lake, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)+2 locations',
#  'Santa Fe Springs, CA 90670',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'Glendale, CA',
#  'San Jose, CA+1 location',
#  'San Francisco, CA (Mission Terrace area)',
#  'Los Angeles, CA',
#  'Menlo Park, CA 94025',
#  'Santa Clara, CA 95054',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Foster City, CA 94404•Temporarily Remote',
#  'Sacramento, CA 95814 (Downtown area)+2 locations',
#  'Poway, CA 92064',
#  'Oakland, CA•Remote',
#  'Irvine, CA 92602•Temporarily Remote',
#  'Oakland, CA',
#  'Santa Fe Springs, CA 90670',
#  'Los Angeles, CA 90067 (Century City area)•Temporarily Remote',
#  'Alhambra, CA•Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'Los Angeles, CA',
#  'Santa Cruz County, CA',
#  'Newport Beach, CA',
#  'Berkeley, CA 94720',
#  'San Francisco, CA',
#  'Universal City, CA',
#  'California•Remote',
#  'Perris, CA 92571',
#  'Oakland, CA+1 location•Remote',
#  'Richmond, CA+1 location',
#  'Santa Clara, CA',
#  'Santa Fe Springs, CA 90670',
#  'Pasadena, CA+5 locations',
#  'Pleasanton, CA',
#  'Cerritos, CA 90703',
#  'San Mateo, CA 94402 (Beresford area)',
#  'San Francisco, CA',
#  'Goleta, CA 93117',
#  'San Luis Obispo, CA 93401',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'San Diego, CA',
#  'Larkspur, CA',
#  'Los Angeles, CA',
#  'Sherman Oaks, CA 91423',
#  'San Diego, CA 92174',
#  'Mountain View, CA 94041',
#  'Davis, CA',
#  'San Dimas, CA 91773',
#  'Sacramento, CA',
#  'Chatsworth, CA 91311',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Los Angeles, CA',
#  'San Jose, CA 95131 (North Valley area)',
#  'Oakland, CA 94612',
#  'Pleasanton, CA 94588•Remote',
#  'Orange, CA',
#  'Fremont, CA•Temporarily Remote',
#  'Stanford, CA',
#  'Chatsworth, CA 91311',
#  'San Francisco, CA (Mission Terrace area)',
#  'Irvine, CA',
#  'Fremont, CA 94555 (Northgate area)+2 locations',
#  'Sherman Oaks, CA 91423',
#  'Sacramento, CA 95833 (Natomas Corporate Center area)',
#  'Carlsbad, CA 92008',
#  'San Diego, CA 92123',
#  'Sherman Oaks, CA 91423',
#  'Orange, CA',
#  'Los Angeles, CA',
#  'San Jose, CA 95131 (North Valley area)+2 locations•Remote',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'Inglewood, CA',
#  'San Luis Obispo, CA 93401',
#  'Mountain View, CA 94041',
#  'Los Angeles, CA 90011 (Central City area)',
#  'Los Angeles, CA',
#  'San Dimas, CA 91773',
#  'Newark, CA',
#  'San Jose, CA',
#  'Glendale, CA',
#  'Los Angeles, CA',
#  'San Diego, CA 92174',
#  'San Francisco, CA',
#  'Manhattan Beach, CA 90266',
#  'Pasadena, CA 91103 (West Central area)',
#  'Redding, CA',
#  'Palo Alto, CA 94306 (Evergreen Park area)',
#  'Menlo Park, CA 94025+1 location',
#  'Santa Cruz County, CA',
#  'Los Angeles, CA 90067 (Century City area)•Temporarily Remote',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'Redwood City, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'San Diego, CA 92130 (Carmel Valley area)',
#  'Antioch, CA 94509',
#  'Irvine, CA 92612',
#  'Los Angeles, CA 90064 (Sawtelle area)•Remote',
#  'Foster City, CA 94404',
#  'Oakland, CA',
#  'San Francisco, CA',
#  'Sacramento, CA 95822 (Airport area)',
#  'Pleasanton, CA',
#  'San Ramon, CA 94583',
#  'San Carlos, CA 94070',
#  'Los Angeles, CA 90048',
#  'San Jose, CA',
#  'Los Angeles, CA 90011 (Central City area)',
#  'California',
#  'San Francisco, CA (Financial District area)',
#  'Sherman Oaks, CA 91403',
#  'San Diego, CA 92121',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'San Francisco, CA',
#  'Sunnyvale, CA 94089 (Lakewood area)+3 locations',
#  'Los Angeles, CA 90064 (Sawtelle area)•Remote',
#  'Inglewood, CA',
#  'Vista, CA',
#  'Cupertino, CA',
#  'Woodland Hills, CA 91367',
#  'Foster City, CA 94404',
#  'Santa Ana, CA',
#  'Foster City, CA 94404',
#  'Irvine, CA 92618 (Irvine Health and Science Complex area)',
#  'Santa Barbara, CA 93117',
#  'San Diego, CA 92121',
#  'Woodland Hills, CA•Remote',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'Santa Clara, CA•Temporarily Remote',
#  'Berkeley, CA 94720',
#  'Duarte, CA 91010',
#  'Playa Vista, CA•Remote',
#  'San Luis Obispo, CA 93401',
#  'San Diego, CA 92131•Remote',
#  'San Francisco, CA',
#  'Huntington Beach, CA',
#  'Orange, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)+2 locations',
#  'Pasadena, CA',
#  'Los Angeles, CA 90066',
#  'Fremont, CA 94555 (Northgate area)+2 locations',
#  'Palo Alto, CA•Remote',
#  'Redding, CA',
#  'Davis, CA',
#  'Cupertino, CA',
#  'San Francisco, CA 94102 (Van Ness - Civic Center area)',
#  'San Francisco, CA',
#  'Santa Clara, CA•Remote',
#  'Beverly Hills, CA•Temporarily Remote',
#  'Palo Alto, CA 94301 (Professorville area)•Remote',
#  'Santa Clara, CA',
#  'Los Angeles, CA 90066',
#  'Duarte, CA 91010',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Francisco, CA 94104 (Financial District area)',
#  'Davis, CA',
#  'California•Remote',
#  'El Dorado Hills, CA',
#  'China Lake, CA',
#  'California',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Santa Barbara, CA 93117',
#  'Ontario, CA 91761•Temporarily Remote',
#  'Westlake Village, CA 91361',
#  'Fremont, CA 94538 (Downtown area)',
#  'Los Angeles, CA',
#  'Milpitas, CA•Temporarily Remote',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA',
#  'Rosemead, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'California•Remote',
#  'Santa Clara, CA•Remote',
#  'California•Remote',
#  'San Diego, CA 92174',
#  'Pleasanton, CA 94588',
#  'Mountain View, CA 94041',
#  'Los Angeles, CA',
#  'Sunnyvale, CA',
#  'Newark, CA',
#  'California•Remote',
#  'Milpitas, CA 95035•Remote',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'El Segundo, CA',
#  'San Francisco, CA 94105 (South Beach area)•Remote',
#  'San Francisco Bay Area, CA',
#  'Oakland, CA',
#  'Torrance, CA 90502',
#  'Los Angeles, CA 90006 (Harvard Heights area)',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Irvine, CA 92612 (Business District area)•Remote',
#  'Oakland, CA•Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Glendale, CA 91203 (City Center area)•Temporarily Remote',
#  'Escondido, CA 92025',
#  'Burbank, CA 91504',
#  'San Jose, CA',
#  'Burbank, CA',
#  'Los Angeles, CA 90095•Temporarily Remote',
#  'California•Remote',
#  'San Diego, CA 92126',
#  'Glendale, CA',
#  'Port Hueneme, CA',
#  'Pleasanton, CA',
#  'San Francisco, CA',
#  'Carlsbad, CA',
#  'Menlo Park, CA 94025',
#  'Los Angeles, CA',
#  'Oakland, CA•Remote',
#  'Santa Ana, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA 90064 (Sawtelle area)+1 location',
#  'Los Angeles, CA 90064 (Sawtelle area)+1 location',
#  'San Luis Obispo, CA 93401',
#  'Santa Monica, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Redwood City, CA',
#  'Fresno, CA 93740 (Hoover area)',
#  'Culver City, CA',
#  'Los Angeles, CA 90011 (Central City area)',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Costa Mesa, CA 92626',
#  'San Francisco Bay Area, CA•Remote',
#  'Los Angeles, CA',
#  'California',
#  'San Francisco, CA•Remote',
#  'Burbank, CA 91505',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Glendale, CA',
#  'Port Hueneme, CA',
#  'Sunnyvale, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Pleasanton, CA 94588•Remote',
#  'San Francisco, CA 94102 (Van Ness - Civic Center area)',
#  'Los Angeles, CA 90012',
#  'Los Angeles, CA 90013 (Downtown area)+2 locations',
#  'San Francisco, CA 94124 (Bayview area)',
#  'San Jose, CA 95113 (Downtown area)+3 locations',
#  'Fremont, CA',
#  'California',
#  'Los Angeles County, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Palo Alto, CA 94301 (Professorville area)',
#  'Aptos, CA 95003+1 location',
#  'Palo Alto, CA (Evergreen Park area)',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'Foster City, CA 94404',
#  'Mountain View, CA 94041•Temporarily Remote',
#  'San Jose, CA 95113 (Downtown area)',
#  'California•Remote',
#  'Hollywood, CA 90028',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Merced, CA 95340',
#  'California',
#  'Los Angeles, CA 90025 (West Los Angeles area)',
#  'Palo Alto, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'San Jose, CA 95131 (North Valley area)',
#  'Gardena, CA',
#  'San Francisco, CA 94124 (Bayview area)',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Palo Alto, CA',
#  'Irvine, CA 92612',
#  'Los Angeles, CA 90012',
#  'California•Remote',
#  'Los Angeles, CA 90017 (Westlake area)',
#  'San Jose, CA',
#  'Costa Mesa, CA 92626',
#  'Mountain View, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Los Angeles, CA 90095',
#  'California•Remote',
#  'El Centro, CA 92243',
#  'Huntington Beach, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Santa Clara, CA',
#  'San Francisco, CA 94124 (Bayview area)',
#  'California•Remote',
#  'California•Remote',
#  'San Diego, CA 92130 (Carmel Valley area)•Remote',
#  'Los Angeles, CA 90028 (Hollywood area)',
#  'Carlsbad, CA',
#  'Los Angeles, CA 90047 (South Los Angeles area)',
#  'Los Angeles, CA•Remote',
#  'Los Angeles, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'San Gabriel Valley, CA',
#  'Hollywood, CA 90028',
#  'Palo Alto, CA•Remote',
#  'Santa Monica, CA',
#  'Denver, CO 80012•Remote',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'Santa Clara, CA',
#  'San Francisco, CA 94124 (Bayview area)',
#  'Los Angeles, CA 90064 (West Los Angeles area)•Remote',
#  'California•Remote',
#  'Santa Clara, CA',
#  'San Francisco, CA',
#  'Rancho Cucamonga, CA•Remote',
#  'Los Angeles, CA',
#  'Santa Clara, CA 95054•Temporarily Remote',
#  'Los Angeles, CA',
#  'Newport Beach, CA•Remote',
#  'Naval Medical Center San Diego, CA•Remote',
#  'Los Angeles, CA',
#  'San Jose, CA',
#  'Irvine, CA 92618•Temporarily Remote',
#  'Los Angeles, CA 90095•Temporarily Remote',
#  'Cupertino, CA (South Blaney area)',
#  'Vista, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'Los Angeles, CA 90095•Temporarily Remote',
#  'Santa Monica, CA•Remote',
#  'Menlo Park, CA 94025',
#  'San Diego, CA 92121',
#  'Roseville, CA',
#  'Duarte, CA 91010',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'Santa Ana, CA 92702•Remote',
#  'Carlsbad, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Santa Ana, CA',
#  'Merced, CA 95340',
#  'Milpitas, CA•Temporarily Remote',
#  'California',
#  'California•Remote',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Davis, CA',
#  'Santa Monica, CA•Remote',
#  'San Diego, CA 92126',
#  'San Mateo, CA',
#  'Naval Medical Center San Diego, CA•Remote',
#  'Scotts Valley, CA',
#  'Buena Park, CA 90620',
#  'Venice, CA',
#  'Los Angeles, CA 90006 (Harvard Heights area)',
#  'Los Angeles, CA 90064 (West Los Angeles area)•Remote',
#  'Palo Alto, CA•Remote',
#  'San Diego, CA 92122 (University City area)',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Costa Mesa, CA 92626',
#  'California•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Diego, CA 92121 (University City area)',
#  'San Ramon, CA',
#  'Menlo Park, CA',
#  'Mountain View, CA',
#  'Denver, CO 80012•Remote',
#  'Los Angeles, CA',
#  'Palo Alto, CA 94301 (Professorville area)•Remote',
#  'San Carlos, CA 94070',
#  'San Francisco, CA 94134 (Portola area)',
#  'Orange, CA',
#  'Los Angeles, CA•Remote',
#  'Sacramento, CA 95833 (Natomas Corporate Center area)',
#  'San Francisco, CA 94104 (Financial District area)',
#  'Los Angeles, CA',
#  'Menlo Park, CA',
#  'California•Remote',
#  'San Jose, CA',
#  'Costa Mesa, CA 92626',
#  'Foster City, CA 94404+1 location',
#  'Sacramento, CA+3 locations•Remote',
#  'California',
#  'Irvine, CA',
#  'California•Remote',
#  'California',
#  'Duarte, CA 91010',
#  'Sunnyvale, CA 94086 (East Murphy area)',
#  'San Diego, CA',
#  'Irvine, CA',
#  'Los Angeles, CA 90066 (Del Rey area)',
#  'Oakland, CA 94612',
#  'Burbank, CA 91505',
#  'Inglewood, CA 90301',
#  'California•Remote',
#  'Los Angeles, CA',
#  'San Jose, CA',
#  'San Francisco, CA 94143 (Haight-Ashbury area)',
#  'Berkeley, CA',
#  'San Diego, CA',
#  'California•Remote',
#  'Rancho Cucamonga, CA•Remote',
#  'California•Remote',
#  'California•Remote',
#  'Palo Alto, CA',
#  'San Francisco, CA',
#  'Sacramento, CA•Temporarily Remote',
#  'Los Angeles, CA 90048 (Mid City West area)',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Oakland, CA',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'California•Remote',
#  'Carlsbad, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Simi Valley, CA 93063',
#  'San Francisco, CA 94143 (Haight-Ashbury area)+2 locations',
#  'California•Remote',
#  'Mountain View, CA 94040 (Old Mountain View area)',
#  'San Francisco Bay Area, CA•Remote',
#  'Los Angeles, CA 90071•Temporarily Remote',
#  'Oakland, CA',
#  'Alameda, CA',
#  'San Francisco, CA',
#  'San Leandro, CA•Temporarily Remote',
#  'French Camp, CA',
#  'San Diego, CA',
#  'Los Angeles, CA 90064 (West Los Angeles area)•Remote',
#  'Los Angeles, CA',
#  'Santa Clara, CA•Remote',
#  'Berkeley, CA',
#  'Lake Forest, CA 92630',
#  'Rancho Cucamonga, CA•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'French Camp, CA',
#  'Roseville, CA',
#  'Palo Alto, CA+1 location•Remote',
#  'San Francisco, CA',
#  'Burbank, CA 91505',
#  'Pasadena, CA 91101 (South area)•Remote',
#  'Glendale, CA 91203 (City Center area)•Temporarily Remote',
#  'Cupertino, CA (South Blaney area)',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'Fresno, CA',
#  'Palo Alto, CA',
#  'California•Remote',
#  'Carlsbad, CA',
#  'San Francisco, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'French Camp, CA 95231',
#  'Oakland, CA 94612 (Downtown area)',
#  'Los Angeles, CA',
#  'Carlsbad, CA',
#  'San Francisco, CA 94104 (Financial District area)',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Palo Alto, CA 94305',
#  'Orange, CA',
#  'San Francisco, CA',
#  'Mountain View, CA 94041',
#  'Duarte, CA 91010',
#  'Los Angeles, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Duarte, CA 91010',
#  'Redwood City, CA',
#  'Vista, CA',
#  'San Diego, CA',
#  'Santa Ana, CA',
#  'Los Angeles, CA 90068 (Hollywood Hills area)•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'Anaheim, CA',
#  'South San Francisco, CA 94080',
#  'Pleasanton, CA 94588',
#  'Oakland, CA',
#  'Carlsbad, CA•Temporarily Remote',
#  'Santa Ana, CA 92702',
#  'Costa Mesa, CA 92626',
#  'Aptos, CA 95003+1 location',
#  'Sacramento, CA 95828•Remote',
#  'Pasadena, CA 91109',
#  'California•Remote',
#  'Folsom, CA 95630',
#  'Edwards, CA 93523',
#  'Palo Alto, CA 94305',
#  'Burbank, CA 91505',
#  'Redwood City, CA',
#  'Los Angeles, CA',
#  'Davis, CA',
#  'Los Angeles, CA 90015 (Downtown area)',
#  'San Diego, CA 92126',
#  'Oakland, CA 94612 (Downtown area)',
#  'Rancho Cordova, CA',
#  'Costa Mesa, CA 92626',
#  'San Jose, CA 95131 (North Valley area)',
#  'Santa Barbara, CA',
#  'Irvine, CA 92618',
#  'San Leandro, CA•Temporarily Remote',
#  'San Jose, CA 95126 (Downtown area)•Temporarily Remote',
#  'Oakland, CA',
#  'San Francisco, CA',
#  'Burbank, CA 91504',
#  'Philadelphia, PA 19019 (Somerton area)•Remote',
#  'Thousand Oaks, CA',
#  'Glendale, CA 91205 (Mariposa area)',
#  'California•Remote',
#  'San Leandro, CA•Temporarily Remote',
#  'Richmond, CA',
#  'San Francisco Bay Area, CA',
#  'La Mesa, CA',
#  'San Jose, CA',
#  'Sacramento, CA•Temporarily Remote',
#  'Oakland, CA',
#  'Rancho Cucamonga, CA•Remote',
#  'Roseville, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Ramon, CA',
#  'Sunnyvale, CA 94086',
#  'City of Anaheim, CA',
#  'Mountain View, CA 94041',
#  'San Francisco, CA 94124 (Bayview area)',
#  'Costa Mesa, CA 92626',
#  'Los Angeles, CA 90015 (Downtown area)',
#  'Foster City, CA 94404+1 location',
#  'Sunnyvale, CA',
#  'Newport Beach, CA•Remote',
#  'Carlsbad, CA',
#  'San Jose, CA',
#  'Los Angeles, CA•Remote',
#  'California•Remote',
#  'Palo Alto, CA',
#  'Sacramento, CA•Remote',
#  'San Jose, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90015 (Downtown area)',
#  'Los Angeles, CA',
#  'Oakland, CA+2 locations',
#  'Sunnyvale, CA 94087',
#  'Santa Clara Valley, CA 95014',
#  'Scotts Valley, CA',
#  'San Francisco, CA 94133 (Russian Hill area)•Temporarily Remote',
#  'San Diego, CA 92093 (Torrey Pines area)',
#  'Pasadena, CA 91109',
#  'San Diego, CA',
#  'Milpitas, CA 95035•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Parlier, CA',
#  'Long Beach, CA',
#  'San Diego, CA 92121',
#  'San Jose, CA',
#  'Oakland, CA 94612 (Downtown area)',
#  'Burbank, CA 91505',
#  'Burbank, CA 91505',
#  'Oakland, CA',
#  'Sunnyvale, CA 94089',
#  'Emeryville, CA 94608',
#  'Emeryville, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Diego, CA',
#  'Mountain View, CA',
#  'Los Angeles, CA',
#  'San Francisco Bay Area, CA•Remote',
#  'San Francisco, CA 94109 (Van Ness - Civic Center area)',
#  'San Bruno, CA 94066+1 location',
#  'El Centro, CA 92243',
#  'California•Remote',
#  'South San Francisco, CA 94080',
#  'San Diego, CA 92122 (University City area)',
#  'California',
#  'San Diego, CA',
#  'Costa Mesa, CA 92626',
#  'Folsom, CA 95630',
#  'San Francisco, CA•Remote',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'San Luis Obispo, CA 93401',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Burlingame, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA•Remote',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'Costa Mesa, CA 92626',
#  'Burlingame, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Parlier, CA',
#  'French Camp, CA 95231',
#  'Mountain View, CA',
#  'Roseville, CA',
#  'Santa Ana, CA 92702',
#  'California•Remote',
#  'Los Angeles, CA 90095',
#  'South El Monte, CA 91733',
#  'Long Beach, CA 90802•Remote',
#  'West Hills, CA 91304•Temporarily Remote',
#  'Pasadena, CA',
#  'Costa Mesa, CA 92626',
#  'Los Altos, CA 94022',
#  'California•Remote',
#  'Santa Clara, CA',
#  'California•Remote',
#  'San Diego, CA',
#  'San Ramon, CA•Remote',
#  'San Francisco, CA',
#  'San Jose, CA 95110 (Downtown area)',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'San Francisco Bay Area, CA+1 location',
#  'San Francisco, CA',
#  'Burbank, CA 91504•Remote',
#  'San Diego, CA 92122 (University City area)',
#  'Los Angeles, CA',
#  'San Jose, CA',
#  'Anaheim, CA 92807 (Anaheim Hills area)',
#  'Los Angeles, CA 90057+1 location',
#  'San Diego, CA 92109',
#  'Sunnyvale, CA 94086',
#  'Parlier, CA 93648',
#  'Los Angeles, CA•Remote',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'Culver City, CA 90232 (Washington Culver area)',
#  'Sacramento, CA•Temporarily Remote',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'California•Remote',
#  'Oakland, CA+2 locations',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Irvine, CA 92618•Temporarily Remote',
#  'Santa Cruz, CA 95064',
#  'Milpitas, CA 95035•Remote',
#  'Santa Monica, CA 90403 (Wilshire/Montana area)•Remote',
#  'Los Alamitos, CA 90720•Temporarily Remote',
#  'San Diego, CA',
#  'Sacramento, CA 95814 (Downtown area)•Temporarily Remote',
#  'San Francisco, CA•Remote',
#  'Burbank, CA',
#  'California•Remote',
#  'Santa Clara, CA 95054',
#  'Sunnyvale, CA (Lakewood area)',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Irvine, CA',
#  'Chico, CA',
#  'Los Angeles, CA',
#  'California•Remote',
#  'San Jose, CA',
#  'Rancho Cordova, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'Los Angeles, CA',
#  'Corona, CA',
#  'Vandenberg AFB, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Venice, CA',
#  'California+1 location•Remote',
#  'Fremont, CA 94538 (Downtown area)',
#  'Los Angeles, CA',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'Oakland, CA',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'California•Remote',
#  'San Rafael, CA 94901 (Downtown area)•Remote',
#  'San Francisco, CA 94133 (Russian Hill area)•Temporarily Remote',
#  'San Jose, CA 95110 (Downtown area)•Temporarily Remote',
#  'San Diego, CA',
#  'San Diego, CA',
#  'Brea, CA',
#  'La Jolla, CA 92037',
#  'Burbank, CA',
#  'San Francisco, CA 94107 (South Beach area)',
#  'Inglewood, CA 90301',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'Los Angeles, CA•Remote',
#  'Sunnyvale, CA (Lakewood area)',
#  'San Francisco, CA 94107 (South Of Market area)+1 location',
#  'Oakland, CA 94612 (Downtown area)',
#  'San Francisco, CA',
#  'Richmond, CA',
#  'San Clemente, CA 92673',
#  'Mountain View, CA',
#  'Los Alamitos, CA 90720•Temporarily Remote',
#  'San Diego, CA 92093 (Torrey Pines area)',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'San Diego, CA 92123 (Kearny Mesa area)•Remote',
#  'Lodi, CA 95240',
#  'Santa Clara Valley, CA 95014',
#  'Los Angeles, CA',
#  'San Francisco, CA 94124 (Bayview area)',
#  'San Francisco, CA',
#  'Sacramento, CA•Remote',
#  'Westlake Village, CA 91361',
#  'California•Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA 94105 (South Beach area)•Remote',
#  'California',
#  'San Jose, CA',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'San Diego, CA 92121',
#  'Burbank, CA 91504•Remote',
#  'Vernon, CA',
#  'Woodland Hills, CA 91367',
#  'San Francisco, CA',
#  'Rancho Cordova, CA 95670+1 location',
#  'Santa Clara, CA 95054',
#  'San Francisco, CA',
#  'Los Angeles, CA 90016',
#  'Menlo Park, CA 94025',
#  'Irvine, CA',
#  'Mountain View, CA 94043•Remote',
#  'San Leandro, CA•Temporarily Remote',
#  'Woodland Hills, CA 91367',
#  'South San Francisco, CA 94080',
#  'Santa Clara Valley, CA 95014',
#  'Manteca, CA 95336',
#  'Los Angeles, CA',
#  'Mountain View, CA 94043•Remote',
#  'Woodland Hills, CA 91367',
#  'Woodland Hills, CA 91367',
#  'Palo Alto, CA',
#  'Manteca, CA 95336',
#  'San Diego, CA',
#  'Newport Beach, CA',
#  'San Diego, CA 92126',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Seaside, CA 93955',
#  'Long Beach, CA 90808 (Airport Area area)',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'California•Remote',
#  'El Segundo, CA 90245•Remote',
#  'Glendale, CA 91203 (City Center area)•Temporarily Remote',
#  'Valencia, CA 91355',
#  'San Diego, CA 92093 (Torrey Pines area)',
#  'California•Remote',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'El Segundo, CA',
#  'San Francisco, CA',
#  'Pleasanton, CA 94588•Remote',
#  'Newark, CA 94560',
#  'San Francisco, CA 94104 (Financial District area)',
#  'Seaside, CA 93955',
#  'Oakland, CA 94612 (Downtown area)',
#  'San Leandro, CA•Temporarily Remote',
#  'Los Angeles, CA+1 location',
#  'Rancho Cucamonga, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Palo Alto, CA 94303',
#  'Cerritos, CA',
#  'Naval Medical Center San Diego, CA',
#  'San Francisco, CA 94103 (Yerba Buena area)',
#  'Santa Clara, CA',
#  'Santa Monica, CA•Remote',
#  'Ventura, CA 93001 (Downtown area)',
#  'Yreka, CA',
#  'Santa Barbara, CA',
#  'Irvine, CA 92618 (Irvine Health and Science Complex area)',
#  'Parlier, CA',
#  'San Francisco, CA',
#  'Encinitas, CA',
#  'Hercules, CA',
#  'Palo Alto, CA',
#  'Carson, CA 90810',
#  'San Francisco, CA•Temporarily Remote',
#  'Encinitas, CA',
#  'Alturas, CA',
#  'Palo Alto, CA 94304',
#  'Los Angeles, CA 90010',
#  'Claremont, CA 91711 (The Claremont Colleges and Affiliated Institutions area)',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Parlier, CA',
#  'San Francisco, CA',
#  'Seaside, CA 93955',
#  'California•Remote',
#  'Santa Clara, CA 95054',
#  'Los Angeles, CA 90071•Temporarily Remote',
#  'Mountain View, CA 94043',
#  'San Francisco, CA 94111 (Financial District area)',
#  'Seaside, CA 93955',
#  'San Jose, CA',
#  'Daly City, CA 94014',
#  'Los Angeles, CA',
#  'Santa Clara Valley, CA 95014',
#  'Sacramento, CA+3 locations•Remote',
#  'Fremont, CA',
#  'San Diego, CA 92103 (Hillcrest area)',
#  'Mountain View, CA 94041',
#  'Simi Valley, CA 93063',
#  'Carlsbad, CA•Temporarily Remote',
#  'San Jose, CA',
#  'Pasadena, CA',
#  'Redwood City, CA',
#  'San Jose, CA',
#  'Rancho Mirage, CA 92270',
#  'San Luis Obispo, CA 93401',
#  'Los Angeles, CA 90001•Remote',
#  'Los Angeles, CA',
#  'California•Remote',
#  'Claremont, CA 91711 (The Claremont Colleges and Affiliated Institutions area)',
#  'Sacramento, CA 95814 (Downtown area)',
#  'Los Angeles, CA 90025 (Brentwood area)•Temporarily Remote',
#  'Lake Forest, CA 92630',
#  'Mountain View, CA 94041',
#  'San Diego, CA 92112 (Park West area)',
#  'San Jose, CA 95124',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Los Angeles, CA 90016',
#  'Los Angeles, CA',
#  'Los Angeles, CA 90013 (Downtown area)+2 locations',
#  'Los Angeles, CA•Remote',
#  'Lake Forest, CA 92630',
#  'San Jose, CA 95110 (Downtown area)',
#  'Los Angeles, CA',
#  'Sylmar, CA',
#  'Sacramento, CA•Remote',
#  'Sunnyvale, CA 94086',
#  'San Francisco, CA•Remote',
#  'Foster City, CA 94404+1 location',
#  'San Francisco, CA',
#  'California•Remote',
#  'Sunnyvale, CA 94089 (Lakewood area)',
#  'Los Angeles, CA',
#  'Folsom, CA 95630',
#  'Rancho Cordova, CA 95670',
#  'Santa Monica, CA',
#  'California•Remote',
#  'San Diego, CA',
#  'Sacramento, CA•Temporarily Remote',
#  'Livingston, CA 95334',
#  'Folsom, CA 95630',
#  'Pasadena, CA',
#  'Corona, CA',
#  'Rancho Cordova, CA 95670•Remote',
#  'San Diego, CA 92108',
#  'Chatsworth, CA 91311•Remote',
#  'San Diego, CA 92112 (Park West area)',
#  'Sylmar, CA 91342',
#  'Los Angeles, CA',
#  'California•Remote',
#  'San Diego, CA',
#  'San Diego, CA 92108',
#  'United States',
#  'Irvine, CA 92618•Temporarily Remote',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Daly City, CA 94014',
#  'Foothill Ranch, CA+2 locations',
#  'Los Angeles, CA',
#  'Los Angeles, CA',
#  'Los Angeles, CA•Remote',
#  'San Francisco, CA 94123 (Cow Hollow area)',
#  'Los Angeles, CA 90045 (Westchester area)',
#  'Woodland Hills, CA 91367',
#  'California•Remote',
#  'San Diego, CA 92093 (Torrey Pines area)',
#  'Santa Rosa, CA',
#  'Oakland, CA',
#  'Orange, CA 92867',
#  'Menlo Park, CA',
#  'Cerritos, CA',
#  'Irvine, CA 92618',
#  'Rosemead, CA',
#  'Valencia, CA 91355',
#  'Irvine, CA 92618•Temporarily Remote',
#  'San Diego, CA•Remote',
#  'Vista, CA 92084',
#  'Menlo Park, CA',
#  'United States',
#  'Rancho Cordova, CA 95670•Remote',
#  'Fountain Valley, CA',
#  'Irvine, CA 92618',
#  'Westlake Village, CA 91361',
#  'Temecula, CA 92591',
#  'Los Angeles, CA 90017 (Downtown area)',
#  'Los Alamitos, CA',
#  'San Diego, CA 92121 (Sorrento Valley area)',
#  'San Ramon, CA 94583',
#  'Rancho Cordova, CA',
#  'Los Angeles, CA•Temporarily Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'South San Francisco, CA 94083',
#  'Stanford, CA 94305•Remote',
#  'San Diego, CA 92121',
#  'San Francisco, CA',
#  'Irvine, CA•Temporarily Remote']

# %%
summaries11
# Out:
# ['Strong grasp on data structure and data integrity issues.\nAttention to detail and work ethic for dealing with a variety of data issues.',
#  'Analyze route efficiencies using historical data.\nGather and analyze data to deliver weekly reports for managers.\nStrong analytical skills and Excel.',
#  'Designs and implements processes and solutions associated with a wide variety of data sets used for data/text mining, analysis, modeling, and predicting to…',
#  'Establish best practices around data model governance, data sharing, and scalable reporting in partnership with Finance, Sales Operations, and Data Science.',
#  'The main function of a data analyst is to coordinate changes to computer databases, test, and implement the database applying knowledge of database management…',
#  '\\* Owner of the core company data pipeline, responsible for scaling up data processing flow to meet the rapid data growth;\n目前急招 Full-time.',
#  'Put Your Skills to the Test – Analyze data to test hypotheses and answer business questions.\nThe Consumer Insights, Measurement, and Analytics (CIMA)…',
#  'Assess the effectiveness and accuracy of new data sources and data gathering techniques.\nPartner and lead cross-functional teams to realize data relationships…',
#  'They will be responsible for data administration tasks such as pulling data from internal systems to scrub and sort.\n1+ years of Data Administration experience.',
#  "As an entry level data analyst you'll get hands on experience using data to build better software.\nThe job of the entry level data analyst requires a breadth of…",
#  'To support that mission, they are now looking for a strong data / business analyst to help drive their marketing efforts.\nData Science Tools (Python, R, etc.).',
#  'Provides plan with data, reporting, and analyses that enable data-driven decision-making.\nExperience with other relational databases, BI reporting and data…',
#  'Strong at data analysis – SQL, Snowflake.\nMoreover, the offices have been designed to foster creativity and communication, bringing a little bit of home into…',
#  'This individual will also manipulate data and create new data fields to enhance our ability to use data for informed decision making.',
#  'Responds to data requests for grant/proposal preparation and other needs of the agency 6.\nDesigns data collection instruments, including forms and fields in…',
#  'Strong at data analysis – SQL, Snowflake.\nMoreover, the offices have been designed to foster creativity and communication, bringing a little bit of home into…',
#  'This individual will also manipulate data and create new data fields to enhance our ability to use data for informed decision making.',
#  'Responds to data requests for grant/proposal preparation and other needs of the agency 6.\nDesigns data collection instruments, including forms and fields in…',
#  'Determine additional data collection and reporting requirements.\nUse system reports and analyses to identify potentially problematic data, make corrections, and…',
#  'Experience building out large data sets and pipelines.\nData pipelines: 6 years (Preferred).\nExperience problem solving and providing business insights and…',
#  '3-5 years exp with SQL, and working with multiple datasets.\nExperience working with/on data warehouses, including data architecture, ETL tools/workflows, a plus…',
#  'Work with additional data analysts/technicians to identify trends in data and service technician areas of improvement.',
#  'Handle all data entry of purchase orders for emergency requirements and periodical stock replenishment.\nProficiency in Microsoft Suite Applications (Word, Excel…',
#  'Data Quality: Perform general data quality control tasks.\nOne to three years of data industry experience (preferred).\nStrong Individual and team work ethics.',
#  'Analyze data to derive insights and develop data visualizations to cultivate decision making.\nCreate data sources in Tableau to support reporting for internal…',
#  'Experience visualizing data and creating reports.\nExperience identifying and adapting to imperfect data.\nLeverage a combination of internal and external data…',
#  'Good knowledge and understanding of Edwards policies, procedures and guidelines relevant to data analytics.\nBuild routine quantitative models and/or tools with…',
#  'Maintains enterprise dataset data dictionaries and definitions.\nThe person in this role will be required to work with the BI team to identify the data needs,…',
#  'Create SAS and/or Stata datasets from raw data and write data analysis programs.\nAdhere to data security requirements.\nPerforming programming and data analyses.',
#  'Attention to detail and accuracy, sound judgment.\nThe Business Data Analyst should have a passion for working with the Commercial Team and customers, as well as…',
#  'Maintains enterprise dataset data dictionaries and definitions.\nThe person in this role will be required to work with the BI team to identify the data needs,…',
#  'Create SAS and/or Stata datasets from raw data and write data analysis programs.\nAdhere to data security requirements.\nPerforming programming and data analyses.',
#  'Attention to detail and accuracy, sound judgment.\nThe Business Data Analyst should have a passion for working with the Commercial Team and customers, as well as…',
#  '1-3 years of equivalent experience as an analyst in a data and analytics domain, in a professional or academic setting.',
#  'Great attention to detail; experience delivering exceptional quality in reports and data analysis.\nAbility to bring data to life for any audience via written…',
#  'Collect and aggregate data from published medical literature and appendices.\nClean up and enter data, and when possible create simple interfaces for less…',
#  'Tests and maintains data integrity.\nUnder close supervision, this position exists to assist the organization in making strategic data-related decisions by…',
#  'Support initiatives related to data hygiene and integrity.\nIdentify, analyze, and interpret trends, alarms, events or patterns in complex data sets within the…',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'You will apply functional knowledge of data analysis, data visualization, report writing, data integration, and Cloud environments in order to perform the…',
#  "Perform exploratory data analysis to confirm data integrity and to derive appropriate analytical attributes.\nExperian's Decision Analytics team is looking for a…",
#  'Develop and maintain data dictionaries and other data management documents (fidelity check lists, data plans and specifications, etc.) to support teams with…',
#  "The data analyst will work on our data team alongside data scientists and software engineers.\nThe objective is to increase the data team's capacity for…",
#  'Working with/querying complex data collection/management systems, including understanding and utilizing computer programming and processing methods to generate,…',
#  'Analyze, interpret, summarize, and present administrative and technical information and data in an effective manner.\nRecord keeping principles and procedures.',
#  'Assist in creating data best practices and documentation to help streamline data operations.\nAdvanced proficiency in data manipulation including SQL, python or…',
#  'Pathways is an Excepted Service Appointment, Schedule D, 5 CFR Part 362, and may NOT be combined with other Excepted Service Appointments (e.g., Schedule A).',
#  'Experience extracting data from RDBMS system.\nExperience with Microsoft Excel and experience performing data cleansing activities in an excel.',
#  'Passion for data, technology and people.\nAdvanced ability to perform exploratory data analysis.\nStrong analytical capabilities to translate business problems…',
#  'This role focuses on language data, primarily in the areas of writing and general data analysis deliverables.\nWriting high-quality and engaging copy.',
#  'Gathering data from across various data sources, cleaning that data, and working with the CTO to help craft the story for our Series A round later in the year.',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Solid organizational skills including attention to detail and multitasking skills.\nCommunicate and liaison with senior stakeholders on key changes and ensure to…',
#  'Digital marketing: 2 years (Required).',
#  'Comfort working with data systems and learning new data systems.\nThe Assistant Data Analyst works within the HFH Policy & Procurement data team and supports the…',
#  'Experience with analytic reporting, data interpretation, and effective communication of findings to varied audiences.\nHigh School Graduate or Equivalent.',
#  'Experience framing business questions with data and translating business needs into actionable data deliverables - processes, analyses, reports, and datasets.',
#  'You should be comfortable doing both exploratory evaluations of data in a big data environment and identifying new cutting-edge data sources to drive commercial…',
#  'Expert experience pulling large and complex data using SQL.\nExperience with a data visualization tool (e.g. Tableau).\nFamiliarity with Python or R is a plus.',
#  'Work with other analysts to process large data to transform to usable information.\nMinimum 6 years prior business analytics and data analysis experience.',
#  'If you are a current City of Redding Employee and took and passed the Management Analyst examination within the last 5 years, you are not required to retest and…',
#  'Must have a strong background in statistical analysis, including developing data models, preparing reports, and data presentation.\nShift Hours:8 Hour Shift.',
#  'Job Types: Full-time, Contract.\nTemporarily due to COVID-19.',
#  'Designs and implements processes and solutions associated with a wide variety of data sets used for data/text mining, analysis, modeling, and predicting to…',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Gathers data and identifies and forecasts program costs.\nLeads the employee data auditing process and generates complex reports.',
#  'Understand the requirements of partners and map them with the data sources/data warehouse.\nPartner with Data Governance and engineering teams to define the data…',
#  'Daily analysis of all data is necessary in order to complete weekly reporting to internal team, manager, and cross-functional teams.',
#  'Assist with software deployments and data integration projects.\nAnalyze data / systems and develop detailed specifications for implementation.',
#  'Experience with data quality processes, data quality checks, validations, data quality metrics definition and measurement.',
#  'Apply your expertise in quantitative analysis and data presentation to identify, analyze and provide insights into large data sets.',
#  '2 years of experience in data modeling, data retrieval and gathering, transforming and manipulating data.\n4 years of experience manipulating data sets using SQL…',
#  'Build new data assets by merging data from multiple data sources.\nDeliver business insights by building dashboards, reports and analyst views.',
#  'Analyze data and produce report as required.\nThe primary responsibility of this position is to enter data and provide oversight to the inventory System.',
#  'The user acquisition analytics role is building the foundation that will shape analytics and automation for user acquisition across Activision.',
#  'Comfort interpreting a variety of different data sources from qualitative research to primary survey data to secondary data sources and creating one cohesive…',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Partner with analytics and data engineering teams to identify and close gaps in logging and data infrastructure.',
#  'A master of healthcare data, data quality management, systems analysis, and statistical analysis including: health system information systems and data flow and…',
#  'Must have at least 2 years of related experience, including preparing, analyzing and reporting on market and sales data.\nRight to Work (English/Spanish).',
#  'Apply advanced analytics techniques (data mining, data visualization, statistical analysis, machine learning) on large-scale, high-dimensional data to help…',
#  'Advanced proficiency with analytics, data manipulation and primary research.\nYou will analyze market trends, cold chain product innovations, and climate…',
#  'Act as a data steward to monitor and improve overall data quality.\nDocumenting data flows and processes.\nExperience profiling data, including data discovery,…',
#  '1 to 3 years data analyst experience.\nThe analyst designs, creates and analyzes data reports for results, trends and variations.',
#  'The Studio Analytics team is responsible for developing a strategy and vision for cross-functional and complex data analysis projects.',
#  'As the first data analyst on our Analytics team, you will help shape and guide the understanding of our marketplace and customer experience through insights,…',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nMinimum of 1-2 years working as a data analyst.',
#  "Empower the Product team to access data independently by training them on Trove's data, self-service tools, and analytical methodologies.",
#  'Perform descriptive and inferential analysis of data.\nPrepare tables, graphs and other data visualizations to present results.',
#  'Conduct data processing, data fusion and statistical analysis by applying database tools.\nApply data mining principles to perform data analysis of the…',
#  'At Niagara, we’re looking for Team Members who want to be part of achieving our mission to provide our customers the highest quality most affordable bottled…',
#  "What we're building Every company needs to keep track of its finances, and most hire a bookkeeping firm to help do so. Today, there is no clear best-in-class…",
#  'The Stanford Center for Population Health Sciences (PHS) is seeking a Research Data Analyst 2 (1 Year Fixed Term) for data management, data analysis, and data…',
#  'Company Description ActiveVideo is a Silicon Valley company that harnesses the power of the cloud to accelerate multi-platform television experiences and is…',
#  '• High school diploma or equivalent • Ability to work extra hours as required • Proficient with Microsoft Excel Amazon Web Services (AWS) is seeking a Data…',
#  'Job no: 504033 Work type: Staff Location: Long Beach Categories: Unit 9 - CSUEU - Technical Support Services, Administrative, Temporary, Full Time Job…',
#  'Job Title: Data Labeling Analyst Location: Menlo Park, CA Duration: 6 Months Summary: The main function of a data labeling analyst is to create and manage…',
#  'Duties Summary Click on "" button below to view Eligibilities being considered and other IMPORTANT information. WHERE CAN I FIND OUT MORE ABOUT OTHER IRS…',
#  'Description: *Overview* The Data Analyst serves as an analytics specialist in the business, focusing on the management of data from various sources and…',
#  "About the job We're looking for a versatile Data Analyst who will be responsible for executing quantitative analyses that translate data into actionable…",
#  'OptumRx is looking for a curious and self-motivated individual with comprehensive data analyst experience to solve complex Business problems. The pharmacy…',
#  'We are looking for someone with a good blend of writing, speaking and presentation skills to draft analysis reports with clarity and present statistical…',
#  "Business Analyst(Job Number: AHM0005QB) American Honda Motor Co., Inc. Description Honda has a clear vision for the future in 2030, and it's a joyful one!…",
#  'Who We Are BigRentz is an online construction equipmentrental marketplace. Our 4,000+ rental partners and 10,000+ partner locationsrepresent the largest…',
#  'BUSINESS ANALYST: LEVEL 1 – Offering both full-time and internships positions About the Job: Our Business Analyst plays an important role as the “glue” in…',
#  'You will analyze internal processes, data, and problems and identify benefits from enabling new capabilities within the business.',
#  "Performs forecasting and reconciliation of internal data.\nCompiles and analyzes data to support organization's strategic initiatives.",
#  'Minimum of one years experience as an analyst, developer, data scientist, business analyst, or quality assurance specialist.',
#  'The ideal candidate is an intelligent, sharp, detail-oriented, and highly quantitative individual who loves working with and analyzing data.',
#  'Research analyst for data integration in support of financial, operating, and productivity reporting processes.',
#  'Good Knowledge of: Statistics, data processing software; data collection instrument development; community college programs.',
#  'Data analytics: 5 years (Preferred).\nThe in depth data analysis is must as customer is looking for possible business solution that helps the BI part to be more…',
#  'The Data Management Analyst responsibilities include the collection and preparation of test data from test facilities for data analysis; provide technical…',
#  'The individual will work with quantitative data including basic data analysis, data validation, data cleaning, and analysis and interpretation of research…',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nMinimum of 1-2 years working as a data analyst.',
#  'Together with Database Administrator, complete regular review of data for reporting to ensure quality.\nMinimum 2 years’ experience generating complex aggregate…',
#  'Present data analysis findings and/or translate data into an understandable document or dashboard.\nStrong SQL with experience in querying large, complex data…',
#  'Leverage global reporting, analysis, and business modeling to translate data into insights to proactively drive action.',
#  'Experience using data visualization tools (i.e., Domo, Tableau, Looker); comfortable transforming data into actionable insights.',
#  'Ability to manage and analyze data.\nKnowledge of business statistics and data analyses techniques.\nProvides recommendations and conclusions gained from…',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Analyzes the interrelationships of data and defines logical aspects of data sets.\nMay supervise data entry, database management and research analysis of…',
#  "Contribute to data models and designs for the data warehouse.\nOur Data Strategy and Operations team is focused on implementing and evolving client's investment…",
#  'Monitoring games through data to identify data anomalies and risks- Follow up these problems in time;\nMore than 2 years of experience in data analysis and data…',
#  '1-3 years of work experience in data analytics/science.\nStrong analytical mindset with a drive toward actionable insights from data.',
#  'Analysis of complex Health Information technology, Medicaid Management Information System databases, reports and system processes.',
#  '1-3 years of work experience as a data analyst or in related field is preferred.\nProviding technical expertise on data storage structures, data mining, and data…',
#  'These positions function both as a consultant and as a high-level data analyst.\nThe Data Analytic Consultant provides support in making strategic data-related…',
#  'Experience in data visualization e.g. Tableau and ability to communicate results to a nontechnical audience.\nExtensive experience working with complex queries ,…',
#  'Collect and extract data from data warehouse.\nPerforms comprehensive data profiling, analysis, predictive analysis or forecasting.\nM, DAX, R a plus.',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nMinimum of 1-2 years working as a data analyst.',
#  'Interact regularly and directly with the Operations function and has close user working relationship to ensure industry and best practices are employed.',
#  'Ability to manipulate and analyze data to produce accurate results and tell a story of those results in data visualizations, dashboards, and reports.',
#  'Improve analytics quality and efficiency in collaboration with data scientists and data engineers.\nAs a data analyst at Opendoor, you will be part of our…',
#  'Experience running or participating in data projects.\nStrong Oracle SQL Query skills.\nTableau development skills or similar dashboarding tools.',
#  'BEREAVEMENT LEAVE - 3 days paid in California, 5 days paid out-of-state.\nThe candidate will be part of a BA team that includes developers and analysts who will…',
#  'Ensure robust data handling data of new and existing resources.\nDefining goals for data management and strategizing how to use data resources most effectively.',
#  'Collects and generates original data sets for the purpose of complementing existing data sets and identify errors.\nInvolves draft editing of Economics papers.',
#  'Escalates complex and non-standard data record issues to manager for joint resolution.\nAssist in updating and maintaining data related to the CRA Public File…',
#  'Experience working with/on data warehouses, including data architecture, ETL tools/workflows, a plus.\nExperience with one or more data visualization business…',
#  'Problems not solutions - engineers focus on solving problems, not building solutions handed to them.',
#  'For example, the morning hours from 8 to 12 would be dedicated to specific needs pertaining to Synergy’s SoCal Division and the hours from 1 to 5 would be…',
#  'Understanding of data warehousing and relational data modeling fundamentals.\nKeen attention to detail and data integrity.',
#  'The Data Analyst will conduct data analytics using CAIR data to identify gaps and disparities in immunization coverage from over 11,000 participating clinical…',
#  'Collaborate with partners in BI and Data Engineering orgs to build robust data pipelines to “productionalize” new data sources and KPIs.',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nMinimum of 1-2 years working as a data analyst.',
#  'Under general supervision, this position exists to assist the organization in making strategic data-related decisions by analyzing, manipulating, tracking,…',
#  '5+ years of professional experience in a data analyst role.\nWe work cross functionally with multiple business partners, and support each other as we problem…',
#  'Advanced SQL experience, query optimization, data extract.\nConduct complex analysis and build models to uncover key learning form data, leading to appropriate…',
#  'Exceptional analytical skills, comfortable working with large amounts of data and communicating data findings.',
#  'Familiarize yourself with Volta’s data infrastructure and reporting platforms.\nPassion for media, EVs, consumer insights and behavior, or just how to do things…',
#  'Analyze data to derive insights and develop data visualizations to cultivate decision making.\nCreate data sources in Tableau to support reporting for internal…',
#  'Filter and “clean” data by reviewing customer data sets.\nAcquire data from primary or secondary data sources, utilizing internal ETL tools.',
#  'Build new data assets by merging data from multiple data sources.\nApply statistical methodologies and data mining skill sets on large volume of data Analyze…',
#  'Experience with NetSuite data or Salesforce data.\nPassion for data quality and delivering effective data to impact the business.',
#  'Identify gaps in data capture needed to execute theses cases efficiently.\nInvestigate issues or anomalies in usage data to assess severity and ascertain causes.',
#  'Assist in creating data best practices and documentation to help streamline data operations.\nAdvanced proficiency in data manipulation including SQL, python or…',
#  'Create and manage the company’s online BI tool, including dashboard creation, using complex data from different data sources, such as our data warehouse and…',
#  'Two or more years of experience in data analysis.\nCandidates should have proficiency variety of data and information management systems, should be self-starters…',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Analyzing and visualizing data using python.\nExperience in manipulating and visualizing data using Excel.\nManipulating and analyzing large-scale data using SQL.',
#  'Experience in data analysis and visualization methods with large volumes of data.\nPull and integrate data from disparate sources (e.g. cost and claims or…',
#  'This individual will also manipulate data and create new data fields to enhance our ability to use data for informed decision making.',
#  'Job responsibilities include: preparing daily, weekly, monthly, and quarterly reports via Excel and SQL, interpreting and analyzing data from primary and…',
#  'Experience with data lakes, ETL, Data pipelining and data warehousing.\nManage data requests in JIRA and summarizes data findings and processes in JIRA and…',
#  'Experience extracting data from RDBMS system.\nExperience with Microsoft Excel and experience performing data cleansing activities in an excel.',
#  '3+ years of working experience in data analyst role preferred.\nAs a data analyst, You will play a key role to provide analysis of RMA data for various…',
#  'Monitoring data quality and removing corrupt data.\nBuild data catalog, data dictionary and make data searchable for our stakeholders and users.',
#  'Experience with data visualization and storytelling.\nAnalytics and data accuracy go hand-in-hand with this role.\nHands on experience with Domo.',
#  'Taking part in master data quality improvement activities through analysis and remediation of data quality issues.\nProficient with Excel, SQL and Tableau.',
#  'Lean Six Sigma: 5 years (Required).\nSQL Server Management Studio: 5 years (Required).\nExperience in Process Improvement (LEAN / Six Sigma Black Belt preferred)…',
#  'Ability to collect data using a variety of methods, such as data mining and hardcopy or electronic documentation studies, to improve or expand databases.',
#  'Job responsibilities include: preparing daily, weekly, monthly, and quarterly reports via Excel and SQL, interpreting and analyzing data from primary and…',
#  'Experience using data visualization tools (i.e., Domo, Tableau, Looker); comfortable transforming data into actionable insights.',
#  "Bachelor's Degree and 3 years of related experience in data management.\nDevelop insights and analytics by applying expertise in data analysis and data mining…",
#  'Experience with data management, specifically with validating and auditing data and reports from multiple systems.\nExperience with R or Python.',
#  'Create and manage the company’s online BI tool, including dashboard creation, using complex data from different data sources, such as our data warehouse and…',
#  'Experience analyzing and manipulating large and complex data sets.\nExperience using data visualization and analytical tools, such as Microsoft Power BI and…',
#  'They will be responsible for data administration tasks such as pulling data from internal systems to scrub and sort.\n1+ years of Data Administration experience.',
#  'The Data Analyst strategically supports the Informatics team as well as internal business units to analyze key data to encourage data-driven decisions.',
#  'Create and manage the company’s online BI tool, including dashboard creation, using complex data from different data sources, such as our data warehouse and…',
#  'Taking part in master data quality improvement activities through analysis and remediation of data quality issues.\nProficient with Excel, SQL and Tableau.',
#  'Monitoring games through data to identify data anomalies and risks- Follow up these problems in time;\nMore than 2 years of experience in data analysis and data…',
#  'Understand the requirements of partners and map them with the data sources/data warehouse.\nPartner with Data Governance and engineering teams to define the data…',
#  'Build new data assets by merging data from multiple data sources.\nApply statistical methodologies and data mining skill sets on large volume of data Analyze…',
#  'Experience in analyzing data to draw business-relevant conclusions.\nSoFi Stadium and Hollywood Park is seeking a business analyst who can assist with analyzing…',
#  'Filter and “clean” data by reviewing customer data sets.\nAcquire data from primary or secondary data sources, utilizing internal ETL tools.',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Review and validate data entry across all data systems to ensure data entry is accurate, effective, and efficient.\nCombination of field and office environment.',
#  'Basic Qualifications:* 2-3 years of month-end close, general ledger accounting, and reporting experience.\nEffective in managing competing priorities with high…',
#  'Experience in data analysis and visualization methods with large volumes of data.\nPull and integrate data from disparate sources (e.g. cost and claims or…',
#  'Perform data modeling, data analysis, and development of key performance indicators.\n2-3 years of experience in data mapping and/or integration documentation…',
#  'Coordinate transcript receipting and data/workflow processing.\nAbility to perform standard business math, track financial data, and make simple projections.',
#  'Present data analysis findings and/or translate data into an understandable document or dashboard.\nStrong SQL with experience in querying large, complex data…',
#  'Ability to manage and analyze data.\nKnowledge of business statistics and data analyses techniques.\nProvides recommendations and conclusions gained from…',
#  'Two or more years of experience in data analysis.\nCandidates should have proficiency variety of data and information management systems, should be self-starters…',
#  'Foster a culture of broad access to data and autonomy in obtaining answers by implementing dashboards and other tools that helps your data customers extract,…',
#  'You have 3-5 years of experience in data analysis.\nMonitor data streams, collect and record marketing data in dashboards and scorecards.',
#  'The AVP, Sr SQL/ETL developer will serve as a lead developer and data analyst who will be responsible for leading development team to understand business…',
#  'If you are a current City of Redding Employee and took and passed the Management Analyst examination within the last 5 years, you are not required to retest and…',
#  'Build analytics to collect, process, and analyze huge sets of data.\nHave the ability to write ETL jobs to extract data for the analytics.',
#  'Experience with data management, specifically with building data systems and validating reports from disparate systems.\nExperience with R or Python.',
#  'BEREAVEMENT LEAVE - 3 days paid in California, 5 days paid out-of-state.\nThe candidate will be part of a BA team that includes developers and analysts who will…',
#  'Interact regularly and directly with the Operations function and has close user working relationship to ensure industry and best practices are employed.',
#  'Build new data assets by merging data from multiple data sources.\nApply statistical methodologies and data mining skill sets on large volume of data Analyze…',
#  "2+ years of experience in data analytics.\nExcellence in logical thinking, problem solving and proven familiarity with big data.\nBachelor's degree is required.",
#  'Frequently (2 - 5 hrs/day).\nThis is a temporary, grant-funded, full time, benefitted position.\nHousing for Health (HFH) is a program office within Health…',
#  'This is a highly cross-functional role and you will work alongside analysts, data scientists, data architects, product managers and functional leads to lay…',
#  'Minimum of one years experience as an analyst, developer, data scientist, business analyst, or quality assurance specialist.',
#  'Determines data needs, collects and validates data, selects from different analytical techniques to achieve desired data outcomes.',
#  '3+ years of experience in business and data analysis, including data profiling, data migration, data integration, and metadata management services.',
#  'Knowledge of data management principles and methodologies such as data quality, data governance and master data management.',
#  'We are also looking for a more junior BA to help support with OCM related activities (meeting notes, document updates, slide deck creation, etc.) and other…',
#  'Production data manipulation and formatting.\nData analysts will perform the pre- and post-modeling data review and manipulation for the Statistical Analysts.',
#  '1+ years of experience in data analyst position,.\nBuilding useful data visualisations and communicate a story through data, conducting impact analysis and…',
#  'If you want operate at start up speed, solve some of the hardest problems and build a service which customers love, Amazon.in might just be the place for you.',
#  '5+ years of professional experience in a data analyst role.\nWe work cross functionally with multiple business partners, and support each other as we problem…',
#  'Advanced Excel skills and experience working with large data sets.\nAsset Failure Data Manipulation– Investigate asset failure via field reports and collect…',
#  'Technical expertise regarding data models, database query, data segmentation techniques;\n3+ years of overall data centric experience preferred; preferably in…',
#  'A master of healthcare data, data quality management, systems analysis, and statistical analysis including: health system information systems and data flow and…',
#  'Connect the dots across various data sources to tell a story through data visualization and insights.\nUse data for process improvement, highlight portfolio…',
#  'Review and validate data entry across all data systems to ensure data entry is accurate, effective, and efficient.\nCombination of field and office environment.',
#  'Maintain ongoing quality assurance of assigned data deliverables.\nIdentify data inconsistencies or other possible areas of concern, assess potential impact, and…',
#  'Data Analyst -Experienced analyzing source system documentation to draft a target data dictionary, identify data patterns (real time, intraday, batch) and…',
#  'Expertise in building Excel-based financial models, with an emphasis on aggregating and analyzing data to provide actionable insights.',
#  'Attention to detail and with strong data analysis and problem-solving skills.\nWorking knowledge of SQL, ETL, data cleansing, and various data visualization…',
#  'Build new data assets by merging data from multiple data sources.\nApply statistical methodologies and data mining skill sets on large volume of data Analyze…',
#  'Build automated data quality check using combination of advanced SQL and Tableau, to ensure that data refreshes meet quality thresholds.',
#  'Own the aggregation and reporting of manufacturing systems data, including – MES data, Shop floor trend data, metrology raw data, metrology production data,…',
#  'Knowledge of data management principles and methodologies such as data quality, data governance and master data management.',
#  'Experience in analyzing data to draw business-relevant conclusions.\nSoFi Stadium and Hollywood Park is seeking a business analyst who can assist with analyzing…',
#  'You will leverage technical and analytical skills to mine data for delivering business insights.\nPerforms regular audits of reported information to verify…',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nStrong data and analytic skills, knowledge of excel, numbers and data…',
#  'Requires an AA/AS in Information Systems, Health Care Management or Business or related field; 3+ years of experience in analytical role, including 1+ years as…',
#  'We are also looking for a more junior BA to help support with OCM related activities (meeting notes, document updates, slide deck creation, etc.) and other…',
#  'Minimum of 3-5 yrs of professional experience in data science.\nFrom national institutes, census data, transportation data, weather data, paid data, or other…',
#  '7+ years data analyst or related experience, including proficiency with analytical software or equivalent related education.',
#  '3+ years in a data analyst role working directly with databases and manipulating large datasets.\nThis position will mine transactional data from a variety of…',
#  'Minimum of 3-5 years of work experience in a Data Analytics role.\nA Data Analyst who will enable strategic business decisions for Screening by delivering timely…',
#  'Perform data analysis on public and proprietary genomics data.\nExperience with analysis of human genetics data, including prioritization and identification of…',
#  'Understanding of relational databases, data systems and data warehouses.\nExperience in working in a data warehouse environment as well as the ability to work…',
#  'Must have at least 2 years of related experience, including preparing, analyzing and reporting on market and sales data.\nRight to Work (English/Spanish).',
#  'Data analytics: 5 years (Preferred).\nThe in depth data analysis is must as customer is looking for possible business solution that helps the BI part to be more…',
#  'Collects and generates original data sets for the purpose of complementing existing data sets and identify errors.\nInvolves draft editing of Economics papers.',
#  'Participate in enterprise-level metadata, master data management and data governance initiatives.\nPreferably experience in data visualization.',
#  'Help drive a data-first culture where data is understood and leveraged in decision making.\nMinimum of 2 years experience (4-6 years preferred) performing…',
#  'Reviews data for completeness and accuracy.\nWorks with program staff and management to determine ways to make data collection and entry more efficient.',
#  '5-7 years minimum work experience in master data in SAP.\nTroubleshoot issues related to master data and identify opportunities for improving data management…',
#  'Foster a culture of broad access to data and autonomy in obtaining answers by implementing dashboards and other tools that helps your data customers extract,…',
#  'Proven working experience as a data analyst or similar position.\nTechnical expertise regarding data models, database design, data mining and segmentation…',
#  'Taking part in master data quality improvement activities through analysis and remediation of data quality issues.\nProficient with Excel, SQL and Tableau.',
#  'Basic Qualifications:* 2-3 years of month-end close, general ledger accounting, and reporting experience.\nEffective in managing competing priorities with high…',
#  'The individual will work with quantitative data including basic data analysis, data validation, data cleaning, and analysis and interpretation of research…',
#  'Minimum five (5) years of related analytical or consulting in technology/data science experience.\nCollaborate with other analysts on assigned components of…',
#  'The typical candidate should have a background in a quantitative or technical field, experience working with large data sets, and experience in data-driven…',
#  'Experience with data management, specifically with validating and auditing data and reports from multiple systems.\nExperience with R or Python.',
#  'BI governance including data dictionary, report integrity, data quality and data audits.\nExperience with querying and exploring data stored in data warehouses.',
#  'If you are a current City of Redding Employee and took and passed the Management Analyst examination within the last 5 years, you are not required to retest and…',
#  'MS or equivalent education and experience, PhD preferred, in Plant Genetics, Bioanalysis or Statistics, with 3-5 years professional experience involving…',
#  'Acquire data from primary or secondary data sources and maintain databases/data systems.\nStrong data and analytic skills, knowledge of excel, numbers and data…',
#  '2+ years of work experience as a data analyst, data engineer, or in a highly analytical role.\nDevelop data models in our data warehouse that enable performant,…',
#  '3+ years of analytical experience in consulting, data analytics, data science, or machine learning and predictive analytics.',
#  'Experience and Skills: • 8+ years’ experience in data analysis with 4+ years’ experience as an analyst in an enterprise-wide data governance initiative • 2+…',
#  'Strong analytical and data modeling skills.\nStrong Healthcare integration and data transformation skills.\nGood understanding of data transfer mechanisms like…',
#  'Superb ability to audit and cleanse/investigate data to make sure data is trustworthy.\nStrong database, data warehouse and ETL experience to pull data from…',
#  'Experience with data analysis, statistics, and data visualization.\nDrive data analysis by rapidly prototyping new tools.\n2+ years of working experience.',
#  'The typical candidate should have a background in a quantitative or technical field, experience working with large data sets, and experience in data-driven…',
#  'Participate in enterprise-level metadata, master data management and data governance initiatives.\nPreferably experience in data visualization.',
#  'Experience summarizing complex data down to the "so what", especially for a non-data savvy audience.\n3+ years experience working with data to shape strategy…',
#  'Advanced data analytics, data science.\nEnterprise data architecture master data management.\nCritical is an in-depth understanding of the business data and…',
#  'Very strong organizational skills, with the ability to drive data initiatives and elevate the data maturity across the business.\nStrong SQL skills a must.',
#  'MS or equivalent education and experience, PhD preferred, in Plant Genetics, Bioanalysis or Statistics, with 3-5 years professional experience involving…',
#  'Help build out our reporting model as well as suggesting new areas for data retrieval (e.g. clickstream events, survey data) to help answer questions that we…',
#  'Perform routine and ad hoc data maintenance.\nWork experience in data extraction from multiple databases.\nEvaluate and confirm incoming/outgoing data sets meet…',
#  'The Data Management Analyst responsibilities include the collection and preparation of test data from test facilities for data analysis; provide technical…',
#  'Maintain ongoing quality assurance of assigned data deliverables.\nIdentify data inconsistencies or other possible areas of concern, assess potential impact, and…',
#  '3+ years of analytical experience in consulting, data analytics, data science, or machine learning and predictive analytics.',
#  'Experience building aggregates and optimizing data workstreams.\nExpert fluency in SQL-based data manipulation.\nYou will report to the Head of Creator Products.',
#  'Experience with analytic reporting, data interpretation, and effective communication of findings to varied audiences.\nHigh School Graduate or Equivalent.',
#  'Exercises timely and accurate data mining techniques and develops new or modifies existing reports that ensure consistent conclusions to data analysis.',
#  'Accuracy and a keen eye for detail are especially important when processing merchant banking data for multiple corporations, banks, and accounts.',
#  'Troubleshoot data issues by validating different data sources.\nCreate dashboards, spreadsheet analysis and presentations as requested by regional analysts.',
#  'Democratize our data by proposing and developing new data products, data pipelines and tools and provide documentation and training to stakeholders.',
#  'Solid organizational skills including attention to detail and multitasking skills.\n*Proven experience working with data process mapping, order to cash,…',
#  'Possess a strong foundation in data analytics, an understanding and foundation in data science.\n8+ years of experience writing advanced SQL, performance tuning…',
#  'This is a highly cross-functional role and you will work alongside analysts, data scientists, data architects, product managers and functional leads to lay…',
#  'The candidate will oversee and manage all data entry into various tracking tools and provide continuous maintenance and support to ensure data accuracy.',
#  '3-5 years of experience in technical reporting and analytics fields.\nA keen eye for identifying and resolving data inconsistencies.',
#  'Strong data science experience with deep understanding of machine learning algorithms and statistical analysis.\nFlexible Spending and Health Savings Accounts.',
#  'Experience and Skills: • 8+ years’ experience in data analysis with 4+ years’ experience as an analyst in an enterprise-wide data governance initiative • 2+…',
#  '5+ years of experience as a data analyst.\nApply your expertise in quantitative analysis, data visualization and data-mining to create data alerts and derive…',
#  'Two or more years of experience in data analysis.\nCandidates should have proficiency variety of data and information management systems, should be self-starters…',
#  'Implement mass data changes needed for projects and programs.\nSupport merchandising projects and programs with implementation of new data elements.',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Own and maintain reports/tools in Tableau, Python and other data tools.\nConsequently, Criteo may use your personal data in relation to the evaluation and…',
#  'Troubleshoot data issues by validating different data sources.\nCreate dashboards, spreadsheet analysis, and presentations as requested by regional analysts.',
#  'Perform data modeling, data analysis, and development of key performance indicators.\n2-3 years of experience in data mapping and/or integration documentation…',
#  '3-4 years of experience working in roles like product data analyst or business intelligence engineer with product managers, business groups, and data engineers.',
#  'Should have hands on experience in any ETL, data modelling concepts and implementation.\nFollow standard practices and procedures in analyzing situations or data…',
#  'Have extensive experience working with health care claims data (large datasets, millions of records) (required).\nHave expert knowledge of Tableau (required).',
#  'You have a passion for numbers, data visualization and turning massive amounts of data into digestible and actionable content.',
#  'Work closely with data engineers/scientists to automate the collection/analysis of raw data for models;\nAssist in extracting and analyzing data from large data…',
#  'The ideal candidate is an intelligent, sharp, detail-oriented, and highly quantitative individual who loves working with and analyzing data.',
#  'Working across media analytics and account service teams, the analyst will help us ensure quality in our data and present the data in a way that makes it easy…',
#  'Offering both full-time and internships positions.\nAs our primary in-house client advocate, the Business Analyst works closely with the client stakeholders and…',
#  'Exceptional Excel skills to manipulate data and import/export data between systems.\nStrong quantitative analytical, data mining, and problem-solving skills…',
# ...
#  'Coordinate data reporting from ARIES to support contractors, including data required to develop and submit monthly progress reports.',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Compiles and analyzes data for Board agenda items, resolutions, report and surveys.\nWork closely with department Administrative Secretary and assisting with…',
#  'Become the subject matter expert on all revenue data streams.\nExpert Excel skills with the ability to work with large data sets.\nUnlimited PTO (paid time off).',
#  'Conduct data analysis, clean or integrate datasets, provide data insights, and make data-driven recommendations;\nSeeks to develop and share best practices.',
#  'Cleans data collected in research studies and performs statistical analyses on the data.\nDetermines the most efficient approach to data collection and…',
#  'Analyze data and provide data sets to users for analysis.\nSpecifies functional designs and works with developers and analysts to implement.',
#  'Professional experience with designing a data flow.\nBehavior data and huge opportunities of growth.\nAcademic basis in the domain of data analytics.',
#  'Three (3) or more years of analytical experience in consulting, data analytics, data science, or machine learning and predictive analytics.',
#  'A storyteller, be able to make sense of data and extrapolate meaningful and actionable insights.\nAnalyze website performance data (overall trends, clickstream,…',
#  '3-5 years of work experience as a data analyst or in a related field.\nTo do well in this role you need a very fine eye for detail, experience as a data analyst,…',
#  'Support the business with time-critical data analyses.\nProficient in tools used for data analysis and reporting (SQL, Excel).',
#  "Analyze data across our marketing channels and internal systems to understand and strategize around our user base.\nBachelor's degree, or equivalent experience.",
#  'A minimum of 3 years of experience with progressive project management/business process redesign management, preferably with administrative and/or IT systems is…',
#  'You will act as project manager and lead business analysts regarding the development and implementation of COTS and custom applications, systems and tools.',
#  'Familiarity with online research techniques, economic and financial data sources.\nRespond to copyedits and critiques of writing style, data accuracy and logic…',
#  'Responsible for managing the loan boarding process through complex data analysis and ensuring data integrity throughout all systems.',
#  'The typical data labeling analyst will have experience in data quality assurance.\nThe main function of a data labeling analyst is to create and manage labeling…',
#  'Deliver business analytics, logical data modeling (multi-dimensional), query optimization, data load strategies and designs including data transformation and.',
#  'Ability to concentrate and pay close attention to detail for 50 to 80 percent of work time when filing, typing and proofing materials.',
#  'Experience manipulating large data sets with SQL.\nApply your expertise in quantitative business analysis, data mining, and the presentation of data to identify…',
#  'Strong ability to model data to meet reporting requirements.\nPerform complex analysis of datasets and conduct regular data validation and governance.',
#  'Support the business with time-critical data analyses.\nProficient in tools used for data analysis and reporting (SQL, Excel).',
#  "2+ years' of experience with technical release process.\nPrevious experience with UAT's, test cases, technical specification documents, and release process.",
#  'Conduct audits and troubleshoot tracking gaps to maintain data confidence and implement data standardization practices.',
#  'Responsible for managing the loan boarding process through complex data analysis and ensuring data integrity throughout all systems.',
#  'Builds and monitors data quality dashboards/scorecards on existing Salesforce data and performs ad hoc analysis of data quality issues.',
#  'You have the analytical firepower to take advantage of rich data and answer important questions.\nCreate output that tells the story behind the data to non…',
#  'Experience level: *2-4 years of experience.\nTools in use (nice to have some of them)*.\nThe *Business Systems Analyst* is the primary liaison between the IT and…',
#  'Construct dashboards and tools that enable non-analysts to explore data on their own.\nExperience building data aggregations and ETLs.',
#  'In this role, you will be responsible for the day-to-day maintenance, administration, and execution of discounts and promotion requests from Sales, Marketing,…',
#  'Good understanding of data extraction and loading.\n4-6 years of experience in BI tools development like Looker , Tableau etc.\nExposure to Snowflake is a plus.',
#  'Not looking for technical resources and those with more business process expertise.\nExperience on business process and product transition.',
#  '2-4 years of work experience as a business analyst, data analyst, or similar position.\nAbility to draw conclusions from raw data then summarize results quickly…',
#  '3 years of experience supporting sales strategy or 5 years of experience supporting a large (200+) matrixed sales organization requiring regular communication…',
#  'Experience manipulating large data sets with SQL.\nApply your expertise in quantitative business analysis, data mining, and the presentation of data to identify…',
#  '3-5 years’ experience in a hands-on analytical role with a focus on analyzing business problems.\nSupport the business with time-critical data analyses.',
#  'Data analyst or related experience; experience in reporting and data mining as well as the ability to analyze large sets of data.',
#  'Support various projects through research, data analysis, data mining, identification, and potential implementation of tax credit programs.',
#  'Minimum 5 years of experience in a data analytics role.\nExperience in programming, especially with data science & visualization libraries in Python or R.',
#  'Partner with Engineering to optimize data tracking / quality and drive data warehouse improvements.\nComfortable with large data sets and interest in building…',
#  'Must be customer focused and possess:(1) the ability to develop solutions to a variety of problems of diverse scope and complexity;(2) excellent analytical,…',
#  'Job Types: Full-time, Part-time, Contract.\nSacramento, CA: Reliably commute or planning to relocate before starting work (Preferred).',
#  'Strong mathematical, analytical / problem-solving skills and detail-oriented.\nPreferably two years of experience in or associated with Payroll, Tax, Finance, HR…',
#  'Improve decision making through increased viability to data leading better Supply Utilization and Forecast Accuracy in ERP Systems.',
#  'Under general supervision, this position exists to assist the organization in making strategic data-related decisions by analyzing, manipulating, tracking,…',
#  'The role requires someone who is part data analyst and part technical analyst.\nTechnical skills including editing and writing Boolean and/or SQL queries with…',
#  'Works independently to improve data quality, data collection and analysis processes; develops data modeling methodologies and report design to meet diverse and…',
#  'Conducts data collection, data mining, analysis and reporting of data requests/reports.\nTrack and trends NCMRs and production data and follows escalation plan…',
#  'The ideal candidate is someone who has worked in ecommerce or other consumer facing websites, as a business analyst or other technical or digital marketing role…',
#  'Deliver business analytics, logical data modeling (multi-dimensional), query optimization, data load strategies and designs including data transformation and.',
#  'Assist with the compilation and review of metric reports for data measurements of performance against annual operating plan.',
#  '5+ years of experience in data analytics.\nConduct research, quantitative analysis, data modeling, data mining, and the presentation of data to see beyond the…',
#  'Partner with Engineering to optimize data tracking / quality and drive data warehouse improvements.\nComfortable with large data sets and interest in building…',
#  'This position would act as a lead analyst, providing guidance and coaching to other team analysts.\nThe Reporting & Analytics Specialist provides business…',
#  'Supports departmental management team by providing trending and performance data.\nManages small to medium sized projects, system enhancements impacting data…',
#  "The Data Analyst will combine clinical knowledge, data and information retrieval skills to actively address client's need for business and clinical insights…",
#  'You’ll help drive business value by assembling structured and unstructured data and information, leveraging advanced knowledge of American Funds enterprise data…',
#  'Build automated data quality check using combination of advanced SQL and Tableau, to ensure that data refreshes meet quality thresholds.',
#  'Use statistical analysis or data mining tools to analyze data, identify insightful trends, and interpret the technical data into meaningful recommendations for…',
#  'Develop and implement databases, data collection systems and data analytics models.\nTechnical expertise regarding data models, database design development, data…',
#  'The Business Analyst is responsible for developing business and usability requirements for client projects and related online media to support business in…',
#  '3-5 years’ experience in a hands-on analytical role with a focus on analyzing business problems.\nSupport the business with time-critical data analyses.',
#  'Strong technical skill in SQL, data engineering, and data analysis.\nInfluence engineering roadmap to instrument data that feeds organizational metrics.',
#  'Conduct audits and troubleshoot tracking gaps to maintain data confidence and implement data standardization practices.',
#  'Our client, a global life sciences leader, has an immediate need for a Senior IT Business Analyst to join its San Francisco peninsula operations.…',
#  'The Senior Data Analyst reports to the Director of Advancement Information Services. H/she shares responsibility with two other Senior Data Analysts for the…',
#  'Responsibilities: Coordinate with customer to determine functional requirements and determine technical solutions. Analyze data in support of proposed…',
#  'Please note that although all positions at Synctera are remote, candidates must be located and authorized to work in the US or Canada as a precondition of…',
#  'Payroll Title: BUS INTEL SPEC 2 Department: JACOBS SCH. OF ENGINEERING Hiring Salary Range $53,600 - 70,000 /year Worksite: Campus Appointment Type: Career…',
#  'HERBL is California’s largest cannabis distributor and supply chain solutions company servicing more than 850 storefront and non-storefront retail licensees.…',
#  'Named as a Forbes Fintech 50 the last two years in a row, Marqeta powers innovative payment solutions for many of the apps and services you enjoy daily. Our…',
#  'Summary: Business Analyst At our Company, we grow People, Brands, and Businesses! We are seeking a dynamic Business Analyst to provide our Sales Managers…',
#  'GRAIL is a healthcare company whose mission is to detect cancer early, when it can be cured. GRAIL is focused on alleviating the global burden of cancer by…',
#  'Overview Provide reporting, analytic review and support to members of the BI, Commercial Strategy, Commercial Sales and Commercial Operations teams to assist…',
#  'At OluKai, we build premium products for the ocean lifestyle. Our footwear is created using the highest quality materials and crafted into beautiful,…',
#  'Job ID: 171859 Analyst will be responsible for supporting the Training Development team by capturing and tracking key training data, in preparation for the…',
#  'ROLE RESPONSIBILITY Under general direction, to perform a variety of analyst and administrative duties involved in the support of Fruit Growers Supply Company…',
#  'Req ID: 41046 Location: Irvine, CA Other location(s): N/A Relocation benefits offered: No Travel required: None “I can be myself at work.” You define…',
#  "*Goodway Group is Ad Age's #3 Company to Work For! Our roles are fully remote, working from home offices anywhere in the United States.* *We are looking for…",
#  'Experience with multidimensional data warehouses and data programming.\nMultidimensional data warehouses and data programming: 1 year (Required).',
#  'The main function of a data analyst is to coordinate changes to computer databases, test, and implement the database applying knowledge of database management…',
#  'Support data integrity by routinely following data governance best practices through testing, documentation (e.g. data dictionaries) and building controls into…',
#  'Three years of experience in data gathering, research & analytics, problem identification, and presenting solution recommendations.',
#  'Position will start remote and may require hybrid (2-3 day a week) in the near future.\nCreating ad hoc reports and visualizations.',
#  'In-depth understanding of organizational data flow and its use in management decision-making.\nThe BA will also assist the PM in project management activities…',
#  'Strong Finance background with an understanding of cloud data.\nThis person will be responsible for the development, preparation, review and analysis of HR…',
#  "Analyze data from our software system on each child's progress and adjust the programs accordingly.\nWe use best-of-industry software on tablets for all plan…",
#  'Full-time employees accrue vacation leave at a rate of 2 weeks (10 days) per year, with an additional week (5 days) increase after 5 years of employment.',
#  'Minimum 5 years of experience in data privacy program development and management.\nMonitor the data request and usage processes matters for personal data across.',
#  'MINIMUM EDUCATION AND EXPERIENCE REQUIREMENTS: 3 years toward a Bachelor’s Degree in any field and 5 years of experience as a business analyst or in a related…',
#  'Assist in the ongoing development of technical best practices for data movement, data quality, data cleansing, data security and privacy.',
#  'Knowledge of data mapping and interface specifications.\nAbility to function as a business analyst as needed.\nThis position will be remote due to COVID and once…',
#  'Working with large sets of 1st-party, in-house data for Ad Monetization.\n6 Month Contract-to-Hire.\nThe successful Senior Business Intelligence Analyst …',
#  'Strong understanding of statistics and ability to analyze data and create reports;\nY) Helps streamline workflows, expedite completion of assignments, and…',
#  '5+ years experience in generating insights from marketing and product data.\nChampion data driven decision making both within your team and the wider company.',
#  'Acquires abstract primary or secondary data from existing internal or external data sources.\nPerforms data mining, research, analysis, and modeling on clinical…',
#  'Understanding of data architecture concepts such as data modeling, metadata, workflow management, data quality is a plus.\nMinimum of a Bachelor’s degree.',
#  'Additionally, Majesco offers consulting and insurance specific IT services for testing, data conversion, data-warehousing/BI, mobility, enterprise integration…',
#  '1-3 years of systems analyst experience.\nProficiency with Microsoft Excel is mentioned in virtually any financial analyst job description; familiarity with data…',
#  'Expertise in Adobe Analytics and web clickstream data.\nCollaborate with various teams to ensure ongoing data quality by validating analytics instrumentation.',
#  'Ability to analyze data and interpret inconsistencies.\nRate and Contracting support for new and existing Customers.\nHigh School Diploma is Required*.']

# %%
job_list_max_df = pd.DataFrame(list(zip(jobs11, companies11, locations11, summaries11)),
               columns = ['job_title', 'company_name', 'location', 'summary'])
job_list_max_df
# Out:
#                                            job_title  \
# 0                             Data Analyst - YouTube
# 1                                 Data Entry Analyst
# 2                    Marketing Data Analyst (REMOTE)
# 3                                       Data Analyst
# 4                                       Data Analyst
# ..                                               ...
# 992                 Data Analyst - San Francisco, CA
# 993                       Principal Business Analyst
# 994                                 Business Analyst
# 995                              Digital Web Analyst
# 996  Financial Analyst Assistant - Logistics Company
#
#                       company_name                          location  \
# 0                 Webhelp Americas  San Bruno, CA•Temporarily Remote
# 1                CR&R Incorporated                       Stanton, CA
# 2                Molina Healthcare       Long Beach, CA 90802•Remote
# 3                       Databricks      California+1 location•Remote
# 4                            Ursus               Sunnyvale, CA 94089
# ..                             ...                               ...
# 992                          Kelly     South San Francisco, CA 94083
# 993    Majesco- Insurance/Software         Stanford, CA 94305•Remote
# 994             APR Consulting Inc               San Diego, CA 92121
# 995                          Ursus                 San Francisco, CA
# 996  Wollborg Michelson Recruiting     Irvine, CA•Temporarily Remote
#
#                                                summary
# 0    Strong grasp on data structure and data integr...
# 1    Analyze route efficiencies using historical da...
# 2    Designs and implements processes and solutions...
# 3    Establish best practices around data model gov...
# 4    The main function of a data analyst is to coor...
# ..                                                 ...
# 992  Understanding of data architecture concepts su...
# 993  Additionally, Majesco offers consulting and in...
# 994  1-3 years of systems analyst experience.\nProf...
# 995  Expertise in Adobe Analytics and web clickstre...
# 996  Ability to analyze data and interpret inconsis...
#
# [997 rows x 4 columns]

# %%
job_list_max_df.to_csv('job_list_analyst.csv', index=False)
