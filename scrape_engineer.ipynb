# %%
import requests
import bs4
from bs4 import BeautifulSoup as bs
import pandas as pd
from splinter import Browser
import os
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

max_page = 340

jobs14 = []
companies14 = []
locations14 = []
summaries14 = []

for start in range(0, max_page, 10):
    indeed_url = 'http://www.indeed.com/jobs?q=data%20engineer&l=California&start=' + str(start)
    browser.visit(indeed_url)
    time.sleep(5)  
    html = browser.html
    soup = bs(html, "html.parser")
    print(indeed_url)  
    
    #grabbing job title
    #for div in soup.find_all(name='div', attrs={'class':'job_seen_beacon'}):
    for td in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div in td.find_all(name='div', attrs={'class':'heading4 color-text-primary singleLineTitle tapItem-gutter'}):
            for span in div.find_all(name='span'):
                if span.text.strip() != 'new':
                    jobs14.append(span.text.strip())  

    #grabbing company name
    for td2 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div2 in td2.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for span2 in div2.find_all(name='span', attrs={'class':'companyName'}):
                companies14.append(span2.text.strip())      

    #grabbing location
    for td3 in soup.find_all(name='td', attrs={'class':'resultContent'}):
        for div3 in td3.find_all(name='div', attrs={'class':'heading6 company_location tapItem-gutter'}):
            for div4 in div3.find_all(name='div'):
                locations14.append(div4.text.strip())   

    #grabbing summary text
    divs = soup.findAll('div', attrs={'class': 'job-snippet'})
    for div5 in divs:
        summaries14.append(div5.text.strip())

browser.quit()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\SC\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=0
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=10
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=20
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=30
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=40
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=50
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=60
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=70
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=80
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=90
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=100
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=110
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=120
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=130
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=140
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=150
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=160
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=170
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=180
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=190
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=200
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=210
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=220
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=230
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=240
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=250
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=260
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=270
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=280
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=290
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=300
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=310
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=320
# http://www.indeed.com/jobs?q=data%20engineer&l=California&start=330

# %%
jobs14
# Out:
# ['Software Engineer 2, Big Data',
#  'Staff Software Engineer, Big Data',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'SENIOR DATA PLATFORM ENGINEER',
#  'SENIOR DATA ENGINEER',
#  'Data Engineer/ETL Engineer',
#  'Data Engineer',
#  'Data Analyst/Data Engineer',
#  'Data Engineer, Users and Products',
#  'Data Engineer',
#  'Data Engineer (Full Time) United States',
#  'Data Engineer',
#  'Entry Level - Data Engineer / Data Analyst (STEM)',
#  'Entry Level - Data Engineer / Data Analyst (STEM)',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Geospatial Modeling Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'REMOTE Sr. Big Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer (Remote)',
#  'Data Engineer',
#  'Senior Visualization Data Engineer',
#  'Senior Visualization Data Engineer',
#  'Data Engineer - Remote',
#  'Data Engineer (1043), DataSF',
#  'Data Engineer Manager',
#  'Sr. Big Data Engineer',
#  'Data Engineer - All Levels',
#  'Data Engineer',
#  'Data Engineer',
#  'L3 Network Data Center Engineer',
#  'Data Engineer (Python, SQL hands-on)',
#  'AWS Data Engineer',
#  'Software Development Engineer, Big Data',
#  'Senior Data Engineer',
#  'Infrastructure Engineer (Data)',
#  'Data Engineer',
#  'Data Engineer',
#  'SQL Data Engineer',
#  'Associate Data Engineer',
#  'Sr. Data Engineer',
#  'Data Engineer, Growth',
#  'Data Engineer',
#  'Data Infrastructure Engineer',
#  'Data Analyst / Data Engineer',
#  'Data Infrastructure Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Sr. Data Engineer',
#  'Machine Learning Engineer, Risk Data Mining',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer, Data Platform',
#  'Data Engineer, Data Platform - TikTok-US-Tech Services',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Sr Data Engineer',
#  'Freelance - Data Engineer',
#  'Sr. ETL Data Engineer (open to remote)',
#  'Devops Engineer, Data',
#  'Data Engineer, Marketing',
#  'Senior Data Engineer',
#  'Data Science Engineer',
#  'Sr. Security Data Engineer',
#  'Data Engineer',
#  'Big Data/Python Engineer - Junior',
#  'Data Engineer',
#  'Data Engineer',
#  'Entry Level Data Engineer',
#  'Senior Data Engineer (Series D Startup)',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'ML Data Infrastructure Engineer',
#  'Data Engineer, Core Growth',
#  'Principal Data Engineer',
#  'Sr. Data Engineer SDI + Hana',
#  'Data Engineer',
#  'Backend Data Engineer',
#  'Data Engineer',
#  'Network Data Center Engineer',
#  'ML/Data Engineer (NO C2C!!)',
#  'Data Visualization Engineer',
#  'Data Engineer, Core Automation Services',
#  'Data Engineer',
#  'Data Engineer, Analytics (Generalist)',
#  'Data Engineer',
#  'Data Center Equipment Manufacturing Engineer',
#  'Data Engineer I',
#  'Data Visualization Engineer',
#  'Sr. Snowflake / Data Warehouse Data Engineer',
#  'Data Analytics Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Big Data Engineer with Performance Tuning Experience',
#  'Senior Data Engineer',
#  'Data Infrastructure Engineer',
#  'Senior Data Engineer',
#  'Software Engineer - Ads Data',
#  'Data Engineer',
#  'Senior Performance Engineer - Big Data',
#  'Big Data Engineer',
#  'Data Engineer - Drug Discovery',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer (Remote)',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Software Engineer, Online Data Storage',
#  'Sr. Data Engineer, Annotation',
#  'Junior Data Science Engineer (Remote)',
#  'Data Engineer',
#  'Senior Data Engineer BI/ETL',
#  'Data Scientist/ Engineer - R Expertise',
#  'Data Engineer',
#  'Data Reliability Engineer',
#  'Data Engineer',
#  'DATA ENGINEER',
#  'Big Data Engineer',
#  'Software Engineer, Big Data',
#  'Data Engineer',
#  'Data Engineer Manager',
#  'Data Engineer',
#  'Software Engineer, Big Data Matching',
#  'Machine Learning Engineer, Risk Data Mining',
#  'Data Engineer',
#  'Sr. Big Data Engineer',
#  'Data Engineer',
#  'Senior Data/ML Engineer- #7921',
#  'Data Engineer/Analyst',
#  'Data Engineer, Systems',
#  'Software Engineer, Data Infrastructure',
#  'Senior Software Engineer, Data',
#  'Senior Performance Engineer - Big Data',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Sr. Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Machine Learning Engineer, Risk Data Mining',
#  'Data Engineer',
#  'Software Engineer, Big Data',
#  'Hadoop Data Engineer',
#  'Data Engineer',
#  'Data Engineer, Product Analytics',
#  'Data Engineer [Remote]',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Data',
#  'Data Engineer',
#  'Senior Software Engineer, Data',
#  'Software Engineer, SaaS Data Protection',
#  'Big Data/Python Engineer - Junior',
#  'Senior Data Warehouse Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Junior Data Science Engineer (Remote)',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer, Intelligence',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer - Data',
#  'Data Engineer',
#  'Data Engineer, Systems',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Machine Learning Engineer, Data',
#  'Big Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer, Intelligence',
#  'Entry Level Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer - Data',
#  'Data Engineer',
#  'Data Engineer Manager',
#  'Data Engineer',
#  'Sr. Data Engineer',
#  'Data and Visualization Software Engineer',
#  'Big Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Infrastructure Engineer',
#  'Senior Data Engineer',
#  'Data Visualization Engineer',
#  'Data Engineer II',
#  'Data Engineer, Analytics (Generalist)',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer - Big Data Technologies',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Sr. Software Engineer Data Ingestion',
#  'Data Engineer Pipeline (Kafka Heavy)',
#  'Software Engineer, ML Data Intelligence',
#  'Senior Data Engineer',
#  'Data Engineer : 21-04320',
#  'Data Engineer, Machine Learning',
#  'Software Engineer, Risk Data Mining',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Big Data',
#  'Data Engineer II',
#  'Data Engineer',
#  'Senior Software Engineer, Data Privacy',
#  'Data Engineer',
#  'Software Engineer - Risk Data Mining',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Data Platform Engineer',
#  'Senior Data Engineer',
#  'Data Center Efficiency Engineer, Advanced Technology and Inn...',
#  'Data Engineer, Data Platform - TikTok-US-Tech Services',
#  'Senior Data Engineer',
#  'Data Scientist and AI Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Data Platform',
#  'Sr. Software Engineer Data Ingestion',
#  'Data Engineer - Drug Discovery',
#  'Data Engineer, Product Analytics',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'QA Data Engineer',
#  'Data Engineer',
#  'Data Analytics Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Big Data Software Engineer',
#  'Software Engineer - Data',
#  'Data engineer',
#  'Senior Performance Engineer - Big Data',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Senior Software Engineer, Data',
#  'Senior Data Engineer',
#  'Sr. Adobe Campaign Data Engineer',
#  'Data Engineer',
#  'Data Engineer - 3786626',
#  'Data Engineer',
#  'Sr Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Data Center Equipment Manufacturing Engineer',
#  'Data Services Engineer I',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Global Data Warehouse',
#  'Data Engineer',
#  'Cloud Data Engineer',
#  'Senior Software Engineer- Data Engineering',
#  'Senior Data Engineer - Machine Learning',
#  'Product Sensing Data Engineer',
#  'Healthcare Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Sr. Data Engineer',
#  'Senior Data Engineer',
#  'Sr. Data Engineer',
#  'Sr. Data Engineer',
#  'Software Engineer - Big Data Technologies',
#  'Software Engineer, SaaS Data Protection',
#  'R&D Test Engineer: Data Scientist',
#  'Autonomous Driving - Staff Robotics Engineer - Grid based Se...',
#  'Sr. Data Engineer SDI + Hana',
#  'Data Engineer',
#  'SR Data Engineer',
#  'Data Engineer, Product Analytics',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Entry Level Data Engineer',
#  'Big Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer',
#  'Software Engineer - Ads Data',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Software Engineer- Data Engineering',
#  'Data Analytics Engineer',
#  'Autonomous Driving - Staff Robotics Engineer - Grid based Se...',
#  'Data Engineer I',
#  'Data Scientist / Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer (Remote)',
#  'Senior Data Engineer',
#  'Software Engineer - Data Platform',
#  'Biomedical Data Engineer',
#  'Data Engineer I',
#  'Senior Data Engineer – Disney Streaming',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Systems Engineer',
#  'Data Engineer',
#  'Sr. Data Engineer',
#  'Software Engineer, CRM Data',
#  'Sr. Data Engineer',
#  'Senior Data Engineer',
#  'IT Data & Integration Engineer',
#  'Data Engineer',
#  'Sr. Data Engineer - Microservices',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Senior Data Engineer - Machine Learning',
#  'Software Engineer - Data Engineer',
#  'Sr. Data Engineer, Data Platform',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Sr. Data Engineer - Homebase',
#  'Software Engineer, Data Products',
#  'Software Engineer, Data',
#  'Software Engineer, Data',
#  'Senior Data Engineer',
#  'Big Data Engineer (Remote for now)',
#  'Data Analytics Engineer',
#  'IT Data Engineer - Reporting, Analytics and Data Delivery',
#  'SQL Data Engineer',
#  'Senior Data Engineer',
#  'Sr. Data Engineer',
#  'Senior Data Engineer - Central Technology Leadership, Biz Op...',
#  'Senior Data Engineer, Intelligence',
#  'Software Engineer, Big Data',
#  'Software Engineer Data Lake Storage',
#  'Data Engineer',
#  'Software Engineer, ML Data Intelligence',
#  'Data engineer',
#  'Data Engineer (Must have professional experience with Spark...',
#  'Big Data Engineer (Remote for now)',
#  'Software Engineer III, Core Data, SQL Language Layer',
#  'MMS Data Management Application Engineer',
#  'Senior Data Engineer',
#  'Software Engineer - Data Engineer',
#  'Data Platform Engineer',
#  'Data Analytics Engineer',
#  'Senior Frontend Software Engineer, Data Visualization',
#  'Senior Software Engineer, Data Privacy',
#  'Data engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Sr. Data Engineer SDI + Hana',
#  'Data Engineer, Analytics (Generalist)',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Data Platform',
#  'Sr Staff Data Engineer',
#  'Senior Data Engineer- Data Streaming',
#  'Sr. Data Engineer, CRM / Martech',
#  'Senior, AWS Data Engineer',
#  'Software Engineer - Data',
#  'Data Engineer / Python Developer',
#  'Software Engineer, Data',
#  'Data Visualization Engineer',
#  'Lead Software Engineer, Core Data',
#  'Data Scientist and AI Engineer',
#  'Software and Data Engineer',
#  'Data Engineer',
#  'Big Data Engineer with Performance Tuning Experience',
#  'Devops Engineer, Data',
#  'Senior Software Engineer, Data Privacy',
#  'Data Engineer I',
#  'Data Engineer II - Wild Rift',
#  'Data Visualization Engineer (Tableau Developer)',
#  'Sr. Data Engineer, Annotation',
#  'Data Engineer',
#  'Data engineer',
#  'Data Engineer',
#  'Data Infrastructure Engineer',
#  'Tooling & Data Visualization Engineer',
#  'Software Engineer - Data Stream Processing - US REMOTE',
#  'Data Infrastructure Engineer',
#  'Data Infrastructure Engineer',
#  'Data Scientist and AI Engineer',
#  'Data Engineer',
#  'Backend Software Engineer - Data Storage',
#  'MMS Data Management Application Engineer',
#  'Machine Learning Data Engineer',
#  'Data Engineer / Python Developer',
#  'Data Engineer I',
#  'Software Engineer - Data',
#  'Backend Engineer - Data Platform (Remix by Via)',
#  'Senior Data Engineer',
#  'Senior Data Analysis Engineer',
#  'Data engineer',
#  'Senior Software Engineer, Data Privacy',
#  'Front End Engineer - Data Visualization',
#  'Data Engineer',
#  'Data Analytics Engineer (Remote Friendly)',
#  'QA Data Engineer',
#  'Autonomous Driving - Lead Robotics Engineer - Grid based Sen...',
#  'Data Center Engineer',
#  'Software Engineer, Data Platform',
#  'Senior UI Engineer, Data',
#  'Sr. Data Engineer',
#  'Software Engineer, Data Engineer',
#  'Senior Data Analysis Engineer',
#  'Sr Staff Data Engineer',
#  'Software and Data Engineer',
#  'Sr. Data Engineer – Snowflake',
#  'Data Engineer',
#  'Lead Data Engineer',
#  'Senior Data Engineer',
#  'Backend Engineer - Data Platform (Remix by Via)',
#  'Software Engineer - Big Data',
#  'Data Science Engineer',
#  'Data Engineer',
#  'Data Engineer, Infastructure and Data Quality',
#  'Data Scientist / ML Engineer',
#  'Big Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer',
#  'Software Engineer III, Optics Data Pipeline and Analysis',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Data/ML Infrastructure',
#  'Data Engineer',
#  'Data Engineer',
#  'Data Engineer',
#  'Software Engineer, Data Engineer',
#  'Data Engineer',
#  'Senior Software Engineer, Data',
#  'Senior Data QA Engineer',
#  'Data Science Engineer (AI)',
#  'Data Analytics Engineer (Remote Friendly)',
#  'Senior Data Engineer',
#  'Data Modeling Engineer (Remote)',
#  'Data Engineer',
#  'Data Platform Software Engineer',
#  'Senior Data Engineer- Data Streaming',
#  'EA18G Growler Mission Data Engineer',
#  'Senior Software Engineer - Big Data with Optimization',
#  'Data Engineer / Python Developer',
#  'Software Engineer, Online Data Storage',
#  'Senior Data Engineer - 19232',
#  'Staff Software Engineer - Data Platform',
#  'Data Engineer',
#  'Software Engineer - Data',
#  'Data Science - Analytics Engineer',
#  'Sr. Data Engineer',
#  'Senior Data Engineer',
#  'Data Engineer',
#  'Senior Data Engineer, Data Platform',
#  'Senior Data Engineer - Global Marketing',
#  'Data Engineer',
#  'Senior Data Platform Engineer',
#  'Software Engineer, Data Infrastructure',
#  'Data and Visualization Software Engineer',
#  'Data Engineer',
#  'Data Visualization Engineer (Tableau Developer)',
#  'SR Data Engineer',
#  'Senior Data Engineer, Business Intelligence',
#  'Machine Learning/Data Science Engineer',
#  'Backend Engineer, Data Platform',
#  'Backend Engineer - Data Collection & Automation',
#  'Data Engineer',
#  'Data Science - Analytics Engineer',
#  'Senior Data Engineer',
#  'Data Analytics Engineer',
#  'Senior Data Engineer',
#  'Data Engineer I']

# %%
companies14
# Out:
# ['Intuit',
#  'Intuit',
#  'Lendistry',
#  'Synaptein Solutions',
#  'Best High technologies',
#  'Harnham',
#  'Harnham',
#  'CDM search',
#  'Robin Healthcare',
#  'MT Global US INC',
#  'Google',
#  "The World's Fastest Growing Rideshare Company",
#  'Cisco Systems',
#  'Projas Technologies',
#  'PCS Global Tech',
#  'PCS Global Tech',
#  "The World's Fastest Growing Rideshare Company",
#  'Johnson Controls',
#  'Awning',
#  'PDS Tech, Inc.',
#  'Yochana IT inc',
#  'KPI Partners',
#  'Kollasoft Inc',
#  'Experian',
#  'Red Bull',
#  'Techwave Consulting Inc.',
#  'Consumer Direct Inc.',
#  'Wurl, Inc',
#  'FocusKPI Inc.',
#  'Activision',
#  'Activision',
#  'Experian',
#  'City and County of San Francisco',
#  'Snapchat',
#  'QuantumBricks',
#  'FanDuel',
#  'IT Hub Inc.',
#  'IBISWorld',
#  'Rangam Consultants Inc.',
#  'Kani Solutions Inc.',
#  'AUTOCONTENT',
#  'Zillow Group',
#  'CoinList',
#  'Invitae',
#  'Sia Partners',
#  'Amazon.com Services LLC',
#  'Thermo Fisher Scientific',
#  'PG&E Corporation',
#  'Capgemini',
#  'Square',
#  'Hive',
#  'Retain.ai',
#  'Alphataraxia',
#  'Komodo Health',
#  'SZ Media',
#  "The World's Largest Social Network",
#  'SIS',
#  'Netflix',
#  'Osmind',
#  'Tech Holding',
#  'Measurabl',
#  'Betterfuture solutions',
#  'TikTok',
#  'TikTok',
#  'Clara Analytics',
#  'HCL Technologies',
#  'Peloton',
#  'TikTok',
#  'First Republic Bank',
#  'LatentView Analytics',
#  "The World's Largest Social Network",
#  'Kaiser Permanente',
#  'Edmunds.com',
#  'Visa',
#  'Tesla',
#  'Saatchi & Saatchi (We Are Saatchi)',
#  'Experian',
#  'Housecall Pro',
#  'Square',
#  'Visa',
#  'Ancestry',
#  'Workday',
#  'Saama Technologies Inc',
#  'Bloom Energy',
#  'Komodo Health',
#  "The World's Largest Social Network",
#  'FieldLevel',
#  'Recruiting From Scratch',
#  'The County of Santa Clara - Technology Services...',
#  'CK Franchising, Inc.',
#  'Aluna',
#  'Snapchat',
#  'InfoObjects',
#  'QuantumBricks',
#  'Tesla',
#  'The Evolvers Group',
#  'Snackpass',
#  'Fisec Gobal',
#  'Braintrust',
#  'Verana Health',
#  'Tesla',
#  "The World's Largest Social Network",
#  'Facebook',
#  'Deckers Brands',
#  'Google',
#  'Park Place Technologies',
#  'Unicorn Technologies, LLC',
#  'OSI Digital',
#  'Projas Technologies',
#  'Kinect',
#  'mPulse Mobile',
#  'Formac Inc',
#  'Intercom',
#  'Cisco Systems',
#  'Balbix',
#  'TikTok',
#  "The World's Largest Social Network",
#  'Workday',
#  'TCS',
#  'Amgen',
#  'Falkonry',
#  'Natera',
#  'Brillio',
#  'Stefanini, Inc',
#  'Backblaze',
#  'Obsidian Security',
#  'Transcend Digital',
#  'Square',
#  'Rivian Automotive',
#  'Wurl, Inc',
#  "The World's Largest Social Network",
#  'eCivis',
#  'Cognizant Technology Solutions',
#  'Facebook',
#  'Hulu',
#  'Chan Zuckerberg Initiative',
#  'Big Bright International',
#  'TCS',
#  'TikTok',
#  'Reddit',
#  'Snapchat',
#  'XIFIN',
#  'LiveRamp',
#  'TikTok',
#  'OEC Group',
#  'QuantumBricks',
#  'Brillio',
#  'Fanatics Inc.',
#  'Proofpoint',
#  'Standard Cognition',
#  'Airtable',
#  'Course Hero',
#  'Workday',
#  'SymphonyRM',
#  'Hemisphere Media Group',
#  'SquareTrade',
#  'Netskope',
#  'Vivo',
#  'Fox Corporation',
#  'REX',
#  'Lyra Health',
#  'Falkonry',
#  'Hive',
#  'Synthego',
#  'RIOS Intelligent Machines, Inc.',
#  'TikTok',
#  'Freestar',
#  'TikTok',
#  'Techwave Consulting Inc.',
#  'NBCUniversal',
#  'Facebook',
#  'Blue Owl',
#  'Lineage Logistics',
#  'Netskope',
#  'Hemisphere Media Group',
#  'Engage3',
#  'Human Interest',
#  'Grabango',
#  'Course Hero',
#  'Rubrik Job Board',
#  'Bloom Energy',
#  'Apixio',
#  'Komodo Health',
#  'Engage3',
#  'Synthego',
#  'AmeriHome Mortgage',
#  'Wurl, Inc',
#  'Panasonic Corporation of North America',
#  'Momentive',
#  'Transcend Digital',
#  'Chipper Cash',
#  'Fox Corporation',
#  'SureCo',
#  'Wing',
#  'Avetta, LLC',
#  'Standard Cognition',
#  'SymphonyRM',
#  'Tesla',
#  'Beshton Software',
#  'Toyota Research Institute',
#  'Squadex',
#  'SureCo',
#  'Chipper Cash',
#  'FieldLevel',
#  'Tradesy',
#  'Agama Solutions',
#  'Twitch Interactive, Inc.',
#  'Facebook',
#  'Snapchat',
#  'Twilio',
#  'Vivo',
#  'Lark Health',
#  'Laiba Technologies',
#  'WarnerMedia',
#  'SureCo',
#  'Facebook',
#  'E. & J. Gallo Winery',
#  'Johnson & Johnson Family of Companies',
#  'Momentive',
#  'LexisNexis',
#  'Tolfrey Group Inc',
#  'Facebook',
#  'San Diego Padres',
#  'Hollywood Park',
#  'The Public Health Company',
#  'Catalytic Data Science',
#  'IBM',
#  'SymphonyRM',
#  'Synthego',
#  'Morecommerce',
#  'Sojern',
#  'Decision Minds India',
#  'Square',
#  'Teladoc Health',
#  'Akraya Inc.',
#  'Motional',
#  'TikTok',
#  '8k Miles',
#  'WarnerMedia',
#  'TikTok',
#  'Tolfrey Group Inc',
#  'Levi Strauss & Co.',
#  'Google',
#  'Tron',
#  'Bytedance',
#  'Netskope',
#  'Metromile',
#  'Synthego',
#  'XPeng Motors',
#  'Numentica LLC',
#  'Google',
#  'TikTok',
#  'EarnUp',
#  'SKT Lab',
#  'EDO, Inc',
#  'Transcend Digital',
#  'Nuro',
#  'Sojern',
#  'Amgen',
#  'Facebook',
#  'HCL Technologies',
#  'Two Chairs',
#  'Activision',
#  'CK Franchising, Inc.',
#  'Projas Technologies',
#  'Incept Data Solutions, Inc',
#  'San Diego Padres',
#  'HP',
#  'Twitch Interactive, Inc.',
#  'DUOPEAK',
#  'Workday',
#  'SADA',
#  'LendUS LLC',
#  'SymphonyRM',
#  'Course Hero',
#  'Carrum Health',
#  'RAPP',
#  'Twitch',
#  'Accenture',
#  'MOLOCO',
#  'WarnerMedia',
#  'Komodo Health',
#  'Teladoc Health',
#  'Google',
#  'HRL Laboratories LLC',
#  'BXGI',
#  'Foursquare',
#  'Uber',
#  'Frontapp',
#  'Trace3',
#  'Robinhood',
#  'Samsara',
#  'Rockley Photonics',
#  'Amino, Inc.',
#  'Trianz',
#  'Fabric Inc.',
#  'Adobe',
#  'Momentive',
#  'Callaway Golf Company',
#  'Proofpoint',
#  'IBM',
#  'Rubrik Job Board',
#  'Mainspring Energy',
#  'Bosch Group',
#  'QuantumBricks',
#  'Twilio',
#  'Surya Systems',
#  'Facebook',
#  'NBCUniversal',
#  'Sprig',
#  'Zefr',
#  'FieldLevel',
#  'Bloom Energy',
#  'Zuora',
#  'Beshton Software',
#  'REX',
#  'Numentica LLC',
#  'TikTok',
#  'Sprig',
#  'SADA',
#  'San Diego Padres',
#  'Robinhood',
#  'Meltwater',
#  'Bosch Group',
#  'Kroll',
#  'DeepMap, Inc',
#  'Tesla',
#  'Zuora',
#  'Natera',
#  'Atlassian',
#  'Amgen',
#  'Stefanini, Inc',
#  'Cosm',
#  'Twilio',
#  'Penumbra US',
#  'Acumen LLC',
#  'Disney Streaming Services',
#  'Twitch',
#  'Tricon Residential',
#  'Lawrence Berkeley National Laboratory',
#  'Streamlit',
#  'Uber',
#  'TikTok',
#  'Finix Payments',
#  'Recruiting From Scratch',
#  'Monolithic Power Systems',
#  '8k Miles',
#  'Enquero Inc',
#  'Blend',
#  'Altruist',
#  'Samsara',
#  'Transform Data',
#  'Faraday Future',
#  'Trianz',
#  'Cowbell Cyber Inc.',
#  'Tradesy',
#  'Opendoor',
#  'Square',
#  'Fathom',
#  'Step Mobile',
#  'Hookit',
#  'Stefanini, Inc',
#  'Projas Technologies',
#  'PennyMac',
#  'Thermo Fisher Scientific',
#  'FieldLevel',
#  'NTERSOL',
#  'Riot Games',
#  'Chipper Cash',
#  'TikTok',
#  'Uber',
#  'Verantos',
#  'Square',
#  'DUOPEAK',
#  'Luth Research',
#  'Stefanini, Inc',
#  'Google',
#  'Hitachi ABB Power Grids',
#  'Helium 10',
#  'Transform Data',
#  'Bloomberg',
#  'Projas Technologies',
#  'Motional',
#  'Google',
#  'DUOPEAK',
#  'Verantos',
#  'Palnar Transmedia',
#  'MotorTrend Group',
#  'QuantumBricks',
#  'Facebook',
#  'Mendel',
#  'MotorTrend Group',
#  'Freestar',
#  'Nuna',
#  'WarnerMedia',
#  'Pluto TV',
#  'MasterClass',
#  'ResMed',
#  'Obsidian Security',
#  'TWO NIL',
#  'Mercari',
#  'LexisNexis',
#  '6sense',
#  'SKT Lab',
#  'TGS Management Company',
#  'Hagerty Consulting Inc',
#  'Formac Inc',
#  'Housecall Pro',
#  'Google',
#  'Acumen LLC',
#  'Riot Games',
#  'Luxoft',
#  'Rivian Automotive',
#  'Atlassian',
#  'DUOPEAK',
#  'Rockstar Games',
#  'Twitch Interactive, Inc.',
#  'TGS Management Company',
#  'Splunk',
#  'Tasktoday',
#  'Tasktoday',
#  'SKT Lab',
#  'Atlassian',
#  'Commure',
#  'Hitachi ABB Power Grids',
#  'Toyota Research Institute',
#  'TWO NIL',
#  'Acumen LLC',
#  'Obsidian Security',
#  'Via',
#  'NutaNXT Technologies',
#  'Light Labs, Inc.',
#  'DUOPEAK',
#  'Google',
#  'Motional',
#  'Embodied Inc.',
#  'Vouch Insurance',
#  'Activision',
#  'Bosch Group',
#  'New Millenium Consulting',
#  'Nuna',
#  'Illumio',
#  'NTERSOL',
#  'Lyell Immunopharma',
#  'light.io',
#  'WarnerMedia',
#  'TGS Management Company',
#  'ServiceNow',
#  'Pluralsight',
#  'California State University',
#  'Syntronic',
#  'Via',
#  'U.S. Bank',
#  'OpenTable',
#  'Alldus',
#  'Brightline',
#  'INFISWIFT TECHNOLOGIES',
#  'Ahead',
#  'BXGI',
#  'Wealthfront',
#  'Fieldwire',
#  'Google',
#  'Verantos',
#  'Beshton Software',
#  'Epirus',
#  'Axos Bank',
#  'Beshton Software',
#  'Navis',
#  'Lyell Immunopharma',
#  'Verantos',
#  'Course Hero',
#  'Hippo Insurance',
#  'Glacier',
#  'Vouch Insurance',
#  'Havas Media',
#  'Fractal.ai',
#  'SS&C Technologies',
#  'Clari',
#  'Pluto TV',
#  'SAIC',
#  'PubMatic',
#  'TWO NIL',
#  'Square',
#  'Splunk',
#  'Discord',
#  'Aspiration Partners',
#  'Lark Health',
#  'Transform Data',
#  'Empower Retirement',
#  'ChowNow',
#  'NBCUniversal',
#  'Peloton',
#  'Riot Games',
#  'HCL Technologies',
#  'Blue River Technology',
#  'Square',
#  'Lark Health',
#  'CipherTrace',
#  'Luxoft',
#  'Surya Systems',
#  'Square',
#  'Salesforce',
#  'Remix',
#  'JetFuel',
#  'Network Capital Funding Corporation',
#  'Resonance AI',
#  'HackerRank',
#  'PARACHUTE HOME',
#  'Intapp',
#  'Kroll']

# %%
locations14
# Out:
# ['Mountain View, CA 94041',
#  'Mountain View, CA 94041',
#  'San Jose, CA•Remote',
#  'Thousand Oaks, CA',
#  'San Jose, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'Union City, CA',
#  'Berkeley, CA 94701•Remote',
#  'California•Remote',
#  'Foster City, CA 94404',
#  'Mountain View, CA',
#  'San Francisco, CA•Remote',
#  'San Jose, CA',
#  'San Jose, CA 95126 (Downtown area)•Temporarily Remote',
#  'Poway, CA•Temporarily Remote',
#  'Poway, CA•Temporarily Remote',
#  'San Francisco, CA•Remote',
#  'San Jose, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94103 (South Of Market area)',
#  'San Francisco, CA•Temporarily Remote',
#  'Newark, CA 94560•Temporarily Remote',
#  'Fremont, CA 94555 (Ardenwood area)',
#  'Costa Mesa, CA 92626•Remote',
#  'Santa Monica, CA',
#  'San Diego, CA 92101',
#  'Irvine, CA (Business District area)',
#  'California•Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'Santa Monica, CA',
#  'Santa Monica, CA',
#  'Costa Mesa, CA 92626•Remote',
#  'San Francisco, CA 94102 (Downtown area)•Temporarily Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'Milpitas, CA•Temporarily Remote',
#  'Los Angeles, CA 90045 (Westchester area)',
#  'Long Beach, CA 90822',
#  'Los Angeles, CA 90012•Remote',
#  'Menlo Park, CA•Remote',
#  'Los Angeles, CA•Temporarily Remote',
#  'Irvine, CA',
#  'San Francisco, CA 94102 (Downtown area)•Remote',
#  'California•Remote',
#  'San Francisco, CA 94107 (South of Market area)+2 locations',
#  'Palo Alto, CA 94303',
#  'Santa Monica, CA 90404 (Mid-City area)',
#  'Carlsbad, CA 92008',
#  'San Francisco, CA 94105 (Financial District area)',
#  'San Jose, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Francisco, CA 94107 (South Of Market area)',
#  'Newport Beach, CA',
#  'San Francisco, CA',
#  'Burbank, CA',
#  'Fremont, CA',
#  'Austin, CA',
#  'Los Gatos, CA',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA 90023',
#  'San Diego, CA 92101•Remote',
#  'Foster City, CA 94404',
#  'Mountain View, CA',
#  'Mountain View, CA',
#  'Santa Clara, CA 95050',
#  'Sunnyvale, CA•Temporarily Remote',
#  'Santa Clara, CA',
#  'Mountain View, CA',
#  'San Francisco, CA 94111 (Financial District area)',
#  'San Jose, CA•Temporarily Remote',
#  'Fremont, CA',
#  'Oakland, CA',
#  'Santa Monica, CA 90404 (Mid-City area)•Remote',
#  'Foster City, CA',
#  'Lathrop, CA',
#  'El Segundo, CA 90245',
#  'Costa Mesa, CA 92626•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'Foster City, CA',
#  'San Francisco, CA 94107 (South Beach area)',
#  'Pleasanton, CA',
#  'Campbell, CA 95008',
#  'San Jose, CA 95134 (North San Jose area)',
#  'California•Remote',
#  'Fremont, CA',
#  'California•Remote',
#  'Sunnyvale, CA 94085+20 locations•Remote',
#  'Santa Clara, CA',
#  'Irvine, CA 92614',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Jose, CA•Remote',
#  'Milpitas, CA•Temporarily Remote',
#  'Fremont, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'Menlo Park, CA',
#  'San Francisco, CA 94147 (Marina area)•Remote',
#  'San Francisco, CA•Remote',
#  'Fremont, CA',
#  'Fremont, CA',
#  'Burlingame, CA 94010+3 locations',
#  'Goleta, CA 93117',
#  'Sunnyvale, CA (Lakewood area)',
#  'Santa Barbara, CA',
#  'Oakland, CA•Temporarily Remote',
#  'Irvine, CA•Remote',
#  'San Francisco, CA 94104 (Financial District area)•Temporarily Remote',
#  'California+1 location',
#  'Los Angeles, CA 91436 (Encino area)•Remote',
#  'Sunnyvale, CA',
#  'San Francisco, CA 94105 (South Beach area)',
#  'San Jose, CA',
#  'San Jose, CA',
#  'Mountain View, CA',
#  'Fremont, CA',
#  'San Mateo, CA 94402 (Aragon area)',
#  'Costa Mesa, CA 92626',
#  'Thousand Oaks, CA',
#  'Sunnyvale, CA 94087 (Serra area)•Remote',
#  'San Carlos, CA 94070',
#  'Santa Clara, CA 95054',
#  'San Francisco, CA•Remote',
#  'San Mateo, CA 94401 (North Central area)•Remote',
#  'Newport Beach, CA 92660+1 location',
#  'Los Angeles, CA•Remote',
#  'San Francisco, CA',
#  'Irvine, CA+1 location',
#  'California•Remote',
#  'Fremont, CA',
#  'Pasadena, CA 91103 (West Central area)',
#  'Campbell, CA',
#  'Menlo Park, CA 94025+1 location',
#  'Santa Monica, CA',
#  'California•Remote',
#  'Irvine, CA',
#  'Costa Mesa, CA 92626',
#  'Mountain View, CA',
#  'California•Remote',
#  'Los Angeles, CA 90291 (Venice area)',
#  'San Diego, CA 92130',
#  'San Francisco, CA•Remote',
#  'Mountain View, CA',
#  'Cerritos, CA 90703',
#  'Milpitas, CA•Temporarily Remote',
#  'Santa Clara, CA 95054',
#  'San Mateo, CA',
#  'Sunnyvale, CA 94085',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'Redwood City, CA',
#  'San Mateo, CA 94402 (Aragon area)',
#  'Palo Alto, CA 94301 (Professorville area)+1 location•Temporarily Remote',
#  'Santa Monica, CA 90404',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Jose, CA',
#  'Los Angeles, CA',
#  'Woodland Hills, CA 91367',
#  'Burlingame, CA 94010',
#  'Sunnyvale, CA 94087 (Serra area)•Remote',
#  'San Francisco, CA',
#  'Menlo Park, CA 94025•Temporarily Remote',
#  'San Francisco Bay Area, CA',
#  'Mountain View, CA',
#  'California•Remote',
#  'Mountain View, CA',
#  'San Diego, CA 92101',
#  'List, CA+1 location',
#  'Burlingame, CA 94010+4 locations',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'Santa Monica, CA 90404',
#  'Davis, CA',
#  'California•Remote',
#  'California•Remote',
#  'Redwood City, CA',
#  'Palo Alto, CA+1 location',
#  'San Jose, CA 95134 (North San Jose area)',
#  'San Mateo, CA',
#  'California•Remote',
#  'Davis, CA',
#  'Menlo Park, CA 94025•Temporarily Remote',
#  'Thousand Oaks, CA',
#  'California•Remote',
#  'Palo Alto, CA',
#  'California•Remote',
#  'Los Angeles, CA•Remote',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Santa Ana, CA 92707',
#  'Palo Alto, CA',
#  'California•Remote',
#  'San Francisco, CA•Remote',
#  'Palo Alto, CA 94301 (Professorville area)+1 location•Temporarily Remote',
#  'Fremont, CA',
#  'San Francisco Bay Area, CA',
#  'Los Altos, CA 94022',
#  'Palo Alto, CA',
#  'Santa Ana, CA 92707',
#  'California•Remote',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Menlo Park, CA 94025+1 location',
#  'Los Angeles, CA 90291 (Venice area)',
#  'California•Remote',
#  'San Jose, CA',
#  'California•Remote',
#  'Sunnyvale, CA•Temporarily Remote',
#  'Burbank, CA 91505+1 location',
#  'Santa Ana, CA 92707',
#  'Menlo Park, CA 94025+1 location',
#  'Modesto, CA',
#  'Redwood City, CA 94065 (Dolphin area)+1 location',
#  'California•Remote',
#  'Menlo Park, CA•Remote',
#  'San Francisco, CA 94107 (South Of Market area)•Remote',
#  'Burlingame, CA 94010+3 locations',
#  'San Diego, CA (East Village area)',
#  'Inglewood, CA',
#  'California•Remote',
#  'San Francisco, CA 94102 (Downtown area)',
#  'San Jose, CA 95101 (North Valley area)',
#  'Palo Alto, CA 94301 (Professorville area)+1 location•Temporarily Remote',
#  'Menlo Park, CA 94025•Temporarily Remote',
#  'Chico, CA',
#  'San Francisco, CA 94111 (Financial District area)•Remote',
#  'Santa Clara, CA',
#  'San Francisco, CA',
#  'Mountain View, CA',
#  'Sunnyvale, CA 94086+1 location',
#  'Santa Monica, CA',
#  'Mountain View, CA',
#  'Pleasanton, CA',
#  'Burbank, CA 91505+1 location',
#  'Mountain View, CA',
#  'San Francisco, CA 94107 (South Of Market area)•Remote',
#  'San Francisco, CA (North Waterfront area)',
#  'San Francisco, CA',
#  'California•Remote',
#  'Mountain View, CA',
#  'California•Remote',
#  'San Francisco, CA 94107 (Yerba Buena area)',
#  'Menlo Park, CA 94025•Temporarily Remote',
#  'Mountain View, CA',
#  'Palo Alto, CA',
#  'Sunnyvale, CA (Lakewood area)',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'Santa Clara, CA',
#  'San Francisco, CA 94117 (Hayes Valley area)+1 location',
#  'Los Angeles, CA•Remote',
#  'Mountain View, CA',
#  'San Francisco, CA 94111 (Financial District area)•Remote',
#  'Thousand Oaks, CA',
#  'Burlingame, CA 94010+4 locations',
#  'Sunnyvale, CA•Temporarily Remote',
#  'California',
#  'Sherman Oaks, CA',
#  'Irvine, CA 92614',
#  'San Francisco, CA 94104 (Financial District area)•Temporarily Remote',
#  'San Jose, CA',
#  'San Diego, CA (East Village area)',
#  'San Diego, CA 92127 (Rancho Bernardo area)',
#  'San Francisco, CA',
#  'Menlo Park, CA',
#  'San Mateo, CA 94402 (Aragon area)',
#  'San Francisco, CA+1 location',
#  'Alamo, CA',
#  'Palo Alto, CA 94301 (Professorville area)+1 location•Temporarily Remote',
#  'Redwood City, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA 90010 (Koreatown area)',
#  'San Francisco, CA',
#  'Walnut Creek, CA+5 locations',
#  'Redwood City, CA',
#  'Culver City, CA+1 location',
#  'California•Remote',
#  'Mountain View, CA',
#  'Sunnyvale, CA (Lakewood area)',
#  'Malibu, CA 90265',
#  'Palo Alto, CA•Remote',
#  'Los Angeles, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA',
#  'Irvine, CA',
#  'Menlo Park, CA',
#  'San Francisco, CA',
#  'Irvine, CA 92617',
#  'California•Remote',
#  'San Francisco, CA 94104 (Financial District area)',
#  'California•Remote',
#  'San Jose, CA',
#  'California•Remote',
#  'Carlsbad, CA 92008 (North Beach area)',
#  'Sunnyvale, CA 94085',
#  'San Jose, CA 95101 (North Valley area)',
#  'Palo Alto, CA+1 location',
#  'Menlo Park, CA 94025',
#  'Sunnyvale, CA 94085 (East Murphy area)',
#  'Milpitas, CA•Temporarily Remote',
#  'California•Remote',
#  'San Francisco, CA•Temporarily Remote',
#  'Burlingame, CA 94010+4 locations',
#  'Burbank, CA+1 location',
#  'San Francisco, CA',
#  'California•Remote',
#  'California•Remote',
#  'San Jose, CA 95134 (North San Jose area)•Remote',
#  'California•Remote',
#  'San Francisco Bay Area, CA',
#  'Redwood City, CA 94065 (Dolphin area)',
#  'Palo Alto, CA',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'San Francisco, CA+1 location',
#  'San Diego, CA (East Village area)',
#  'Menlo Park, CA',
#  'San Francisco, CA•Remote',
#  'Sunnyvale, CA 94085 (East Murphy area)',
#  'Pomona, CA',
#  'Palo Alto, CA 94303',
#  'Fremont, CA',
#  'California•Remote',
#  'San Carlos, CA 94070',
#  'San Francisco, CA',
#  'Thousand Oaks, CA+1 location',
#  'San Francisco, CA•Remote',
#  'Los Angeles, CA',
#  'California•Remote',
#  'Alameda, CA',
#  'Burlingame, CA 94010',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Santa Ana, CA 92705',
#  'San Francisco Bay Area, CA•Remote',
#  'California•Remote',
#  'San Francisco, CA 94103 (South of Market area)',
#  'Mountain View, CA',
#  'San Francisco, CA',
#  'Burlingame, CA 94010+27 locations',
#  'San Jose, CA 95119 (Santa Teresa area)',
#  'Pleasanton, CA',
#  'Milpitas, CA 95035•Remote',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA•Remote',
#  'Gardena, CA',
#  'San Francisco, CA 94104 (Financial District area)',
#  'Pleasanton, CA 94566',
#  'California•Remote',
#  'San Francisco Bay Area, CA•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'Palo Alto, CA',
#  'San Diego, CA',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA 94104 (Financial District area)•Temporarily Remote',
#  "Agoura Hills, CA 91301 (Whizin's Row area)",
#  'Carlsbad, CA 92008',
#  'California•Remote',
#  'Orange County, CA',
#  'Los Angeles, CA 90064 (Sawtelle area)',
#  'California•Remote',
#  'Mountain View, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'California•Remote',
#  'San Francisco, CA',
#  'Menlo Park, CA',
#  'San Diego, CA 92101 (Core-Columbia area)',
#  'San Francisco, CA•Remote',
#  'Sunnyvale, CA (Lakewood area)',
#  'San Jose, CA',
#  'California•Remote',
#  'San Francisco, CA•Remote',
#  'San Francisco, CA',
#  'San Francisco, CA 94104 (Financial District area)•Temporarily Remote',
#  'Santa Monica, CA 90401 (Downtown/Third Street Promenade area)',
#  'San Francisco, CA',
#  'Menlo Park, CA',
#  'California•Remote',
#  'San Francisco, CA+1 location•Temporarily Remote',
#  'California•Remote',
#  'Milpitas, CA•Temporarily Remote',
#  'Burlingame, CA 94010+3 locations',
#  'San Jose, CA 95126 (Downtown area)',
#  'California•Remote',
#  'California•Remote',
#  'San Francisco, CA',
#  'Culver City, CA',
#  'Los Angeles, CA 90069',
#  'San Francisco, CA',
#  'San Diego, CA 92123 (Kearny Mesa area)',
#  'Redwood City, CA 94063+1 location',
#  'Los Angeles, CA•Temporarily Remote',
#  'California•Remote',
#  'Menlo Park, CA•Remote',
#  'San Francisco, CA',
#  'Santa Clara, CA',
#  'Irvine, CA 92604',
#  'Sacramento, CA 95814 (Mansion Flats area)',
#  'Sunnyvale, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Burlingame, CA 94010',
#  'Los Angeles, CA 90064 (Sawtelle area)',
#  'Oakland, CA',
#  'Irvine, CA+1 location',
#  'San Francisco, CA',
#  'Menlo Park, CA',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'Irvine, CA 92604',
#  'San Francisco, CA 94107 (South Of Market area)+1 location•Remote',
#  'Newark, CA',
#  'Newark, CA',
#  'Santa Clara, CA',
#  'San Francisco, CA',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'Los Altos, CA 94022•Remote',
#  'Los Angeles, CA•Temporarily Remote',
#  'Burlingame, CA 94010',
#  'Redwood City, CA 94063+1 location',
#  'California•Remote',
#  'Santa Clara, CA',
#  'Redwood City, CA',
#  'Menlo Park, CA',
#  'San Francisco, CA',
#  'Los Angeles, CA',
#  'Pasadena, CA•Remote',
#  'San Francisco, CA•Remote',
#  'Sherman Oaks, CA',
#  'Sunnyvale, CA 94085 (East Murphy area)',
#  'Hollywood, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'California•Remote',
#  'Orange County, CA',
#  'South San Francisco, CA',
#  'Redwood City, CA',
#  'Culver City, CA',
#  'Irvine, CA 92604',
#  'Santa Clara, CA 95054',
#  'Los Angeles, CA•Remote',
#  'San Jose, CA',
#  'Santa Clara, CA',
#  'California•Remote',
#  'San Francisco, CA',
#  'Los Angeles, CA+1 location',
#  'California',
#  'California•Remote',
#  'Milpitas, CA•Remote',
#  'San Ramon, CA',
#  'Palo Alto, CA•Remote',
#  'Palo Alto, CA 94301 (University South area)•Remote',
#  'California•Remote',
#  'Mountain View, CA',
#  'California•Remote',
#  'San Francisco Bay Area, CA',
#  'Hawthorne, CA',
#  'San Diego, CA 92122 (University City area)',
#  'San Francisco Bay Area, CA',
#  'Oakland, CA',
#  'South San Francisco, CA',
#  'California•Remote',
#  'Redwood City, CA',
#  'Palo Alto, CA',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA•Remote',
#  'Carlsbad, CA',
#  'California•Remote',
#  'San Francisco, CA 94104 (Financial District area)',
#  'San Francisco Bay Area, CA',
#  'Los Angeles, CA 90069',
#  'Point Mugu NAWC, CA',
#  'Redwood City, CA 94063 (Downtown area)',
#  'Los Angeles, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'San Jose, CA 95131 (North Valley area)+4 locations',
#  'California+1 location•Remote',
#  'Los Angeles, CA•Remote',
#  'California•Remote',
#  'San Francisco, CA•Remote',
#  'Redwood City, CA',
#  'Los Angeles, CA (Playa Vista area)•Remote',
#  'List, CA+1 location',
#  'Santa Clara, CA',
#  'Los Angeles, CA 90064 (Sawtelle area)',
#  'Sunnyvale, CA•Temporarily Remote',
#  'Sunnyvale, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'San Francisco Bay Area, CA',
#  'Oakland, CA',
#  'San Francisco, CA•Temporarily Remote',
#  'San Francisco, CA',
#  'Palo Alto, CA 94301 (Downtown North area)+1 location',
#  'San Francisco, CA 94103 (South of Market area)',
#  'San Francisco, CA',
#  'Irvine, CA',
#  'San Francisco, CA',
#  'California•Remote',
#  'Los Angeles, CA',
#  'Palo Alto, CA 94306',
#  'Pomona, CA']

# %%
summaries14
# Out:
# ['Overview Our formula for innovation begins with agile, cross-functional teams that welcome diverse perspectives and embrace collaboration. Inspirational…',
#  'Overview Our formula for innovation begins with agile, cross-functional teams that welcome diverse perspectives and embrace collaboration. Inspirational…',
#  'Partner with data producers in understanding data sources, enable data contracts, and define the data model that drives analytics.',
#  'Proven proficiency with scripting languages such as Python, Ruby, and JavaScript, and build tools such as Jenkins, Maven, Ant, Gradle or Ivy.',
#  'Demonstrated ability to analyze large data sets to identify gaps and inconsistencies, provide data insights and advance effective product solutions.',
#  'Define best data driven practices.\nImplement and maintain data processing code.\nCommercial experience with managing data infrastructure.',
#  'Define best data driven practices.\nImplement and maintain data processing code.\nCommercial experience with managing data infrastructure.',
#  'Troubleshoot emergent customer data pipeline issues.\nUnderstand the evolving needs of the customer-facing product and data science teams, and how these will be…',
#  'Develop democratized dashboards, data sets, and KPIs that empower less technical owners and operators across the business to make data-driven business decisions…',
#  '\\* Owner of the core company data pipeline, responsible for scaling up data processing flow to meet the rapid data growth;\n目前急招 Full-time.',
#  'Experience designing data models and data warehouses and with non-relational data storage systems (NoSQL and distributed database management systems).',
#  'Own core company data pipeline, being responsible for scaling up data processing flow to meet rapid data growth.\nSchedule: Monday - Friday, 40 hours per week.',
#  'Analyze structural requirements for data storage solutions and software.\nData Engineers are focused on enabling a data driven approach to optimization by…',
#  '\\*3+ years’ experience working as an engineer in a data focused team developing data processing frameworks and capabilities.\nJob Types: Full-time, Contract.',
#  'Provides plan with data, reporting, and analyses that enable data-driven decision-making.\nExperience with other relational databases, BI reporting and data…',
#  'Provides plan with data, reporting, and analyses that enable data-driven decision-making.\nExperience with other relational databases, BI reporting and data…',
#  'Own core company data pipeline, being responsible for scaling up data processing flow to meet rapid data growth.\nSchedule: Monday - Friday, 40 hours per week.',
#  'Design and implement scalable and reliable data models for our data.\nDesign and build efficient data pipelines to move data across systems – SQL, NoSQL, GCP.',
#  'Integrate third-party data sources with our data infrastructure.\nYou have 3+ years or experience and are capable of working as the sole data & machine learning…',
#  'Implement scalable data-intensive processing pipelines that applies geospatial data to ML/DL models.\nExperience in stats/ML model training, validation, data…',
#  'Major skills required: Tableau, ETL, Informatica and GCP.\nSkills: All GCP core services, Python, SQL, Big query, Data Warehousing, Data Modelling, ETL, Oracle…',
#  'We have quite a few open positions with our direct clients in West Coast Area, USA with least or no competition.\nType: Citizens, GC,H1B, H4, OPT.',
#  'Data modeling and data pipeline development.\nData modeling and data pipeline development: 8 years (Required).\nMust sit in California or Seattle, WA (no remote).',
#  'Strong understanding of data analytics and data visualization.\nRealtime data feed processing using Big Data ecosystem.\nMaster Degree is a plus.',
#  'Ensure ongoing data quality and manage data governance that enables rapid adoption- Support the creation and facilitation of data engineering education programs…',
#  'Define data validation tests to run in the data pipeline.\nYou and the team are responsible for building, deploying, maintaining, and optimizing the data…',
#  'Build data expertise and own data quality for allocated areas of ownership.\n3+ years of experience in implementing modern data architecture-based data…',
#  'Wurl is seeking a detail-oriented data scientist/engineer with strong analytical and communication skills to join and grow with our data analytics team.',
#  'Experience designing and operating data services & data pipelines.\nOptimize existing data pipelines and create new ones to manage data sets while learning the…',
#  '3+ years of experience as a data engineer.\nHelp shape the growth of in-house data resources to support business Intelligence, analytics, and data science.',
#  '3+ years of experience as a data engineer.\nHelp shape the growth of in-house data resources to support business Intelligence, analytics, and data science.',
#  'Experience with commercial credit data.\nThe analyst will be conducting analyses and producing reports based on data generated from several different sources and…',
#  'We work to streamline data access through light, agile data infrastructure, improving data management and governance, boosting capacity to use data through…',
#  'Experience leading a small team of data or software engineers.\nDevelop data pipelines adhering with privacy and governance principles.',
#  'Deep understanding of Big data and Hadoop architecture.\nStrong knowledge of data structures, algorithms, & distributed systems.\nJob Types: Part-time, Contract.',
#  'Our competitive edge comes from making decisions based on accurate and timely data.\nYou should be comfortable building complex yet performant SQL queries on…',
#  'Demonstrated ability to analyze large data sets to identify gaps and inconsistencies, provide data insights, and advance effective product solutions.',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures and data sets.\nThe Data Engineer will support our software developers, database…',
#  'Looking for those network/data center engineers that like blinky lights.\nProvide onsite network support and expertise for all teams on the local data center,…',
#  '5+ years of experience in data engineering.\nStrong background in data warehouse concept and design.\nHire Type: *Permanent / Full Time OR Contract (6 Months+).',
#  'Looking for AWS Data engineer.\nExperienced in using various AWS services related to Data.\nJob Types: Full-time, Contract.',
#  'In certain cases, an employee in a remote-designated job may need to live in a specific region or time zone to support customers or clients as part of their…',
#  'A data engineer with at least 3 years of work experience.\nDesign and implement data warehousing solutions.\nDesign and enhance data collection procedures.',
#  "BONUS: Prior experience utilizing data warehousing or building out data warehouses.\nImprove our data platform's observability utilizing custom metrics and/or…",
#  'Partner with our client’s leadership teams, engineers, program managers and data analysts to understand data needs.\nExperience with data quality and validation.',
#  'Experience in data modeling, data warehousing, and building data pipelines.\nKnowledge of data warehousing concepts.',
#  'Understand various business needs and requirements for a consistent and flexible set of data rules and standards.',
#  'Build high-performance data pipelines and prototypes that enable business use of the data.\nExperience in data engineering, 1 years.',
#  'Expertise in writing/leveraging connectors to different data stores for extracting the data.\nHands on Data wrangling/profiling/transforming expertise with…',
#  'Understand and implement data logging best practices to support our data flow.\nPartner closely with data scientists, business Intelligence analysts and machine…',
#  'Building out our data infrastructure and managing dependencies between data pipelines.\nYou have 1-2 years of industry experience as a data engineer.',
#  'The Retain product has found a strong product/market fit, and as one of the first data engineers on the team you will have full ownership and autonomy to define…',
#  'Ensure robust data handling data of new and existing resources.\nDefining goals for data management and strategizing how to use data resources most effectively.',
#  "Experience with cloud and big-data tools and frameworks like Spark, Airflow, Snowflake, and so on.\nWe own Komodo's software infrastructure, which all…",
#  'An ability to provide technical guidance, direction and problem solving to data engineering team members.\n8+ years of experience as a Data Warehouse Analyst,…',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures, and data sets.\nThe ideal candidate is an experienced data pipeline builder and data…',
#  'Experience in implementing data pipelines using python.\nWork with team members to assist with data-related technical issues and support their data product needs…',
#  'Our Streaming Data Science & Engineering team is looking for a Senior Data Engineer fluent in data engineering and software engineering to build reliable,…',
#  'Develop complex data processing pipelines from multiple data sources.\n4+ years data engineering experience.\nLead the design of our data infrastructure.',
#  'The Data Engineer will support our software developers, data analysts, and data scientists on data initiatives.',
#  'Build infrastructure required for optimal ETL/ELT of data into the data warehouse.\nAbility to build and optimize data sets, data pipelines, and architectures.',
#  'Experience analyzing and collecting data as our data needs grow.\nWe have MySQL databases for our production OLTP systems and our data lake/data warehouse built…',
#  'Reason and communicate in result-oriented, data-driven manner.\nProtect TikTok users, including and beyond content consumers, creators, advertisers;',
#  '6、Collaborate team members (e.g., data architects, data scientists) on the project’s goals.\n3、Recommend different ways to constantly improve data reliability…',
#  'Build frameworks to handle data at high scale using technologies like Apache Spark and data cataloging tools like Apache Hive, AWS Glue on top of a multi-tiered…',
#  'Should have working experience of using Spark data frame and data sets.\n_\\*Candidates must be authorized to work in the U.S. We are unable to sponsor work visas…',
#  'As a part of the Data Platform team, you will be working across a wide range of problems in the data ingestion, data compute, data transport, data orchestration…',
#  'Experience in performing data analysis, data ingestion and ETL(Extraction, Transformation & Loading).\nEstablish solid design and best engineering practice for…',
#  'Develop Pipelines, ensuring the best practice are implemented for data governance, data quality, data lineage and data cleansing.',
#  'Big data: 3 years (Required).\n3+ years of experience in working with big data and related technologies.\nLatentView Analytics is a leading global analytics and…',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures, and data sets.\nThe ideal candidate is an experienced data pipeline builder and data…',
#  'You will transform data from data warehouse tables into impactful membership growth initiatives.\nYou will sit at the intersection of data engineering and data…',
#  'Big data tools: Spark, etc.\nWork with stakeholders including the Executive, Product, and Data teams to assist with data-related technical issues and support…',
#  'Develop custom data models and algorithms to apply to data sets.\nExtracting and aggregating data from large data sets using SQL/Hive or Spark.',
#  'Have extensive knowledge building data pipelines and infrastructure that can adapt and scale as data volume grows and customer needs evolve.',
#  'Familiarity with best practices for data visualization.\n5+ years of hands-on data experience.\nAn ideal candidate will have hands-on experience working with ETL…',
#  'Assist in defining virtualized and physical data models to meet business needs.\nExperience with data catalog tools such as Alation and Collibra is a plus.',
#  'You have experience in data warehousing and working with relational databases for the purpose of building data solutions for analytics and data science.',
#  'Make data model and ETL code improvements to improve pipeline efficiency and data quality.\nAnalyze new data sources and work with stakeholders to understand the…',
#  'Experience with extracting and aggregating data from large data sets using SQL or other tools.\nCommunicate with clients to understand the challenges they face…',
#  'Write new data pipeline jobs to retrieve and validate training data.\nThis team provides data pipelines and data APIs to data scientists so they can make our…',
#  'You will be working closely with the Security Operations, Network, Security, and IT teams in coordinating and automating data on-boarding in Splunk and in…',
#  '1+ years in a data engineering role.\nExperience with building stream and batch data processing systems.\nCollaborate with Integration team to build ETL processes…',
#  'Design and delivery of scalable data-driven applications in real-time platforms.\nAssist in analyzing diverse sets of imperfect data and finding common patterns,…',
#  'Helped implement continuous improvements to our data governance practices and implemented data quality improvements.',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures, and data sets.\nThe ideal candidate is an experienced data pipeline builder and data…',
#  "You'll work side-by-side with engineers, data analysts, and data scientists to implement solutions to some of the toughest problems in data processing.",
#  'Working to supplement our current data providers to create an enriched data-set (unstructured data such as images, new data providers, integrations, etc.).',
#  'Under general supervision, to provide technical leadership to staff in the building and maintaining of data processing systems and pipelines that combine core…',
#  'Working with data scientists and digital teams to meet strategic data needs through project management tools like Microsoft Teams, JIRA, are desired.',
#  'Experience working with regulated data such as medical or financial data.\nAssist in building web-based data labeling tools with optimized UI/UX to enable…',
#  'Democratize data access amongst engineers, PMs, and scientists with well-documented and extensible pipelines and datasets.\nExperience with Airflow and Druid.',
#  'You have a deep understanding of data governance and data privacy best practices.\nYou will lead teams in implementing modern data architecture, data engineering…',
#  'Bachelor’s degree - Computer Science, Electronics, Electrical.\n3+ years’ relevant experience in the product/platform engineering space.',
#  'Strong background in data modeling, data access, and data storage techniques.\nCollaborate with internal and external data providers on data validation providing…',
#  'Distributed data management or data virtualization.\nData governance and data quality.\nThe DE may also be involved in assisting other IT/business personnel with…',
#  'Write data quality tests to monitor the integrity of operation-critical data sources.\nExperience with automated data quality testing.',
#  'Looking for those network/data center engineers that like blinky lights.\nAnd architectures, including *data center switching platforms.*.',
#  'Experience working with event data in a data lake.\nA self-service tool that allows data scientists, data engineers, and ML engineers on the Marketing Data…',
#  'Prior experience in performing and documenting data analysis, data validation, and data mapping/design.\nProven experience of working as a data scientist, or in…',
#  'Work with data engineers and data scientists to drive efficient solutions from the platform.\nHelp define the data story and enable data-driven solutions at…',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures, and data sets.\nThe ideal candidate is an experienced data pipeline builder and data…',
#  'Collaborate with engineers, product managers, and data scientists to understand data needs, representing key data insights visually in a meaningful way.',
#  'Create data pipeline monitoring automation.\nAn understanding of leveraging data storage in Amazon S3.\nDevelop integrations with external resources (sFTP, API’s,…',
#  'Ability to proactively influence the product design process by proposing improvements with associated data.\nIdentify and evaluate contract manufacturers/vendors…',
#  'Design and develop data pipelines to move data from source to target utilizing tools in BI toolbox.\nStrong understanding of data visualization tools and…',
#  'Experience defining and rationalizing complex data models within data warehousing environment.\nKnowledge of data warehousing and information management best…',
#  'Analyze and organize raw data.\nBuild data systems and pipelines.\nIdentify opportunities for data acquisition.\nCollaborate with data scientists and architects on…',
#  '\\* Using ETL tools to aggregate data from sources.\n\\* Collaborating with the rest of the team to optimize data architecture and tool selection.',
#  'The Data Engineer will support our software developers, data analysts, and data scientists on data initiatives.',
#  '5 years of direct experience as a data engineer or working directing in data engineering / data science.\n5 years of direct experience as a data engineer or…',
#  'Big data: 1 year (Required).\nBig data engineering and Hadoop ecosystem experience is Mandatory.\nAbility to create code and data files; investigate processing…',
#  'They use their deep technical expertise to design the right data models and reliably turn these models into high-quality core data assets in our data warehouse.',
#  'Data governance – experienced in developing and integrating software allowing for flexible and scalable data transformation with data quality controls.',
#  'You will collaborate closely with our data scientists, threat researchers and network experts to solve real-world problems plaguing cybersecurity.',
#  'Build data expertise and own data quality for allocated areas of ownership.\nWork with product managers and data analysts to build data products that power our…',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures, and data sets.\nThe ideal candidate is an experienced data pipeline builder and data…',
#  'Experience in building data pipelines.\nWorkday’s analytics products span data acquisition, data preparation, data discovery, business intelligence, and…',
#  'Integrate new data sources and tools.\nImplement scalable and reliable distributed data replication strategies.\nAzure | Java | Python.',
#  'Experience in data science techniques.\nPreparation, analysis and visualization of broad range of research data.\nKnowledge of database tools and best practices.',
#  'IoT data is an important class of operational data and is used to record signatures of operational phenomena.\nFalkonry has developed a full stack of time series…',
#  'This position is responsible for analyzing data and collaborate with business analyst and developers to translate data requirements into logical data models,…',
#  'Strong experience and understanding of very largescale data architecture, solutioning and operationalization of data warehouses, data lakes and analytics…',
#  'Background in data security, governance and cybersecurity solutions.\nYou will be working multi-functionally with Product Managers, Architects, Engineers,…',
#  'Experience in operational data stores and real time data integration.\n3+ years in designing relational database, data modeling and ETL.',
#  'This expert engineer will be expected to have both deep technical skills in data architecture and big data, as well as leadership and organizational skills.',
#  'Experience building and maintaining a data warehouse in production.\nExperience with data transformation tools like Spark or Hadoop.',
#  'Square made credit card payments possible for all by turning a mobile phone into a credit card reader.\nThe Online Data Storage team (ODS) is responsible for…',
#  'Defining processes for data monitoring as well as maintaining data integrity in our data ecosystem.\nTechnical support of data analytics operation.',
#  'Wurl is seeking a detail-oriented data scientist/engineer with strong analytical and communication skills to join and grow with our data analytics team.',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures, and data sets.\nThe ideal candidate is an experienced data pipeline builder and data…',
#  'Detect data quality issues, identify their root causes, implement fixes, and design data audits to capture issues.\nExperience with Amazon SageMaker is a plus.',
#  'Our clients need flexible data structures and a streamlined data architecture that quickly turns data resources in.\nEmployee Status : Full Time Employee.',
#  'Build deep HR data expertise and own data quality for allocated areas of ownership.\nIdentify, investigate and solve data quality issues and make sure the data…',
#  'A passionate bias to action and passion for delivering high-quality data solutions.\nThe Data Reliability Engineering team for Disney Streaming Services (DSS), a…',
#  'Determine the data infrastructure needs for sharing data with external partners.\nMaintain the standard methodologies for data privacy and security while…',
#  'Data Engineer at various unanticipated client locations throughout the US to provide design, development, testing and implementation for business computer…',
#  'Integrate new data sources and tools.\nImplement scalable and reliable distributed data replication strategies.\nAzure | Java | Python.',
#  'Design and implement systems under trillion level data environment;\nWork with product managers to define and develop big data applications;',
#  'As a data engineer, you will build and maintain the data infrastructure tools used by the entire company to generate, ingest, and access petabytes of raw data.',
#  'Experience leading a small team of data or software engineers.\nDevelop data pipelines adhering with privacy and governance principles.',
#  'Combine/Integrate data from various sources, cleanse, standardize and load into OLTP and data warehouse targets.',
#  'The Matching team owns the largest big data service at LiveRamp that processes petabytes of data per day.\nWork collaboratively in a small specialized team of…',
#  'Reason and communicate in result-oriented, data-driven manner.\nProtect TikTok users, including and beyond content consumers, creators, advertisers;',
#  'The right candidate will not only possess data analysis and data preparation experience, but also a strong business sense.\nNET C# and HTML is a plus.',
#  'Deep understanding of Big data and Hadoop architecture.\nStrong knowledge of data structures, algorithms, & distributed systems.\nJob Types: Part-time, Contract.',
#  'Strong experience and understanding of very largescale data architecture, solutioning and operationalization of data warehouses, data lakes and analytics…',
#  'You will collaborate closely with data-scientists, other ML Engineers, Software engineers, PMs, cross functional business units to address challenging problems…',
#  'Create Enterprise-class reports and visualizations into the data.\nProvide your expertise in understanding how data can be consumed across services.',
#  'You will be focused on building ETL pipelines, data processing jobs and developing data schemas that enable downstream analysts and data scientists.',
#  "You have professional experience working with modern data storage and processing technologies, and you've wrangled enough data to understand how often the…",
#  'Work with our teams of data analysts, machine learning engineers and software engineers to develop data marts that provide convenient access to the data for…',
#  'Experience in building data pipelines.\nWorkday’s analytics products span data acquisition, data preparation, data discovery, business intelligence, and…',
#  'Scaling our data infrastructure and developing software that allows for improved data processing and automation.\nExperience with Apache Airflow and/or Pandas.',
#  'Proficiency in SQL, data modeling, and data warehousing.\nCollaborate with product teams and data analysts to design and build data-forward solutions.',
#  'You’ve got a solid foundation: This role requires both a broad and deep understanding of data; you must have an advanced understanding of MPP databases, data…',
#  'The Data Engineer candidate will build an ETL pipeline of data to supply data to an enterprise data warehouse for analysis by the BI team.',
#  'Expert level skills in SQL, Python based data integration, data modeling and data architecture.\nBuild large-scale batch and real-time data pipelines using the…',
#  'You have experience building and maintaining ETLs, data pipelines, and data models.\nStrong experience with distributed data architectures and big data…',
#  'As a data Engineer, you will build from scratch highly available and highly scalable data processing systems using AWS technologies, Kafka, Map-Reduce, Hive and…',
#  'Work on implementing and designing a data warehouse for all data use cases.\nWork with stakeholders on requirements and solutions for data pipelines and data…',
#  'IoT data is an important class of operational data and is used to record signatures of operational phenomena.\nFalkonry has developed a full stack of time series…',
#  'Building out our data infrastructure and managing dependencies between data pipelines.\nYou have 1-2 years of industry experience as a data engineer.',
#  '5 years professional software experience, including data warehousing, data integration, and ETL/analytics pipelines.\nMust wear a mask when working onsite.',
#  'Knowledge in scaling data-driven systems.\nExperience architecting data infrastructure for machine learning applications.\nFlexible time off & paid holidays.',
#  'Reason and communicate in result-oriented, data-driven manner.\nProtect TikTok users, including and beyond content consumers, creators, advertisers;',
#  'Performs data analysis required to troubleshoot data related issues and assist in the resolution of data issues.\nAmple relevant knowledge and experience.',
#  'Design and implement systems under trillion level data environment;\nWork with product managers to define and develop big data applications;',
#  'For multiple enterprise customers we collaborate in global high performing teams of Hadoop data engineers, Hadoop data warehouse engineers and platform…',
#  'Knowledge of data management fundamentals and data storage principles.\nInterface with other technology teams to extract, transform, and load data from a wide…',
#  'Collaborate with engineers, product managers and data scientists to understand data needs, representing key data insights visually in a meaningful way.',
#  'Experience with integrations and data warehousing using tools like redshift.\nStong, hands-on experience with Python-centric code base and Python best practices.',
#  'Support the automation of data quality checks and seek to investigate and resolve related issues by debugging all aspects of the data pipeline and correcting…',
#  'The Data Engineer candidate will build an ETL pipeline of data to supply data to an enterprise data warehouse for analysis by the BI team.',
#  'Proficiency in SQL, data modeling, and data warehousing.\nCollaborate with product teams and data analysts to design and build data-forward solutions.',
#  'You have experience working with large, complex data sets (preferably retail industry data or something relevant) for 3-5 years.',
#  'Help build a world class data environment.\nWork with engineering teams across the company to improve data tracking.\nWe comply with CCPA guidelines.',
#  '4-7 years of experience as a data engineer.\nBuild out our data warehouse and own the data flow between production databases and our data warehouse.',
#  'Work with our teams of data analysts, machine learning engineers and software engineers to develop data marts that provide convenient access to the data for…',
#  "You will design, build, and maintain Rubrik's cloud data protection services.\nExperience in data structures, algorithms, software design, and systems analysis.",
#  'Design and delivery of scalable data-driven applications in real-time platforms.\nAssist in analyzing diverse sets of imperfect data and finding common patterns,…',
#  'Build data pipelines to collect data from primary / secondary data sources and transform data within the warehouse.\nParties, picnics, and Friday wine-downs.',
#  'Helped implement continuous improvements to our data governance practices and implemented data quality improvements.',
#  'You have experience working with large, complex data sets (preferably retail industry data or something relevant) for 3-5 years.',
#  '5 years professional software experience, including data warehousing, data integration, and ETL/analytics pipelines.\nMust wear a mask when working onsite.',
#  'Experience in data modeling, data warehousing and data visualization is a big plus.\nData: Design, develop and maintain core databases that support the company…',
#  'Wurl is seeking a detail-oriented data scientist/engineer with strong analytical and communication skills to join and grow with our data analytics team.',
#  'Experience with visualizing data (e.g. data dashboards).\nYou will work in a small team of data science and algorithm engineers to expand our internal and…',
#  'Design, architect and build data pipelines to support existing data models.\nExperience with transforming, developing data structures, metadata, dependency and…',
#  'Experience building and maintaining a data warehouse in production.\nExperience with data transformation tools like Spark or Hadoop.',
#  'Experience with data visualization software.\nStrong background in SQL data analysis.\nExperience in data analysis using Python.',
#  'You have experience building and maintaining ETLs, data pipelines, and data models.\nStrong experience with distributed data architectures and big data…',
#  'Detect data quality issues, identify their root causes, implement fixes, and design data audits to capture issues.\n5+ years of relevant work experience.',
#  'The ideal candidate has a thorough understanding of data pipeline scalability, has experience with managing distributed data collection systems, and has an…',
#  'Strong understanding of relational data models.\nDesigning and building intuitive relational and non-relational data models.\nWriting and managing ETL processes.',
#  'You will be focused on building ETL pipelines, data processing jobs and developing data schemas that enable downstream analysts and data scientists.',
#  'Scaling our data infrastructure and developing software that allows for improved data processing and automation.\nExperience with Apache Airflow and/or Pandas.',
#  'Strong background in data modeling, data access, and data storage techniques.\nCollaborate with internal and external data providers on data validation providing…',
#  'Apply knowledge of statistics and mathematics to software data analysis and provide analytical support on big data projects;',
#  'Experience with data analysis, data munging and relative machine learning skills.\nBuild a robust data platform that enables ML practitioners to build and…',
#  'Responsible for designing, implementing, and maintaining LeadGenius’s big data pipeline infrastructure — including data ingestions, stream processing, data…',
#  'Detect data quality issues, identify their root causes, implement fixes, and design data audits to capture issues.\n5+ years of relevant work experience.',
#  'Experience with data visualization software.\nStrong background in SQL data analysis.\nExperience in data analysis using Python.',
#  "You'll work side-by-side with engineers, data analysts, and data scientists to implement solutions to some of the toughest problems in data processing.",
#  'The successful data engineer will leverage tools and build systems to deliver data to teams and applications.\nExperience with streaming data pipelines is a plus…',
#  'Creating AWS infrastructure for Salesforce syncs to/from Redshift.\nManaging AWS infrastructure as code using Terraform.',
#  "You've made petabytes of data usable.\nDevelop new capabilities in our data warehouses and pipelines.\nWe provide tools to store, transform, move, and understand…",
#  'Build deep HR data expertise and own data quality for allocated areas of ownership.\nIdentify, investigate and solve data quality issues and make sure the data…',
#  'Experience leading a small team of data or software engineers.\nDevelop data pipelines adhering with privacy and governance principles.',
#  'This person will design and build data integrations, ETL workflows, dimensional data models, and manage our data warehouse and integration infrastructure that…',
#  'Expert level skills in SQL, Python based data integration, data modeling and data architecture.\nBuild large-scale batch and real-time data pipelines using the…',
#  'Good understanding of data, and working with SQL/structured data to produce visualizations.\nFluent in data structures, algorithms.',
#  'Solutions engineer with 8+ yrs of hands-on experience in building big data solutions.\nCandidate with strong experience in Kafka, Kubernetes, Spark, Hive, and…',
#  'Experience using Alation for catalogging data.\nProactively monitor the data flows with a focus on continued performance improvements.',
#  'Detect data quality issues, identify their root causes, implement fixes, and design data audits to capture issues.\n5+ years of relevant work experience.',
#  'Build deep HR data expertise and own data quality for allocated areas of ownership.\nIdentify, investigate and solve data quality issues and make sure the data…',
#  "Builds and optimizes data sets, 'big data' data pipelines and architectures.\nExperience building and optimizing ‘big data’ data pipelines and architectures.",
#  'Manage and create insightful data visualizations and dashboards.\nWork with internal teams to establish ETL and data cleansing processes.',
#  'Design, architect and build data pipelines to support existing data models.\nExperience with transforming, developing data structures, metadata, dependency and…',
#  'Write code using Python and Pyramid to retrieve and arrange data for best use in visualizations.\nYou think that arranging complex bodies of legal data into…',
#  'You will support our data analysts on data initiatives and will ensure optimal data delivery architecture is consistent throughout ongoing projects.',
#  'Collaborate with engineers, product managers, and data scientists to understand data needs, representing key data insights visually in a meaningful way.',
#  'The role is responsible for working internally to optimize proprietary data as well as helping to build out the ingestion of third party data from a variety of…',
#  'Work with various vendor APIs to ingest data into our data warehouse.\nExperience with data modeling, large data warehousing, and building ETL pipelines.',
#  '6+ years professional experience as a data engineer.\nCollaborate with data scientists and architects to create the required data layer for projects.',
#  'Help customers bring their data to the platform.\nExperience building and operating cloud-native data pipelines.\nFamiliarity with building and using containers.',
#  'IBM SWG is looking for an experienced software engineer to join the Big Data and Open Source DB North America Support team.',
#  'Scaling our data infrastructure and developing software that allows for improved data processing and automation.\nExperience with Apache Airflow and/or Pandas.',
#  '5 years professional software experience, including data warehousing, data integration, and ETL/analytics pipelines.\nMust wear a mask when working onsite.',
#  'Develop protocols and manage the data governance process to promote data standards, data quality & data security.\nBenefits: medical, dental, vision, 401k.',
#  'Developing a Sojern client SDK to place on data partner websites for sharing data.\nExcellent grasp of CS fundamentals - data structures and algorithms.',
#  "Preferably someone who has knowledge on using REST API's to get data.\nEngineer who can work with the business team to understand data requirements and explore…",
#  'Build tools and systems that make data scientists happier and more productive.\nMentor your teammates and assist engineers on other teams who integrate with our…',
#  'After our Members, data is pretty significant at Livongo and our engineers design and develop data pipelines to manage how data flows between our disparate…',
#  'Build end to end data pipelines with Hive and Spark.\n3+ years of solid Java and 2+ years experience in design, implementation, and support of solutions big data…',
#  'Experience with ETL or large scale data processing.\n1+ year or professional work experience as a software engineer or relevant internships.',
#  'Familiarity with data mining, data science or machine learning.\nReason and communicate in result-oriented, data-driven manner.',
#  'Experience with data pipeline and workflow management tools: Azkaban, Luigi, Airflow.\nExperience with big data tools: Hadoop, Spark, Kafka, etc.',
#  'Experience using Alation for catalogging data.\nProactively monitor the data flows with a focus on continued performance improvements.',
#  'Design and implement systems under trillion level data environment;\nWork with product managers to define and develop big data applications;',
#  'You will support our data analysts on data initiatives and will ensure optimal data delivery architecture is consistent throughout ongoing projects.',
#  'Experience with data modeling, data warehousing, KPI generation etc.\nStrong knowledge of data pipeline and workflow management tools (Airflow).',
#  '5 years of experience with software development in one or more programming languages, and with data structures/algorithms.',
#  'Iterate alongside other engineers and business leaders to continue to deliver on the promise of being a data-driven company.',
#  'Familiarity with data mining, data science or machine learning.\nReason and communicate in result-oriented, data-driven manner.',
#  'The Data Engineer candidate will build an ETL pipeline of data to supply data to an enterprise data warehouse for analysis by the BI team.',
#  'Design data models, data ingestion pipelines and implement scalable ETL / ELT processes.\nThis role would contribute to the vision for data infrastructure and…',
#  '5 years professional software experience, including data warehousing, data integration, and ETL/analytics pipelines.\nMust wear a mask when working onsite.',
#  '3+ years of working experience in data platform or infrastruture.\nWork closely with cross-functional teams to ship data products on time with quality.',
#  'Develop deep understanding of the data sources, implement data standards, maintain data quality and master data management.\nDeveloping data services and API.',
#  'Conduct empirical statistical analysis and modeling with data relevant to data center efficiency.\nFamiliarity with data center infrastructure design and…',
#  'Experience in performing data analysis, data ingestion and ETL(Extraction, Transformation & Loading).\nEstablish solid design and best engineering practice for…',
#  'Experience with data cleansing and repair.\nAutomate data quality and system health checks.\nMentor junior engineers and lead technical development.',
#  "Experience with big data tools.\nWe are looking for a candidate with 5+ years of experience in a Data Scientist role, who has Bachelor's or Graduate degree in…",
#  'Our complex and challenging data pipeline combines multiple sources of advertising occurrence data and metadata with our own proprietary engagement data in real…',
#  'Experience building and maintaining a data warehouse in production.\nExperience with data transformation tools like Spark or Hadoop.',
#  'Experience with large-scale data systems, pipelines, or data engineering.\nDevelop continuous testing and validation systems to ensure the robustness of our data…',
#  'Developing a Sojern client SDK to place on data partner websites for sharing data.\nExcellent grasp of CS fundamentals - data structures and algorithms.',
#  'Experience in data science techniques.\nPreparation, analysis and visualization of broad range of research data.\nKnowledge of database tools and best practices.',
#  'Collaborate with engineers, product managers and data scientists to understand data needs, representing key data insights visually in a meaningful way.',
#  'Should have working experience of using Spark data frame and data sets.\n_\\*Candidates must be authorized to work in the U.S. We are unable to sponsor work visas…',
#  'Have experience in data modeling, schema design, and data warehousing.\n5+ years of data engineering experience.\nAmple paid time off to relax and recharge.',
#  'Partner with instrumentation team engineers, studio engineers, and data analytics teams to identify and communicate issues/defects effectively.',
#  'Working with data scientists and digital teams to meet strategic data needs through project management tools like Microsoft Teams, JIRA, are desired.',
#  '\\* Using ETL tools to aggregate data from sources.\n\\* Collaborating with the rest of the team to optimize data architecture and tool selection.',
#  'Develop data pipelines using Apache Spark/Databricks.\nExperienced in building Real-time/Batch Ingestion and data processing pipelines built using Apache Spark…',
#  'The role is responsible for working internally to optimize proprietary data as well as helping to build out the ingestion of third party data from a variety of…',
#  'Collaborates with peers, senior engineers, data scientists and project team.\nUsing data engineering tools, languages, frameworks to cleanse, mine and explore…',
#  "You've made petabytes of data usable.\nDevelop new capabilities in our data warehouses and pipelines.\nWe provide tools to store, transform, move, and understand…",
#  'Experience building and optimizing ‘big data’ data pipelines, architectures and data sets.\nBuild the infrastructure required for optimal extraction,…',
#  'Experience in building data pipelines.\nWorkday’s analytics products span data acquisition, data preparation, data discovery, business intelligence, and…',
#  'Engagements vary from being purely consultative to requiring heavy hands-on work and cover a diverse array of domain areas, such as data migrations, data…',
#  'Experience architecting data warehouses and data lakes that are organized, performant, and easy to use.\nThe Senior Data Engineer determines and identifies high…',
#  'As a Senior Data Engineer, you’ll play a critical role in developing tools to automate data ETL processing, assess data quality from multiple sources, and build…',
#  'Work with our teams of data analysts, machine learning engineers and software engineers to develop data marts that provide convenient access to the data for…',
#  'Intimate experience working with Postgres database and other data stores with a preference for simple solutions to complex data storage needs.',
#  'As a senior data engineer, you define solutions for the use, extraction and manipulation of data - driven by the balanced combination of business needs and…',
#  "We're looking for an experienced data engineer to join our central analytics team, which is focused on empowering staff throughout Twitch to use and trust our…",
#  '1 year SQL, Python, Apache Airflow, pipeline creation, maintenance, data visualization.\nAccenture Flex offers you the flexibility of local fixed duration…',
#  'Implement backend data pipelines for manipulating and managing big data.\nWe are seeking exceptional data engineers to join us in building a state-of-the-art…',
#  'Ensure data quality by implementing re-usable data quality frameworks.\nDevelop and enforce data engineering, security, data quality standards through automation…',
#  'Recommended continuous improvements to our data governance practices and implemented data quality improvements.\nWe Breathe Life Into Data!',
#  'After our Members, data is pretty significant at Livongo and our engineers design and develop data pipelines to manage how data flows between our disparate…',
#  "We're proud to be our engineers' engineers and love voiding warranties by taking things apart so we can rebuild them.",
#  'Develop a frontend/backend solution for a data analysis framework that enables Python-based modules to extract device performance metrics from a database of raw…',
#  'Past experience maintaining data repositories with disparate data sources.\nCreate and maintain a data repository for analytics by combining multiple data…',
#  'This team helps to build data processing infrastructure to derive insights from billions of location data points every day.\nExperience operating systems in AWS.',
#  'Engineers in GDW focus on data architecture, design, source data instrumentation, ETL pipeline optimization, and data model implementation.',
#  'Interface with data scientists, analysts, product managers and all data stakeholders to understand their needs and promote best data practices.',
#  'Architecting and implementing data governance and security for data platforms on AZURE.\nMinimum 6 months of designing and building production data pipelines…',
#  'Build scalable data pipelines (using Spark and Airflow) to move data from different applications into our data warehouse.',
#  '3+ years experience as a data engineer or data-focused Software Engineer.\nBuild highly reliable computed tables (including unstructured data like video and…',
#  'The Sensing Products team is looking for a qualified engineer with expertise in data pipelines to work with cross-functional teams to develop, implement and…',
#  "You'll build and maintain a first-class data infrastructure that supports delivery of data.\nYou have worked with ETL pipelines before and are familiar with…",
#  'Build data expertise and own data quality for allocated areas of ownership.\nExperience with large data sets, Hadoop, and data visualization tools.',
#  'Proven ability to identify and solve issues concerning data management and data quality.\nDevelop data architecture and design patterns to process and store high…',
#  "Collaborate with enterprise customer's engineering team to identify data sources, profile and quantify quality of data sources, develop tools to prepare data…",
#  'Design, architect and build data pipelines to support existing data models.\nExperience with transforming, developing data structures, metadata, dependency and…',
#  'The primary responsibilities will be in building, managing and optimizing data pipelines and then moving these data pipelines effectively into production for…',
#  'Experience with CI/CD automation tooling for data processing.\nCollaborate with teams throughout the company to plan, design, develop and deploy data ingestion…',
#  'IBM SWG is looking for an experienced software engineer to join the Big Data and Open Source DB North America Support team.',
#  "You will design, build, and maintain Rubrik's cloud data protection services.\nExperience in data structures, algorithms, software design, and systems analysis.",
#  'Provide quality assurance of data and data processing, supporting initiatives for data integrity and normalization.\nAs a member of the team, you will:',
#  'In particular, we are looking for an experienced staff robotics engineer for our Grid Sensor Data Fusion team with Product Owner experience and outstanding…',
#  'Hands on Experience in Creating SDI replication task , Transformations, Flow graph Modeling, Scheduling and Monitoring the data provisioning tasks.',
#  'This person will design and build data integrations, ETL workflows, dimensional data models, and manage our data warehouse and integration infrastructure that…',
# ...
#  'You have experience in data warehousing and working with relational databases for the purpose of building data solutions for analytics and data science.',
#  '5 years of experience with software development in one or more programming languages, and with data structures/algorithms.',
#  'Develop data structures, databases, and querying programs which facilitate efficient data access.\nDevelop complex data processing algorithms that combine…',
#  '3+ years of experience developing data pipelines and data modeling.\nProficiency in data structures and algorithms.',
#  'Experience defining and rationalizing complex data models within data warehousing environment.\nKnowledge of data warehousing and information management best…',
#  'Defining processes for data monitoring as well as maintaining data integrity in our data ecosystem.\nTechnical support of data analytics operation.',
#  'Constantly strive to optimize the data models to provide data with quality and trust.\nBuild high volume, distributed, and scalable data platform capabilities…',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures and data sets.\nBuild the infrastructure required for optimal extraction,…',
#  'Develop data monitoring framework to ensure highest data quality.\nIn collaboration with other data engineers, database administrators, and developers, the…',
#  'Designing, building, and running the data infrastructure to support the Video organizations growing data needs.',
#  'Data visualization: experience creating elegant visualizations for complex systems, tools, and data sets.\nProgramming: strong experience with JavaScript, Python…',
#  "As part of Splunk's Data Stream Processor team, DevOps engineers help build out the infrastructure and automation for our product running on customer-managed…",
#  'Extensive experience with data infrastructure and reporting tools.\nAs our user base rapidly grows, you will architect and develop improvements to our data…',
#  'Extensive experience with data infrastructure and reporting tools.\nAs our user base rapidly grows, you will architect and develop improvements to our data…',
#  "Experience with big data tools.\nWe are looking for a candidate with 5+ years of experience in a Data Scientist role, who has Bachelor's or Graduate degree in…",
#  'Constantly strive to optimize the data models to provide data with quality and trust.\nBuild high volume, distributed, and scalable data platform capabilities…',
#  'Have end-to-end ownership of projects throughout their lifecycle, supporting both engineers at Commure and third-party developers.',
#  'This role is responsible for focusing in retrieving, validating, processing and storing various data to guarantee the accessibility, reliability, and timeliness…',
#  'Experience with data analysis, data, munging and relative machine learning skills.\nHireArt is helping Toyota Research Institute (TRI) find a Machine Learning…',
#  'Collaborate with data scientists, data analysts, QA, and DevOps.\nBuild ETL processes, data validation, data scrubbing, and transformations using Python.',
#  'Develop data structures, databases, and querying programs which facilitate efficient data access.\nDevelop complex data processing algorithms that combine…',
#  'You are a strong, analytically inclined engineer who loves solving complex problems using data.\nWork in tandem with data science and data engineering teams to…',
#  'Build out our data platform including data storage, APIs, and pipelines.\nDevelop new processes around data operations.\nExperience with Ruby on Rails.',
#  'Design and build production data pipelines from ingestion to consumption within a big data architecture, using Python, PySpark or Scala.',
#  'We analyze data needed to provide actionable insights, draw conclusions from the data and support data driven decision making at Light.',
#  'Experience building and optimizing ‘big data’ data pipelines, architectures and data sets.\nBuild the infrastructure required for optimal extraction,…',
#  '5 years of experience with software development in one or more programming languages, and with data structures/algorithms.',
#  'Experience with data visualization and data analysis tools.\nPrior work in building data pipelines, internal or B2B tools.',
#  'Lead efforts to extract meaningful insights from multimodal big data.\nExcellent communication skills to effectively communicate business relevant data insights.',
#  '3+ years experience developing ETL workflows as a data analytics engineer, data engineer, or data analyst.\nExperience with data transformation tooling (dbt is…',
#  'Partner with instrumentation team engineers, studio engineers, and data analytics teams to identify and communicate issues/defects effectively.',
#  'Grid based sensor data fusion (static & dynamic grid).\nStrong expertise in grid based approaches for sensor data fusion (static & dynamic grids).',
#  'Performs activities related to the creation, implementation, and sustainment of attraction industrial data centers and communications.',
#  'Work on a cross-functional team of engineers and data scientists to design and build a scalable and efficient data pipeline.\nA healthy bias towards action.',
#  "Founded on the principle of least privilege in 2013, Illumio provides visibility and segmentation for endpoints, data centers or clouds.\nMaster's degree a plus.",
#  'Hands-on experience of building data pipeline on at least one of the following cloud platforms: AWS, Azure or GCP.',
#  'Managing data on S3 data lakes, SQL data warehouses, or NoSQL systems.\nDefine data models, and implement robust data pipelines that that push data from…',
#  'We analyze data needed to provide actionable insights, draw conclusions from the data and support data driven decision making at Light.',
#  'Ensure data quality by implementing re-usable data quality frameworks.\nDevelop and enforce data engineering, security, data quality standards through automation…',
#  'Large data sets: experience developing programs to parse, process, clean, organize, and analyze large data sets.',
#  'Design, develop and test data pipelines and data transformations for variety of data-sources.\n10+ years of documented experience as a software engineer working…',
#  'Experience in data modeling for batch processing and streaming data feeds; structured and unstructured data.\nKnowledge of data management fundamentals and data…',
#  'Building and maintaining production data pipelines for data analytics.\nThis includes identifying and pulling data from 500+ individual databases across SJSU and…',
#  'Evolve and optimize data pipeline architecture and optimizing data flow and collection for high velocity and vorticity data from 5G platform.',
#  'Build out our data platform including data storage, APIs, and pipelines.\nDevelop new processes around data operations.\nExperience with Ruby on Rails.',
#  'Able to communicate processes and results with all parties involved in the product team, including engineers, product owner, scrum master, third party vendors…',
#  'Deep understanding of data structures and OO design.\nOur team is looking for someone passionate about Machine Learning with a strong background in Software…',
#  'Knowledge of geospatial / Computer vision data.\nProposing solutions to any issues or problems with existing data.\nYou as the ideal candidate will require.',
#  'Lead our efforts to maintain world-class data quality and security for internal data pipelines and data that is being delivered to partners.',
#  'Proficiency in computer science fundamentals such as data structures, algorithms and networking.\nOptimization of complex manufacturing pipelines using machine…',
#  'Building new streaming data pipelines to capture analytical insights to and from various sources.\nThis Big Data Engineer will be responsible for using modern…',
#  'Past experience maintaining data repositories with disparate data sources.\nCreate and maintain a data repository for analytics by combining multiple data…',
#  'Most data platforms use data for reporting and ad hoc analysis.\nMaintain a data catalog of business entities and their attributes to help others understand data…',
#  'Take complete ownership of the data quality for the data feeds built and have a passion for high-quality data.\nOur HQ is in beautiful San Francisco, CA.',
#  'Build data pipelines for collection, storage, processing, and analysis of metrology data.\n2 years of experience with data structures or algorithms.',
#  'Experience with building ETL pipelines, data warehousing and data modeling.\nMaintain and test data pipelines, including tracking data availability and stability…',
#  'Apply knowledge of statistics and mathematics to software data analysis and provide analytical support on big data projects;',
#  'Develop client-side Analytics SDKs for collecting data across multiple products and research areas.\nImplement backend web services to reliably transport and…',
#  'Technical expertise in the areas of data profiling, data mining and data analytics.\nDefine, prepare, execute and implement data validation and unit testing…',
#  'Apply knowledge of statistics and mathematics to software data analysis and provide analytical support on big data projects;',
#  'Developing data infrastructure that ingest & transforms data from different sources, securely and at scale.\nLeverage API & Microservices architecture for Data…',
#  'Managing data on S3 data lakes, SQL data warehouses, or NoSQL systems.\nDefine data models, and implement robust data pipelines that that push data from…',
#  'Experience with building ETL pipelines, data warehousing and data modeling.\nMaintain and test data pipelines, including tracking data availability and stability…',
#  'Work with our teams of data analysts, machine learning engineers and software engineers to develop data marts that provide convenient access to the data for…',
#  'Experience in working with large scale Enterprise data warehouse, data integration, data migration and data quality verification.',
#  'Knowledge of data mining and big data analytics techniques.\nThis area of responsibility is broad and includes: building ML infrastructure, building analytics…',
#  '3+ years experience developing ETL workflows as a data analytics engineer, data engineer, or data analyst.\nExperience with data transformation tooling (dbt is…',
#  'These solutions include ETL, data modeling, data quality assessment and data delivery.\nWork closely with product engineers and developers to fix data issues.',
#  'Experience in doing technical landscape and data assessment in context of data transformation projects.\nBuild Facts & dimensions schema for supply chain data.',
#  'Skills of transforming data, developing data structures, building a metadata store, setting up data pipelines or data workflows.\nPassion of big data platform.',
#  'Learn and contribute to all aspects of the data platform, from data extraction from external systems to data modeling, transformation and data management.',
#  'Demonstrated expertise with streaming data.\nWorking as part of the Data Engineering team responsible for managing data feeds and collecting analytical streaming…',
#  'Manipulates structured databases to document and deliver technical data packages to EA-18G squadrons for mission planning and employment and to JATO engineers…',
#  'Design, manage, innovate the Big Data platform, big data infrastructure, and big data workflow at PubMatic, scaling to 10PB in size, across multiple data…',
#  'Collaborate with data scientists, data analysts, QA, and DevOps.\nBuild ETL processes, data validation, data scrubbing, and transformations using Python.',
#  'Square made credit card payments possible for all by turning a mobile phone into a credit card reader.\nThe Online Data Storage team (ODS) is responsible for…',
#  'As a data and reporting engineer you will drive transformational data and analytics initiatives for improving the effectiveness and efficiency for Enterprise…',
#  'Experience with data products on Google Cloud Platform.\nWe operate a petabyte-scale data warehouse and provide tools that empower the machine learning, data…',
#  'Develop, design data models, data structures for data acquisition and manipulation purposes.\nEnsure data quality, integrity, security and completeness…',
#  'Develop integrations to move data into the raw zone of the data lake.\nDrive data literacy across business functions.\nTechnologies we use in data engineering:',
#  'Experience with relational data modeling and metadata management.\nAnalyze and translate business needs into long-term data models.',
#  'Familiarity with data orchestration pipeline using Argo or Airflow.\nYou have a deep understanding of the full life data lifecycle and the role that high-quality…',
#  'Incorporate a new data source into the data warehouse.\nGet to know the current state of data at ChowNow, from original source to the data warehouse to…',
#  'Knowledge of data management fundamentals and data storage principles.\nInterface with other technology teams to extract, transform, and load data from a wide…',
#  'Coach and mentor engineers across the engineering team to build a data culture.\nYou have 5+ years of experience in engineering, especially data infrastructure…',
#  'Experience building data models and developing data pipelines.\nWork with data scientists and software engineers to ship data-powered features to players in…',
#  'Should have working experience of using Spark data frame and data sets.\n_\\*Candidates must be authorized to work in the U.S. We are unable to sponsor work visas…',
#  'Build solutions to satisfy the data management, and data versioning needs of Blue River.\nImplement and optimize data model, queries, and ETLs for complicated…',
#  'You will collaborate with many teams across Square to understand data needs and turn those needs into data infrastructure and services, monitor and maintain the…',
#  'Good understanding of data, and working with SQL/structured data to produce visualizations.\nFluent in data structures, algorithms.',
#  'Good understanding of the blockchain technical space and data structures >= 4 years analyzing relevant data structures (i.e., in tabular or network forms).',
#  'Experience defining and rationalizing complex data models within data warehousing environment.\nKnowledge of data warehousing and information management best…',
#  'Experience working with large data volumes.\nBroad knowledge of the data infrastructure ecosystem.\nExperience in building Data Warehouses and data modeling.',
#  '7+ years of data engineer experience in a successful data engineering or business intelligence team with expert knowledge of data warehouse architecture and…',
#  'Working with internal product teams to ingest their data and sprinkle machine/deep learning fairy dust on their products.',
#  'Collaborating with the data visualization team to product-ize data integrations.\nBuilding out our data platform including data storage, APIs, and pipelines.',
#  "You hate being told to 'stay in your lane' and prefer to be in control of your own destiny.\nFull-time hire benefits include:",
#  'Utilized gathered data to generate tasks that can be automated to keep track of data/models/requirement changes.\nDevelopment of data related/instruments.',
#  'Experience with relational data modeling and metadata management.\nAnalyze and translate business needs into long-term data models.',
#  'Establish, mentor and advice on data engineering best practices.\nArchitect, Develop and maintain our data warehouse and analytics database.',
#  'Design customized data tests to guarantee quality of data model results.\nExperience with transactional data processing, ETL, data warehouse, data mart, data…',
#  'Build data quality and audit framework, data transformations to serve data products that empower data-driven decision making.',
#  'Transform data and engineer new features for machine learning models.\nExperience with big data tools like data lakes, Spark, Hadoop, etc.']

# %%
job_list_max4_df = pd.DataFrame(list(zip(jobs14, companies14, locations14, summaries14)),
               columns = ['job_title', 'company_name', 'location', 'summary'])
job_list_max4_df
# Out:
#                              job_title            company_name  \
# 0        Software Engineer 2, Big Data                  Intuit
# 1    Staff Software Engineer, Big Data                  Intuit
# 2                 Senior Data Engineer               Lendistry
# 3                        Data Engineer     Synaptein Solutions
# 4                        Data Engineer  Best High technologies
# ..                                 ...                     ...
# 505  Data Science - Analytics Engineer            Resonance AI
# 506               Senior Data Engineer              HackerRank
# 507            Data Analytics Engineer          PARACHUTE HOME
# 508               Senior Data Engineer                  Intapp
# 509                    Data Engineer I                   Kroll
#
#                             location  \
# 0            Mountain View, CA 94041
# 1            Mountain View, CA 94041
# 2                San Jose, CA•Remote
# 3                  Thousand Oaks, CA
# 4    San Jose, CA•Temporarily Remote
# ..                               ...
# 505                San Francisco, CA
# 506                California•Remote
# 507                  Los Angeles, CA
# 508              Palo Alto, CA 94306
# 509                       Pomona, CA
#
#                                                summary
# 0    Overview Our formula for innovation begins wit...
# 1    Overview Our formula for innovation begins wit...
# 2    Partner with data producers in understanding d...
# 3    Proven proficiency with scripting languages su...
# 4    Demonstrated ability to analyze large data set...
# ..                                                 ...
# 505  Experience with relational data modeling and m...
# 506  Establish, mentor and advice on data engineeri...
# 507  Design customized data tests to guarantee qual...
# 508  Build data quality and audit framework, data t...
# 509  Transform data and engineer new features for m...
#
# [510 rows x 4 columns]

# %%
job_list_max4_df.to_csv('job_list_engineer.csv', index=False)
